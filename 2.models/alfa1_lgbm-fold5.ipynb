# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
import math
import os
import gc
import sys
import pickle
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, plot_confusion_matrix, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, CatBoostRegressor, Pool, cv, sum_models
import lightgbm as lgb
import xgboost as xgb
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
from six.moves import xrange
from sklearn import preprocessing
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
def reduce_mem_usage(df):
    """ 
    iterate through all the columns of a dataframe and 
    modify the data type to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage of dataframe is {:.2f}' 
                     'MB').format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max <\
                  np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max <\
                   np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max <\
                   np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max <\
                   np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max <\
                   np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max <\
                   np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
    end_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage after optimization is: {:.2f}' 
                              'MB').format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) 
                                             / start_mem))
    
    return df

# %%
df_train = pd.read_csv("alfa1_df_train6.csv")
df_valid = pd.read_csv("alfa1_df_valid6.csv")

# %%
df_train.fillna('nothing', inplace=True)
df_valid.fillna('nothing', inplace=True)

# %%
df_train = reduce_mem_usage(df_train)
df_valid = reduce_mem_usage(df_valid)
# Out:
# Memory usage of dataframe is 1775.78MB
# Memory usage after optimization is: 337.39MB
# Decreased by 81.0%
# Memory usage of dataframe is 49.16MB
# Memory usage after optimization is: 12.29MB
# Decreased by 75.0%

# %%
df_train_exp = pd.read_csv("alfa1_df_train10.csv")
df_valid_exp = pd.read_csv("alfa1_df_valid10.csv")

# %%
df_train_exp = reduce_mem_usage(df_train_exp)
df_valid_exp = reduce_mem_usage(df_valid_exp)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp1 = pd.read_csv("alfa1_df_train11.csv")
df_valid_exp1 = pd.read_csv("alfa1_df_valid11.csv")

# %%
df_train_exp1 = reduce_mem_usage(df_train_exp1)
df_valid_exp1 = reduce_mem_usage(df_valid_exp1)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp2 = pd.read_csv("alfa1_df_train12.csv")
df_valid_exp2 = pd.read_csv("alfa1_df_valid12.csv")

# %%
df_train_exp2 = reduce_mem_usage(df_train_exp2)
df_valid_exp2 = reduce_mem_usage(df_valid_exp2)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
aug = df_train_exp.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug1 = df_train_exp1.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug2 = df_train_exp2.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns

# %%
df_train[aug] = df_train_exp[aug]
df_valid[aug] = df_valid_exp[aug]
df_train[aug1] = df_train_exp1[aug1]
df_valid[aug1] = df_valid_exp1[aug1]
df_train[aug2] = df_train_exp2[aug2]
df_valid[aug2] = df_valid_exp2[aug2]

# %%
from_parq = ['application_id', 'event_type', 'event_category', 'event_name', 'device_screen_name', 'timezone', 'net_connection_type', 'net_connection_tech']

# %%
trn_input_lag_cols = []
for i in range(2, 36):
        trn_input_lag_cols.append(f'lag_{i}')

# %%
to_drop = []
to_drop.append('lag_1')
to_drop.append('client_pin')
to_drop.append('weight')
to_drop.append('class_weight')

# %%
categorical = trn_input_lag_cols + from_parq + ['most_popular']

# %%
df_weight = pd.DataFrame()
df_weight['lag_1'] = df_train['lag_1'].unique()
df_weight['class_weight'] = compute_class_weight(classes=df_train['lag_1'].unique(), y=df_train['lag_1'], class_weight='balanced')**0.5

# %%
df_train = df_train.merge(df_weight, how='left', on='lag_1')
df_valid = df_valid.merge(df_weight, how='left', on='lag_1')

# %%
weights = np.array(df_train['weight'])**2 * np.array(df_train['class_weight'])
weights_val = np.array(df_valid['weight'])**2 * np.array(df_valid['class_weight'])

# %%
le1 = preprocessing.LabelEncoder()
le1.fit(df_valid['lag_1'].unique())
# Out:
# LabelEncoder()

# %%
df_train['lag_1'] = le1.transform(df_train['lag_1'])
df_valid['lag_1'] = le1.transform(df_valid['lag_1'])

# %%
X, y = pd.DataFrame(pd.concat((df_valid.drop(to_drop, axis=1), df_train.drop(to_drop, axis=1))).reset_index(drop=True)), pd.concat((df_valid['lag_1'], df_train['lag_1'])).reset_index(drop=True)
weights = np.concatenate([weights_val,weights])

# %%
X['event_type'] = X['event_type'].astype('category')
X['net_connection_tech'] = X['net_connection_tech'].astype('category')

# %%
n_splits = 8
folds = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=777)

# %%
trn_idx, val_idx = list(folds.split(X, y))[5]

# %%
X, y = X.iloc[trn_idx],  y.iloc[trn_idx]
weights = weights[trn_idx, ]

# %%
lgb_train = lgb.Dataset(X, y, weight=weights)
lgb_eval = lgb.Dataset(df_valid.drop(to_drop, axis=1), df_valid['lag_1'], reference=lgb_train, weight=weights_val)

# %%
def evalerror(preds, dtrain):
    labels = dtrain.get_label()
    preds = preds.reshape(10, -1).T
    preds = preds.argmax(axis = 1)
    f_score = f1_score(labels , preds,  average = 'macro')
    return 'f1_score', f_score, True

# %%
tree_params = {
    "objective" : "multiclass",
    'metric':'custom',
    "num_class" : 10,
    'learning_rate': 0.12,
    'max_depth': 5,
    'n_jobs': 5,
    "num_leaves" : 24,
    'boosting':'dart',
    "bagging_fraction" : 0.9,  # subsample
    "feature_fraction" : 0.9,  # colsample_bytree
    "bagging_freq" : 5,        # subsample_freq
    "bagging_seed" : 2020,
    'n_estimators': 1000
}

# %%
model = lgb.train(tree_params, 
                  lgb_train,
                  feval = evalerror,
                  valid_sets=[lgb_eval],
                  early_stopping_rounds=250)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's f1_score: 0.0603859
# /opt/conda/lib/python3.7/site-packages/lightgbm/callback.py:188: UserWarning: Early stopping is not available in dart mode
#   warnings.warn('Early stopping is not available in dart mode')
# [2]	valid_0's f1_score: 0.142893
# [3]	valid_0's f1_score: 0.230598
# [4]	valid_0's f1_score: 0.314595
# [5]	valid_0's f1_score: 0.357444
# [6]	valid_0's f1_score: 0.377767
# [7]	valid_0's f1_score: 0.390592
# [8]	valid_0's f1_score: 0.382685
# [9]	valid_0's f1_score: 0.393959
# [10]	valid_0's f1_score: 0.399274
# [11]	valid_0's f1_score: 0.404952
# [12]	valid_0's f1_score: 0.402583
# [13]	valid_0's f1_score: 0.406445
# [14]	valid_0's f1_score: 0.408446
# [15]	valid_0's f1_score: 0.410396
# [16]	valid_0's f1_score: 0.410977
# [17]	valid_0's f1_score: 0.411621
# [18]	valid_0's f1_score: 0.412814
# [19]	valid_0's f1_score: 0.414193
# [20]	valid_0's f1_score: 0.415148
# [21]	valid_0's f1_score: 0.414487
# [22]	valid_0's f1_score: 0.414932
# [23]	valid_0's f1_score: 0.415577
# [24]	valid_0's f1_score: 0.416281
# [25]	valid_0's f1_score: 0.416834
# [26]	valid_0's f1_score: 0.41705
# [27]	valid_0's f1_score: 0.417747
# [28]	valid_0's f1_score: 0.417478
# [29]	valid_0's f1_score: 0.417897
# [30]	valid_0's f1_score: 0.4182
# [31]	valid_0's f1_score: 0.418237
# [32]	valid_0's f1_score: 0.418937
# [33]	valid_0's f1_score: 0.418774
# [34]	valid_0's f1_score: 0.418885
# [35]	valid_0's f1_score: 0.418779
# [36]	valid_0's f1_score: 0.418778
# [37]	valid_0's f1_score: 0.418992
# [38]	valid_0's f1_score: 0.419461
# [39]	valid_0's f1_score: 0.419804
# [40]	valid_0's f1_score: 0.42035
# [41]	valid_0's f1_score: 0.420177
# [42]	valid_0's f1_score: 0.42041
# [43]	valid_0's f1_score: 0.420392
# [44]	valid_0's f1_score: 0.420364
# [45]	valid_0's f1_score: 0.420776
# [46]	valid_0's f1_score: 0.42025
# [47]	valid_0's f1_score: 0.420095
# [48]	valid_0's f1_score: 0.420428
# [49]	valid_0's f1_score: 0.420366
# [50]	valid_0's f1_score: 0.420348
# [51]	valid_0's f1_score: 0.420806
# [52]	valid_0's f1_score: 0.42164
# [53]	valid_0's f1_score: 0.421495
# [54]	valid_0's f1_score: 0.421793
# [55]	valid_0's f1_score: 0.421733
# [56]	valid_0's f1_score: 0.421395
# [57]	valid_0's f1_score: 0.421788
# [58]	valid_0's f1_score: 0.421103
# [59]	valid_0's f1_score: 0.421502
# [60]	valid_0's f1_score: 0.421904
# [61]	valid_0's f1_score: 0.420434
# [62]	valid_0's f1_score: 0.421073
# [63]	valid_0's f1_score: 0.421258
# [64]	valid_0's f1_score: 0.421741
# [65]	valid_0's f1_score: 0.421854
# [66]	valid_0's f1_score: 0.422222
# [67]	valid_0's f1_score: 0.422272
# [68]	valid_0's f1_score: 0.422044
# [69]	valid_0's f1_score: 0.422246
# [70]	valid_0's f1_score: 0.42236
# [71]	valid_0's f1_score: 0.422836
# [72]	valid_0's f1_score: 0.422928
# [73]	valid_0's f1_score: 0.423062
# [74]	valid_0's f1_score: 0.422971
# [75]	valid_0's f1_score: 0.422941
# [76]	valid_0's f1_score: 0.423105
# [77]	valid_0's f1_score: 0.423044
# [78]	valid_0's f1_score: 0.423707
# [79]	valid_0's f1_score: 0.423596
# [80]	valid_0's f1_score: 0.423925
# [81]	valid_0's f1_score: 0.424018
# [82]	valid_0's f1_score: 0.423974
# [83]	valid_0's f1_score: 0.424096
# [84]	valid_0's f1_score: 0.424273
# [85]	valid_0's f1_score: 0.424102
# [86]	valid_0's f1_score: 0.424183
# [87]	valid_0's f1_score: 0.424545
# [88]	valid_0's f1_score: 0.424409
# [89]	valid_0's f1_score: 0.424656
# [90]	valid_0's f1_score: 0.424391
# [91]	valid_0's f1_score: 0.423304
# [92]	valid_0's f1_score: 0.42324
# [93]	valid_0's f1_score: 0.423413
# [94]	valid_0's f1_score: 0.423324
# [95]	valid_0's f1_score: 0.423462
# [96]	valid_0's f1_score: 0.423603
# [97]	valid_0's f1_score: 0.42387
# [98]	valid_0's f1_score: 0.424048
# [99]	valid_0's f1_score: 0.423819
# [100]	valid_0's f1_score: 0.424148
# [101]	valid_0's f1_score: 0.423516
# [102]	valid_0's f1_score: 0.423431
# [103]	valid_0's f1_score: 0.423438
# [104]	valid_0's f1_score: 0.423588
# [105]	valid_0's f1_score: 0.423244
# [106]	valid_0's f1_score: 0.423419
# [107]	valid_0's f1_score: 0.423422
# [108]	valid_0's f1_score: 0.423791
# [109]	valid_0's f1_score: 0.423792
# [110]	valid_0's f1_score: 0.423792
# [111]	valid_0's f1_score: 0.423762
# [112]	valid_0's f1_score: 0.424477
# [113]	valid_0's f1_score: 0.424968
# [114]	valid_0's f1_score: 0.425269
# [115]	valid_0's f1_score: 0.425347
# [116]	valid_0's f1_score: 0.425251
# [117]	valid_0's f1_score: 0.425281
# [118]	valid_0's f1_score: 0.425383
# [119]	valid_0's f1_score: 0.425445
# [120]	valid_0's f1_score: 0.425594
# [121]	valid_0's f1_score: 0.425398
# [122]	valid_0's f1_score: 0.425418
# [123]	valid_0's f1_score: 0.425743
# [124]	valid_0's f1_score: 0.425529
# [125]	valid_0's f1_score: 0.425666
# [126]	valid_0's f1_score: 0.425745
# [127]	valid_0's f1_score: 0.42555
# [128]	valid_0's f1_score: 0.425688
# [129]	valid_0's f1_score: 0.425693
# [130]	valid_0's f1_score: 0.426008
# [131]	valid_0's f1_score: 0.425715
# [132]	valid_0's f1_score: 0.425874
# [133]	valid_0's f1_score: 0.42592
# [134]	valid_0's f1_score: 0.425812
# [135]	valid_0's f1_score: 0.425803
# [136]	valid_0's f1_score: 0.425835
# [137]	valid_0's f1_score: 0.425917
# [138]	valid_0's f1_score: 0.425608
# [139]	valid_0's f1_score: 0.425978
# [140]	valid_0's f1_score: 0.426242
# [141]	valid_0's f1_score: 0.426249
# [142]	valid_0's f1_score: 0.426127
# [143]	valid_0's f1_score: 0.426284
# [144]	valid_0's f1_score: 0.426346
# [145]	valid_0's f1_score: 0.426627
# [146]	valid_0's f1_score: 0.426548
# [147]	valid_0's f1_score: 0.426458
# [148]	valid_0's f1_score: 0.42664
# [149]	valid_0's f1_score: 0.426542
# [150]	valid_0's f1_score: 0.426662
# [151]	valid_0's f1_score: 0.426497
# [152]	valid_0's f1_score: 0.425948
# [153]	valid_0's f1_score: 0.426216
# [154]	valid_0's f1_score: 0.426338
# [155]	valid_0's f1_score: 0.426552
# [156]	valid_0's f1_score: 0.426385
# [157]	valid_0's f1_score: 0.426296
# [158]	valid_0's f1_score: 0.426305
# [159]	valid_0's f1_score: 0.4262
# [160]	valid_0's f1_score: 0.42624
# [161]	valid_0's f1_score: 0.426501
# [162]	valid_0's f1_score: 0.426605
# [163]	valid_0's f1_score: 0.426095
# [164]	valid_0's f1_score: 0.426612
# [165]	valid_0's f1_score: 0.426567
# [166]	valid_0's f1_score: 0.426599
# [167]	valid_0's f1_score: 0.426651
# [168]	valid_0's f1_score: 0.426705
# [169]	valid_0's f1_score: 0.426764
# [170]	valid_0's f1_score: 0.426512
# [171]	valid_0's f1_score: 0.426643
# [172]	valid_0's f1_score: 0.42611
# [173]	valid_0's f1_score: 0.426501
# [174]	valid_0's f1_score: 0.426833
# [175]	valid_0's f1_score: 0.426763
# [176]	valid_0's f1_score: 0.42705
# [177]	valid_0's f1_score: 0.427141
# [178]	valid_0's f1_score: 0.426926
# [179]	valid_0's f1_score: 0.427181
# [180]	valid_0's f1_score: 0.427144
# [181]	valid_0's f1_score: 0.427266
# [182]	valid_0's f1_score: 0.427378
# [183]	valid_0's f1_score: 0.42736
# [184]	valid_0's f1_score: 0.427998
# [185]	valid_0's f1_score: 0.427914
# [186]	valid_0's f1_score: 0.427594
# [187]	valid_0's f1_score: 0.427617
# [188]	valid_0's f1_score: 0.427662
# [189]	valid_0's f1_score: 0.427888
# [190]	valid_0's f1_score: 0.427927
# [191]	valid_0's f1_score: 0.428061
# [192]	valid_0's f1_score: 0.428191
# [193]	valid_0's f1_score: 0.428289
# [194]	valid_0's f1_score: 0.428189
# [195]	valid_0's f1_score: 0.428155
# [196]	valid_0's f1_score: 0.427856
# [197]	valid_0's f1_score: 0.42788
# [198]	valid_0's f1_score: 0.42775
# [199]	valid_0's f1_score: 0.427787
# [200]	valid_0's f1_score: 0.427839
# [201]	valid_0's f1_score: 0.427791
# [202]	valid_0's f1_score: 0.427843
# [203]	valid_0's f1_score: 0.427883
# [204]	valid_0's f1_score: 0.427842
# [205]	valid_0's f1_score: 0.428258
# [206]	valid_0's f1_score: 0.428417
# [207]	valid_0's f1_score: 0.428284
# [208]	valid_0's f1_score: 0.428293
# [209]	valid_0's f1_score: 0.428208
# [210]	valid_0's f1_score: 0.428191
# [211]	valid_0's f1_score: 0.428048
# [212]	valid_0's f1_score: 0.428105
# [213]	valid_0's f1_score: 0.428411
# [214]	valid_0's f1_score: 0.428775
# [215]	valid_0's f1_score: 0.428495
# [216]	valid_0's f1_score: 0.428499
# [217]	valid_0's f1_score: 0.428845
# [218]	valid_0's f1_score: 0.428878
# [219]	valid_0's f1_score: 0.428996
# [220]	valid_0's f1_score: 0.429113
# [221]	valid_0's f1_score: 0.429193
# [222]	valid_0's f1_score: 0.429368
# [223]	valid_0's f1_score: 0.429817
# [224]	valid_0's f1_score: 0.429747
# [225]	valid_0's f1_score: 0.429701
# [226]	valid_0's f1_score: 0.429655
# [227]	valid_0's f1_score: 0.429631
# [228]	valid_0's f1_score: 0.42987
# [229]	valid_0's f1_score: 0.429988
# [230]	valid_0's f1_score: 0.429993
# [231]	valid_0's f1_score: 0.430215
# [232]	valid_0's f1_score: 0.430412
# [233]	valid_0's f1_score: 0.430325
# [234]	valid_0's f1_score: 0.430451
# [235]	valid_0's f1_score: 0.430381
# [236]	valid_0's f1_score: 0.430534
# [237]	valid_0's f1_score: 0.430653
# [238]	valid_0's f1_score: 0.430405
# [239]	valid_0's f1_score: 0.430375
# [240]	valid_0's f1_score: 0.430874
# [241]	valid_0's f1_score: 0.43097
# [242]	valid_0's f1_score: 0.430727
# [243]	valid_0's f1_score: 0.430616
# [244]	valid_0's f1_score: 0.430575
# [245]	valid_0's f1_score: 0.430672
# [246]	valid_0's f1_score: 0.43095
# [247]	valid_0's f1_score: 0.430786
# [248]	valid_0's f1_score: 0.430683
# [249]	valid_0's f1_score: 0.430749
# [250]	valid_0's f1_score: 0.431011
# [251]	valid_0's f1_score: 0.430996
# [252]	valid_0's f1_score: 0.431064
# [253]	valid_0's f1_score: 0.431092
# [254]	valid_0's f1_score: 0.43117
# [255]	valid_0's f1_score: 0.431432
# [256]	valid_0's f1_score: 0.43156
# [257]	valid_0's f1_score: 0.431405
# [258]	valid_0's f1_score: 0.431725
# [259]	valid_0's f1_score: 0.431752
# [260]	valid_0's f1_score: 0.431823
# [261]	valid_0's f1_score: 0.43175
# [262]	valid_0's f1_score: 0.431528
# [263]	valid_0's f1_score: 0.431567
# [264]	valid_0's f1_score: 0.431652
# [265]	valid_0's f1_score: 0.431862
# [266]	valid_0's f1_score: 0.431709
# [267]	valid_0's f1_score: 0.431781
# [268]	valid_0's f1_score: 0.431773
# [269]	valid_0's f1_score: 0.431758
# [270]	valid_0's f1_score: 0.43156
# [271]	valid_0's f1_score: 0.431556
# [272]	valid_0's f1_score: 0.431896
# [273]	valid_0's f1_score: 0.431674
# [274]	valid_0's f1_score: 0.431562
# [275]	valid_0's f1_score: 0.432025
# [276]	valid_0's f1_score: 0.431956
# [277]	valid_0's f1_score: 0.432316
# [278]	valid_0's f1_score: 0.432129
# [279]	valid_0's f1_score: 0.43263
# [280]	valid_0's f1_score: 0.432657
# [281]	valid_0's f1_score: 0.432777
# [282]	valid_0's f1_score: 0.433046
# [283]	valid_0's f1_score: 0.433034
# [284]	valid_0's f1_score: 0.433538
# [285]	valid_0's f1_score: 0.433411
# [286]	valid_0's f1_score: 0.433778
# [287]	valid_0's f1_score: 0.433523
# [288]	valid_0's f1_score: 0.433654
# [289]	valid_0's f1_score: 0.433966
# [290]	valid_0's f1_score: 0.434115
# [291]	valid_0's f1_score: 0.434045
# [292]	valid_0's f1_score: 0.433836
# [293]	valid_0's f1_score: 0.433815
# [294]	valid_0's f1_score: 0.433763
# [295]	valid_0's f1_score: 0.433765
# [296]	valid_0's f1_score: 0.433835
# [297]	valid_0's f1_score: 0.43372
# [298]	valid_0's f1_score: 0.433741
# [299]	valid_0's f1_score: 0.433881
# [300]	valid_0's f1_score: 0.433895
# [301]	valid_0's f1_score: 0.433629
# [302]	valid_0's f1_score: 0.433921
# [303]	valid_0's f1_score: 0.433923
# [304]	valid_0's f1_score: 0.433844
# [305]	valid_0's f1_score: 0.43373
# [306]	valid_0's f1_score: 0.433728
# [307]	valid_0's f1_score: 0.433837
# [308]	valid_0's f1_score: 0.433895
# [309]	valid_0's f1_score: 0.433869
# [310]	valid_0's f1_score: 0.433485
# [311]	valid_0's f1_score: 0.433842
# [312]	valid_0's f1_score: 0.434211
# [313]	valid_0's f1_score: 0.434212
# [314]	valid_0's f1_score: 0.43415
# [315]	valid_0's f1_score: 0.434054
# [316]	valid_0's f1_score: 0.434029
# [317]	valid_0's f1_score: 0.434414
# [318]	valid_0's f1_score: 0.434385
# [319]	valid_0's f1_score: 0.434284
# [320]	valid_0's f1_score: 0.434421
# [321]	valid_0's f1_score: 0.434226
# [322]	valid_0's f1_score: 0.434429
# [323]	valid_0's f1_score: 0.434597
# [324]	valid_0's f1_score: 0.434472
# [325]	valid_0's f1_score: 0.434452
# [326]	valid_0's f1_score: 0.434516
# [327]	valid_0's f1_score: 0.434753
# [328]	valid_0's f1_score: 0.434831
# [329]	valid_0's f1_score: 0.434579
# [330]	valid_0's f1_score: 0.434661
# [331]	valid_0's f1_score: 0.434647
# [332]	valid_0's f1_score: 0.434471
# [333]	valid_0's f1_score: 0.434437
# [334]	valid_0's f1_score: 0.434463
# [335]	valid_0's f1_score: 0.434575
# [336]	valid_0's f1_score: 0.434667
# [337]	valid_0's f1_score: 0.434607
# [338]	valid_0's f1_score: 0.434535
# [339]	valid_0's f1_score: 0.434425
# [340]	valid_0's f1_score: 0.434574
# [341]	valid_0's f1_score: 0.434532
# [342]	valid_0's f1_score: 0.434823
# [343]	valid_0's f1_score: 0.434857
# [344]	valid_0's f1_score: 0.434651
# [345]	valid_0's f1_score: 0.434864
# [346]	valid_0's f1_score: 0.434973
# [347]	valid_0's f1_score: 0.434982
# [348]	valid_0's f1_score: 0.435185
# [349]	valid_0's f1_score: 0.435105
# [350]	valid_0's f1_score: 0.435028
# [351]	valid_0's f1_score: 0.435131
# [352]	valid_0's f1_score: 0.435024
# [353]	valid_0's f1_score: 0.435036
# [354]	valid_0's f1_score: 0.43516
# [355]	valid_0's f1_score: 0.435165
# [356]	valid_0's f1_score: 0.435304
# [357]	valid_0's f1_score: 0.435347
# [358]	valid_0's f1_score: 0.435697
# [359]	valid_0's f1_score: 0.435663
# [360]	valid_0's f1_score: 0.435854
# [361]	valid_0's f1_score: 0.435787
# [362]	valid_0's f1_score: 0.436109
# [363]	valid_0's f1_score: 0.435896
# [364]	valid_0's f1_score: 0.436016
# [365]	valid_0's f1_score: 0.435854
# [366]	valid_0's f1_score: 0.435934
# [367]	valid_0's f1_score: 0.435904
# [368]	valid_0's f1_score: 0.435817
# [369]	valid_0's f1_score: 0.435885
# [370]	valid_0's f1_score: 0.435719
# [371]	valid_0's f1_score: 0.435736
# [372]	valid_0's f1_score: 0.436144
# [373]	valid_0's f1_score: 0.435793
# [374]	valid_0's f1_score: 0.436154
# [375]	valid_0's f1_score: 0.436095
# [376]	valid_0's f1_score: 0.436119
# [377]	valid_0's f1_score: 0.43588
# [378]	valid_0's f1_score: 0.435871
# [379]	valid_0's f1_score: 0.435857
# [380]	valid_0's f1_score: 0.436112
# [381]	valid_0's f1_score: 0.436134
# [382]	valid_0's f1_score: 0.436069
# [383]	valid_0's f1_score: 0.436249
# [384]	valid_0's f1_score: 0.436408
# [385]	valid_0's f1_score: 0.436336
# [386]	valid_0's f1_score: 0.436537
# [387]	valid_0's f1_score: 0.4366
# [388]	valid_0's f1_score: 0.436528
# [389]	valid_0's f1_score: 0.436638
# [390]	valid_0's f1_score: 0.436716
# [391]	valid_0's f1_score: 0.436725
# [392]	valid_0's f1_score: 0.437255
# [393]	valid_0's f1_score: 0.437348
# [394]	valid_0's f1_score: 0.437149
# [395]	valid_0's f1_score: 0.43763
# [396]	valid_0's f1_score: 0.437623
# [397]	valid_0's f1_score: 0.43712
# [398]	valid_0's f1_score: 0.43758
# [399]	valid_0's f1_score: 0.437626
# [400]	valid_0's f1_score: 0.437874
# [401]	valid_0's f1_score: 0.437802
# [402]	valid_0's f1_score: 0.438042
# [403]	valid_0's f1_score: 0.437909
# [404]	valid_0's f1_score: 0.438168
# [405]	valid_0's f1_score: 0.438025
# [406]	valid_0's f1_score: 0.437884
# [407]	valid_0's f1_score: 0.438261
# [408]	valid_0's f1_score: 0.438004
# [409]	valid_0's f1_score: 0.437959
# [410]	valid_0's f1_score: 0.438077
# [411]	valid_0's f1_score: 0.438136
# [412]	valid_0's f1_score: 0.438013
# [413]	valid_0's f1_score: 0.438013
# [414]	valid_0's f1_score: 0.438267
# [415]	valid_0's f1_score: 0.438557
# [416]	valid_0's f1_score: 0.439131
# [417]	valid_0's f1_score: 0.439076
# [418]	valid_0's f1_score: 0.438791
# [419]	valid_0's f1_score: 0.438858
# [420]	valid_0's f1_score: 0.438808
# [421]	valid_0's f1_score: 0.439176
# [422]	valid_0's f1_score: 0.439067
# [423]	valid_0's f1_score: 0.439199
# [424]	valid_0's f1_score: 0.439097
# [425]	valid_0's f1_score: 0.439305
# [426]	valid_0's f1_score: 0.439511
# [427]	valid_0's f1_score: 0.439519
# [428]	valid_0's f1_score: 0.4395
# [429]	valid_0's f1_score: 0.439261
# [430]	valid_0's f1_score: 0.439219
# [431]	valid_0's f1_score: 0.439687
# [432]	valid_0's f1_score: 0.439449
# [433]	valid_0's f1_score: 0.439348
# [434]	valid_0's f1_score: 0.439293
# [435]	valid_0's f1_score: 0.439185
# [436]	valid_0's f1_score: 0.439233
# [437]	valid_0's f1_score: 0.439367
# [438]	valid_0's f1_score: 0.439287
# [439]	valid_0's f1_score: 0.43941
# [440]	valid_0's f1_score: 0.439666
# [441]	valid_0's f1_score: 0.439344
# [442]	valid_0's f1_score: 0.439698
# [443]	valid_0's f1_score: 0.439631
# [444]	valid_0's f1_score: 0.43992
# [445]	valid_0's f1_score: 0.440115
# [446]	valid_0's f1_score: 0.440064
# [447]	valid_0's f1_score: 0.440103
# [448]	valid_0's f1_score: 0.440306
# [449]	valid_0's f1_score: 0.440187
# [450]	valid_0's f1_score: 0.440271
# [451]	valid_0's f1_score: 0.440304
# [452]	valid_0's f1_score: 0.440299
# [453]	valid_0's f1_score: 0.44014
# [454]	valid_0's f1_score: 0.4402
# [455]	valid_0's f1_score: 0.440553
# [456]	valid_0's f1_score: 0.440535
# [457]	valid_0's f1_score: 0.440331
# [458]	valid_0's f1_score: 0.440422
# [459]	valid_0's f1_score: 0.440413
# [460]	valid_0's f1_score: 0.4403
# [461]	valid_0's f1_score: 0.440345
# [462]	valid_0's f1_score: 0.440339
# [463]	valid_0's f1_score: 0.440323
# [464]	valid_0's f1_score: 0.44029
# [465]	valid_0's f1_score: 0.440697
# [466]	valid_0's f1_score: 0.44064
# [467]	valid_0's f1_score: 0.44068
# [468]	valid_0's f1_score: 0.440613
# [469]	valid_0's f1_score: 0.440449
# [470]	valid_0's f1_score: 0.440405
# [471]	valid_0's f1_score: 0.440573
# [472]	valid_0's f1_score: 0.440565
# [473]	valid_0's f1_score: 0.44053
# [474]	valid_0's f1_score: 0.440698
# [475]	valid_0's f1_score: 0.440711
# [476]	valid_0's f1_score: 0.440668
# [477]	valid_0's f1_score: 0.440926
# [478]	valid_0's f1_score: 0.440781
# [479]	valid_0's f1_score: 0.440803
# [480]	valid_0's f1_score: 0.440924
# [481]	valid_0's f1_score: 0.44091
# [482]	valid_0's f1_score: 0.441039
# [483]	valid_0's f1_score: 0.440731
# [484]	valid_0's f1_score: 0.441018
# [485]	valid_0's f1_score: 0.440987
# [486]	valid_0's f1_score: 0.4409
# [487]	valid_0's f1_score: 0.440972
# [488]	valid_0's f1_score: 0.441301
# [489]	valid_0's f1_score: 0.441564
# [490]	valid_0's f1_score: 0.441482
# [491]	valid_0's f1_score: 0.441471
# [492]	valid_0's f1_score: 0.441416
# [493]	valid_0's f1_score: 0.441444
# [494]	valid_0's f1_score: 0.44131
# [495]	valid_0's f1_score: 0.441556
# [496]	valid_0's f1_score: 0.441695
# [497]	valid_0's f1_score: 0.44171
# [498]	valid_0's f1_score: 0.44195
# [499]	valid_0's f1_score: 0.441928
# [500]	valid_0's f1_score: 0.442089
# [501]	valid_0's f1_score: 0.442115
# [502]	valid_0's f1_score: 0.442062
# [503]	valid_0's f1_score: 0.441973
# [504]	valid_0's f1_score: 0.442043
# [505]	valid_0's f1_score: 0.442018
# [506]	valid_0's f1_score: 0.442359
# [507]	valid_0's f1_score: 0.442482
# [508]	valid_0's f1_score: 0.442573
# [509]	valid_0's f1_score: 0.442813
# [510]	valid_0's f1_score: 0.442964
# [511]	valid_0's f1_score: 0.442865
# [512]	valid_0's f1_score: 0.443046
# [513]	valid_0's f1_score: 0.443082
# [514]	valid_0's f1_score: 0.443005
# [515]	valid_0's f1_score: 0.443027
# [516]	valid_0's f1_score: 0.443035
# [517]	valid_0's f1_score: 0.44301
# [518]	valid_0's f1_score: 0.443058
# [519]	valid_0's f1_score: 0.443049
# [520]	valid_0's f1_score: 0.442976
# [521]	valid_0's f1_score: 0.443187
# [522]	valid_0's f1_score: 0.443002
# [523]	valid_0's f1_score: 0.442973
# [524]	valid_0's f1_score: 0.442912
# [525]	valid_0's f1_score: 0.442912
# [526]	valid_0's f1_score: 0.443278
# [527]	valid_0's f1_score: 0.443288
# [528]	valid_0's f1_score: 0.443225
# [529]	valid_0's f1_score: 0.443129
# [530]	valid_0's f1_score: 0.443263
# [531]	valid_0's f1_score: 0.443254
# [532]	valid_0's f1_score: 0.443103
# [533]	valid_0's f1_score: 0.442955
# [534]	valid_0's f1_score: 0.442933
# [535]	valid_0's f1_score: 0.443071
# [536]	valid_0's f1_score: 0.442934
# [537]	valid_0's f1_score: 0.4429
# [538]	valid_0's f1_score: 0.443088
# [539]	valid_0's f1_score: 0.443117
# [540]	valid_0's f1_score: 0.443094
# [541]	valid_0's f1_score: 0.443064
# [542]	valid_0's f1_score: 0.442582
# [543]	valid_0's f1_score: 0.442504
# [544]	valid_0's f1_score: 0.442549
# [545]	valid_0's f1_score: 0.44281
# [546]	valid_0's f1_score: 0.443102
# [547]	valid_0's f1_score: 0.442994
# [548]	valid_0's f1_score: 0.443187
# [549]	valid_0's f1_score: 0.443062
# [550]	valid_0's f1_score: 0.443335
# [551]	valid_0's f1_score: 0.44347
# [552]	valid_0's f1_score: 0.443994
# [553]	valid_0's f1_score: 0.443972
# [554]	valid_0's f1_score: 0.444022
# [555]	valid_0's f1_score: 0.443915
# [556]	valid_0's f1_score: 0.443975
# [557]	valid_0's f1_score: 0.443951
# [558]	valid_0's f1_score: 0.443917
# [559]	valid_0's f1_score: 0.443857
# [560]	valid_0's f1_score: 0.444085
# [561]	valid_0's f1_score: 0.444062
# [562]	valid_0's f1_score: 0.444134
# [563]	valid_0's f1_score: 0.443991
# [564]	valid_0's f1_score: 0.443946
# [565]	valid_0's f1_score: 0.444052
# [566]	valid_0's f1_score: 0.444262
# [567]	valid_0's f1_score: 0.444015
# [568]	valid_0's f1_score: 0.444148
# [569]	valid_0's f1_score: 0.444106
# [570]	valid_0's f1_score: 0.444168
# [571]	valid_0's f1_score: 0.444076
# [572]	valid_0's f1_score: 0.444441
# [573]	valid_0's f1_score: 0.444433
# [574]	valid_0's f1_score: 0.4444
# [575]	valid_0's f1_score: 0.444326
# [576]	valid_0's f1_score: 0.444369
# [577]	valid_0's f1_score: 0.444351
# [578]	valid_0's f1_score: 0.444344
# [579]	valid_0's f1_score: 0.444293
# [580]	valid_0's f1_score: 0.444144
# [581]	valid_0's f1_score: 0.444188
# [582]	valid_0's f1_score: 0.444113
# [583]	valid_0's f1_score: 0.444287
# [584]	valid_0's f1_score: 0.444226
# [585]	valid_0's f1_score: 0.444084
# [586]	valid_0's f1_score: 0.444017
# [587]	valid_0's f1_score: 0.444417
# [588]	valid_0's f1_score: 0.444395
# [589]	valid_0's f1_score: 0.444338
# [590]	valid_0's f1_score: 0.444299
# [591]	valid_0's f1_score: 0.44428
# [592]	valid_0's f1_score: 0.444327
# [593]	valid_0's f1_score: 0.444114
# [594]	valid_0's f1_score: 0.444109
# [595]	valid_0's f1_score: 0.444181
# [596]	valid_0's f1_score: 0.444542
# [597]	valid_0's f1_score: 0.444487
# [598]	valid_0's f1_score: 0.444356
# [599]	valid_0's f1_score: 0.444205
# [600]	valid_0's f1_score: 0.444248
# [601]	valid_0's f1_score: 0.444167
# [602]	valid_0's f1_score: 0.444093
# [603]	valid_0's f1_score: 0.444148
# [604]	valid_0's f1_score: 0.44418
# [605]	valid_0's f1_score: 0.444131
# [606]	valid_0's f1_score: 0.444122
# [607]	valid_0's f1_score: 0.444086
# [608]	valid_0's f1_score: 0.444262
# [609]	valid_0's f1_score: 0.44418
# [610]	valid_0's f1_score: 0.444081
# [611]	valid_0's f1_score: 0.443792
# [612]	valid_0's f1_score: 0.444005
# [613]	valid_0's f1_score: 0.444098
# [614]	valid_0's f1_score: 0.444211
# [615]	valid_0's f1_score: 0.44446
# [616]	valid_0's f1_score: 0.444429
# [617]	valid_0's f1_score: 0.44437
# [618]	valid_0's f1_score: 0.444441
# [619]	valid_0's f1_score: 0.444438
# [620]	valid_0's f1_score: 0.444483
# [621]	valid_0's f1_score: 0.444417
# [622]	valid_0's f1_score: 0.444248
# [623]	valid_0's f1_score: 0.444222
# [624]	valid_0's f1_score: 0.44424
# [625]	valid_0's f1_score: 0.444258
# [626]	valid_0's f1_score: 0.444581
# [627]	valid_0's f1_score: 0.444977
# [628]	valid_0's f1_score: 0.44491
# [629]	valid_0's f1_score: 0.444867
# [630]	valid_0's f1_score: 0.444957
# [631]	valid_0's f1_score: 0.445153
# [632]	valid_0's f1_score: 0.445114
# [633]	valid_0's f1_score: 0.445166
# [634]	valid_0's f1_score: 0.445095
# [635]	valid_0's f1_score: 0.445213
# [636]	valid_0's f1_score: 0.445033
# [637]	valid_0's f1_score: 0.444904
# [638]	valid_0's f1_score: 0.444955
# [639]	valid_0's f1_score: 0.4449
# [640]	valid_0's f1_score: 0.445115
# [641]	valid_0's f1_score: 0.44509
# [642]	valid_0's f1_score: 0.445241
# [643]	valid_0's f1_score: 0.44549
# [644]	valid_0's f1_score: 0.445476
# [645]	valid_0's f1_score: 0.44558
# [646]	valid_0's f1_score: 0.445505
# [647]	valid_0's f1_score: 0.445662
# [648]	valid_0's f1_score: 0.445545
# [649]	valid_0's f1_score: 0.445615
# [650]	valid_0's f1_score: 0.445581
# [651]	valid_0's f1_score: 0.445228
# [652]	valid_0's f1_score: 0.445256
# [653]	valid_0's f1_score: 0.445281
# [654]	valid_0's f1_score: 0.445234
# [655]	valid_0's f1_score: 0.445632
# [656]	valid_0's f1_score: 0.445518
# [657]	valid_0's f1_score: 0.445347
# [658]	valid_0's f1_score: 0.445544
# [659]	valid_0's f1_score: 0.445623
# [660]	valid_0's f1_score: 0.44564
# [661]	valid_0's f1_score: 0.445678
# [662]	valid_0's f1_score: 0.445503
# [663]	valid_0's f1_score: 0.445446
# [664]	valid_0's f1_score: 0.44536
# [665]	valid_0's f1_score: 0.445287
# [666]	valid_0's f1_score: 0.44535
# [667]	valid_0's f1_score: 0.445362
# [668]	valid_0's f1_score: 0.445254
# [669]	valid_0's f1_score: 0.445658
# [670]	valid_0's f1_score: 0.445478
# [671]	valid_0's f1_score: 0.445504
# [672]	valid_0's f1_score: 0.445566
# [673]	valid_0's f1_score: 0.445389
# [674]	valid_0's f1_score: 0.445647
# [675]	valid_0's f1_score: 0.445811
# [676]	valid_0's f1_score: 0.446285
# [677]	valid_0's f1_score: 0.445954
# [678]	valid_0's f1_score: 0.446003
# [679]	valid_0's f1_score: 0.44602
# [680]	valid_0's f1_score: 0.446494
# [681]	valid_0's f1_score: 0.446408
# [682]	valid_0's f1_score: 0.446328
# [683]	valid_0's f1_score: 0.446253
# [684]	valid_0's f1_score: 0.44654
# [685]	valid_0's f1_score: 0.446455
# [686]	valid_0's f1_score: 0.446518
# [687]	valid_0's f1_score: 0.446515
# [688]	valid_0's f1_score: 0.44641
# [689]	valid_0's f1_score: 0.446808
# [690]	valid_0's f1_score: 0.446868
# [691]	valid_0's f1_score: 0.446719
# [692]	valid_0's f1_score: 0.446754
# [693]	valid_0's f1_score: 0.44675
# [694]	valid_0's f1_score: 0.446881
# [695]	valid_0's f1_score: 0.446845
# [696]	valid_0's f1_score: 0.446902
# [697]	valid_0's f1_score: 0.446834
# [698]	valid_0's f1_score: 0.446824
# [699]	valid_0's f1_score: 0.446843
# [700]	valid_0's f1_score: 0.446942
# [701]	valid_0's f1_score: 0.447193
# [702]	valid_0's f1_score: 0.447099
# [703]	valid_0's f1_score: 0.447161
# [704]	valid_0's f1_score: 0.447057
# [705]	valid_0's f1_score: 0.447033
# [706]	valid_0's f1_score: 0.447073
# [707]	valid_0's f1_score: 0.44708
# [708]	valid_0's f1_score: 0.447336
# [709]	valid_0's f1_score: 0.447383
# [710]	valid_0's f1_score: 0.447355
# [711]	valid_0's f1_score: 0.447342
# [712]	valid_0's f1_score: 0.447402
# [713]	valid_0's f1_score: 0.447698
# [714]	valid_0's f1_score: 0.447867
# [715]	valid_0's f1_score: 0.447799
# [716]	valid_0's f1_score: 0.447895
# [717]	valid_0's f1_score: 0.447741
# [718]	valid_0's f1_score: 0.447715
# [719]	valid_0's f1_score: 0.447665
# [720]	valid_0's f1_score: 0.447727
# [721]	valid_0's f1_score: 0.447688
# [722]	valid_0's f1_score: 0.447717
# [723]	valid_0's f1_score: 0.447745
# [724]	valid_0's f1_score: 0.448023
# [725]	valid_0's f1_score: 0.447896
# [726]	valid_0's f1_score: 0.447698
# [727]	valid_0's f1_score: 0.44773
# [728]	valid_0's f1_score: 0.448128
# [729]	valid_0's f1_score: 0.448153
# [730]	valid_0's f1_score: 0.448221
# [731]	valid_0's f1_score: 0.448113
# [732]	valid_0's f1_score: 0.448169
# [733]	valid_0's f1_score: 0.448089
# [734]	valid_0's f1_score: 0.448016
# [735]	valid_0's f1_score: 0.447871
# [736]	valid_0's f1_score: 0.447913
# [737]	valid_0's f1_score: 0.447985
# [738]	valid_0's f1_score: 0.447583
# [739]	valid_0's f1_score: 0.447797
# [740]	valid_0's f1_score: 0.447816
# [741]	valid_0's f1_score: 0.447803
# [742]	valid_0's f1_score: 0.447828
# [743]	valid_0's f1_score: 0.448062
# [744]	valid_0's f1_score: 0.447983
# [745]	valid_0's f1_score: 0.447911
# [746]	valid_0's f1_score: 0.447835
# [747]	valid_0's f1_score: 0.447718
# [748]	valid_0's f1_score: 0.447885
# [749]	valid_0's f1_score: 0.447785
# [750]	valid_0's f1_score: 0.447986
# [751]	valid_0's f1_score: 0.44804
# [752]	valid_0's f1_score: 0.448062
# [753]	valid_0's f1_score: 0.448079
# [754]	valid_0's f1_score: 0.448098
# [755]	valid_0's f1_score: 0.44839
# [756]	valid_0's f1_score: 0.448404
# [757]	valid_0's f1_score: 0.448387
# [758]	valid_0's f1_score: 0.448282
# [759]	valid_0's f1_score: 0.448511
# [760]	valid_0's f1_score: 0.448537
# [761]	valid_0's f1_score: 0.448715
# [762]	valid_0's f1_score: 0.448946
# [763]	valid_0's f1_score: 0.448803
# [764]	valid_0's f1_score: 0.448808
# [765]	valid_0's f1_score: 0.448831
# [766]	valid_0's f1_score: 0.448981
# [767]	valid_0's f1_score: 0.448824
# [768]	valid_0's f1_score: 0.448849
# [769]	valid_0's f1_score: 0.448481
# [770]	valid_0's f1_score: 0.44843
# [771]	valid_0's f1_score: 0.448409
# [772]	valid_0's f1_score: 0.448469
# [773]	valid_0's f1_score: 0.448454
# [774]	valid_0's f1_score: 0.448372
# [775]	valid_0's f1_score: 0.448471
# [776]	valid_0's f1_score: 0.448391
# [777]	valid_0's f1_score: 0.448947
# [778]	valid_0's f1_score: 0.449118
# [779]	valid_0's f1_score: 0.449173
# [780]	valid_0's f1_score: 0.449067
# [781]	valid_0's f1_score: 0.449393
# [782]	valid_0's f1_score: 0.449622
# [783]	valid_0's f1_score: 0.449547
# [784]	valid_0's f1_score: 0.449487
# [785]	valid_0's f1_score: 0.449699
# [786]	valid_0's f1_score: 0.449679
# [787]	valid_0's f1_score: 0.449629
# [788]	valid_0's f1_score: 0.449613
# [789]	valid_0's f1_score: 0.44936
# [790]	valid_0's f1_score: 0.449377
# [791]	valid_0's f1_score: 0.449708
# [792]	valid_0's f1_score: 0.449656
# [793]	valid_0's f1_score: 0.449978
# [794]	valid_0's f1_score: 0.449912
# [795]	valid_0's f1_score: 0.45013
# [796]	valid_0's f1_score: 0.45018
# [797]	valid_0's f1_score: 0.450272
# [798]	valid_0's f1_score: 0.450117
# [799]	valid_0's f1_score: 0.45007
# [800]	valid_0's f1_score: 0.45009
# [801]	valid_0's f1_score: 0.450127
# [802]	valid_0's f1_score: 0.450131
# [803]	valid_0's f1_score: 0.450138
# [804]	valid_0's f1_score: 0.45016
# [805]	valid_0's f1_score: 0.450136
# [806]	valid_0's f1_score: 0.450132
# [807]	valid_0's f1_score: 0.45
# [808]	valid_0's f1_score: 0.450317
# [809]	valid_0's f1_score: 0.450246
# [810]	valid_0's f1_score: 0.450099
# [811]	valid_0's f1_score: 0.450184
# [812]	valid_0's f1_score: 0.450222
# [813]	valid_0's f1_score: 0.450185
# [814]	valid_0's f1_score: 0.450238
# [815]	valid_0's f1_score: 0.450216
# [816]	valid_0's f1_score: 0.450411
# [817]	valid_0's f1_score: 0.450463
# [818]	valid_0's f1_score: 0.450421
# [819]	valid_0's f1_score: 0.450352
# [820]	valid_0's f1_score: 0.450319
# [821]	valid_0's f1_score: 0.450524
# [822]	valid_0's f1_score: 0.450561
# [823]	valid_0's f1_score: 0.450533
# [824]	valid_0's f1_score: 0.450582
# [825]	valid_0's f1_score: 0.450739
# [826]	valid_0's f1_score: 0.450728
# [827]	valid_0's f1_score: 0.450672
# [828]	valid_0's f1_score: 0.45102
# [829]	valid_0's f1_score: 0.450896
# [830]	valid_0's f1_score: 0.451054
# [831]	valid_0's f1_score: 0.451475
# [832]	valid_0's f1_score: 0.451231
# [833]	valid_0's f1_score: 0.451359
# [834]	valid_0's f1_score: 0.451411
# [835]	valid_0's f1_score: 0.451438
# [836]	valid_0's f1_score: 0.451303
# [838]	valid_0's f1_score: 0.451421
# [839]	valid_0's f1_score: 0.451213
# [840]	valid_0's f1_score: 0.451399
# [841]	valid_0's f1_score: 0.45145
# [842]	valid_0's f1_score: 0.451481
# [843]	valid_0's f1_score: 0.45187
# [844]	valid_0's f1_score: 0.45185
# [845]	valid_0's f1_score: 0.451703
# [846]	valid_0's f1_score: 0.451677
# [847]	valid_0's f1_score: 0.452278
# [848]	valid_0's f1_score: 0.452205
# [849]	valid_0's f1_score: 0.452166
# [850]	valid_0's f1_score: 0.452298
# [851]	valid_0's f1_score: 0.452191
# [852]	valid_0's f1_score: 0.452396
# [853]	valid_0's f1_score: 0.452421
# [854]	valid_0's f1_score: 0.45239
# [855]	valid_0's f1_score: 0.452635
# [856]	valid_0's f1_score: 0.452778
# [857]	valid_0's f1_score: 0.452772
# [858]	valid_0's f1_score: 0.452791
# [859]	valid_0's f1_score: 0.452725
# [860]	valid_0's f1_score: 0.452672
# [861]	valid_0's f1_score: 0.452631
# [862]	valid_0's f1_score: 0.45272
# [863]	valid_0's f1_score: 0.452633
# [864]	valid_0's f1_score: 0.45262
# [865]	valid_0's f1_score: 0.452509
# [866]	valid_0's f1_score: 0.452558
# [867]	valid_0's f1_score: 0.452701
# [868]	valid_0's f1_score: 0.452735
# [869]	valid_0's f1_score: 0.452913
# [870]	valid_0's f1_score: 0.452969
# [871]	valid_0's f1_score: 0.452969
# [872]	valid_0's f1_score: 0.453075
# [873]	valid_0's f1_score: 0.453024
# [874]	valid_0's f1_score: 0.45285
# [875]	valid_0's f1_score: 0.452843
# [876]	valid_0's f1_score: 0.453137
# [877]	valid_0's f1_score: 0.453109
# [878]	valid_0's f1_score: 0.45343
# [879]	valid_0's f1_score: 0.453465
# [880]	valid_0's f1_score: 0.453452
# [881]	valid_0's f1_score: 0.45347
# [882]	valid_0's f1_score: 0.453504
# [883]	valid_0's f1_score: 0.453461
# [884]	valid_0's f1_score: 0.453567
# [885]	valid_0's f1_score: 0.453522
# [886]	valid_0's f1_score: 0.45361
# [887]	valid_0's f1_score: 0.453671
# [888]	valid_0's f1_score: 0.453441
# [889]	valid_0's f1_score: 0.453343
# [890]	valid_0's f1_score: 0.453783
# [891]	valid_0's f1_score: 0.453671
# [892]	valid_0's f1_score: 0.45366
# [893]	valid_0's f1_score: 0.453722
# [894]	valid_0's f1_score: 0.453757
# [895]	valid_0's f1_score: 0.453802
# [896]	valid_0's f1_score: 0.453725
# [897]	valid_0's f1_score: 0.453789
# [898]	valid_0's f1_score: 0.453677
# [899]	valid_0's f1_score: 0.453721
# [900]	valid_0's f1_score: 0.453722
# [901]	valid_0's f1_score: 0.453643
# [902]	valid_0's f1_score: 0.453685
# [903]	valid_0's f1_score: 0.453753
# [904]	valid_0's f1_score: 0.453988
# [905]	valid_0's f1_score: 0.453955
# [906]	valid_0's f1_score: 0.453926
# [907]	valid_0's f1_score: 0.4542
# [908]	valid_0's f1_score: 0.454198
# [909]	valid_0's f1_score: 0.454072
# [910]	valid_0's f1_score: 0.454184
# [911]	valid_0's f1_score: 0.454298
# [912]	valid_0's f1_score: 0.454324
# [913]	valid_0's f1_score: 0.454391
# [914]	valid_0's f1_score: 0.454312
# [915]	valid_0's f1_score: 0.454357
# [916]	valid_0's f1_score: 0.454342
# [917]	valid_0's f1_score: 0.454306
# [918]	valid_0's f1_score: 0.454331
# [919]	valid_0's f1_score: 0.454395
# [920]	valid_0's f1_score: 0.454401
# [921]	valid_0's f1_score: 0.454408
# [922]	valid_0's f1_score: 0.454465
# [923]	valid_0's f1_score: 0.454541
# [924]	valid_0's f1_score: 0.454636
# [925]	valid_0's f1_score: 0.45469
# [926]	valid_0's f1_score: 0.454914
# [927]	valid_0's f1_score: 0.45483
# [928]	valid_0's f1_score: 0.454827
# [929]	valid_0's f1_score: 0.454828
# [930]	valid_0's f1_score: 0.454858
# [931]	valid_0's f1_score: 0.454904
# [932]	valid_0's f1_score: 0.454895
# [933]	valid_0's f1_score: 0.454918
# [934]	valid_0's f1_score: 0.454876
# [935]	valid_0's f1_score: 0.455038
# [936]	valid_0's f1_score: 0.455049
# [937]	valid_0's f1_score: 0.455064
# [938]	valid_0's f1_score: 0.454909
# [939]	valid_0's f1_score: 0.454799
# [940]	valid_0's f1_score: 0.454939
# [941]	valid_0's f1_score: 0.454948
# [942]	valid_0's f1_score: 0.455229
# [943]	valid_0's f1_score: 0.455231
# [944]	valid_0's f1_score: 0.455496
# [945]	valid_0's f1_score: 0.4555
# [946]	valid_0's f1_score: 0.455552
# [947]	valid_0's f1_score: 0.455408
# [948]	valid_0's f1_score: 0.455422
# [949]	valid_0's f1_score: 0.455342
# [950]	valid_0's f1_score: 0.45586
# [951]	valid_0's f1_score: 0.455985
# [952]	valid_0's f1_score: 0.455911
# [953]	valid_0's f1_score: 0.455855
# [954]	valid_0's f1_score: 0.45593
# [955]	valid_0's f1_score: 0.455705
# [956]	valid_0's f1_score: 0.455542
# [957]	valid_0's f1_score: 0.455616
# [958]	valid_0's f1_score: 0.455529
# [959]	valid_0's f1_score: 0.455659
# [960]	valid_0's f1_score: 0.45545
# [961]	valid_0's f1_score: 0.455764
# [962]	valid_0's f1_score: 0.455664
# [963]	valid_0's f1_score: 0.455829
# [964]	valid_0's f1_score: 0.455792
# [965]	valid_0's f1_score: 0.455889
# [966]	valid_0's f1_score: 0.455925
# [967]	valid_0's f1_score: 0.45584
# [968]	valid_0's f1_score: 0.455736
# [969]	valid_0's f1_score: 0.45572
# [970]	valid_0's f1_score: 0.456002
# [971]	valid_0's f1_score: 0.456111
# [972]	valid_0's f1_score: 0.45596
# [973]	valid_0's f1_score: 0.455931
# [974]	valid_0's f1_score: 0.455909
# [975]	valid_0's f1_score: 0.45592
# [976]	valid_0's f1_score: 0.455692
# [977]	valid_0's f1_score: 0.455648
# [978]	valid_0's f1_score: 0.455803
# [979]	valid_0's f1_score: 0.455664
# [980]	valid_0's f1_score: 0.45576
# [981]	valid_0's f1_score: 0.455918
# [982]	valid_0's f1_score: 0.455833
# [983]	valid_0's f1_score: 0.455978
# [984]	valid_0's f1_score: 0.456133
# [985]	valid_0's f1_score: 0.456171
# [986]	valid_0's f1_score: 0.456166
# [987]	valid_0's f1_score: 0.456169
# [988]	valid_0's f1_score: 0.456156
# [989]	valid_0's f1_score: 0.456154
# [990]	valid_0's f1_score: 0.456203
# [991]	valid_0's f1_score: 0.456334
# [992]	valid_0's f1_score: 0.456606
# [993]	valid_0's f1_score: 0.456585
# [994]	valid_0's f1_score: 0.456453
# [995]	valid_0's f1_score: 0.456497
# [996]	valid_0's f1_score: 0.456692
# [997]	valid_0's f1_score: 0.456759
# [998]	valid_0's f1_score: 0.456767
# [999]	valid_0's f1_score: 0.456777
# [1000]	valid_0's f1_score: 0.456773

# %%
with open('lgb_model8_fold5.pkl', 'wb') as fout:
    pickle.dump(model, fout)
