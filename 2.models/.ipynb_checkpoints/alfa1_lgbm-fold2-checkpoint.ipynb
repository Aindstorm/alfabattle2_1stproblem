# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
import math
import os
import gc
import sys
import pickle
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, plot_confusion_matrix, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, CatBoostRegressor, Pool, cv, sum_models
import lightgbm as lgb
import xgboost as xgb
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
from six.moves import xrange
from sklearn import preprocessing
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
def reduce_mem_usage(df):
    """ 
    iterate through all the columns of a dataframe and 
    modify the data type to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage of dataframe is {:.2f}' 
                     'MB').format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max <\
                  np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max <\
                   np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max <\
                   np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max <\
                   np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max <\
                   np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max <\
                   np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
    end_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage after optimization is: {:.2f}' 
                              'MB').format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) 
                                             / start_mem))
    
    return df

# %%
df_train = pd.read_csv("alfa1_df_train6.csv")
df_valid = pd.read_csv("alfa1_df_valid6.csv")

# %%
df_train.fillna('nothing', inplace=True)
df_valid.fillna('nothing', inplace=True)

# %%
df_train = reduce_mem_usage(df_train)
df_valid = reduce_mem_usage(df_valid)
# Out:
# Memory usage of dataframe is 1775.78MB
# Memory usage after optimization is: 337.39MB
# Decreased by 81.0%
# Memory usage of dataframe is 49.16MB
# Memory usage after optimization is: 12.29MB
# Decreased by 75.0%

# %%
df_train_exp = pd.read_csv("alfa1_df_train10.csv")
df_valid_exp = pd.read_csv("alfa1_df_valid10.csv")

# %%
df_train_exp = reduce_mem_usage(df_train_exp)
df_valid_exp = reduce_mem_usage(df_valid_exp)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp1 = pd.read_csv("alfa1_df_train11.csv")
df_valid_exp1 = pd.read_csv("alfa1_df_valid11.csv")

# %%
df_train_exp1 = reduce_mem_usage(df_train_exp1)
df_valid_exp1 = reduce_mem_usage(df_valid_exp1)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp2 = pd.read_csv("alfa1_df_train12.csv")
df_valid_exp2 = pd.read_csv("alfa1_df_valid12.csv")

# %%
df_train_exp2 = reduce_mem_usage(df_train_exp2)
df_valid_exp2 = reduce_mem_usage(df_valid_exp2)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
aug = df_train_exp.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug1 = df_train_exp1.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug2 = df_train_exp2.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns

# %%
df_train[aug] = df_train_exp[aug]
df_valid[aug] = df_valid_exp[aug]
df_train[aug1] = df_train_exp1[aug1]
df_valid[aug1] = df_valid_exp1[aug1]
df_train[aug2] = df_train_exp2[aug2]
df_valid[aug2] = df_valid_exp2[aug2]

# %%
from_parq = ['application_id', 'event_type', 'event_category', 'event_name', 'device_screen_name', 'timezone', 'net_connection_type', 'net_connection_tech']

# %%
trn_input_lag_cols = []
for i in range(2, 36):
        trn_input_lag_cols.append(f'lag_{i}')

# %%
to_drop = []
to_drop.append('lag_1')
to_drop.append('client_pin')
to_drop.append('weight')
to_drop.append('class_weight')

# %%
categorical = trn_input_lag_cols + from_parq + ['most_popular']

# %%
df_weight = pd.DataFrame()
df_weight['lag_1'] = df_train['lag_1'].unique()
df_weight['class_weight'] = compute_class_weight(classes=df_train['lag_1'].unique(), y=df_train['lag_1'], class_weight='balanced')**0.5

# %%
df_train = df_train.merge(df_weight, how='left', on='lag_1')
df_valid = df_valid.merge(df_weight, how='left', on='lag_1')

# %%
weights = np.array(df_train['weight'])**2 * np.array(df_train['class_weight'])
weights_val = np.array(df_valid['weight'])**2 * np.array(df_valid['class_weight'])

# %%
le1 = preprocessing.LabelEncoder()
le1.fit(df_valid['lag_1'].unique())
# Out:
# LabelEncoder()

# %%
df_train['lag_1'] = le1.transform(df_train['lag_1'])
df_valid['lag_1'] = le1.transform(df_valid['lag_1'])

# %%
X, y = pd.DataFrame(pd.concat((df_valid.drop(to_drop, axis=1), df_train.drop(to_drop, axis=1))).reset_index(drop=True)), pd.concat((df_valid['lag_1'], df_train['lag_1'])).reset_index(drop=True)
weights = np.concatenate([weights_val,weights])

# %%
X['event_type'] = X['event_type'].astype('category')
X['net_connection_tech'] = X['net_connection_tech'].astype('category')

# %%
n_splits = 8
folds = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=777)

# %%
trn_idx, val_idx = list(folds.split(X, y))[2]

# %%
X, y = X.iloc[trn_idx],  y.iloc[trn_idx]
weights = weights[trn_idx, ]

# %%
lgb_train = lgb.Dataset(X, y, weight=weights)
lgb_eval = lgb.Dataset(df_valid.drop(to_drop, axis=1), df_valid['lag_1'], reference=lgb_train, weight=weights_val)

# %%
def evalerror(preds, dtrain):
    labels = dtrain.get_label()
    preds = preds.reshape(10, -1).T
    preds = preds.argmax(axis = 1)
    f_score = f1_score(labels , preds,  average = 'macro')
    return 'f1_score', f_score, True

# %%
tree_params = {
    "objective" : "multiclass",
    'metric':'custom',
    "num_class" : 10,
    'learning_rate': 0.12,
    'max_depth': 5,
    'n_jobs': 5,
    "num_leaves" : 24,
    'boosting':'dart',
    "bagging_fraction" : 0.9,  # subsample
    "feature_fraction" : 0.9,  # colsample_bytree
    "bagging_freq" : 5,        # subsample_freq
    "bagging_seed" : 2020,
    'n_estimators': 1000
}

# %%
model = lgb.train(tree_params, 
                  lgb_train,
                  feval = evalerror,
                  valid_sets=[lgb_eval],
                  early_stopping_rounds=250)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's f1_score: 0.0603859
# /opt/conda/lib/python3.7/site-packages/lightgbm/callback.py:188: UserWarning: Early stopping is not available in dart mode
#   warnings.warn('Early stopping is not available in dart mode')
# [2]	valid_0's f1_score: 0.136991
# [3]	valid_0's f1_score: 0.227562
# [4]	valid_0's f1_score: 0.314119
# [5]	valid_0's f1_score: 0.356523
# [6]	valid_0's f1_score: 0.377328
# [7]	valid_0's f1_score: 0.389912
# [8]	valid_0's f1_score: 0.382257
# [9]	valid_0's f1_score: 0.39428
# [10]	valid_0's f1_score: 0.400661
# [11]	valid_0's f1_score: 0.406093
# [12]	valid_0's f1_score: 0.403279
# [13]	valid_0's f1_score: 0.407172
# [14]	valid_0's f1_score: 0.409757
# [15]	valid_0's f1_score: 0.410812
# [16]	valid_0's f1_score: 0.41335
# [17]	valid_0's f1_score: 0.414382
# [18]	valid_0's f1_score: 0.41526
# [19]	valid_0's f1_score: 0.416566
# [20]	valid_0's f1_score: 0.4172
# [21]	valid_0's f1_score: 0.417299
# [22]	valid_0's f1_score: 0.4176
# [23]	valid_0's f1_score: 0.417731
# [24]	valid_0's f1_score: 0.417917
# [25]	valid_0's f1_score: 0.418529
# [26]	valid_0's f1_score: 0.418822
# [27]	valid_0's f1_score: 0.41865
# [28]	valid_0's f1_score: 0.419059
# [29]	valid_0's f1_score: 0.41907
# [30]	valid_0's f1_score: 0.419308
# [31]	valid_0's f1_score: 0.41941
# [32]	valid_0's f1_score: 0.42017
# [33]	valid_0's f1_score: 0.420226
# [34]	valid_0's f1_score: 0.420573
# [35]	valid_0's f1_score: 0.420461
# [36]	valid_0's f1_score: 0.420215
# [37]	valid_0's f1_score: 0.4202
# [38]	valid_0's f1_score: 0.420268
# [39]	valid_0's f1_score: 0.420866
# [40]	valid_0's f1_score: 0.421156
# [41]	valid_0's f1_score: 0.420763
# [42]	valid_0's f1_score: 0.421044
# [43]	valid_0's f1_score: 0.421125
# [44]	valid_0's f1_score: 0.421347
# [45]	valid_0's f1_score: 0.421062
# [46]	valid_0's f1_score: 0.421433
# [47]	valid_0's f1_score: 0.421676
# [48]	valid_0's f1_score: 0.42177
# [49]	valid_0's f1_score: 0.42136
# [50]	valid_0's f1_score: 0.420986
# [51]	valid_0's f1_score: 0.421628
# [52]	valid_0's f1_score: 0.42194
# [53]	valid_0's f1_score: 0.42157
# [54]	valid_0's f1_score: 0.421805
# [55]	valid_0's f1_score: 0.422155
# [56]	valid_0's f1_score: 0.422218
# [57]	valid_0's f1_score: 0.422232
# [58]	valid_0's f1_score: 0.421278
# [59]	valid_0's f1_score: 0.422093
# [60]	valid_0's f1_score: 0.422094
# [61]	valid_0's f1_score: 0.42008
# [62]	valid_0's f1_score: 0.421006
# [63]	valid_0's f1_score: 0.421279
# [64]	valid_0's f1_score: 0.421583
# [65]	valid_0's f1_score: 0.421765
# [66]	valid_0's f1_score: 0.421752
# [67]	valid_0's f1_score: 0.422203
# [68]	valid_0's f1_score: 0.422375
# [69]	valid_0's f1_score: 0.422431
# [70]	valid_0's f1_score: 0.422686
# [71]	valid_0's f1_score: 0.422827
# [72]	valid_0's f1_score: 0.423674
# [73]	valid_0's f1_score: 0.423641
# [74]	valid_0's f1_score: 0.423416
# [75]	valid_0's f1_score: 0.423436
# [76]	valid_0's f1_score: 0.423424
# [77]	valid_0's f1_score: 0.423247
# [78]	valid_0's f1_score: 0.423618
# [79]	valid_0's f1_score: 0.423706
# [80]	valid_0's f1_score: 0.423627
# [81]	valid_0's f1_score: 0.42357
# [82]	valid_0's f1_score: 0.423605
# [83]	valid_0's f1_score: 0.423333
# [84]	valid_0's f1_score: 0.42344
# [85]	valid_0's f1_score: 0.423231
# [86]	valid_0's f1_score: 0.423558
# [87]	valid_0's f1_score: 0.423538
# [88]	valid_0's f1_score: 0.423796
# [89]	valid_0's f1_score: 0.423711
# [90]	valid_0's f1_score: 0.423211
# [91]	valid_0's f1_score: 0.423707
# [92]	valid_0's f1_score: 0.423244
# [93]	valid_0's f1_score: 0.423504
# [94]	valid_0's f1_score: 0.423476
# [95]	valid_0's f1_score: 0.423473
# [96]	valid_0's f1_score: 0.423707
# [97]	valid_0's f1_score: 0.423551
# [98]	valid_0's f1_score: 0.423929
# [99]	valid_0's f1_score: 0.423689
# [100]	valid_0's f1_score: 0.424058
# [101]	valid_0's f1_score: 0.423618
# [102]	valid_0's f1_score: 0.423554
# [103]	valid_0's f1_score: 0.423429
# [104]	valid_0's f1_score: 0.423654
# [105]	valid_0's f1_score: 0.423327
# [106]	valid_0's f1_score: 0.423532
# [107]	valid_0's f1_score: 0.423381
# [108]	valid_0's f1_score: 0.423469
# [109]	valid_0's f1_score: 0.423224
# [110]	valid_0's f1_score: 0.423338
# [111]	valid_0's f1_score: 0.423722
# [112]	valid_0's f1_score: 0.423857
# [113]	valid_0's f1_score: 0.424203
# [114]	valid_0's f1_score: 0.424582
# [115]	valid_0's f1_score: 0.424919
# [116]	valid_0's f1_score: 0.424947
# [117]	valid_0's f1_score: 0.424894
# [118]	valid_0's f1_score: 0.425425
# [119]	valid_0's f1_score: 0.425235
# [120]	valid_0's f1_score: 0.425226
# [121]	valid_0's f1_score: 0.425024
# [122]	valid_0's f1_score: 0.425034
# [123]	valid_0's f1_score: 0.424915
# [124]	valid_0's f1_score: 0.424918
# [125]	valid_0's f1_score: 0.424861
# [126]	valid_0's f1_score: 0.424719
# [127]	valid_0's f1_score: 0.424997
# [128]	valid_0's f1_score: 0.425003
# [129]	valid_0's f1_score: 0.425394
# [130]	valid_0's f1_score: 0.424917
# [131]	valid_0's f1_score: 0.425062
# [132]	valid_0's f1_score: 0.425173
# [133]	valid_0's f1_score: 0.425185
# [134]	valid_0's f1_score: 0.425172
# [135]	valid_0's f1_score: 0.425149
# [136]	valid_0's f1_score: 0.424899
# [137]	valid_0's f1_score: 0.424784
# [138]	valid_0's f1_score: 0.424873
# [139]	valid_0's f1_score: 0.425011
# [140]	valid_0's f1_score: 0.425064
# [141]	valid_0's f1_score: 0.425228
# [142]	valid_0's f1_score: 0.42507
# [143]	valid_0's f1_score: 0.425196
# [144]	valid_0's f1_score: 0.42515
# [145]	valid_0's f1_score: 0.425319
# [146]	valid_0's f1_score: 0.425507
# [147]	valid_0's f1_score: 0.425508
# [148]	valid_0's f1_score: 0.425563
# [149]	valid_0's f1_score: 0.425556
# [150]	valid_0's f1_score: 0.425854
# [151]	valid_0's f1_score: 0.425551
# [152]	valid_0's f1_score: 0.426041
# [153]	valid_0's f1_score: 0.425818
# [154]	valid_0's f1_score: 0.425721
# [155]	valid_0's f1_score: 0.42602
# [156]	valid_0's f1_score: 0.425862
# [157]	valid_0's f1_score: 0.425805
# [158]	valid_0's f1_score: 0.425553
# [159]	valid_0's f1_score: 0.425586
# [160]	valid_0's f1_score: 0.425519
# [161]	valid_0's f1_score: 0.4258
# [162]	valid_0's f1_score: 0.425921
# [163]	valid_0's f1_score: 0.425654
# [164]	valid_0's f1_score: 0.425897
# [165]	valid_0's f1_score: 0.425825
# [166]	valid_0's f1_score: 0.425999
# [167]	valid_0's f1_score: 0.42629
# [168]	valid_0's f1_score: 0.426414
# [169]	valid_0's f1_score: 0.426657
# [170]	valid_0's f1_score: 0.426316
# [171]	valid_0's f1_score: 0.427035
# [172]	valid_0's f1_score: 0.426533
# [173]	valid_0's f1_score: 0.426685
# [174]	valid_0's f1_score: 0.426721
# [175]	valid_0's f1_score: 0.426592
# [176]	valid_0's f1_score: 0.42659
# [177]	valid_0's f1_score: 0.426585
# [178]	valid_0's f1_score: 0.426744
# [179]	valid_0's f1_score: 0.427295
# [180]	valid_0's f1_score: 0.427201
# [181]	valid_0's f1_score: 0.42696
# [182]	valid_0's f1_score: 0.427407
# [183]	valid_0's f1_score: 0.427805
# [184]	valid_0's f1_score: 0.428197
# [185]	valid_0's f1_score: 0.428094
# [186]	valid_0's f1_score: 0.428124
# [187]	valid_0's f1_score: 0.428328
# [188]	valid_0's f1_score: 0.428033
# [189]	valid_0's f1_score: 0.428009
# [190]	valid_0's f1_score: 0.427897
# [191]	valid_0's f1_score: 0.428591
# [192]	valid_0's f1_score: 0.428546
# [193]	valid_0's f1_score: 0.428768
# [194]	valid_0's f1_score: 0.42866
# [195]	valid_0's f1_score: 0.428569
# [196]	valid_0's f1_score: 0.428323
# [197]	valid_0's f1_score: 0.42861
# [198]	valid_0's f1_score: 0.428506
# [199]	valid_0's f1_score: 0.428637
# [200]	valid_0's f1_score: 0.428536
# [201]	valid_0's f1_score: 0.428581
# [202]	valid_0's f1_score: 0.428224
# [203]	valid_0's f1_score: 0.428741
# [204]	valid_0's f1_score: 0.428678
# [205]	valid_0's f1_score: 0.428641
# [206]	valid_0's f1_score: 0.428944
# [207]	valid_0's f1_score: 0.428934
# [208]	valid_0's f1_score: 0.428796
# [209]	valid_0's f1_score: 0.428894
# [210]	valid_0's f1_score: 0.428695
# [211]	valid_0's f1_score: 0.428702
# [212]	valid_0's f1_score: 0.428694
# [213]	valid_0's f1_score: 0.428927
# [214]	valid_0's f1_score: 0.429036
# [215]	valid_0's f1_score: 0.429393
# [216]	valid_0's f1_score: 0.429377
# [217]	valid_0's f1_score: 0.429477
# [218]	valid_0's f1_score: 0.429585
# [219]	valid_0's f1_score: 0.429298
# [220]	valid_0's f1_score: 0.429724
# [221]	valid_0's f1_score: 0.429708
# [222]	valid_0's f1_score: 0.42976
# [223]	valid_0's f1_score: 0.429722
# [224]	valid_0's f1_score: 0.429796
# [225]	valid_0's f1_score: 0.429803
# [226]	valid_0's f1_score: 0.429909
# [227]	valid_0's f1_score: 0.429897
# [228]	valid_0's f1_score: 0.429603
# [229]	valid_0's f1_score: 0.429597
# [230]	valid_0's f1_score: 0.430034
# [231]	valid_0's f1_score: 0.430048
# [232]	valid_0's f1_score: 0.429833
# [233]	valid_0's f1_score: 0.429914
# [234]	valid_0's f1_score: 0.430104
# [235]	valid_0's f1_score: 0.430172
# [236]	valid_0's f1_score: 0.430124
# [237]	valid_0's f1_score: 0.430454
# [238]	valid_0's f1_score: 0.430277
# [239]	valid_0's f1_score: 0.430133
# [240]	valid_0's f1_score: 0.430539
# [241]	valid_0's f1_score: 0.430544
# [242]	valid_0's f1_score: 0.430538
# [243]	valid_0's f1_score: 0.430591
# [244]	valid_0's f1_score: 0.430399
# [245]	valid_0's f1_score: 0.430319
# [246]	valid_0's f1_score: 0.430529
# [247]	valid_0's f1_score: 0.430491
# [248]	valid_0's f1_score: 0.430573
# [249]	valid_0's f1_score: 0.430616
# [250]	valid_0's f1_score: 0.431038
# [251]	valid_0's f1_score: 0.430991
# [252]	valid_0's f1_score: 0.430717
# [253]	valid_0's f1_score: 0.431231
# [254]	valid_0's f1_score: 0.431
# [255]	valid_0's f1_score: 0.431223
# [256]	valid_0's f1_score: 0.431097
# [257]	valid_0's f1_score: 0.431331
# [258]	valid_0's f1_score: 0.431524
# [408]	valid_0's f1_score: 0.437292
# [409]	valid_0's f1_score: 0.437239
# [410]	valid_0's f1_score: 0.437121
# [411]	valid_0's f1_score: 0.437514
# [412]	valid_0's f1_score: 0.437497
# [413]	valid_0's f1_score: 0.437426
# [414]	valid_0's f1_score: 0.437463
# [415]	valid_0's f1_score: 0.43781
# [416]	valid_0's f1_score: 0.438007
# [417]	valid_0's f1_score: 0.438092
# [418]	valid_0's f1_score: 0.438042
# [419]	valid_0's f1_score: 0.438006
# [420]	valid_0's f1_score: 0.437982
# [421]	valid_0's f1_score: 0.438073
# [422]	valid_0's f1_score: 0.438345
# [423]	valid_0's f1_score: 0.438462
# [424]	valid_0's f1_score: 0.438265
# [425]	valid_0's f1_score: 0.438322
# [426]	valid_0's f1_score: 0.438394
# [427]	valid_0's f1_score: 0.438578
# [428]	valid_0's f1_score: 0.438543
# [429]	valid_0's f1_score: 0.438883
# [430]	valid_0's f1_score: 0.438758
# [431]	valid_0's f1_score: 0.438543
# [432]	valid_0's f1_score: 0.438653
# [433]	valid_0's f1_score: 0.438733
# [434]	valid_0's f1_score: 0.438674
# [435]	valid_0's f1_score: 0.43868
# [436]	valid_0's f1_score: 0.438716
# [437]	valid_0's f1_score: 0.438711
# [438]	valid_0's f1_score: 0.438731
# [439]	valid_0's f1_score: 0.43866
# [440]	valid_0's f1_score: 0.438819
# [441]	valid_0's f1_score: 0.438589
# [442]	valid_0's f1_score: 0.438737
# [443]	valid_0's f1_score: 0.438564
# [444]	valid_0's f1_score: 0.438584
# [445]	valid_0's f1_score: 0.438877
# [446]	valid_0's f1_score: 0.438836
# [447]	valid_0's f1_score: 0.439235
# [448]	valid_0's f1_score: 0.439537
# [449]	valid_0's f1_score: 0.439584
# [450]	valid_0's f1_score: 0.439913
# [451]	valid_0's f1_score: 0.439976
# [452]	valid_0's f1_score: 0.439957
# [453]	valid_0's f1_score: 0.439902
# [454]	valid_0's f1_score: 0.439979
# [455]	valid_0's f1_score: 0.439972
# [456]	valid_0's f1_score: 0.43994
# [457]	valid_0's f1_score: 0.439892
# [458]	valid_0's f1_score: 0.439857
# [459]	valid_0's f1_score: 0.439901
# [460]	valid_0's f1_score: 0.439877
# [461]	valid_0's f1_score: 0.439784
# [462]	valid_0's f1_score: 0.439823
# [463]	valid_0's f1_score: 0.439792
# [464]	valid_0's f1_score: 0.439911
# [465]	valid_0's f1_score: 0.439983
# [466]	valid_0's f1_score: 0.439734
# [467]	valid_0's f1_score: 0.439579
# [468]	valid_0's f1_score: 0.439675
# [469]	valid_0's f1_score: 0.439993
# [470]	valid_0's f1_score: 0.440022
# [471]	valid_0's f1_score: 0.439823
# [472]	valid_0's f1_score: 0.439828
# [473]	valid_0's f1_score: 0.439938
# [474]	valid_0's f1_score: 0.439847
# [475]	valid_0's f1_score: 0.440159
# [476]	valid_0's f1_score: 0.440034
# [477]	valid_0's f1_score: 0.439869
# [478]	valid_0's f1_score: 0.440009
# [479]	valid_0's f1_score: 0.440046
# [480]	valid_0's f1_score: 0.440075
# [481]	valid_0's f1_score: 0.440097
# [631]	valid_0's f1_score: 0.444577
# [632]	valid_0's f1_score: 0.444565
# [633]	valid_0's f1_score: 0.444539
# [634]	valid_0's f1_score: 0.444535
# [635]	valid_0's f1_score: 0.444436
# [636]	valid_0's f1_score: 0.444423
# [637]	valid_0's f1_score: 0.444731
# [638]	valid_0's f1_score: 0.444723
# [639]	valid_0's f1_score: 0.444697
# [640]	valid_0's f1_score: 0.444593
# [641]	valid_0's f1_score: 0.444654
# [642]	valid_0's f1_score: 0.444667
# [643]	valid_0's f1_score: 0.444794
# [644]	valid_0's f1_score: 0.444777
# [645]	valid_0's f1_score: 0.444838
# [646]	valid_0's f1_score: 0.444716
# [647]	valid_0's f1_score: 0.444651
# [648]	valid_0's f1_score: 0.444831
# [649]	valid_0's f1_score: 0.444527
# [650]	valid_0's f1_score: 0.444569
# [651]	valid_0's f1_score: 0.444937
# [652]	valid_0's f1_score: 0.444967
# [653]	valid_0's f1_score: 0.445071
# [654]	valid_0's f1_score: 0.445049
# [655]	valid_0's f1_score: 0.444897
# [656]	valid_0's f1_score: 0.444884
# [657]	valid_0's f1_score: 0.444922
# [658]	valid_0's f1_score: 0.445142
# [659]	valid_0's f1_score: 0.445139
# [660]	valid_0's f1_score: 0.44518
# [661]	valid_0's f1_score: 0.445212
# [662]	valid_0's f1_score: 0.445161
# [663]	valid_0's f1_score: 0.445195
# [664]	valid_0's f1_score: 0.445138
# [665]	valid_0's f1_score: 0.445107
# [666]	valid_0's f1_score: 0.445147
# [667]	valid_0's f1_score: 0.445139
# [668]	valid_0's f1_score: 0.445068
# [669]	valid_0's f1_score: 0.445009
# [670]	valid_0's f1_score: 0.445114
# [671]	valid_0's f1_score: 0.445142
# [672]	valid_0's f1_score: 0.445257
# [673]	valid_0's f1_score: 0.445254
# [674]	valid_0's f1_score: 0.445243
# [675]	valid_0's f1_score: 0.445377
# [676]	valid_0's f1_score: 0.445337
# [677]	valid_0's f1_score: 0.445573
# [678]	valid_0's f1_score: 0.445585
# [679]	valid_0's f1_score: 0.445368
# [680]	valid_0's f1_score: 0.44553
# [681]	valid_0's f1_score: 0.445568
# [682]	valid_0's f1_score: 0.44547
# [683]	valid_0's f1_score: 0.445347
# [684]	valid_0's f1_score: 0.445433
# [685]	valid_0's f1_score: 0.44545
# [686]	valid_0's f1_score: 0.445724
# [687]	valid_0's f1_score: 0.44564
# [688]	valid_0's f1_score: 0.445665
# [689]	valid_0's f1_score: 0.446028
# [690]	valid_0's f1_score: 0.445896
# [691]	valid_0's f1_score: 0.44583
# [692]	valid_0's f1_score: 0.445835
# [693]	valid_0's f1_score: 0.446194
# [694]	valid_0's f1_score: 0.44627
# [695]	valid_0's f1_score: 0.446257
# [696]	valid_0's f1_score: 0.446383
# [697]	valid_0's f1_score: 0.446537
# [698]	valid_0's f1_score: 0.446728
# [699]	valid_0's f1_score: 0.446714
# [700]	valid_0's f1_score: 0.446873
# [701]	valid_0's f1_score: 0.446725
# [702]	valid_0's f1_score: 0.446862
# [703]	valid_0's f1_score: 0.446725
# [704]	valid_0's f1_score: 0.446621
# [705]	valid_0's f1_score: 0.446609
# [706]	valid_0's f1_score: 0.446564
# [707]	valid_0's f1_score: 0.446632
# [708]	valid_0's f1_score: 0.446756
# [709]	valid_0's f1_score: 0.446973
# [710]	valid_0's f1_score: 0.446876
# [711]	valid_0's f1_score: 0.446809
# [712]	valid_0's f1_score: 0.446816
# [713]	valid_0's f1_score: 0.446867
# [714]	valid_0's f1_score: 0.447035
# [715]	valid_0's f1_score: 0.447136
# [716]	valid_0's f1_score: 0.447143
# [717]	valid_0's f1_score: 0.446925
# [718]	valid_0's f1_score: 0.447049
# [719]	valid_0's f1_score: 0.446946
# [720]	valid_0's f1_score: 0.446953
# [721]	valid_0's f1_score: 0.446929
# [722]	valid_0's f1_score: 0.447015
# [723]	valid_0's f1_score: 0.447073
# [724]	valid_0's f1_score: 0.447114
# [725]	valid_0's f1_score: 0.446991
# [726]	valid_0's f1_score: 0.44704
# [727]	valid_0's f1_score: 0.447577
# [728]	valid_0's f1_score: 0.44771
# [729]	valid_0's f1_score: 0.447421
# [730]	valid_0's f1_score: 0.447243
# [731]	valid_0's f1_score: 0.447266
# [732]	valid_0's f1_score: 0.447221
# [733]	valid_0's f1_score: 0.447214
# [734]	valid_0's f1_score: 0.447239
# [735]	valid_0's f1_score: 0.44745
# [736]	valid_0's f1_score: 0.447482
# [737]	valid_0's f1_score: 0.447417
# [738]	valid_0's f1_score: 0.447715
# [739]	valid_0's f1_score: 0.447617
# [740]	valid_0's f1_score: 0.447738
# [741]	valid_0's f1_score: 0.447741
# [742]	valid_0's f1_score: 0.448047
# [743]	valid_0's f1_score: 0.448193
# [744]	valid_0's f1_score: 0.448358
# [745]	valid_0's f1_score: 0.448287
# [746]	valid_0's f1_score: 0.44824
# [747]	valid_0's f1_score: 0.448442
# [748]	valid_0's f1_score: 0.44846
# [749]	valid_0's f1_score: 0.448591
# [750]	valid_0's f1_score: 0.448637
# [751]	valid_0's f1_score: 0.44841
# [752]	valid_0's f1_score: 0.448443
# [753]	valid_0's f1_score: 0.448231
# [754]	valid_0's f1_score: 0.448238
# [755]	valid_0's f1_score: 0.448262
# [756]	valid_0's f1_score: 0.448195
# [757]	valid_0's f1_score: 0.448197
# [758]	valid_0's f1_score: 0.448202
# [759]	valid_0's f1_score: 0.448509
# [760]	valid_0's f1_score: 0.448444
# [761]	valid_0's f1_score: 0.448694
# [762]	valid_0's f1_score: 0.448593
# [763]	valid_0's f1_score: 0.448606
# [764]	valid_0's f1_score: 0.448679
# [765]	valid_0's f1_score: 0.448631
# [766]	valid_0's f1_score: 0.448814
# [767]	valid_0's f1_score: 0.448828
# [768]	valid_0's f1_score: 0.44875
# [769]	valid_0's f1_score: 0.448975
# [770]	valid_0's f1_score: 0.448945
# [771]	valid_0's f1_score: 0.448944
# [772]	valid_0's f1_score: 0.448972
# [773]	valid_0's f1_score: 0.448991
# [774]	valid_0's f1_score: 0.448973
# [775]	valid_0's f1_score: 0.448787
# [776]	valid_0's f1_score: 0.448897
# [777]	valid_0's f1_score: 0.449008
# [778]	valid_0's f1_score: 0.449018
# [779]	valid_0's f1_score: 0.449131
# [780]	valid_0's f1_score: 0.449237
# [781]	valid_0's f1_score: 0.449136
# [782]	valid_0's f1_score: 0.449234
# [783]	valid_0's f1_score: 0.4493
# [784]	valid_0's f1_score: 0.449215
# [785]	valid_0's f1_score: 0.449159
# [786]	valid_0's f1_score: 0.449166
# [787]	valid_0's f1_score: 0.449129
# [788]	valid_0's f1_score: 0.44911
# [789]	valid_0's f1_score: 0.449127
# [790]	valid_0's f1_score: 0.449401
# [791]	valid_0's f1_score: 0.449145
# [792]	valid_0's f1_score: 0.449117
# [793]	valid_0's f1_score: 0.449244
# [794]	valid_0's f1_score: 0.449233
# [795]	valid_0's f1_score: 0.449271
# [796]	valid_0's f1_score: 0.449324
# [797]	valid_0's f1_score: 0.4493
# [798]	valid_0's f1_score: 0.449284
# [799]	valid_0's f1_score: 0.449318
# [800]	valid_0's f1_score: 0.44922
# [801]	valid_0's f1_score: 0.449229
# [802]	valid_0's f1_score: 0.449256
# [803]	valid_0's f1_score: 0.449177
# [804]	valid_0's f1_score: 0.449337
# [805]	valid_0's f1_score: 0.449315
# [806]	valid_0's f1_score: 0.449387
# [807]	valid_0's f1_score: 0.449247
# [808]	valid_0's f1_score: 0.449634
# [809]	valid_0's f1_score: 0.449593
# [810]	valid_0's f1_score: 0.449515
# [811]	valid_0's f1_score: 0.449687
# [812]	valid_0's f1_score: 0.449747
# [813]	valid_0's f1_score: 0.449808
# [814]	valid_0's f1_score: 0.449902
# [815]	valid_0's f1_score: 0.449871
# [816]	valid_0's f1_score: 0.44998
# [817]	valid_0's f1_score: 0.450003
# [818]	valid_0's f1_score: 0.450043
# [819]	valid_0's f1_score: 0.450121
# [820]	valid_0's f1_score: 0.449986
# [821]	valid_0's f1_score: 0.450148
# [822]	valid_0's f1_score: 0.450121
# [823]	valid_0's f1_score: 0.450182
# [824]	valid_0's f1_score: 0.449842
# [825]	valid_0's f1_score: 0.450042
# [826]	valid_0's f1_score: 0.450114
# [827]	valid_0's f1_score: 0.450159
# [828]	valid_0's f1_score: 0.450072
# [829]	valid_0's f1_score: 0.450218
# [830]	valid_0's f1_score: 0.450109
# [831]	valid_0's f1_score: 0.450088
# [832]	valid_0's f1_score: 0.449976
# [833]	valid_0's f1_score: 0.450339
# [834]	valid_0's f1_score: 0.450317
# [835]	valid_0's f1_score: 0.450365
# [836]	valid_0's f1_score: 0.450211
# [837]	valid_0's f1_score: 0.450354
# [838]	valid_0's f1_score: 0.450353
# [839]	valid_0's f1_score: 0.450379
# [840]	valid_0's f1_score: 0.450394
# [841]	valid_0's f1_score: 0.450529
# [842]	valid_0's f1_score: 0.450671
# [843]	valid_0's f1_score: 0.45068
# [844]	valid_0's f1_score: 0.450707
# [845]	valid_0's f1_score: 0.450636
# [846]	valid_0's f1_score: 0.450596
# [847]	valid_0's f1_score: 0.450809
# [848]	valid_0's f1_score: 0.450699
# [849]	valid_0's f1_score: 0.450735
# [850]	valid_0's f1_score: 0.450843
# [851]	valid_0's f1_score: 0.450812
# [852]	valid_0's f1_score: 0.450956
# [853]	valid_0's f1_score: 0.450954
# [854]	valid_0's f1_score: 0.450955
# [855]	valid_0's f1_score: 0.451013
# [856]	valid_0's f1_score: 0.451251
# [857]	valid_0's f1_score: 0.451303
# [858]	valid_0's f1_score: 0.451362
# [859]	valid_0's f1_score: 0.451262
# [860]	valid_0's f1_score: 0.451437
# [861]	valid_0's f1_score: 0.451473
# [862]	valid_0's f1_score: 0.451765
# [863]	valid_0's f1_score: 0.451779
# [864]	valid_0's f1_score: 0.451684
# [865]	valid_0's f1_score: 0.451567
# [866]	valid_0's f1_score: 0.451708
# [867]	valid_0's f1_score: 0.45189
# [868]	valid_0's f1_score: 0.451875
# [869]	valid_0's f1_score: 0.451514
# [870]	valid_0's f1_score: 0.451484
# [871]	valid_0's f1_score: 0.451456
# [872]	valid_0's f1_score: 0.4518
# [873]	valid_0's f1_score: 0.451883
# [874]	valid_0's f1_score: 0.45194
# [875]	valid_0's f1_score: 0.451761
# [876]	valid_0's f1_score: 0.451865
# [877]	valid_0's f1_score: 0.451879
# [878]	valid_0's f1_score: 0.452112
# [879]	valid_0's f1_score: 0.452101
# [880]	valid_0's f1_score: 0.452129
# [881]	valid_0's f1_score: 0.451995
# [882]	valid_0's f1_score: 0.452198
# [883]	valid_0's f1_score: 0.452219
# [884]	valid_0's f1_score: 0.45245
# [885]	valid_0's f1_score: 0.452439
# [886]	valid_0's f1_score: 0.452246
# [887]	valid_0's f1_score: 0.452547
# [888]	valid_0's f1_score: 0.452474
# [889]	valid_0's f1_score: 0.452417
# [890]	valid_0's f1_score: 0.452562
# [891]	valid_0's f1_score: 0.452652
# [892]	valid_0's f1_score: 0.452849
# [893]	valid_0's f1_score: 0.452873
# [894]	valid_0's f1_score: 0.452811
# [895]	valid_0's f1_score: 0.452801
# [896]	valid_0's f1_score: 0.45282
# [897]	valid_0's f1_score: 0.452895
# [898]	valid_0's f1_score: 0.452903
# [899]	valid_0's f1_score: 0.452875
# [900]	valid_0's f1_score: 0.452696
# [901]	valid_0's f1_score: 0.453016
# [902]	valid_0's f1_score: 0.453033
# [903]	valid_0's f1_score: 0.452921
# [904]	valid_0's f1_score: 0.452931
# [905]	valid_0's f1_score: 0.453041
# [906]	valid_0's f1_score: 0.452994
# [907]	valid_0's f1_score: 0.453367
# [908]	valid_0's f1_score: 0.453459
# [909]	valid_0's f1_score: 0.453446
# [910]	valid_0's f1_score: 0.453448
# [911]	valid_0's f1_score: 0.453009
# [912]	valid_0's f1_score: 0.453013
# [913]	valid_0's f1_score: 0.453042
# [914]	valid_0's f1_score: 0.453333
# [915]	valid_0's f1_score: 0.453208
# [916]	valid_0's f1_score: 0.453184
# [917]	valid_0's f1_score: 0.45317
# [918]	valid_0's f1_score: 0.453224
# [919]	valid_0's f1_score: 0.453205
# [920]	valid_0's f1_score: 0.453181
# [921]	valid_0's f1_score: 0.45297
# [922]	valid_0's f1_score: 0.45295
# [923]	valid_0's f1_score: 0.452925
# [924]	valid_0's f1_score: 0.453044
# [925]	valid_0's f1_score: 0.453073
# [926]	valid_0's f1_score: 0.453489
# [927]	valid_0's f1_score: 0.453496
# [928]	valid_0's f1_score: 0.453371
# [929]	valid_0's f1_score: 0.453525
# [930]	valid_0's f1_score: 0.453404
# [931]	valid_0's f1_score: 0.453462
# [932]	valid_0's f1_score: 0.453419
# [933]	valid_0's f1_score: 0.453453
# [934]	valid_0's f1_score: 0.45352
# [935]	valid_0's f1_score: 0.453531
# [936]	valid_0's f1_score: 0.453531
# [937]	valid_0's f1_score: 0.453525
# [938]	valid_0's f1_score: 0.453445
# [939]	valid_0's f1_score: 0.453467
# [940]	valid_0's f1_score: 0.453332
# [941]	valid_0's f1_score: 0.453429
# [942]	valid_0's f1_score: 0.45364
# [943]	valid_0's f1_score: 0.453614
# [944]	valid_0's f1_score: 0.453832
# [945]	valid_0's f1_score: 0.453866
# [946]	valid_0's f1_score: 0.453931
# [947]	valid_0's f1_score: 0.453862
# [948]	valid_0's f1_score: 0.45389
# [949]	valid_0's f1_score: 0.453902
# [950]	valid_0's f1_score: 0.454146
# [951]	valid_0's f1_score: 0.454435
# [952]	valid_0's f1_score: 0.454382
# [953]	valid_0's f1_score: 0.454248
# [954]	valid_0's f1_score: 0.454233
# [955]	valid_0's f1_score: 0.454093
# [956]	valid_0's f1_score: 0.454025
# [957]	valid_0's f1_score: 0.454046
# [958]	valid_0's f1_score: 0.454115
# [959]	valid_0's f1_score: 0.454004
# [960]	valid_0's f1_score: 0.453932
# [961]	valid_0's f1_score: 0.453731
# [962]	valid_0's f1_score: 0.453815
# [963]	valid_0's f1_score: 0.454099
# [964]	valid_0's f1_score: 0.454076
# [965]	valid_0's f1_score: 0.454336
# [966]	valid_0's f1_score: 0.454301
# [967]	valid_0's f1_score: 0.454408
# [968]	valid_0's f1_score: 0.454284
# [969]	valid_0's f1_score: 0.454288
# [970]	valid_0's f1_score: 0.45415
# [971]	valid_0's f1_score: 0.454667
# [972]	valid_0's f1_score: 0.454592
# [973]	valid_0's f1_score: 0.454533
# [974]	valid_0's f1_score: 0.454531
# [975]	valid_0's f1_score: 0.454541
# [976]	valid_0's f1_score: 0.454519
# [977]	valid_0's f1_score: 0.45456
# [978]	valid_0's f1_score: 0.454258
# [979]	valid_0's f1_score: 0.454333
# [980]	valid_0's f1_score: 0.454737
# [981]	valid_0's f1_score: 0.454802
# [982]	valid_0's f1_score: 0.454919
# [983]	valid_0's f1_score: 0.454851
# [984]	valid_0's f1_score: 0.454844
# [985]	valid_0's f1_score: 0.454915
# [986]	valid_0's f1_score: 0.455015
# [987]	valid_0's f1_score: 0.454957
# [988]	valid_0's f1_score: 0.454985
# [989]	valid_0's f1_score: 0.454986
# [990]	valid_0's f1_score: 0.455024
# [991]	valid_0's f1_score: 0.455101
# [992]	valid_0's f1_score: 0.455135
# [993]	valid_0's f1_score: 0.455161
# [994]	valid_0's f1_score: 0.455095
# [995]	valid_0's f1_score: 0.45505
# [996]	valid_0's f1_score: 0.455189
# [997]	valid_0's f1_score: 0.455414
# [998]	valid_0's f1_score: 0.45552
# [999]	valid_0's f1_score: 0.45601
# [1000]	valid_0's f1_score: 0.45608

# %%
with open('lgb_model8_fold2.pkl', 'wb') as fout:
    pickle.dump(model, fout)
