# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
import math
import os
import gc
import sys
import pickle
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, plot_confusion_matrix, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, CatBoostRegressor, Pool, cv, sum_models
import lightgbm as lgb
import xgboost as xgb
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
from six.moves import xrange
from sklearn import preprocessing
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
def reduce_mem_usage(df):
    """ 
    iterate through all the columns of a dataframe and 
    modify the data type to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage of dataframe is {:.2f}' 
                     'MB').format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max <\
                  np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max <\
                   np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max <\
                   np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max <\
                   np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max <\
                   np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max <\
                   np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
    end_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage after optimization is: {:.2f}' 
                              'MB').format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) 
                                             / start_mem))
    
    return df

# %%
df_train = pd.read_csv("alfa1_df_train6.csv")
df_valid = pd.read_csv("alfa1_df_valid6.csv")

# %%
df_train.fillna('nothing', inplace=True)
df_valid.fillna('nothing', inplace=True)

# %%
df_train = reduce_mem_usage(df_train)
df_valid = reduce_mem_usage(df_valid)
# Out:
# Memory usage of dataframe is 1775.78MB
# Memory usage after optimization is: 337.39MB
# Decreased by 81.0%
# Memory usage of dataframe is 49.16MB
# Memory usage after optimization is: 12.29MB
# Decreased by 75.0%

# %%
df_train_exp = pd.read_csv("alfa1_df_train10.csv")
df_valid_exp = pd.read_csv("alfa1_df_valid10.csv")

# %%
df_train_exp = reduce_mem_usage(df_train_exp)
df_valid_exp = reduce_mem_usage(df_valid_exp)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp1 = pd.read_csv("alfa1_df_train11.csv")
df_valid_exp1 = pd.read_csv("alfa1_df_valid11.csv")

# %%
df_train_exp1 = reduce_mem_usage(df_train_exp1)
df_valid_exp1 = reduce_mem_usage(df_valid_exp1)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp2 = pd.read_csv("alfa1_df_train12.csv")
df_valid_exp2 = pd.read_csv("alfa1_df_valid12.csv")

# %%
df_train_exp2 = reduce_mem_usage(df_train_exp2)
df_valid_exp2 = reduce_mem_usage(df_valid_exp2)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
aug = df_train_exp.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug1 = df_train_exp1.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug2 = df_train_exp2.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns

# %%
df_train[aug] = df_train_exp[aug]
df_valid[aug] = df_valid_exp[aug]
df_train[aug1] = df_train_exp1[aug1]
df_valid[aug1] = df_valid_exp1[aug1]
df_train[aug2] = df_train_exp2[aug2]
df_valid[aug2] = df_valid_exp2[aug2]

# %%
from_parq = ['application_id', 'event_type', 'event_category', 'event_name', 'device_screen_name', 'timezone', 'net_connection_type', 'net_connection_tech']

# %%
trn_input_lag_cols = []
for i in range(2, 36):
        trn_input_lag_cols.append(f'lag_{i}')

# %%
to_drop = []
to_drop.append('lag_1')
to_drop.append('client_pin')
to_drop.append('weight')
to_drop.append('class_weight')

# %%
categorical = trn_input_lag_cols + from_parq + ['most_popular']

# %%
df_weight = pd.DataFrame()
df_weight['lag_1'] = df_train['lag_1'].unique()
df_weight['class_weight'] = compute_class_weight(classes=df_train['lag_1'].unique(), y=df_train['lag_1'], class_weight='balanced')**0.5

# %%
df_train = df_train.merge(df_weight, how='left', on='lag_1')
df_valid = df_valid.merge(df_weight, how='left', on='lag_1')

# %%
weights = np.array(df_train['weight'])**2 * np.array(df_train['class_weight'])
weights_val = np.array(df_valid['weight'])**2 * np.array(df_valid['class_weight'])

# %%
le1 = preprocessing.LabelEncoder()
le1.fit(df_valid['lag_1'].unique())
# Out:
# LabelEncoder()

# %%
df_train['lag_1'] = le1.transform(df_train['lag_1'])
df_valid['lag_1'] = le1.transform(df_valid['lag_1'])

# %%
X, y = pd.DataFrame(pd.concat((df_valid.drop(to_drop, axis=1), df_train.drop(to_drop, axis=1))).reset_index(drop=True)), pd.concat((df_valid['lag_1'], df_train['lag_1'])).reset_index(drop=True)
weights = np.concatenate([weights_val,weights])

# %%
X['event_type'] = X['event_type'].astype('category')
X['net_connection_tech'] = X['net_connection_tech'].astype('category')

# %%
n_splits = 8
folds = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=777)

# %%
trn_idx, val_idx = list(folds.split(X, y))[1]

# %%
X, y = X.iloc[trn_idx],  y.iloc[trn_idx]
weights = weights[trn_idx, ]

# %%
lgb_train = lgb.Dataset(X, y, weight=weights)
lgb_eval = lgb.Dataset(df_valid.drop(to_drop, axis=1), df_valid['lag_1'], reference=lgb_train, weight=weights_val)

# %%
def evalerror(preds, dtrain):
    labels = dtrain.get_label()
    preds = preds.reshape(10, -1).T
    preds = preds.argmax(axis = 1)
    f_score = f1_score(labels , preds,  average = 'macro')
    return 'f1_score', f_score, True

# %%
tree_params = {
    "objective" : "multiclass",
    'metric':'custom',
    "num_class" : 10,
    'learning_rate': 0.12,
    'max_depth': 5,
    'n_jobs': 5,
    "num_leaves" : 24,
    'boosting':'dart',
    "bagging_fraction" : 0.9,  # subsample
    "feature_fraction" : 0.9,  # colsample_bytree
    "bagging_freq" : 5,        # subsample_freq
    "bagging_seed" : 2020,
    'n_estimators': 1000
}

# %%
model = lgb.train(tree_params, 
                  lgb_train,
                  feval = evalerror,
                  valid_sets=[lgb_eval],
                  early_stopping_rounds=250)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's f1_score: 0.0603859
# /opt/conda/lib/python3.7/site-packages/lightgbm/callback.py:188: UserWarning: Early stopping is not available in dart mode
#   warnings.warn('Early stopping is not available in dart mode')
# [2]	valid_0's f1_score: 0.139551
# [3]	valid_0's f1_score: 0.229736
# [4]	valid_0's f1_score: 0.313022
# [5]	valid_0's f1_score: 0.357571
# [6]	valid_0's f1_score: 0.37787
# [7]	valid_0's f1_score: 0.39203
# [8]	valid_0's f1_score: 0.382354
# [9]	valid_0's f1_score: 0.393996
# [10]	valid_0's f1_score: 0.400825
# [11]	valid_0's f1_score: 0.405256
# [12]	valid_0's f1_score: 0.402359
# [13]	valid_0's f1_score: 0.406015
# [14]	valid_0's f1_score: 0.407422
# [15]	valid_0's f1_score: 0.408856
# [16]	valid_0's f1_score: 0.410912
# [17]	valid_0's f1_score: 0.411701
# [18]	valid_0's f1_score: 0.413569
# [19]	valid_0's f1_score: 0.414366
# [20]	valid_0's f1_score: 0.415166
# [21]	valid_0's f1_score: 0.414771
# [22]	valid_0's f1_score: 0.415332
# [23]	valid_0's f1_score: 0.415822
# [24]	valid_0's f1_score: 0.416681
# [25]	valid_0's f1_score: 0.417234
# [26]	valid_0's f1_score: 0.417562
# [27]	valid_0's f1_score: 0.417723
# [28]	valid_0's f1_score: 0.417588
# [29]	valid_0's f1_score: 0.417942
# [30]	valid_0's f1_score: 0.418348
# [31]	valid_0's f1_score: 0.417983
# [32]	valid_0's f1_score: 0.418539
# [33]	valid_0's f1_score: 0.419125
# [34]	valid_0's f1_score: 0.41937
# [35]	valid_0's f1_score: 0.419155
# [36]	valid_0's f1_score: 0.418807
# [37]	valid_0's f1_score: 0.419
# [38]	valid_0's f1_score: 0.418966
# [39]	valid_0's f1_score: 0.419308
# [40]	valid_0's f1_score: 0.419568
# [41]	valid_0's f1_score: 0.419294
# [42]	valid_0's f1_score: 0.419195
# [43]	valid_0's f1_score: 0.419582
# [44]	valid_0's f1_score: 0.419939
# [45]	valid_0's f1_score: 0.419982
# [46]	valid_0's f1_score: 0.419905
# [47]	valid_0's f1_score: 0.420477
# [48]	valid_0's f1_score: 0.420421
# [49]	valid_0's f1_score: 0.420871
# [50]	valid_0's f1_score: 0.420343
# [51]	valid_0's f1_score: 0.420644
# [52]	valid_0's f1_score: 0.420721
# [53]	valid_0's f1_score: 0.421174
# [54]	valid_0's f1_score: 0.421236
# [55]	valid_0's f1_score: 0.421913
# [56]	valid_0's f1_score: 0.421506
# [57]	valid_0's f1_score: 0.421713
# [58]	valid_0's f1_score: 0.420915
# [59]	valid_0's f1_score: 0.421335
# [60]	valid_0's f1_score: 0.421541
# [61]	valid_0's f1_score: 0.420062
# [62]	valid_0's f1_score: 0.420302
# [63]	valid_0's f1_score: 0.421101
# [64]	valid_0's f1_score: 0.421291
# [65]	valid_0's f1_score: 0.421538
# [66]	valid_0's f1_score: 0.421531
# [67]	valid_0's f1_score: 0.422107
# [68]	valid_0's f1_score: 0.422098
# [69]	valid_0's f1_score: 0.421915
# [70]	valid_0's f1_score: 0.421861
# [71]	valid_0's f1_score: 0.422153
# [72]	valid_0's f1_score: 0.422334
# [73]	valid_0's f1_score: 0.422721
# [74]	valid_0's f1_score: 0.422843
# [75]	valid_0's f1_score: 0.422704
# [76]	valid_0's f1_score: 0.422938
# [77]	valid_0's f1_score: 0.422955
# [78]	valid_0's f1_score: 0.423322
# [79]	valid_0's f1_score: 0.423615
# [80]	valid_0's f1_score: 0.423253
# [81]	valid_0's f1_score: 0.42343
# [82]	valid_0's f1_score: 0.423258
# [83]	valid_0's f1_score: 0.423283
# [84]	valid_0's f1_score: 0.423307
# [85]	valid_0's f1_score: 0.423355
# [86]	valid_0's f1_score: 0.423754
# [87]	valid_0's f1_score: 0.423638
# [88]	valid_0's f1_score: 0.423766
# [89]	valid_0's f1_score: 0.424054
# [90]	valid_0's f1_score: 0.42403
# [91]	valid_0's f1_score: 0.422825
# [92]	valid_0's f1_score: 0.423173
# [93]	valid_0's f1_score: 0.422871
# [94]	valid_0's f1_score: 0.422716
# [95]	valid_0's f1_score: 0.42261
# [96]	valid_0's f1_score: 0.422829
# [97]	valid_0's f1_score: 0.423038
# [98]	valid_0's f1_score: 0.423197
# [99]	valid_0's f1_score: 0.423527
# [100]	valid_0's f1_score: 0.423925
# [101]	valid_0's f1_score: 0.423812
# [102]	valid_0's f1_score: 0.42368
# [103]	valid_0's f1_score: 0.423667
# [104]	valid_0's f1_score: 0.42395
# [105]	valid_0's f1_score: 0.423398
# [106]	valid_0's f1_score: 0.423338
# [107]	valid_0's f1_score: 0.423701
# [108]	valid_0's f1_score: 0.423822
# [109]	valid_0's f1_score: 0.423839
# [110]	valid_0's f1_score: 0.423749
# [111]	valid_0's f1_score: 0.423358
# [112]	valid_0's f1_score: 0.423422
# [113]	valid_0's f1_score: 0.424133
# [114]	valid_0's f1_score: 0.42417
# [115]	valid_0's f1_score: 0.424475
# [116]	valid_0's f1_score: 0.424521
# [117]	valid_0's f1_score: 0.424414
# [118]	valid_0's f1_score: 0.42444
# [119]	valid_0's f1_score: 0.424086
# [120]	valid_0's f1_score: 0.424454
# [121]	valid_0's f1_score: 0.424494
# [122]	valid_0's f1_score: 0.423934
# [123]	valid_0's f1_score: 0.424656
# [124]	valid_0's f1_score: 0.424591
# [125]	valid_0's f1_score: 0.424728
# [126]	valid_0's f1_score: 0.424885
# [127]	valid_0's f1_score: 0.424613
# [128]	valid_0's f1_score: 0.424767
# [129]	valid_0's f1_score: 0.424626
# [130]	valid_0's f1_score: 0.425252
# [131]	valid_0's f1_score: 0.425066
# [132]	valid_0's f1_score: 0.42504
# [133]	valid_0's f1_score: 0.425009
# [134]	valid_0's f1_score: 0.425198
# [135]	valid_0's f1_score: 0.425554
# [136]	valid_0's f1_score: 0.425134
# [137]	valid_0's f1_score: 0.42517
# [138]	valid_0's f1_score: 0.425531
# [139]	valid_0's f1_score: 0.425745
# [140]	valid_0's f1_score: 0.425471
# [141]	valid_0's f1_score: 0.425712
# [142]	valid_0's f1_score: 0.425487
# [143]	valid_0's f1_score: 0.425667
# [144]	valid_0's f1_score: 0.425439
# [145]	valid_0's f1_score: 0.425506
# [146]	valid_0's f1_score: 0.425263
# [147]	valid_0's f1_score: 0.425443
# [148]	valid_0's f1_score: 0.425484
# [149]	valid_0's f1_score: 0.425675
# [150]	valid_0's f1_score: 0.425629
# [151]	valid_0's f1_score: 0.425805
# [152]	valid_0's f1_score: 0.425962
# [153]	valid_0's f1_score: 0.425857
# [154]	valid_0's f1_score: 0.425828
# [155]	valid_0's f1_score: 0.426141
# [156]	valid_0's f1_score: 0.426057
# [157]	valid_0's f1_score: 0.425706
# [158]	valid_0's f1_score: 0.42581
# [159]	valid_0's f1_score: 0.425745
# [160]	valid_0's f1_score: 0.425646
# [161]	valid_0's f1_score: 0.42589
# [162]	valid_0's f1_score: 0.426089
# [163]	valid_0's f1_score: 0.426082
# [164]	valid_0's f1_score: 0.426862
# [165]	valid_0's f1_score: 0.426673
# [166]	valid_0's f1_score: 0.426761
# [167]	valid_0's f1_score: 0.426988
# [168]	valid_0's f1_score: 0.427085
# [169]	valid_0's f1_score: 0.427724
# [170]	valid_0's f1_score: 0.427396
# [171]	valid_0's f1_score: 0.427737
# [172]	valid_0's f1_score: 0.427328
# [173]	valid_0's f1_score: 0.427315
# [174]	valid_0's f1_score: 0.427566
# [175]	valid_0's f1_score: 0.427534
# [176]	valid_0's f1_score: 0.427465
# [177]	valid_0's f1_score: 0.427383
# [178]	valid_0's f1_score: 0.427568
# [179]	valid_0's f1_score: 0.427734
# [180]	valid_0's f1_score: 0.427728
# [181]	valid_0's f1_score: 0.427653
# [182]	valid_0's f1_score: 0.427794
# [183]	valid_0's f1_score: 0.428207
# [184]	valid_0's f1_score: 0.428282
# [185]	valid_0's f1_score: 0.428107
# [186]	valid_0's f1_score: 0.428198
# [187]	valid_0's f1_score: 0.42833
# [188]	valid_0's f1_score: 0.428175
# [189]	valid_0's f1_score: 0.428312
# [190]	valid_0's f1_score: 0.428232
# [191]	valid_0's f1_score: 0.428569
# [192]	valid_0's f1_score: 0.428304
# [193]	valid_0's f1_score: 0.428325
# [194]	valid_0's f1_score: 0.428489
# [195]	valid_0's f1_score: 0.428485
# [196]	valid_0's f1_score: 0.428527
# [197]	valid_0's f1_score: 0.428566
# [198]	valid_0's f1_score: 0.428688
# [199]	valid_0's f1_score: 0.428538
# [200]	valid_0's f1_score: 0.428589
# [201]	valid_0's f1_score: 0.428668
# [202]	valid_0's f1_score: 0.428723
# [203]	valid_0's f1_score: 0.428758
# [204]	valid_0's f1_score: 0.428666
# [205]	valid_0's f1_score: 0.428548
# [206]	valid_0's f1_score: 0.42856
# [207]	valid_0's f1_score: 0.428444
# [208]	valid_0's f1_score: 0.428573
# [209]	valid_0's f1_score: 0.428528
# [210]	valid_0's f1_score: 0.428607
# [211]	valid_0's f1_score: 0.428592
# [212]	valid_0's f1_score: 0.428813
# [213]	valid_0's f1_score: 0.428711
# [214]	valid_0's f1_score: 0.428976
# [215]	valid_0's f1_score: 0.428912
# [216]	valid_0's f1_score: 0.428909
# [217]	valid_0's f1_score: 0.428998
# [218]	valid_0's f1_score: 0.429168
# [219]	valid_0's f1_score: 0.428876
# [220]	valid_0's f1_score: 0.428956
# [221]	valid_0's f1_score: 0.428923
# [222]	valid_0's f1_score: 0.429089
# [223]	valid_0's f1_score: 0.42939
# [224]	valid_0's f1_score: 0.429307
# [225]	valid_0's f1_score: 0.42917
# [226]	valid_0's f1_score: 0.429132
# [227]	valid_0's f1_score: 0.429087
# [228]	valid_0's f1_score: 0.429302
# [229]	valid_0's f1_score: 0.429258
# [230]	valid_0's f1_score: 0.429349
# [231]	valid_0's f1_score: 0.429327
# [232]	valid_0's f1_score: 0.429469
# [233]	valid_0's f1_score: 0.429565
# [234]	valid_0's f1_score: 0.429732
# [235]	valid_0's f1_score: 0.429756
# [236]	valid_0's f1_score: 0.430184
# [237]	valid_0's f1_score: 0.430055
# [238]	valid_0's f1_score: 0.429769
# [239]	valid_0's f1_score: 0.429832
# [240]	valid_0's f1_score: 0.43016
# [241]	valid_0's f1_score: 0.430197
# [242]	valid_0's f1_score: 0.430173
# [243]	valid_0's f1_score: 0.430112
# [244]	valid_0's f1_score: 0.430073
# [245]	valid_0's f1_score: 0.430067
# [246]	valid_0's f1_score: 0.430346
# [247]	valid_0's f1_score: 0.430711
# [248]	valid_0's f1_score: 0.430696
# [249]	valid_0's f1_score: 0.430761
# [250]	valid_0's f1_score: 0.430699
# [251]	valid_0's f1_score: 0.430846
# [252]	valid_0's f1_score: 0.430703
# [253]	valid_0's f1_score: 0.430518
# [254]	valid_0's f1_score: 0.430558
# [255]	valid_0's f1_score: 0.430578
# [256]	valid_0's f1_score: 0.431405
# [257]	valid_0's f1_score: 0.431122
# [258]	valid_0's f1_score: 0.43106
# [259]	valid_0's f1_score: 0.430989
# [260]	valid_0's f1_score: 0.430982
# [261]	valid_0's f1_score: 0.430956
# [262]	valid_0's f1_score: 0.431181
# [263]	valid_0's f1_score: 0.431483
# [264]	valid_0's f1_score: 0.431451
# [265]	valid_0's f1_score: 0.431458
# [266]	valid_0's f1_score: 0.431415
# [267]	valid_0's f1_score: 0.431412
# [268]	valid_0's f1_score: 0.431726
# [269]	valid_0's f1_score: 0.431819
# [270]	valid_0's f1_score: 0.43212
# [271]	valid_0's f1_score: 0.432026
# [272]	valid_0's f1_score: 0.431889
# [273]	valid_0's f1_score: 0.431957
# [274]	valid_0's f1_score: 0.431946
# [275]	valid_0's f1_score: 0.432533
# [276]	valid_0's f1_score: 0.432428
# [277]	valid_0's f1_score: 0.432712
# [278]	valid_0's f1_score: 0.432743
# [279]	valid_0's f1_score: 0.432947
# [280]	valid_0's f1_score: 0.432837
# [281]	valid_0's f1_score: 0.432651
# [282]	valid_0's f1_score: 0.433087
# [283]	valid_0's f1_score: 0.432937
# [284]	valid_0's f1_score: 0.432996
# [285]	valid_0's f1_score: 0.433088
# [286]	valid_0's f1_score: 0.433286
# [287]	valid_0's f1_score: 0.433216
# [288]	valid_0's f1_score: 0.433143
# [289]	valid_0's f1_score: 0.433474
# [290]	valid_0's f1_score: 0.433453
# [291]	valid_0's f1_score: 0.433673
# [292]	valid_0's f1_score: 0.433671
# [293]	valid_0's f1_score: 0.433571
# [294]	valid_0's f1_score: 0.433444
# [295]	valid_0's f1_score: 0.433249
# [296]	valid_0's f1_score: 0.433313
# [297]	valid_0's f1_score: 0.433547
# [298]	valid_0's f1_score: 0.433472
# [299]	valid_0's f1_score: 0.433518
# [300]	valid_0's f1_score: 0.433329
# [301]	valid_0's f1_score: 0.433285
# [302]	valid_0's f1_score: 0.433358
# [303]	valid_0's f1_score: 0.433259
# [304]	valid_0's f1_score: 0.433081
# [305]	valid_0's f1_score: 0.433011
# [306]	valid_0's f1_score: 0.432998
# [307]	valid_0's f1_score: 0.432969
# [308]	valid_0's f1_score: 0.433173
# [309]	valid_0's f1_score: 0.432951
# [310]	valid_0's f1_score: 0.433135
# [311]	valid_0's f1_score: 0.433108
# [312]	valid_0's f1_score: 0.433263
# [313]	valid_0's f1_score: 0.43352
# [314]	valid_0's f1_score: 0.433635
# [315]	valid_0's f1_score: 0.433543
# [316]	valid_0's f1_score: 0.433797
# [317]	valid_0's f1_score: 0.433713
# [318]	valid_0's f1_score: 0.43371
# [319]	valid_0's f1_score: 0.433769
# [320]	valid_0's f1_score: 0.433741
# [321]	valid_0's f1_score: 0.433777
# [322]	valid_0's f1_score: 0.433521
# [323]	valid_0's f1_score: 0.433591
# [324]	valid_0's f1_score: 0.433584
# [325]	valid_0's f1_score: 0.433761
# [326]	valid_0's f1_score: 0.433653
# [327]	valid_0's f1_score: 0.433582
# [328]	valid_0's f1_score: 0.43353
# [329]	valid_0's f1_score: 0.433779
# [330]	valid_0's f1_score: 0.433679
# [331]	valid_0's f1_score: 0.433583
# [332]	valid_0's f1_score: 0.433619
# [333]	valid_0's f1_score: 0.433591
# [334]	valid_0's f1_score: 0.433636
# [335]	valid_0's f1_score: 0.433828
# [336]	valid_0's f1_score: 0.433758
# [337]	valid_0's f1_score: 0.43379
# [338]	valid_0's f1_score: 0.433717
# [339]	valid_0's f1_score: 0.433686
# [340]	valid_0's f1_score: 0.433632
# [341]	valid_0's f1_score: 0.434003
# [342]	valid_0's f1_score: 0.434201
# [343]	valid_0's f1_score: 0.43457
# [344]	valid_0's f1_score: 0.434452
# [345]	valid_0's f1_score: 0.434777
# [346]	valid_0's f1_score: 0.43484
# [347]	valid_0's f1_score: 0.434831
# [348]	valid_0's f1_score: 0.43479
# [349]	valid_0's f1_score: 0.43483
# [350]	valid_0's f1_score: 0.434668
# [351]	valid_0's f1_score: 0.434765
# [352]	valid_0's f1_score: 0.435183
# [353]	valid_0's f1_score: 0.4354
# [354]	valid_0's f1_score: 0.435497
# [355]	valid_0's f1_score: 0.435492
# [356]	valid_0's f1_score: 0.435344
# [357]	valid_0's f1_score: 0.435396
# [358]	valid_0's f1_score: 0.435529
# [359]	valid_0's f1_score: 0.435234
# [360]	valid_0's f1_score: 0.435243
# [361]	valid_0's f1_score: 0.435364
# [362]	valid_0's f1_score: 0.435719
# [363]	valid_0's f1_score: 0.435744
# [364]	valid_0's f1_score: 0.435639
# [365]	valid_0's f1_score: 0.435377
# [366]	valid_0's f1_score: 0.435368
# [367]	valid_0's f1_score: 0.43545
# [368]	valid_0's f1_score: 0.435657
# [369]	valid_0's f1_score: 0.435782
# [370]	valid_0's f1_score: 0.436001
# [371]	valid_0's f1_score: 0.436087
# [372]	valid_0's f1_score: 0.436009
# [373]	valid_0's f1_score: 0.436029
# [374]	valid_0's f1_score: 0.435818
# [375]	valid_0's f1_score: 0.435817
# [376]	valid_0's f1_score: 0.435627
# [377]	valid_0's f1_score: 0.435703
# [378]	valid_0's f1_score: 0.435592
# [379]	valid_0's f1_score: 0.435569
# [380]	valid_0's f1_score: 0.435442
# [381]	valid_0's f1_score: 0.435499
# [382]	valid_0's f1_score: 0.435572
# [383]	valid_0's f1_score: 0.435817
# [384]	valid_0's f1_score: 0.436074
# [385]	valid_0's f1_score: 0.436027
# [386]	valid_0's f1_score: 0.43585
# [387]	valid_0's f1_score: 0.435855
# [388]	valid_0's f1_score: 0.436211
# [389]	valid_0's f1_score: 0.436434
# [390]	valid_0's f1_score: 0.43632
# [391]	valid_0's f1_score: 0.4362
# [392]	valid_0's f1_score: 0.436224
# [393]	valid_0's f1_score: 0.436501
# [394]	valid_0's f1_score: 0.436368
# [395]	valid_0's f1_score: 0.436441
# [396]	valid_0's f1_score: 0.436393
# [397]	valid_0's f1_score: 0.436728
# [398]	valid_0's f1_score: 0.436638
# [399]	valid_0's f1_score: 0.436721
# [400]	valid_0's f1_score: 0.436869
# [401]	valid_0's f1_score: 0.436825
# [402]	valid_0's f1_score: 0.437185
# [403]	valid_0's f1_score: 0.437109
# [404]	valid_0's f1_score: 0.437151
# [405]	valid_0's f1_score: 0.437309
# [406]	valid_0's f1_score: 0.437119
# [407]	valid_0's f1_score: 0.43721
# [408]	valid_0's f1_score: 0.437162
# [409]	valid_0's f1_score: 0.437405
# [410]	valid_0's f1_score: 0.437415
# [411]	valid_0's f1_score: 0.43711
# [412]	valid_0's f1_score: 0.437147
# [413]	valid_0's f1_score: 0.437062
# [414]	valid_0's f1_score: 0.437311
# [415]	valid_0's f1_score: 0.437213
# [416]	valid_0's f1_score: 0.437453
# [417]	valid_0's f1_score: 0.437404
# [418]	valid_0's f1_score: 0.437232
# [419]	valid_0's f1_score: 0.437284
# [420]	valid_0's f1_score: 0.437285
# [421]	valid_0's f1_score: 0.437678
# [422]	valid_0's f1_score: 0.437661
# [423]	valid_0's f1_score: 0.43774
# [424]	valid_0's f1_score: 0.438004
# [425]	valid_0's f1_score: 0.437965
# [426]	valid_0's f1_score: 0.437587
# [427]	valid_0's f1_score: 0.43813
# [428]	valid_0's f1_score: 0.438171
# [429]	valid_0's f1_score: 0.43859
# [430]	valid_0's f1_score: 0.438285
# [431]	valid_0's f1_score: 0.438607
# [432]	valid_0's f1_score: 0.43862
# [433]	valid_0's f1_score: 0.438813
# [434]	valid_0's f1_score: 0.438658
# [435]	valid_0's f1_score: 0.438667
# [436]	valid_0's f1_score: 0.438823
# [437]	valid_0's f1_score: 0.43891
# [438]	valid_0's f1_score: 0.438852
# [439]	valid_0's f1_score: 0.438775
# [440]	valid_0's f1_score: 0.438966
# [441]	valid_0's f1_score: 0.438888
# [442]	valid_0's f1_score: 0.438986
# [443]	valid_0's f1_score: 0.439011
# [444]	valid_0's f1_score: 0.439203
# [445]	valid_0's f1_score: 0.438923
# [446]	valid_0's f1_score: 0.438978
# [447]	valid_0's f1_score: 0.439152
# [448]	valid_0's f1_score: 0.438977
# [449]	valid_0's f1_score: 0.439089
# [450]	valid_0's f1_score: 0.43941
# [451]	valid_0's f1_score: 0.439463
# [452]	valid_0's f1_score: 0.439363
# [453]	valid_0's f1_score: 0.439316
# [454]	valid_0's f1_score: 0.439179
# [455]	valid_0's f1_score: 0.439094
# [456]	valid_0's f1_score: 0.439106
# [457]	valid_0's f1_score: 0.439059
# [458]	valid_0's f1_score: 0.438802
# [459]	valid_0's f1_score: 0.439392
# [460]	valid_0's f1_score: 0.439255
# [461]	valid_0's f1_score: 0.4396
# [462]	valid_0's f1_score: 0.439567
# [463]	valid_0's f1_score: 0.439509
# [464]	valid_0's f1_score: 0.439567
# [465]	valid_0's f1_score: 0.439787
# [466]	valid_0's f1_score: 0.439732
# [467]	valid_0's f1_score: 0.439559
# [468]	valid_0's f1_score: 0.439551
# [469]	valid_0's f1_score: 0.43974
# [470]	valid_0's f1_score: 0.43962
# [471]	valid_0's f1_score: 0.439717
# [472]	valid_0's f1_score: 0.439611
# [473]	valid_0's f1_score: 0.439812
# [474]	valid_0's f1_score: 0.439787
# [475]	valid_0's f1_score: 0.439941
# [476]	valid_0's f1_score: 0.440038
# [477]	valid_0's f1_score: 0.440048
# [478]	valid_0's f1_score: 0.440051
# [479]	valid_0's f1_score: 0.439853
# [480]	valid_0's f1_score: 0.439999
# [481]	valid_0's f1_score: 0.439985
# [482]	valid_0's f1_score: 0.440066
# [483]	valid_0's f1_score: 0.4402
# [484]	valid_0's f1_score: 0.439997
# [485]	valid_0's f1_score: 0.43999
# [486]	valid_0's f1_score: 0.4404
# [487]	valid_0's f1_score: 0.440408
# [488]	valid_0's f1_score: 0.440653
# [489]	valid_0's f1_score: 0.440812
# [490]	valid_0's f1_score: 0.440694
# [491]	valid_0's f1_score: 0.440813
# [492]	valid_0's f1_score: 0.440859
# [493]	valid_0's f1_score: 0.440848
# [494]	valid_0's f1_score: 0.440871
# [495]	valid_0's f1_score: 0.440711
# [496]	valid_0's f1_score: 0.440884
# [497]	valid_0's f1_score: 0.441331
# [498]	valid_0's f1_score: 0.441311
# [499]	valid_0's f1_score: 0.441346
# [500]	valid_0's f1_score: 0.441267
# [501]	valid_0's f1_score: 0.441175
# [502]	valid_0's f1_score: 0.441243
# [503]	valid_0's f1_score: 0.441402
# [504]	valid_0's f1_score: 0.441367
# [505]	valid_0's f1_score: 0.441384
# [506]	valid_0's f1_score: 0.441376
# [507]	valid_0's f1_score: 0.441536
# [508]	valid_0's f1_score: 0.441749
# [509]	valid_0's f1_score: 0.44162
# [510]	valid_0's f1_score: 0.441781
# [511]	valid_0's f1_score: 0.441774
# [512]	valid_0's f1_score: 0.442107
# [513]	valid_0's f1_score: 0.441987
# [514]	valid_0's f1_score: 0.442175
# [515]	valid_0's f1_score: 0.442019
# [516]	valid_0's f1_score: 0.442056
# [517]	valid_0's f1_score: 0.442096
# [518]	valid_0's f1_score: 0.442021
# [519]	valid_0's f1_score: 0.442011
# [520]	valid_0's f1_score: 0.442323
# [521]	valid_0's f1_score: 0.441967
# [522]	valid_0's f1_score: 0.44212
# [523]	valid_0's f1_score: 0.442067
# [524]	valid_0's f1_score: 0.441965
# [525]	valid_0's f1_score: 0.442012
# [526]	valid_0's f1_score: 0.442187
# [527]	valid_0's f1_score: 0.442119
# [528]	valid_0's f1_score: 0.442254
# [529]	valid_0's f1_score: 0.442303
# [530]	valid_0's f1_score: 0.44215
# [531]	valid_0's f1_score: 0.442239
# [532]	valid_0's f1_score: 0.4426
# [533]	valid_0's f1_score: 0.442541
# [534]	valid_0's f1_score: 0.442433
# [535]	valid_0's f1_score: 0.442313
# [536]	valid_0's f1_score: 0.442245
# [537]	valid_0's f1_score: 0.442313
# [538]	valid_0's f1_score: 0.442406
# [539]	valid_0's f1_score: 0.442267
# [540]	valid_0's f1_score: 0.442283
# [541]	valid_0's f1_score: 0.44227
# [542]	valid_0's f1_score: 0.442352
# [543]	valid_0's f1_score: 0.442344
# [544]	valid_0's f1_score: 0.442263
# [545]	valid_0's f1_score: 0.442209
# [546]	valid_0's f1_score: 0.442756
# [547]	valid_0's f1_score: 0.442674
# [548]	valid_0's f1_score: 0.44266
# [549]	valid_0's f1_score: 0.442647
# [550]	valid_0's f1_score: 0.442881
# [551]	valid_0's f1_score: 0.443087
# [552]	valid_0's f1_score: 0.44301
# [553]	valid_0's f1_score: 0.443035
# [554]	valid_0's f1_score: 0.443003
# [555]	valid_0's f1_score: 0.443102
# [556]	valid_0's f1_score: 0.443082
# [557]	valid_0's f1_score: 0.443103
# [558]	valid_0's f1_score: 0.443286
# [559]	valid_0's f1_score: 0.443199
# [560]	valid_0's f1_score: 0.443065
# [561]	valid_0's f1_score: 0.443064
# [562]	valid_0's f1_score: 0.442991
# [563]	valid_0's f1_score: 0.443043
# [564]	valid_0's f1_score: 0.442978
# [565]	valid_0's f1_score: 0.443101
# [566]	valid_0's f1_score: 0.443493
# [567]	valid_0's f1_score: 0.443724
# [568]	valid_0's f1_score: 0.44375
# [569]	valid_0's f1_score: 0.443662
# [570]	valid_0's f1_score: 0.443755
# [571]	valid_0's f1_score: 0.443701
# [572]	valid_0's f1_score: 0.443865
# [573]	valid_0's f1_score: 0.443835
# [574]	valid_0's f1_score: 0.443887
# [575]	valid_0's f1_score: 0.443925
# [576]	valid_0's f1_score: 0.443925
# [577]	valid_0's f1_score: 0.44396
# [578]	valid_0's f1_score: 0.443947
# [579]	valid_0's f1_score: 0.444002
# [580]	valid_0's f1_score: 0.443945
# [581]	valid_0's f1_score: 0.443898
# [582]	valid_0's f1_score: 0.443883
# [583]	valid_0's f1_score: 0.444184
# [584]	valid_0's f1_score: 0.444173
# [585]	valid_0's f1_score: 0.444047
# [586]	valid_0's f1_score: 0.444073
# [587]	valid_0's f1_score: 0.44396
# [588]	valid_0's f1_score: 0.443989
# [589]	valid_0's f1_score: 0.443786
# [590]	valid_0's f1_score: 0.44367
# [591]	valid_0's f1_score: 0.443656
# [592]	valid_0's f1_score: 0.443625
# [593]	valid_0's f1_score: 0.443929
# [594]	valid_0's f1_score: 0.443957
# [595]	valid_0's f1_score: 0.443948
# [596]	valid_0's f1_score: 0.444306
# [597]	valid_0's f1_score: 0.444288
# [598]	valid_0's f1_score: 0.444177
# [599]	valid_0's f1_score: 0.443921
# [600]	valid_0's f1_score: 0.444188
# [601]	valid_0's f1_score: 0.444452
# [602]	valid_0's f1_score: 0.444386
# [603]	valid_0's f1_score: 0.444314
# [604]	valid_0's f1_score: 0.444301
# [605]	valid_0's f1_score: 0.444295
# [606]	valid_0's f1_score: 0.44433
# [607]	valid_0's f1_score: 0.444289
# [608]	valid_0's f1_score: 0.444166
# [609]	valid_0's f1_score: 0.444269
# [610]	valid_0's f1_score: 0.44434
# [611]	valid_0's f1_score: 0.444215
# [612]	valid_0's f1_score: 0.444273
# [613]	valid_0's f1_score: 0.444275
# [614]	valid_0's f1_score: 0.444365
# [615]	valid_0's f1_score: 0.444372
# [616]	valid_0's f1_score: 0.444383
# [617]	valid_0's f1_score: 0.444387
# [618]	valid_0's f1_score: 0.444453
# [619]	valid_0's f1_score: 0.444599
# [620]	valid_0's f1_score: 0.444577
# [621]	valid_0's f1_score: 0.44455
# [622]	valid_0's f1_score: 0.444472
# [623]	valid_0's f1_score: 0.44476
# [624]	valid_0's f1_score: 0.444738
# [625]	valid_0's f1_score: 0.444804
# [626]	valid_0's f1_score: 0.444964
# [627]	valid_0's f1_score: 0.445129
# [628]	valid_0's f1_score: 0.445156
# [629]	valid_0's f1_score: 0.445218
# [630]	valid_0's f1_score: 0.445103
# [631]	valid_0's f1_score: 0.445249
# [632]	valid_0's f1_score: 0.445443
# [633]	valid_0's f1_score: 0.445281
# [634]	valid_0's f1_score: 0.44527
# [635]	valid_0's f1_score: 0.44557
# [636]	valid_0's f1_score: 0.44564
# [637]	valid_0's f1_score: 0.44599
# [638]	valid_0's f1_score: 0.445961
# [639]	valid_0's f1_score: 0.445804
# [640]	valid_0's f1_score: 0.445834
# [641]	valid_0's f1_score: 0.445598
# [642]	valid_0's f1_score: 0.44562
# [643]	valid_0's f1_score: 0.445657
# [644]	valid_0's f1_score: 0.445563
# [645]	valid_0's f1_score: 0.445321
# [646]	valid_0's f1_score: 0.44556
# [647]	valid_0's f1_score: 0.445397
# [648]	valid_0's f1_score: 0.445563
# [649]	valid_0's f1_score: 0.445653
# [650]	valid_0's f1_score: 0.445624
# [651]	valid_0's f1_score: 0.445968
# [652]	valid_0's f1_score: 0.446019
# [653]	valid_0's f1_score: 0.446067
# [654]	valid_0's f1_score: 0.445927
# [655]	valid_0's f1_score: 0.445981
# [656]	valid_0's f1_score: 0.445942
# [657]	valid_0's f1_score: 0.445854
# [658]	valid_0's f1_score: 0.446006
# [659]	valid_0's f1_score: 0.445811
# [660]	valid_0's f1_score: 0.445965
# [661]	valid_0's f1_score: 0.445903
# [662]	valid_0's f1_score: 0.446176
# [663]	valid_0's f1_score: 0.446174
# [664]	valid_0's f1_score: 0.445913
# [665]	valid_0's f1_score: 0.445995
# [666]	valid_0's f1_score: 0.445983
# [667]	valid_0's f1_score: 0.445918
# [668]	valid_0's f1_score: 0.445994
# [669]	valid_0's f1_score: 0.445848
# [670]	valid_0's f1_score: 0.445944
# [671]	valid_0's f1_score: 0.446022
# [672]	valid_0's f1_score: 0.446293
# [673]	valid_0's f1_score: 0.446245
# [674]	valid_0's f1_score: 0.446196
# [675]	valid_0's f1_score: 0.446162
# [676]	valid_0's f1_score: 0.446182
# [677]	valid_0's f1_score: 0.446153
# [678]	valid_0's f1_score: 0.446148
# [679]	valid_0's f1_score: 0.446264
# [680]	valid_0's f1_score: 0.446588
# [681]	valid_0's f1_score: 0.446455
# [682]	valid_0's f1_score: 0.446545
# [683]	valid_0's f1_score: 0.44644
# [684]	valid_0's f1_score: 0.446676
# [685]	valid_0's f1_score: 0.44656
# [686]	valid_0's f1_score: 0.446718
# [687]	valid_0's f1_score: 0.446755
# [688]	valid_0's f1_score: 0.446762
# [689]	valid_0's f1_score: 0.44659
# [690]	valid_0's f1_score: 0.446784
# [691]	valid_0's f1_score: 0.446806
# [692]	valid_0's f1_score: 0.446846
# [693]	valid_0's f1_score: 0.446924
# [694]	valid_0's f1_score: 0.446925
# [695]	valid_0's f1_score: 0.446959
# [696]	valid_0's f1_score: 0.446807
# [697]	valid_0's f1_score: 0.446808
# [698]	valid_0's f1_score: 0.447207
# [699]	valid_0's f1_score: 0.447115
# [700]	valid_0's f1_score: 0.447192
# [701]	valid_0's f1_score: 0.447301
# [702]	valid_0's f1_score: 0.447146
# [703]	valid_0's f1_score: 0.44728
# [704]	valid_0's f1_score: 0.447229
# [705]	valid_0's f1_score: 0.447274
# [706]	valid_0's f1_score: 0.447066
# [707]	valid_0's f1_score: 0.447134
# [708]	valid_0's f1_score: 0.447506
# [709]	valid_0's f1_score: 0.447608
# [710]	valid_0's f1_score: 0.447519
# [711]	valid_0's f1_score: 0.447396
# [712]	valid_0's f1_score: 0.44746
# [713]	valid_0's f1_score: 0.447424
# [714]	valid_0's f1_score: 0.447588
# [715]	valid_0's f1_score: 0.447573
# [716]	valid_0's f1_score: 0.447756
# [717]	valid_0's f1_score: 0.447641
# [718]	valid_0's f1_score: 0.447585
# [719]	valid_0's f1_score: 0.44754
# [720]	valid_0's f1_score: 0.447554
# [721]	valid_0's f1_score: 0.448068
# [722]	valid_0's f1_score: 0.44809
# [723]	valid_0's f1_score: 0.448136
# [724]	valid_0's f1_score: 0.448498
# [725]	valid_0's f1_score: 0.448575
# [726]	valid_0's f1_score: 0.448234
# [727]	valid_0's f1_score: 0.448377
# [728]	valid_0's f1_score: 0.448425
# [729]	valid_0's f1_score: 0.448412
# [730]	valid_0's f1_score: 0.448512
# [731]	valid_0's f1_score: 0.448561
# [732]	valid_0's f1_score: 0.448452
# [733]	valid_0's f1_score: 0.44855
# [734]	valid_0's f1_score: 0.448588
# [735]	valid_0's f1_score: 0.448604
# [736]	valid_0's f1_score: 0.448723
# [737]	valid_0's f1_score: 0.448813
# [738]	valid_0's f1_score: 0.448681
# [739]	valid_0's f1_score: 0.448738
# [740]	valid_0's f1_score: 0.448684
# [741]	valid_0's f1_score: 0.448634
# [742]	valid_0's f1_score: 0.448747
# [743]	valid_0's f1_score: 0.449119
# [744]	valid_0's f1_score: 0.449045
# [745]	valid_0's f1_score: 0.448958
# [746]	valid_0's f1_score: 0.448811
# [747]	valid_0's f1_score: 0.448981
# [748]	valid_0's f1_score: 0.449079
# [749]	valid_0's f1_score: 0.449017
# [750]	valid_0's f1_score: 0.449255
# [751]	valid_0's f1_score: 0.449347
# [752]	valid_0's f1_score: 0.449353
# [753]	valid_0's f1_score: 0.449422
# [754]	valid_0's f1_score: 0.449439
# [755]	valid_0's f1_score: 0.449545
# [756]	valid_0's f1_score: 0.449548
# [757]	valid_0's f1_score: 0.449541
# [758]	valid_0's f1_score: 0.449781
# [759]	valid_0's f1_score: 0.449609
# [760]	valid_0's f1_score: 0.449594
# [761]	valid_0's f1_score: 0.449501
# [762]	valid_0's f1_score: 0.449401
# [763]	valid_0's f1_score: 0.449461
# [764]	valid_0's f1_score: 0.449415
# [765]	valid_0's f1_score: 0.449458
# [766]	valid_0's f1_score: 0.44943
# [767]	valid_0's f1_score: 0.449378
# [768]	valid_0's f1_score: 0.449375
# [769]	valid_0's f1_score: 0.449619
# [770]	valid_0's f1_score: 0.449573
# [771]	valid_0's f1_score: 0.449429
# [772]	valid_0's f1_score: 0.449518
# [773]	valid_0's f1_score: 0.449657
# [774]	valid_0's f1_score: 0.449653
# [775]	valid_0's f1_score: 0.449733
# [776]	valid_0's f1_score: 0.449798
# [777]	valid_0's f1_score: 0.449752
# [778]	valid_0's f1_score: 0.44976
# [779]	valid_0's f1_score: 0.449734
# [780]	valid_0's f1_score: 0.449671
# [781]	valid_0's f1_score: 0.449749
# [782]	valid_0's f1_score: 0.449786
# [783]	valid_0's f1_score: 0.449746
# [784]	valid_0's f1_score: 0.449743
# [785]	valid_0's f1_score: 0.449858
# [786]	valid_0's f1_score: 0.449873
# [787]	valid_0's f1_score: 0.449956
# [788]	valid_0's f1_score: 0.449934
# [789]	valid_0's f1_score: 0.449917
# [790]	valid_0's f1_score: 0.450096
# [791]	valid_0's f1_score: 0.450285
# [792]	valid_0's f1_score: 0.450284
# [793]	valid_0's f1_score: 0.450212
# [794]	valid_0's f1_score: 0.45028
# [795]	valid_0's f1_score: 0.450286
# [796]	valid_0's f1_score: 0.450356
# [797]	valid_0's f1_score: 0.450399
# [798]	valid_0's f1_score: 0.450396
# [799]	valid_0's f1_score: 0.450253
# [800]	valid_0's f1_score: 0.450161
# [801]	valid_0's f1_score: 0.450573
# [802]	valid_0's f1_score: 0.450512
# [803]	valid_0's f1_score: 0.450555
# [804]	valid_0's f1_score: 0.450609
# [805]	valid_0's f1_score: 0.450563
# [806]	valid_0's f1_score: 0.450645
# [807]	valid_0's f1_score: 0.450716
# [808]	valid_0's f1_score: 0.450695
# [809]	valid_0's f1_score: 0.450825
# [810]	valid_0's f1_score: 0.450741
# [811]	valid_0's f1_score: 0.450778
# [812]	valid_0's f1_score: 0.450743
# [813]	valid_0's f1_score: 0.450751
# [814]	valid_0's f1_score: 0.450755
# [815]	valid_0's f1_score: 0.450738
# [816]	valid_0's f1_score: 0.451056
# [817]	valid_0's f1_score: 0.451085
# [818]	valid_0's f1_score: 0.451225
# [819]	valid_0's f1_score: 0.451198
# [820]	valid_0's f1_score: 0.45119
# [821]	valid_0's f1_score: 0.451081
# [822]	valid_0's f1_score: 0.45106
# [823]	valid_0's f1_score: 0.45116
# [824]	valid_0's f1_score: 0.451461
# [825]	valid_0's f1_score: 0.451182
# [826]	valid_0's f1_score: 0.451077
# [827]	valid_0's f1_score: 0.451135
# [828]	valid_0's f1_score: 0.451039
# [829]	valid_0's f1_score: 0.451193
# [830]	valid_0's f1_score: 0.451071
# [831]	valid_0's f1_score: 0.451224
# [832]	valid_0's f1_score: 0.451264
# [833]	valid_0's f1_score: 0.451533
# [834]	valid_0's f1_score: 0.451466
# [835]	valid_0's f1_score: 0.451489
# [836]	valid_0's f1_score: 0.451331
# [837]	valid_0's f1_score: 0.451312
# [838]	valid_0's f1_score: 0.451244
# [839]	valid_0's f1_score: 0.451497
# [840]	valid_0's f1_score: 0.451315
# [841]	valid_0's f1_score: 0.451412
# [842]	valid_0's f1_score: 0.451671
# [843]	valid_0's f1_score: 0.451815
# [844]	valid_0's f1_score: 0.451767
# [845]	valid_0's f1_score: 0.4518
# [846]	valid_0's f1_score: 0.451672
# [847]	valid_0's f1_score: 0.451771
# [848]	valid_0's f1_score: 0.451745
# [849]	valid_0's f1_score: 0.45165
# [850]	valid_0's f1_score: 0.451704
# [851]	valid_0's f1_score: 0.451553
# [852]	valid_0's f1_score: 0.451601
# [853]	valid_0's f1_score: 0.451709
# [854]	valid_0's f1_score: 0.451724
# [855]	valid_0's f1_score: 0.451583
# [856]	valid_0's f1_score: 0.451765
# [857]	valid_0's f1_score: 0.451818
# [858]	valid_0's f1_score: 0.451747
# [859]	valid_0's f1_score: 0.451716
# [860]	valid_0's f1_score: 0.451843
# [861]	valid_0's f1_score: 0.451775
# [862]	valid_0's f1_score: 0.452034
# [863]	valid_0's f1_score: 0.45212
# [864]	valid_0's f1_score: 0.452035
# [865]	valid_0's f1_score: 0.452137
# [866]	valid_0's f1_score: 0.452341
# [867]	valid_0's f1_score: 0.452339
# [868]	valid_0's f1_score: 0.452308
# [869]	valid_0's f1_score: 0.452279
# [870]	valid_0's f1_score: 0.452277
# [871]	valid_0's f1_score: 0.452245
# [872]	valid_0's f1_score: 0.45259
# [873]	valid_0's f1_score: 0.452621
# [874]	valid_0's f1_score: 0.452584
# [875]	valid_0's f1_score: 0.452622
# [876]	valid_0's f1_score: 0.452824
# [877]	valid_0's f1_score: 0.452831
# [878]	valid_0's f1_score: 0.45293
# [879]	valid_0's f1_score: 0.452952
# [880]	valid_0's f1_score: 0.452882
# [881]	valid_0's f1_score: 0.452853
# [882]	valid_0's f1_score: 0.452824
# [883]	valid_0's f1_score: 0.452867
# [884]	valid_0's f1_score: 0.452929
# [885]	valid_0's f1_score: 0.452965
# [886]	valid_0's f1_score: 0.452761
# [887]	valid_0's f1_score: 0.452833
# [888]	valid_0's f1_score: 0.452887
# [889]	valid_0's f1_score: 0.452865
# [890]	valid_0's f1_score: 0.453125
# [891]	valid_0's f1_score: 0.453053
# [892]	valid_0's f1_score: 0.45312
# [893]	valid_0's f1_score: 0.453008
# [894]	valid_0's f1_score: 0.453043
# [895]	valid_0's f1_score: 0.453042
# [896]	valid_0's f1_score: 0.452973
# [897]	valid_0's f1_score: 0.453003
# [898]	valid_0's f1_score: 0.453095
# [899]	valid_0's f1_score: 0.453102
# [900]	valid_0's f1_score: 0.453103
# [901]	valid_0's f1_score: 0.453063
# [902]	valid_0's f1_score: 0.453095
# [903]	valid_0's f1_score: 0.453075
# [904]	valid_0's f1_score: 0.453169
# [905]	valid_0's f1_score: 0.45339
# [906]	valid_0's f1_score: 0.453306
# [907]	valid_0's f1_score: 0.453272
# [908]	valid_0's f1_score: 0.453227
# [909]	valid_0's f1_score: 0.453232
# [910]	valid_0's f1_score: 0.453216
# [911]	valid_0's f1_score: 0.453268
# [912]	valid_0's f1_score: 0.453281
# [913]	valid_0's f1_score: 0.453218
# [914]	valid_0's f1_score: 0.453457
# [915]	valid_0's f1_score: 0.453587
# [916]	valid_0's f1_score: 0.453703
# [917]	valid_0's f1_score: 0.453682
# [918]	valid_0's f1_score: 0.453664
# [919]	valid_0's f1_score: 0.45368
# [920]	valid_0's f1_score: 0.453665
# [921]	valid_0's f1_score: 0.453633
# [922]	valid_0's f1_score: 0.453505
# [923]	valid_0's f1_score: 0.453464
# [924]	valid_0's f1_score: 0.453359
# [925]	valid_0's f1_score: 0.453445
# [926]	valid_0's f1_score: 0.453492
# [927]	valid_0's f1_score: 0.453464
# [928]	valid_0's f1_score: 0.453469
# [929]	valid_0's f1_score: 0.453706
# [930]	valid_0's f1_score: 0.453673
# [931]	valid_0's f1_score: 0.453691
# [932]	valid_0's f1_score: 0.45366
# [933]	valid_0's f1_score: 0.45369
# [934]	valid_0's f1_score: 0.453938
# [935]	valid_0's f1_score: 0.453791
# [936]	valid_0's f1_score: 0.453763
# [937]	valid_0's f1_score: 0.453679
# [938]	valid_0's f1_score: 0.453739
# [939]	valid_0's f1_score: 0.453737
# [940]	valid_0's f1_score: 0.454016
# [941]	valid_0's f1_score: 0.453984
# [942]	valid_0's f1_score: 0.454071
# [943]	valid_0's f1_score: 0.454021
# [944]	valid_0's f1_score: 0.454007
# [945]	valid_0's f1_score: 0.454084
# [946]	valid_0's f1_score: 0.454024
# [947]	valid_0's f1_score: 0.453899
# [948]	valid_0's f1_score: 0.453968
# [949]	valid_0's f1_score: 0.45416
# [950]	valid_0's f1_score: 0.454316
# [951]	valid_0's f1_score: 0.454471
# [952]	valid_0's f1_score: 0.454452
# [953]	valid_0's f1_score: 0.454363
# [954]	valid_0's f1_score: 0.4544
# [955]	valid_0's f1_score: 0.454381
# [956]	valid_0's f1_score: 0.454456
# [957]	valid_0's f1_score: 0.454659
# [958]	valid_0's f1_score: 0.454732
# [959]	valid_0's f1_score: 0.454618
# [960]	valid_0's f1_score: 0.454694
# [961]	valid_0's f1_score: 0.45486
# [962]	valid_0's f1_score: 0.455217
# [963]	valid_0's f1_score: 0.454997
# [964]	valid_0's f1_score: 0.454965
# [965]	valid_0's f1_score: 0.455057
# [966]	valid_0's f1_score: 0.455111
# [967]	valid_0's f1_score: 0.455026
# [968]	valid_0's f1_score: 0.455072
# [969]	valid_0's f1_score: 0.455109
# [970]	valid_0's f1_score: 0.455396
# [971]	valid_0's f1_score: 0.455437
# [972]	valid_0's f1_score: 0.455335
# [973]	valid_0's f1_score: 0.455273
# [974]	valid_0's f1_score: 0.45531
# [975]	valid_0's f1_score: 0.45532
# [976]	valid_0's f1_score: 0.455432
# [977]	valid_0's f1_score: 0.455446
# [978]	valid_0's f1_score: 0.455343
# [979]	valid_0's f1_score: 0.4554
# [980]	valid_0's f1_score: 0.455676
# [981]	valid_0's f1_score: 0.455625
# [982]	valid_0's f1_score: 0.455635
# [983]	valid_0's f1_score: 0.455897
# [984]	valid_0's f1_score: 0.455644
# [985]	valid_0's f1_score: 0.455544
# [986]	valid_0's f1_score: 0.455517
# [987]	valid_0's f1_score: 0.455491
# [988]	valid_0's f1_score: 0.455261
# [989]	valid_0's f1_score: 0.455187
# [990]	valid_0's f1_score: 0.455195
# [991]	valid_0's f1_score: 0.455288
# [992]	valid_0's f1_score: 0.455234
# [993]	valid_0's f1_score: 0.455197
# [994]	valid_0's f1_score: 0.455065
# [995]	valid_0's f1_score: 0.455042
# [996]	valid_0's f1_score: 0.455363
# [997]	valid_0's f1_score: 0.455523
# [998]	valid_0's f1_score: 0.455485
# [999]	valid_0's f1_score: 0.455412
# [1000]	valid_0's f1_score: 0.455353

# %%
with open('lgb_model8_fold1.pkl', 'wb') as fout:
    pickle.dump(model, fout)
