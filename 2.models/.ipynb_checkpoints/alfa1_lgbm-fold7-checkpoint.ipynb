# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
import math
import os
import gc
import sys
import pickle
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, plot_confusion_matrix, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, CatBoostRegressor, Pool, cv, sum_models
import lightgbm as lgb
import xgboost as xgb
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
from six.moves import xrange
from sklearn import preprocessing
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
def reduce_mem_usage(df):
    """ 
    iterate through all the columns of a dataframe and 
    modify the data type to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage of dataframe is {:.2f}' 
                     'MB').format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max <\
                  np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max <\
                   np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max <\
                   np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max <\
                   np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max <\
                   np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max <\
                   np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
    end_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage after optimization is: {:.2f}' 
                              'MB').format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) 
                                             / start_mem))
    
    return df

# %%
df_train = pd.read_csv("alfa1_df_train6.csv")
df_valid = pd.read_csv("alfa1_df_valid6.csv")

# %%
df_train.fillna('nothing', inplace=True)
df_valid.fillna('nothing', inplace=True)

# %%
df_train = reduce_mem_usage(df_train)
df_valid = reduce_mem_usage(df_valid)
# Out:
# Memory usage of dataframe is 1775.78MB
# Memory usage after optimization is: 337.39MB
# Decreased by 81.0%
# Memory usage of dataframe is 49.16MB
# Memory usage after optimization is: 12.29MB
# Decreased by 75.0%

# %%
df_train_exp = pd.read_csv("alfa1_df_train10.csv")
df_valid_exp = pd.read_csv("alfa1_df_valid10.csv")

# %%
df_train_exp = reduce_mem_usage(df_train_exp)
df_valid_exp = reduce_mem_usage(df_valid_exp)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp1 = pd.read_csv("alfa1_df_train11.csv")
df_valid_exp1 = pd.read_csv("alfa1_df_valid11.csv")

# %%
df_train_exp1 = reduce_mem_usage(df_train_exp1)
df_valid_exp1 = reduce_mem_usage(df_valid_exp1)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp2 = pd.read_csv("alfa1_df_train12.csv")
df_valid_exp2 = pd.read_csv("alfa1_df_valid12.csv")

# %%
df_train_exp2 = reduce_mem_usage(df_train_exp2)
df_valid_exp2 = reduce_mem_usage(df_valid_exp2)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
aug = df_train_exp.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug1 = df_train_exp1.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug2 = df_train_exp2.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns

# %%
df_train[aug] = df_train_exp[aug]
df_valid[aug] = df_valid_exp[aug]
df_train[aug1] = df_train_exp1[aug1]
df_valid[aug1] = df_valid_exp1[aug1]
df_train[aug2] = df_train_exp2[aug2]
df_valid[aug2] = df_valid_exp2[aug2]

# %%
from_parq = ['application_id', 'event_type', 'event_category', 'event_name', 'device_screen_name', 'timezone', 'net_connection_type', 'net_connection_tech']

# %%
trn_input_lag_cols = []
for i in range(2, 36):
        trn_input_lag_cols.append(f'lag_{i}')

# %%
to_drop = []
to_drop.append('lag_1')
to_drop.append('client_pin')
to_drop.append('weight')
to_drop.append('class_weight')

# %%
categorical = trn_input_lag_cols + from_parq + ['most_popular']

# %%
df_weight = pd.DataFrame()
df_weight['lag_1'] = df_train['lag_1'].unique()
df_weight['class_weight'] = compute_class_weight(classes=df_train['lag_1'].unique(), y=df_train['lag_1'], class_weight='balanced')**0.5

# %%
df_train = df_train.merge(df_weight, how='left', on='lag_1')
df_valid = df_valid.merge(df_weight, how='left', on='lag_1')

# %%
weights = np.array(df_train['weight'])**2 * np.array(df_train['class_weight'])
weights_val = np.array(df_valid['weight'])**2 * np.array(df_valid['class_weight'])

# %%
le1 = preprocessing.LabelEncoder()
le1.fit(df_valid['lag_1'].unique())
# Out:
# LabelEncoder()

# %%
df_train['lag_1'] = le1.transform(df_train['lag_1'])
df_valid['lag_1'] = le1.transform(df_valid['lag_1'])

# %%
X, y = pd.DataFrame(pd.concat((df_valid.drop(to_drop, axis=1), df_train.drop(to_drop, axis=1))).reset_index(drop=True)), pd.concat((df_valid['lag_1'], df_train['lag_1'])).reset_index(drop=True)
weights = np.concatenate([weights_val,weights])

# %%
X['event_type'] = X['event_type'].astype('category')
X['net_connection_tech'] = X['net_connection_tech'].astype('category')

# %%
n_splits = 8
folds = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=777)

# %%
trn_idx, val_idx = list(folds.split(X, y))[7]

# %%
X, y = X.iloc[trn_idx],  y.iloc[trn_idx]
weights = weights[trn_idx, ]

# %%
lgb_train = lgb.Dataset(X, y, weight=weights)
lgb_eval = lgb.Dataset(df_valid.drop(to_drop, axis=1), df_valid['lag_1'], reference=lgb_train, weight=weights_val)

# %%
def evalerror(preds, dtrain):
    labels = dtrain.get_label()
    preds = preds.reshape(10, -1).T
    preds = preds.argmax(axis = 1)
    f_score = f1_score(labels , preds,  average = 'macro')
    return 'f1_score', f_score, True

# %%
tree_params = {
    "objective" : "multiclass",
    'metric':'custom',
    "num_class" : 10,
    'learning_rate': 0.12,
    'max_depth': 5,
    'n_jobs': 5,
    "num_leaves" : 24,
    'boosting':'dart',
    "bagging_fraction" : 0.9,  # subsample
    "feature_fraction" : 0.9,  # colsample_bytree
    "bagging_freq" : 5,        # subsample_freq
    "bagging_seed" : 2020,
    'n_estimators': 1000
}

# %%
model = lgb.train(tree_params, 
                  lgb_train,
                  feval = evalerror,
                  valid_sets=[lgb_eval],
                  early_stopping_rounds=250)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's f1_score: 0.0603859
# /opt/conda/lib/python3.7/site-packages/lightgbm/callback.py:188: UserWarning: Early stopping is not available in dart mode
#   warnings.warn('Early stopping is not available in dart mode')
# [2]	valid_0's f1_score: 0.145529
# [3]	valid_0's f1_score: 0.228689
# [4]	valid_0's f1_score: 0.31517
# [5]	valid_0's f1_score: 0.356764
# [6]	valid_0's f1_score: 0.379259
# [7]	valid_0's f1_score: 0.392187
# [8]	valid_0's f1_score: 0.383547
# [9]	valid_0's f1_score: 0.394653
# [10]	valid_0's f1_score: 0.400481
# [11]	valid_0's f1_score: 0.40469
# [12]	valid_0's f1_score: 0.402793
# [13]	valid_0's f1_score: 0.406091
# [14]	valid_0's f1_score: 0.407282
# [15]	valid_0's f1_score: 0.409652
# [16]	valid_0's f1_score: 0.412114
# [17]	valid_0's f1_score: 0.412903
# [18]	valid_0's f1_score: 0.414044
# [19]	valid_0's f1_score: 0.414942
# [20]	valid_0's f1_score: 0.415575
# [21]	valid_0's f1_score: 0.41536
# [22]	valid_0's f1_score: 0.415917
# [23]	valid_0's f1_score: 0.416549
# [24]	valid_0's f1_score: 0.416582
# [25]	valid_0's f1_score: 0.41666
# [26]	valid_0's f1_score: 0.416902
# [27]	valid_0's f1_score: 0.417042
# [28]	valid_0's f1_score: 0.417017
# [29]	valid_0's f1_score: 0.417151
# [30]	valid_0's f1_score: 0.417776
# [31]	valid_0's f1_score: 0.417982
# [32]	valid_0's f1_score: 0.418265
# [33]	valid_0's f1_score: 0.418626
# [34]	valid_0's f1_score: 0.419547
# [35]	valid_0's f1_score: 0.419073
# [110]	valid_0's f1_score: 0.42531
# [111]	valid_0's f1_score: 0.424918
# [112]	valid_0's f1_score: 0.424831
# [113]	valid_0's f1_score: 0.425004
# [114]	valid_0's f1_score: 0.425221
# [115]	valid_0's f1_score: 0.425759
# [116]	valid_0's f1_score: 0.425188
# [117]	valid_0's f1_score: 0.425262
# [118]	valid_0's f1_score: 0.425567
# [119]	valid_0's f1_score: 0.425772
# [120]	valid_0's f1_score: 0.425584
# [121]	valid_0's f1_score: 0.425737
# [122]	valid_0's f1_score: 0.425605
# [123]	valid_0's f1_score: 0.42574
# [124]	valid_0's f1_score: 0.425895
# [125]	valid_0's f1_score: 0.425839
# [126]	valid_0's f1_score: 0.42567
# [127]	valid_0's f1_score: 0.426261
# [128]	valid_0's f1_score: 0.426506
# [129]	valid_0's f1_score: 0.426489
# [130]	valid_0's f1_score: 0.426763
# [131]	valid_0's f1_score: 0.426822
# [132]	valid_0's f1_score: 0.426632
# [133]	valid_0's f1_score: 0.426929
# [134]	valid_0's f1_score: 0.426421
# [135]	valid_0's f1_score: 0.426834
# [136]	valid_0's f1_score: 0.42655
# [137]	valid_0's f1_score: 0.426716
# [138]	valid_0's f1_score: 0.426174
# [139]	valid_0's f1_score: 0.426061
# [140]	valid_0's f1_score: 0.426365
# [141]	valid_0's f1_score: 0.426528
# [142]	valid_0's f1_score: 0.426433
# [143]	valid_0's f1_score: 0.426941
# [144]	valid_0's f1_score: 0.426888
# [145]	valid_0's f1_score: 0.426983
# [146]	valid_0's f1_score: 0.426915
# [147]	valid_0's f1_score: 0.426712
# [148]	valid_0's f1_score: 0.42684
# [149]	valid_0's f1_score: 0.426718
# [150]	valid_0's f1_score: 0.427008
# [151]	valid_0's f1_score: 0.426656
# [152]	valid_0's f1_score: 0.426459
# [153]	valid_0's f1_score: 0.426765
# [154]	valid_0's f1_score: 0.426876
# [155]	valid_0's f1_score: 0.426938
# [156]	valid_0's f1_score: 0.426949
# [157]	valid_0's f1_score: 0.427129
# [158]	valid_0's f1_score: 0.427061
# [159]	valid_0's f1_score: 0.426996
# [160]	valid_0's f1_score: 0.426832
# [161]	valid_0's f1_score: 0.426535
# [162]	valid_0's f1_score: 0.426537
# [163]	valid_0's f1_score: 0.426664
# [164]	valid_0's f1_score: 0.426627
# [165]	valid_0's f1_score: 0.426256
# [166]	valid_0's f1_score: 0.426508
# [167]	valid_0's f1_score: 0.427059
# [168]	valid_0's f1_score: 0.427063
# [169]	valid_0's f1_score: 0.427353
# [170]	valid_0's f1_score: 0.427166
# [171]	valid_0's f1_score: 0.427864
# [172]	valid_0's f1_score: 0.427729
# [173]	valid_0's f1_score: 0.427832
# [174]	valid_0's f1_score: 0.428171
# [175]	valid_0's f1_score: 0.428067
# [176]	valid_0's f1_score: 0.427751
# [177]	valid_0's f1_score: 0.42786
# [178]	valid_0's f1_score: 0.42787
# [179]	valid_0's f1_score: 0.428026
# [180]	valid_0's f1_score: 0.427904
# [181]	valid_0's f1_score: 0.427907
# [182]	valid_0's f1_score: 0.428222
# [183]	valid_0's f1_score: 0.428487
# [184]	valid_0's f1_score: 0.428923
# [185]	valid_0's f1_score: 0.428638
# [186]	valid_0's f1_score: 0.428417
# [187]	valid_0's f1_score: 0.428366
# [188]	valid_0's f1_score: 0.428702
# [189]	valid_0's f1_score: 0.428714
# [190]	valid_0's f1_score: 0.428732
# [191]	valid_0's f1_score: 0.428808
# [192]	valid_0's f1_score: 0.428939
# [193]	valid_0's f1_score: 0.429094
# [194]	valid_0's f1_score: 0.429097
# [195]	valid_0's f1_score: 0.429091
# [196]	valid_0's f1_score: 0.429199
# [197]	valid_0's f1_score: 0.429161
# [198]	valid_0's f1_score: 0.429212
# [199]	valid_0's f1_score: 0.429346
# [200]	valid_0's f1_score: 0.429319
# [201]	valid_0's f1_score: 0.429325
# [202]	valid_0's f1_score: 0.429334
# [203]	valid_0's f1_score: 0.429859
# [204]	valid_0's f1_score: 0.42986
# [205]	valid_0's f1_score: 0.429174
# [206]	valid_0's f1_score: 0.429448
# [207]	valid_0's f1_score: 0.429466
# [208]	valid_0's f1_score: 0.429563
# [209]	valid_0's f1_score: 0.429519
# [210]	valid_0's f1_score: 0.429765
# [211]	valid_0's f1_score: 0.429791
# [212]	valid_0's f1_score: 0.42959
# [213]	valid_0's f1_score: 0.429392
# [214]	valid_0's f1_score: 0.429461
# [215]	valid_0's f1_score: 0.429799
# [216]	valid_0's f1_score: 0.42986
# [217]	valid_0's f1_score: 0.429933
# [218]	valid_0's f1_score: 0.430238
# [219]	valid_0's f1_score: 0.430014
# [220]	valid_0's f1_score: 0.430252
# [221]	valid_0's f1_score: 0.430262
# [222]	valid_0's f1_score: 0.430375
# [223]	valid_0's f1_score: 0.43059
# [224]	valid_0's f1_score: 0.430657
# [225]	valid_0's f1_score: 0.430736
# [226]	valid_0's f1_score: 0.430775
# [227]	valid_0's f1_score: 0.430563
# [228]	valid_0's f1_score: 0.430477
# [229]	valid_0's f1_score: 0.430723
# [230]	valid_0's f1_score: 0.430934
# [231]	valid_0's f1_score: 0.430677
# [232]	valid_0's f1_score: 0.430804
# [233]	valid_0's f1_score: 0.430885
# [234]	valid_0's f1_score: 0.430627
# [235]	valid_0's f1_score: 0.430751
# [236]	valid_0's f1_score: 0.431031
# [237]	valid_0's f1_score: 0.431202
# [238]	valid_0's f1_score: 0.431482
# [239]	valid_0's f1_score: 0.431294
# [240]	valid_0's f1_score: 0.431095
# [241]	valid_0's f1_score: 0.431056
# [242]	valid_0's f1_score: 0.431342
# [243]	valid_0's f1_score: 0.431475
# [244]	valid_0's f1_score: 0.431025
# [245]	valid_0's f1_score: 0.431371
# [246]	valid_0's f1_score: 0.431367
# [247]	valid_0's f1_score: 0.431386
# [248]	valid_0's f1_score: 0.431364
# [249]	valid_0's f1_score: 0.431384
# [250]	valid_0's f1_score: 0.431333
# [251]	valid_0's f1_score: 0.43147
# [252]	valid_0's f1_score: 0.431405
# [253]	valid_0's f1_score: 0.431523
# [254]	valid_0's f1_score: 0.43176
# [255]	valid_0's f1_score: 0.431515
# [256]	valid_0's f1_score: 0.431845
# [257]	valid_0's f1_score: 0.431994
# [258]	valid_0's f1_score: 0.43203
# [408]	valid_0's f1_score: 0.438805
# [409]	valid_0's f1_score: 0.438975
# [410]	valid_0's f1_score: 0.439005
# [411]	valid_0's f1_score: 0.439158
# [412]	valid_0's f1_score: 0.439189
# [413]	valid_0's f1_score: 0.439103
# [414]	valid_0's f1_score: 0.438965
# [415]	valid_0's f1_score: 0.438976
# [416]	valid_0's f1_score: 0.438954
# [417]	valid_0's f1_score: 0.438869
# [418]	valid_0's f1_score: 0.438865
# [419]	valid_0's f1_score: 0.439081
# [420]	valid_0's f1_score: 0.439151
# [421]	valid_0's f1_score: 0.439405
# [422]	valid_0's f1_score: 0.439385
# [423]	valid_0's f1_score: 0.439431
# [424]	valid_0's f1_score: 0.439613
# [425]	valid_0's f1_score: 0.439608
# [426]	valid_0's f1_score: 0.439598
# [427]	valid_0's f1_score: 0.439794
# [428]	valid_0's f1_score: 0.439883
# [429]	valid_0's f1_score: 0.439994
# [430]	valid_0's f1_score: 0.439858
# [431]	valid_0's f1_score: 0.440069
# [432]	valid_0's f1_score: 0.440211
# [433]	valid_0's f1_score: 0.440262
# [434]	valid_0's f1_score: 0.44025
# [435]	valid_0's f1_score: 0.44022
# [436]	valid_0's f1_score: 0.440513
# [437]	valid_0's f1_score: 0.440486
# [438]	valid_0's f1_score: 0.440524
# [439]	valid_0's f1_score: 0.440301
# [440]	valid_0's f1_score: 0.440531
# [441]	valid_0's f1_score: 0.440625
# [442]	valid_0's f1_score: 0.440912
# [443]	valid_0's f1_score: 0.441021
# [444]	valid_0's f1_score: 0.440892
# [445]	valid_0's f1_score: 0.44081
# [446]	valid_0's f1_score: 0.440833
# [447]	valid_0's f1_score: 0.44109
# [448]	valid_0's f1_score: 0.441165
# [449]	valid_0's f1_score: 0.441392
# [450]	valid_0's f1_score: 0.441673
# [451]	valid_0's f1_score: 0.441498
# [452]	valid_0's f1_score: 0.441435
# [453]	valid_0's f1_score: 0.441388
# [454]	valid_0's f1_score: 0.441514
# [455]	valid_0's f1_score: 0.441531
# [456]	valid_0's f1_score: 0.44161
# [457]	valid_0's f1_score: 0.441518
# [458]	valid_0's f1_score: 0.4415
# [459]	valid_0's f1_score: 0.441602
# [460]	valid_0's f1_score: 0.441637
# [461]	valid_0's f1_score: 0.441858
# [462]	valid_0's f1_score: 0.441663
# [463]	valid_0's f1_score: 0.4418
# [464]	valid_0's f1_score: 0.441455
# [465]	valid_0's f1_score: 0.441604
# [466]	valid_0's f1_score: 0.441597
# [467]	valid_0's f1_score: 0.44183
# [468]	valid_0's f1_score: 0.441813
# [469]	valid_0's f1_score: 0.441813
# [470]	valid_0's f1_score: 0.441683
# [471]	valid_0's f1_score: 0.441607
# [472]	valid_0's f1_score: 0.441503
# [473]	valid_0's f1_score: 0.441828
# [474]	valid_0's f1_score: 0.441804
# [475]	valid_0's f1_score: 0.441714
# [476]	valid_0's f1_score: 0.441829
# [477]	valid_0's f1_score: 0.441806
# [478]	valid_0's f1_score: 0.441818
# [479]	valid_0's f1_score: 0.441757
# [480]	valid_0's f1_score: 0.442023
# [481]	valid_0's f1_score: 0.441927
# [556]	valid_0's f1_score: 0.44441
# [557]	valid_0's f1_score: 0.444409
# [558]	valid_0's f1_score: 0.444558
# [559]	valid_0's f1_score: 0.444791
# [560]	valid_0's f1_score: 0.444753
# [561]	valid_0's f1_score: 0.444734
# [562]	valid_0's f1_score: 0.444825
# [563]	valid_0's f1_score: 0.44483
# [564]	valid_0's f1_score: 0.444724
# [565]	valid_0's f1_score: 0.444515
# [566]	valid_0's f1_score: 0.444611
# [567]	valid_0's f1_score: 0.444928
# [568]	valid_0's f1_score: 0.444935
# [569]	valid_0's f1_score: 0.444933
# [570]	valid_0's f1_score: 0.444886
# [571]	valid_0's f1_score: 0.445125
# [572]	valid_0's f1_score: 0.445165
# [573]	valid_0's f1_score: 0.445212
# [574]	valid_0's f1_score: 0.445207
# [575]	valid_0's f1_score: 0.445008
# [576]	valid_0's f1_score: 0.444905
# [577]	valid_0's f1_score: 0.444985
# [578]	valid_0's f1_score: 0.444923
# [579]	valid_0's f1_score: 0.444953
# [580]	valid_0's f1_score: 0.445
# [581]	valid_0's f1_score: 0.444934
# [582]	valid_0's f1_score: 0.444875
# [583]	valid_0's f1_score: 0.444852
# [584]	valid_0's f1_score: 0.444921
# [585]	valid_0's f1_score: 0.444939
# [586]	valid_0's f1_score: 0.444958
# [587]	valid_0's f1_score: 0.445249
# [588]	valid_0's f1_score: 0.445075
# [589]	valid_0's f1_score: 0.445026
# [590]	valid_0's f1_score: 0.444995
# [591]	valid_0's f1_score: 0.444963
# [592]	valid_0's f1_score: 0.444928
# [593]	valid_0's f1_score: 0.444931
# [594]	valid_0's f1_score: 0.445006
# [595]	valid_0's f1_score: 0.445049
# [596]	valid_0's f1_score: 0.445241
# [597]	valid_0's f1_score: 0.445185
# [598]	valid_0's f1_score: 0.444952
# [599]	valid_0's f1_score: 0.444949
# [600]	valid_0's f1_score: 0.44509
# [601]	valid_0's f1_score: 0.445051
# [602]	valid_0's f1_score: 0.445136
# [603]	valid_0's f1_score: 0.445421
# [604]	valid_0's f1_score: 0.445361
# [605]	valid_0's f1_score: 0.445314
# [606]	valid_0's f1_score: 0.44529
# [607]	valid_0's f1_score: 0.445336
# [608]	valid_0's f1_score: 0.445284
# [609]	valid_0's f1_score: 0.445317
# [610]	valid_0's f1_score: 0.445413
# [611]	valid_0's f1_score: 0.445441
# [612]	valid_0's f1_score: 0.445522
# [613]	valid_0's f1_score: 0.445543
# [614]	valid_0's f1_score: 0.445538
# [615]	valid_0's f1_score: 0.445735
# [616]	valid_0's f1_score: 0.445537
# [617]	valid_0's f1_score: 0.445454
# [618]	valid_0's f1_score: 0.445395
# [619]	valid_0's f1_score: 0.445597
# [620]	valid_0's f1_score: 0.445832
# [621]	valid_0's f1_score: 0.445721
# [622]	valid_0's f1_score: 0.445518
# [623]	valid_0's f1_score: 0.44545
# [624]	valid_0's f1_score: 0.445528
# [625]	valid_0's f1_score: 0.44554
# [626]	valid_0's f1_score: 0.445638
# [627]	valid_0's f1_score: 0.446015
# [628]	valid_0's f1_score: 0.446173
# [629]	valid_0's f1_score: 0.446144
# [630]	valid_0's f1_score: 0.445994
# [631]	valid_0's f1_score: 0.446046
# [632]	valid_0's f1_score: 0.445984
# [633]	valid_0's f1_score: 0.445968
# [634]	valid_0's f1_score: 0.445927
# [635]	valid_0's f1_score: 0.445798
# [636]	valid_0's f1_score: 0.446155
# [637]	valid_0's f1_score: 0.44639
# [638]	valid_0's f1_score: 0.446326
# [639]	valid_0's f1_score: 0.446315
# [640]	valid_0's f1_score: 0.446421
# [641]	valid_0's f1_score: 0.446137
# [642]	valid_0's f1_score: 0.44632
# [643]	valid_0's f1_score: 0.446627
# [644]	valid_0's f1_score: 0.446488
# [645]	valid_0's f1_score: 0.446673
# [646]	valid_0's f1_score: 0.446792
# [647]	valid_0's f1_score: 0.446893
# [648]	valid_0's f1_score: 0.447395
# [649]	valid_0's f1_score: 0.447229
# [650]	valid_0's f1_score: 0.44719
# [651]	valid_0's f1_score: 0.447103
# [652]	valid_0's f1_score: 0.447166
# [653]	valid_0's f1_score: 0.447043
# [654]	valid_0's f1_score: 0.447057
# [655]	valid_0's f1_score: 0.447303
# [656]	valid_0's f1_score: 0.447255
# [657]	valid_0's f1_score: 0.447243
# [658]	valid_0's f1_score: 0.447258
# [659]	valid_0's f1_score: 0.447146
# [660]	valid_0's f1_score: 0.447497
# [661]	valid_0's f1_score: 0.44754
# [662]	valid_0's f1_score: 0.447393
# [663]	valid_0's f1_score: 0.447403
# [664]	valid_0's f1_score: 0.447439
# [665]	valid_0's f1_score: 0.447393
# [666]	valid_0's f1_score: 0.44735
# [667]	valid_0's f1_score: 0.447271
# [668]	valid_0's f1_score: 0.447276
# [669]	valid_0's f1_score: 0.447051
# [670]	valid_0's f1_score: 0.447085
# [671]	valid_0's f1_score: 0.447134
# [672]	valid_0's f1_score: 0.447504
# [673]	valid_0's f1_score: 0.447326
# [674]	valid_0's f1_score: 0.447348
# [675]	valid_0's f1_score: 0.447424
# [676]	valid_0's f1_score: 0.447711
# [677]	valid_0's f1_score: 0.447673
# [678]	valid_0's f1_score: 0.4477
# [679]	valid_0's f1_score: 0.44759
# [680]	valid_0's f1_score: 0.447745
# [681]	valid_0's f1_score: 0.447654
# [682]	valid_0's f1_score: 0.447609
# [683]	valid_0's f1_score: 0.447534
# [684]	valid_0's f1_score: 0.447669
# [685]	valid_0's f1_score: 0.447549
# [686]	valid_0's f1_score: 0.447959
# [687]	valid_0's f1_score: 0.44799
# [688]	valid_0's f1_score: 0.447966
# [689]	valid_0's f1_score: 0.448027
# [690]	valid_0's f1_score: 0.448233
# [691]	valid_0's f1_score: 0.448266
# [692]	valid_0's f1_score: 0.448199
# [693]	valid_0's f1_score: 0.448333
# [694]	valid_0's f1_score: 0.448325
# [695]	valid_0's f1_score: 0.448281
# [696]	valid_0's f1_score: 0.448375
# [697]	valid_0's f1_score: 0.448401
# [698]	valid_0's f1_score: 0.448035
# [699]	valid_0's f1_score: 0.448114
# [700]	valid_0's f1_score: 0.448307
# [701]	valid_0's f1_score: 0.448342
# [702]	valid_0's f1_score: 0.448636
# [703]	valid_0's f1_score: 0.448661
# [704]	valid_0's f1_score: 0.448617
# [705]	valid_0's f1_score: 0.448576
# [706]	valid_0's f1_score: 0.448541
# [707]	valid_0's f1_score: 0.448574
# [708]	valid_0's f1_score: 0.448665
# [709]	valid_0's f1_score: 0.448611
# [710]	valid_0's f1_score: 0.449085
# [711]	valid_0's f1_score: 0.449056
# [712]	valid_0's f1_score: 0.449081
# [713]	valid_0's f1_score: 0.44902
# [714]	valid_0's f1_score: 0.449133
# [715]	valid_0's f1_score: 0.44909
# [716]	valid_0's f1_score: 0.448889
# [717]	valid_0's f1_score: 0.448708
# [718]	valid_0's f1_score: 0.448735
# [719]	valid_0's f1_score: 0.448709
# [720]	valid_0's f1_score: 0.448737
# [721]	valid_0's f1_score: 0.448607
# [722]	valid_0's f1_score: 0.448574
# [723]	valid_0's f1_score: 0.448749
# [724]	valid_0's f1_score: 0.44874
# [725]	valid_0's f1_score: 0.448671
# [726]	valid_0's f1_score: 0.448825
# [727]	valid_0's f1_score: 0.448834
# [728]	valid_0's f1_score: 0.448777
# [729]	valid_0's f1_score: 0.448773
# [730]	valid_0's f1_score: 0.448748
# [731]	valid_0's f1_score: 0.448773
# [732]	valid_0's f1_score: 0.448704
# [733]	valid_0's f1_score: 0.448837
# [734]	valid_0's f1_score: 0.448765
# [735]	valid_0's f1_score: 0.44883
# [736]	valid_0's f1_score: 0.448736
# [737]	valid_0's f1_score: 0.448676
# [738]	valid_0's f1_score: 0.448804
# [739]	valid_0's f1_score: 0.448933
# [740]	valid_0's f1_score: 0.449037
# [741]	valid_0's f1_score: 0.449018
# [742]	valid_0's f1_score: 0.449063
# [743]	valid_0's f1_score: 0.448986
# [744]	valid_0's f1_score: 0.449264
# [745]	valid_0's f1_score: 0.44905
# [746]	valid_0's f1_score: 0.449208
# [747]	valid_0's f1_score: 0.449266
# [748]	valid_0's f1_score: 0.44936
# [749]	valid_0's f1_score: 0.449322
# [750]	valid_0's f1_score: 0.449465
# [751]	valid_0's f1_score: 0.449335
# [752]	valid_0's f1_score: 0.449331
# [753]	valid_0's f1_score: 0.449482
# [754]	valid_0's f1_score: 0.449444
# [755]	valid_0's f1_score: 0.449595
# [756]	valid_0's f1_score: 0.449441
# [757]	valid_0's f1_score: 0.449532
# [758]	valid_0's f1_score: 0.449873
# [759]	valid_0's f1_score: 0.449936
# [760]	valid_0's f1_score: 0.450046
# [761]	valid_0's f1_score: 0.449909
# [762]	valid_0's f1_score: 0.450048
# [763]	valid_0's f1_score: 0.45003
# [764]	valid_0's f1_score: 0.450009
# [765]	valid_0's f1_score: 0.450005
# [766]	valid_0's f1_score: 0.450096
# [767]	valid_0's f1_score: 0.450026
# [768]	valid_0's f1_score: 0.449987
# [769]	valid_0's f1_score: 0.449958
# [770]	valid_0's f1_score: 0.45004
# [771]	valid_0's f1_score: 0.449936
# [772]	valid_0's f1_score: 0.450089
# [773]	valid_0's f1_score: 0.450033
# [774]	valid_0's f1_score: 0.450098
# [775]	valid_0's f1_score: 0.450168
# [776]	valid_0's f1_score: 0.450047
# [777]	valid_0's f1_score: 0.450155
# [778]	valid_0's f1_score: 0.450194
# [779]	valid_0's f1_score: 0.45015
# [780]	valid_0's f1_score: 0.450172
# [781]	valid_0's f1_score: 0.450295
# [782]	valid_0's f1_score: 0.450225
# [783]	valid_0's f1_score: 0.45013
# [784]	valid_0's f1_score: 0.450039
# [785]	valid_0's f1_score: 0.450521
# [786]	valid_0's f1_score: 0.450438
# [787]	valid_0's f1_score: 0.450375
# [788]	valid_0's f1_score: 0.450323
# [789]	valid_0's f1_score: 0.450459
# [790]	valid_0's f1_score: 0.45083
# [791]	valid_0's f1_score: 0.450584
# [792]	valid_0's f1_score: 0.450662
# [793]	valid_0's f1_score: 0.450935
# [794]	valid_0's f1_score: 0.450946
# [795]	valid_0's f1_score: 0.451047
# [796]	valid_0's f1_score: 0.451007
# [797]	valid_0's f1_score: 0.451002
# [798]	valid_0's f1_score: 0.450976
# [799]	valid_0's f1_score: 0.450978
# [800]	valid_0's f1_score: 0.451034
# [801]	valid_0's f1_score: 0.450942
# [802]	valid_0's f1_score: 0.451015
# [803]	valid_0's f1_score: 0.451003
# [804]	valid_0's f1_score: 0.451109
# [805]	valid_0's f1_score: 0.451102
# [806]	valid_0's f1_score: 0.451023
# [807]	valid_0's f1_score: 0.451122
# [808]	valid_0's f1_score: 0.450999
# [809]	valid_0's f1_score: 0.451017
# [810]	valid_0's f1_score: 0.450935
# [811]	valid_0's f1_score: 0.451055
# [812]	valid_0's f1_score: 0.451137
# [813]	valid_0's f1_score: 0.451055
# [814]	valid_0's f1_score: 0.451087
# [815]	valid_0's f1_score: 0.450904
# [816]	valid_0's f1_score: 0.450735
# [817]	valid_0's f1_score: 0.450695
# [818]	valid_0's f1_score: 0.450832
# [819]	valid_0's f1_score: 0.450721
# [820]	valid_0's f1_score: 0.450742
# [821]	valid_0's f1_score: 0.450907
# [822]	valid_0's f1_score: 0.450792
# [823]	valid_0's f1_score: 0.450996
# [824]	valid_0's f1_score: 0.451177
# [825]	valid_0's f1_score: 0.451139
# [826]	valid_0's f1_score: 0.451063
# [827]	valid_0's f1_score: 0.451175
# [828]	valid_0's f1_score: 0.451076
# [829]	valid_0's f1_score: 0.451158
# [830]	valid_0's f1_score: 0.451186
# [831]	valid_0's f1_score: 0.451404
# [832]	valid_0's f1_score: 0.451512
# [833]	valid_0's f1_score: 0.451426
# [834]	valid_0's f1_score: 0.451484
# [835]	valid_0's f1_score: 0.451513
# [836]	valid_0's f1_score: 0.451464
# [837]	valid_0's f1_score: 0.45153
# [838]	valid_0's f1_score: 0.451479
# [839]	valid_0's f1_score: 0.451463
# [840]	valid_0's f1_score: 0.451354
# [841]	valid_0's f1_score: 0.451562
# [842]	valid_0's f1_score: 0.451599
# [843]	valid_0's f1_score: 0.451757
# [844]	valid_0's f1_score: 0.451693
# [845]	valid_0's f1_score: 0.451729
# [846]	valid_0's f1_score: 0.45178
# [847]	valid_0's f1_score: 0.452007
# [848]	valid_0's f1_score: 0.452009
# [849]	valid_0's f1_score: 0.452082
# [850]	valid_0's f1_score: 0.452067
# [851]	valid_0's f1_score: 0.451967
# [852]	valid_0's f1_score: 0.452226
# [853]	valid_0's f1_score: 0.452187
# [854]	valid_0's f1_score: 0.452219
# [855]	valid_0's f1_score: 0.452203
# [856]	valid_0's f1_score: 0.452201
# [857]	valid_0's f1_score: 0.452209
# [858]	valid_0's f1_score: 0.452361
# [859]	valid_0's f1_score: 0.452364
# [860]	valid_0's f1_score: 0.452544
# [861]	valid_0's f1_score: 0.452838
# [862]	valid_0's f1_score: 0.4528
# [863]	valid_0's f1_score: 0.452868
# [864]	valid_0's f1_score: 0.452834
# [865]	valid_0's f1_score: 0.452603
# [866]	valid_0's f1_score: 0.452583
# [867]	valid_0's f1_score: 0.452815
# [868]	valid_0's f1_score: 0.452855
# [869]	valid_0's f1_score: 0.453043
# [870]	valid_0's f1_score: 0.453017
# [871]	valid_0's f1_score: 0.453075
# [872]	valid_0's f1_score: 0.453106
# [873]	valid_0's f1_score: 0.45305
# [874]	valid_0's f1_score: 0.453205
# [875]	valid_0's f1_score: 0.453246
# [876]	valid_0's f1_score: 0.453353
# [877]	valid_0's f1_score: 0.453288
# [878]	valid_0's f1_score: 0.453498
# [879]	valid_0's f1_score: 0.453471
# [880]	valid_0's f1_score: 0.453419
# [881]	valid_0's f1_score: 0.453351
# [882]	valid_0's f1_score: 0.453288
# [883]	valid_0's f1_score: 0.453258
# [884]	valid_0's f1_score: 0.45354
# [885]	valid_0's f1_score: 0.453656
# [886]	valid_0's f1_score: 0.453695
# [887]	valid_0's f1_score: 0.453631
# [888]	valid_0's f1_score: 0.453717
# [889]	valid_0's f1_score: 0.453684
# [890]	valid_0's f1_score: 0.453989
# [891]	valid_0's f1_score: 0.454259
# [892]	valid_0's f1_score: 0.454109
# [893]	valid_0's f1_score: 0.454134
# [894]	valid_0's f1_score: 0.454018
# [895]	valid_0's f1_score: 0.45404
# [896]	valid_0's f1_score: 0.454042
# [897]	valid_0's f1_score: 0.454053
# [898]	valid_0's f1_score: 0.454101
# [899]	valid_0's f1_score: 0.454065
# [900]	valid_0's f1_score: 0.454123
# [901]	valid_0's f1_score: 0.454105
# [902]	valid_0's f1_score: 0.454118
# [903]	valid_0's f1_score: 0.454375
# [904]	valid_0's f1_score: 0.454421
# [905]	valid_0's f1_score: 0.454442
# [906]	valid_0's f1_score: 0.454355
# [907]	valid_0's f1_score: 0.454692
# [908]	valid_0's f1_score: 0.454621
# [909]	valid_0's f1_score: 0.454503
# [910]	valid_0's f1_score: 0.454419
# [911]	valid_0's f1_score: 0.454373
# [912]	valid_0's f1_score: 0.454333
# [913]	valid_0's f1_score: 0.454391
# [914]	valid_0's f1_score: 0.454288
# [915]	valid_0's f1_score: 0.454448
# [916]	valid_0's f1_score: 0.454342
# [917]	valid_0's f1_score: 0.454308
# [918]	valid_0's f1_score: 0.454236
# [919]	valid_0's f1_score: 0.454115
# [921]	valid_0's f1_score: 0.454184
# [922]	valid_0's f1_score: 0.45407
# [923]	valid_0's f1_score: 0.454134
# [924]	valid_0's f1_score: 0.454347
# [925]	valid_0's f1_score: 0.454607
# [926]	valid_0's f1_score: 0.454677
# [927]	valid_0's f1_score: 0.454711
# [928]	valid_0's f1_score: 0.454743
# [929]	valid_0's f1_score: 0.454961
# [930]	valid_0's f1_score: 0.455315
# [931]	valid_0's f1_score: 0.455315
# [932]	valid_0's f1_score: 0.455272
# [933]	valid_0's f1_score: 0.455335
# [934]	valid_0's f1_score: 0.455276
# [935]	valid_0's f1_score: 0.455258
# [936]	valid_0's f1_score: 0.455252
# [937]	valid_0's f1_score: 0.455273
# [938]	valid_0's f1_score: 0.455581
# [939]	valid_0's f1_score: 0.455571
# [940]	valid_0's f1_score: 0.455494
# [941]	valid_0's f1_score: 0.45542
# [942]	valid_0's f1_score: 0.455427
# [943]	valid_0's f1_score: 0.455503
# [944]	valid_0's f1_score: 0.455656
# [945]	valid_0's f1_score: 0.455529
# [946]	valid_0's f1_score: 0.455511
# [947]	valid_0's f1_score: 0.455951
# [948]	valid_0's f1_score: 0.456007
# [949]	valid_0's f1_score: 0.455986
# [950]	valid_0's f1_score: 0.456586
# [951]	valid_0's f1_score: 0.456564
# [952]	valid_0's f1_score: 0.456586
# [953]	valid_0's f1_score: 0.456408
# [954]	valid_0's f1_score: 0.456414
# [955]	valid_0's f1_score: 0.456367
# [956]	valid_0's f1_score: 0.456351
# [957]	valid_0's f1_score: 0.456547
# [958]	valid_0's f1_score: 0.456564
# [959]	valid_0's f1_score: 0.456123
# [960]	valid_0's f1_score: 0.456314
# [961]	valid_0's f1_score: 0.456534
# [962]	valid_0's f1_score: 0.45672
# [963]	valid_0's f1_score: 0.456787
# [964]	valid_0's f1_score: 0.456709
# [965]	valid_0's f1_score: 0.456695
# [966]	valid_0's f1_score: 0.456657
# [967]	valid_0's f1_score: 0.456637
# [968]	valid_0's f1_score: 0.456619
# [969]	valid_0's f1_score: 0.456493
# [970]	valid_0's f1_score: 0.456733
# [971]	valid_0's f1_score: 0.456844
# [972]	valid_0's f1_score: 0.457029
# [973]	valid_0's f1_score: 0.456971
# [974]	valid_0's f1_score: 0.457028
# [975]	valid_0's f1_score: 0.45702
# [976]	valid_0's f1_score: 0.457149
# [977]	valid_0's f1_score: 0.457034
# [978]	valid_0's f1_score: 0.457047
# [979]	valid_0's f1_score: 0.457194
# [980]	valid_0's f1_score: 0.457139
# [981]	valid_0's f1_score: 0.457201
# [982]	valid_0's f1_score: 0.457121
# [983]	valid_0's f1_score: 0.457236
# [984]	valid_0's f1_score: 0.457369
# [985]	valid_0's f1_score: 0.457398
# [986]	valid_0's f1_score: 0.457465
# [987]	valid_0's f1_score: 0.45738
# [988]	valid_0's f1_score: 0.457439
# [989]	valid_0's f1_score: 0.457366
# [990]	valid_0's f1_score: 0.457322
# [991]	valid_0's f1_score: 0.457351
# [992]	valid_0's f1_score: 0.457347
# [993]	valid_0's f1_score: 0.457334
# [994]	valid_0's f1_score: 0.457354
# [995]	valid_0's f1_score: 0.457294
# [996]	valid_0's f1_score: 0.457212
# [997]	valid_0's f1_score: 0.45772
# [998]	valid_0's f1_score: 0.457546
# [999]	valid_0's f1_score: 0.457682
# [1000]	valid_0's f1_score: 0.457652

# %%
with open('lgb_model8_fold7.pkl', 'wb') as fout:
    pickle.dump(model, fout)
