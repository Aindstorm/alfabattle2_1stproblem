# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
import math
import os
import gc
import sys
import pickle
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, plot_confusion_matrix, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, CatBoostRegressor, Pool, cv, sum_models
import lightgbm as lgb
import xgboost as xgb
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
from six.moves import xrange
from sklearn import preprocessing
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
def reduce_mem_usage(df):
    """ 
    iterate through all the columns of a dataframe and 
    modify the data type to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage of dataframe is {:.2f}' 
                     'MB').format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max <\
                  np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max <\
                   np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max <\
                   np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max <\
                   np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max <\
                   np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max <\
                   np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
    end_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage after optimization is: {:.2f}' 
                              'MB').format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) 
                                             / start_mem))
    
    return df

# %%
df_train = pd.read_csv("alfa1_df_train6.csv")
df_valid = pd.read_csv("alfa1_df_valid6.csv")

# %%
df_train.fillna('nothing', inplace=True)
df_valid.fillna('nothing', inplace=True)

# %%
df_train = reduce_mem_usage(df_train)
df_valid = reduce_mem_usage(df_valid)
# Out:
# Memory usage of dataframe is 1775.78MB
# Memory usage after optimization is: 337.39MB
# Decreased by 81.0%
# Memory usage of dataframe is 49.16MB
# Memory usage after optimization is: 12.29MB
# Decreased by 75.0%

# %%
df_train_exp = pd.read_csv("alfa1_df_train10.csv")
df_valid_exp = pd.read_csv("alfa1_df_valid10.csv")

# %%
df_train_exp = reduce_mem_usage(df_train_exp)
df_valid_exp = reduce_mem_usage(df_valid_exp)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp1 = pd.read_csv("alfa1_df_train11.csv")
df_valid_exp1 = pd.read_csv("alfa1_df_valid11.csv")

# %%
df_train_exp1 = reduce_mem_usage(df_train_exp1)
df_valid_exp1 = reduce_mem_usage(df_valid_exp1)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp2 = pd.read_csv("alfa1_df_train12.csv")
df_valid_exp2 = pd.read_csv("alfa1_df_valid12.csv")

# %%
df_train_exp2 = reduce_mem_usage(df_train_exp2)
df_valid_exp2 = reduce_mem_usage(df_valid_exp2)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
aug = df_train_exp.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug1 = df_train_exp1.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug2 = df_train_exp2.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns

# %%
df_train[aug] = df_train_exp[aug]
df_valid[aug] = df_valid_exp[aug]
df_train[aug1] = df_train_exp1[aug1]
df_valid[aug1] = df_valid_exp1[aug1]
df_train[aug2] = df_train_exp2[aug2]
df_valid[aug2] = df_valid_exp2[aug2]

# %%
from_parq = ['application_id', 'event_type', 'event_category', 'event_name', 'device_screen_name', 'timezone', 'net_connection_type', 'net_connection_tech']

# %%
trn_input_lag_cols = []
for i in range(2, 36):
        trn_input_lag_cols.append(f'lag_{i}')

# %%
to_drop = []
to_drop.append('lag_1')
to_drop.append('client_pin')
to_drop.append('weight')
to_drop.append('class_weight')

# %%
categorical = trn_input_lag_cols + from_parq + ['most_popular']

# %%
df_weight = pd.DataFrame()
df_weight['lag_1'] = df_train['lag_1'].unique()
df_weight['class_weight'] = compute_class_weight(classes=df_train['lag_1'].unique(), y=df_train['lag_1'], class_weight='balanced')**0.5

# %%
df_train = df_train.merge(df_weight, how='left', on='lag_1')
df_valid = df_valid.merge(df_weight, how='left', on='lag_1')

# %%
weights = np.array(df_train['weight'])**2 * np.array(df_train['class_weight'])
weights_val = np.array(df_valid['weight'])**2 * np.array(df_valid['class_weight'])

# %%
le1 = preprocessing.LabelEncoder()
le1.fit(df_valid['lag_1'].unique())
# Out:
# LabelEncoder()

# %%
df_train['lag_1'] = le1.transform(df_train['lag_1'])
df_valid['lag_1'] = le1.transform(df_valid['lag_1'])

# %%
X, y = pd.DataFrame(pd.concat((df_valid.drop(to_drop, axis=1), df_train.drop(to_drop, axis=1))).reset_index(drop=True)), pd.concat((df_valid['lag_1'], df_train['lag_1'])).reset_index(drop=True)
weights = np.concatenate([weights_val,weights])

# %%
X['event_type'] = X['event_type'].astype('category')
X['net_connection_tech'] = X['net_connection_tech'].astype('category')

# %%
n_splits = 8
folds = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=777)

# %%
trn_idx, val_idx = list(folds.split(X, y))[3]

# %%
X, y = X.iloc[trn_idx],  y.iloc[trn_idx]
weights = weights[trn_idx, ]

# %%
lgb_train = lgb.Dataset(X, y, weight=weights)
lgb_eval = lgb.Dataset(df_valid.drop(to_drop, axis=1), df_valid['lag_1'], reference=lgb_train, weight=weights_val)

# %%
def evalerror(preds, dtrain):
    labels = dtrain.get_label()
    preds = preds.reshape(10, -1).T
    preds = preds.argmax(axis = 1)
    f_score = f1_score(labels , preds,  average = 'macro')
    return 'f1_score', f_score, True

# %%
tree_params = {
    "objective" : "multiclass",
    'metric':'custom',
    "num_class" : 10,
    'learning_rate': 0.12,
    'max_depth': 5,
    'n_jobs': 5,
    "num_leaves" : 24,
    'boosting':'dart',
    "bagging_fraction" : 0.9,  # subsample
    "feature_fraction" : 0.9,  # colsample_bytree
    "bagging_freq" : 5,        # subsample_freq
    "bagging_seed" : 2020,
    'n_estimators': 1000
}

# %%
model = lgb.train(tree_params, 
                  lgb_train,
                  feval = evalerror,
                  valid_sets=[lgb_eval],
                  early_stopping_rounds=250)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's f1_score: 0.0603859
# /opt/conda/lib/python3.7/site-packages/lightgbm/callback.py:188: UserWarning: Early stopping is not available in dart mode
#   warnings.warn('Early stopping is not available in dart mode')
# [2]	valid_0's f1_score: 0.142518
# [3]	valid_0's f1_score: 0.232785
# [4]	valid_0's f1_score: 0.315113
# [5]	valid_0's f1_score: 0.358312
# [6]	valid_0's f1_score: 0.37966
# [7]	valid_0's f1_score: 0.390235
# [8]	valid_0's f1_score: 0.383309
# [9]	valid_0's f1_score: 0.392596
# [10]	valid_0's f1_score: 0.400403
# [11]	valid_0's f1_score: 0.405062
# [12]	valid_0's f1_score: 0.402882
# [13]	valid_0's f1_score: 0.407059
# [14]	valid_0's f1_score: 0.408921
# [15]	valid_0's f1_score: 0.410363
# [16]	valid_0's f1_score: 0.411725
# [17]	valid_0's f1_score: 0.413035
# [18]	valid_0's f1_score: 0.414
# [19]	valid_0's f1_score: 0.414922
# [20]	valid_0's f1_score: 0.415849
# [21]	valid_0's f1_score: 0.41601
# [22]	valid_0's f1_score: 0.41586
# [23]	valid_0's f1_score: 0.416412
# [24]	valid_0's f1_score: 0.417107
# [25]	valid_0's f1_score: 0.417589
# [26]	valid_0's f1_score: 0.418065
# [27]	valid_0's f1_score: 0.418261
# [28]	valid_0's f1_score: 0.418207
# [29]	valid_0's f1_score: 0.418334
# [30]	valid_0's f1_score: 0.418357
# [31]	valid_0's f1_score: 0.418751
# [32]	valid_0's f1_score: 0.418734
# [33]	valid_0's f1_score: 0.419113
# [34]	valid_0's f1_score: 0.419618
# [35]	valid_0's f1_score: 0.419633
# [36]	valid_0's f1_score: 0.419559
# [37]	valid_0's f1_score: 0.419702
# [38]	valid_0's f1_score: 0.420375
# [39]	valid_0's f1_score: 0.420415
# [40]	valid_0's f1_score: 0.420583
# [41]	valid_0's f1_score: 0.420465
# [42]	valid_0's f1_score: 0.420741
# [43]	valid_0's f1_score: 0.420615
# [44]	valid_0's f1_score: 0.420733
# [45]	valid_0's f1_score: 0.421546
# [46]	valid_0's f1_score: 0.420877
# [47]	valid_0's f1_score: 0.421141
# [48]	valid_0's f1_score: 0.421176
# [49]	valid_0's f1_score: 0.421475
# [50]	valid_0's f1_score: 0.421417
# [51]	valid_0's f1_score: 0.421432
# [52]	valid_0's f1_score: 0.421881
# [53]	valid_0's f1_score: 0.421734
# [54]	valid_0's f1_score: 0.42168
# [55]	valid_0's f1_score: 0.421656
# [56]	valid_0's f1_score: 0.422055
# [57]	valid_0's f1_score: 0.421885
# [58]	valid_0's f1_score: 0.420354
# [59]	valid_0's f1_score: 0.421032
# [60]	valid_0's f1_score: 0.421074
# [61]	valid_0's f1_score: 0.420031
# [62]	valid_0's f1_score: 0.420426
# [63]	valid_0's f1_score: 0.420311
# [64]	valid_0's f1_score: 0.420457
# [65]	valid_0's f1_score: 0.420274
# [66]	valid_0's f1_score: 0.421246
# [67]	valid_0's f1_score: 0.42096
# [68]	valid_0's f1_score: 0.421411
# [69]	valid_0's f1_score: 0.421375
# [70]	valid_0's f1_score: 0.421675
# [71]	valid_0's f1_score: 0.422053
# [72]	valid_0's f1_score: 0.422329
# [73]	valid_0's f1_score: 0.422637
# [74]	valid_0's f1_score: 0.422485
# [75]	valid_0's f1_score: 0.422506
# [76]	valid_0's f1_score: 0.422566
# [77]	valid_0's f1_score: 0.422691
# [78]	valid_0's f1_score: 0.422944
# [79]	valid_0's f1_score: 0.423143
# [80]	valid_0's f1_score: 0.423226
# [81]	valid_0's f1_score: 0.423426
# [82]	valid_0's f1_score: 0.423655
# [83]	valid_0's f1_score: 0.423621
# [84]	valid_0's f1_score: 0.423648
# [85]	valid_0's f1_score: 0.423511
# [86]	valid_0's f1_score: 0.423479
# [87]	valid_0's f1_score: 0.423677
# [88]	valid_0's f1_score: 0.424029
# [89]	valid_0's f1_score: 0.423944
# [90]	valid_0's f1_score: 0.423792
# [91]	valid_0's f1_score: 0.423605
# [92]	valid_0's f1_score: 0.423584
# [93]	valid_0's f1_score: 0.423701
# [94]	valid_0's f1_score: 0.42353
# [95]	valid_0's f1_score: 0.423413
# [96]	valid_0's f1_score: 0.423584
# [97]	valid_0's f1_score: 0.423584
# [98]	valid_0's f1_score: 0.42363
# [99]	valid_0's f1_score: 0.423564
# [100]	valid_0's f1_score: 0.423926
# [101]	valid_0's f1_score: 0.423742
# [102]	valid_0's f1_score: 0.423701
# [103]	valid_0's f1_score: 0.423975
# [104]	valid_0's f1_score: 0.423583
# [105]	valid_0's f1_score: 0.423124
# [106]	valid_0's f1_score: 0.423508
# [107]	valid_0's f1_score: 0.423385
# [108]	valid_0's f1_score: 0.423483
# [109]	valid_0's f1_score: 0.423429
# [185]	valid_0's f1_score: 0.428291
# [186]	valid_0's f1_score: 0.428259
# [187]	valid_0's f1_score: 0.428205
# [188]	valid_0's f1_score: 0.428675
# [189]	valid_0's f1_score: 0.428448
# [190]	valid_0's f1_score: 0.428379
# [191]	valid_0's f1_score: 0.428329
# [192]	valid_0's f1_score: 0.428484
# [193]	valid_0's f1_score: 0.428288
# [194]	valid_0's f1_score: 0.428345
# [195]	valid_0's f1_score: 0.428411
# [196]	valid_0's f1_score: 0.428629
# [197]	valid_0's f1_score: 0.428525
# [198]	valid_0's f1_score: 0.428626
# [199]	valid_0's f1_score: 0.429026
# [200]	valid_0's f1_score: 0.428933
# [201]	valid_0's f1_score: 0.428741
# [202]	valid_0's f1_score: 0.428666
# [203]	valid_0's f1_score: 0.42856
# [204]	valid_0's f1_score: 0.428521
# [205]	valid_0's f1_score: 0.428444
# [206]	valid_0's f1_score: 0.428417
# [207]	valid_0's f1_score: 0.428317
# [208]	valid_0's f1_score: 0.428604
# [209]	valid_0's f1_score: 0.428494
# [210]	valid_0's f1_score: 0.428343
# [211]	valid_0's f1_score: 0.428445
# [212]	valid_0's f1_score: 0.428545
# [213]	valid_0's f1_score: 0.428603
# [214]	valid_0's f1_score: 0.428784
# [215]	valid_0's f1_score: 0.428945
# [216]	valid_0's f1_score: 0.428963
# [217]	valid_0's f1_score: 0.429357
# [218]	valid_0's f1_score: 0.429208
# [219]	valid_0's f1_score: 0.428654
# [220]	valid_0's f1_score: 0.429111
# [221]	valid_0's f1_score: 0.429029
# [222]	valid_0's f1_score: 0.429056
# [223]	valid_0's f1_score: 0.429164
# [224]	valid_0's f1_score: 0.429027
# [225]	valid_0's f1_score: 0.42899
# [226]	valid_0's f1_score: 0.428947
# [227]	valid_0's f1_score: 0.429002
# [228]	valid_0's f1_score: 0.429231
# [229]	valid_0's f1_score: 0.429289
# [230]	valid_0's f1_score: 0.429386
# [231]	valid_0's f1_score: 0.42961
# [232]	valid_0's f1_score: 0.429878
# [233]	valid_0's f1_score: 0.429634
# [234]	valid_0's f1_score: 0.429378
# [235]	valid_0's f1_score: 0.429478
# [236]	valid_0's f1_score: 0.42954
# [237]	valid_0's f1_score: 0.429863
# [238]	valid_0's f1_score: 0.42967
# [239]	valid_0's f1_score: 0.429831
# [240]	valid_0's f1_score: 0.430027
# [241]	valid_0's f1_score: 0.429961
# [242]	valid_0's f1_score: 0.430308
# [243]	valid_0's f1_score: 0.430272
# [244]	valid_0's f1_score: 0.429898
# [245]	valid_0's f1_score: 0.430182
# [246]	valid_0's f1_score: 0.430861
# [247]	valid_0's f1_score: 0.430778
# [248]	valid_0's f1_score: 0.430737
# [249]	valid_0's f1_score: 0.430691
# [250]	valid_0's f1_score: 0.430815
# [251]	valid_0's f1_score: 0.430719
# [252]	valid_0's f1_score: 0.430723
# [253]	valid_0's f1_score: 0.430883
# [254]	valid_0's f1_score: 0.431075
# [255]	valid_0's f1_score: 0.431024
# [256]	valid_0's f1_score: 0.431026
# [257]	valid_0's f1_score: 0.431146
# [258]	valid_0's f1_score: 0.431248
# [408]	valid_0's f1_score: 0.436856
# [409]	valid_0's f1_score: 0.437112
# [410]	valid_0's f1_score: 0.437031
# [411]	valid_0's f1_score: 0.436951
# [412]	valid_0's f1_score: 0.437011
# [413]	valid_0's f1_score: 0.437091
# [414]	valid_0's f1_score: 0.437097
# [415]	valid_0's f1_score: 0.4372
# [416]	valid_0's f1_score: 0.437428
# [417]	valid_0's f1_score: 0.437325
# [418]	valid_0's f1_score: 0.43731
# [419]	valid_0's f1_score: 0.437409
# [420]	valid_0's f1_score: 0.437311
# [421]	valid_0's f1_score: 0.437339
# [422]	valid_0's f1_score: 0.437505
# [423]	valid_0's f1_score: 0.437708
# [424]	valid_0's f1_score: 0.437848
# [425]	valid_0's f1_score: 0.437579
# [426]	valid_0's f1_score: 0.437501
# [427]	valid_0's f1_score: 0.437726
# [428]	valid_0's f1_score: 0.437845
# [429]	valid_0's f1_score: 0.437748
# [430]	valid_0's f1_score: 0.437707
# [431]	valid_0's f1_score: 0.437857
# [432]	valid_0's f1_score: 0.438152
# [433]	valid_0's f1_score: 0.437914
# [434]	valid_0's f1_score: 0.437891
# [435]	valid_0's f1_score: 0.437875
# [436]	valid_0's f1_score: 0.43831
# [437]	valid_0's f1_score: 0.438162
# [438]	valid_0's f1_score: 0.438213
# [439]	valid_0's f1_score: 0.438222
# [440]	valid_0's f1_score: 0.4384
# [441]	valid_0's f1_score: 0.438707
# [442]	valid_0's f1_score: 0.438654
# [443]	valid_0's f1_score: 0.438594
# [444]	valid_0's f1_score: 0.438508
# [445]	valid_0's f1_score: 0.438473
# [446]	valid_0's f1_score: 0.43843
# [447]	valid_0's f1_score: 0.438546
# [448]	valid_0's f1_score: 0.438455
# [449]	valid_0's f1_score: 0.438296
# [450]	valid_0's f1_score: 0.438596
# [451]	valid_0's f1_score: 0.438668
# [452]	valid_0's f1_score: 0.43873
# [453]	valid_0's f1_score: 0.438681
# [454]	valid_0's f1_score: 0.43862
# [455]	valid_0's f1_score: 0.438694
# [456]	valid_0's f1_score: 0.438629
# [457]	valid_0's f1_score: 0.438646
# [458]	valid_0's f1_score: 0.438689
# [459]	valid_0's f1_score: 0.438727
# [460]	valid_0's f1_score: 0.43874
# [461]	valid_0's f1_score: 0.438901
# [462]	valid_0's f1_score: 0.438892
# [463]	valid_0's f1_score: 0.43885
# [464]	valid_0's f1_score: 0.439098
# [465]	valid_0's f1_score: 0.439569
# [466]	valid_0's f1_score: 0.439485
# [467]	valid_0's f1_score: 0.439849
# [468]	valid_0's f1_score: 0.439782
# [469]	valid_0's f1_score: 0.439799
# [470]	valid_0's f1_score: 0.439427
# [471]	valid_0's f1_score: 0.439508
# [472]	valid_0's f1_score: 0.439435
# [473]	valid_0's f1_score: 0.439645
# [474]	valid_0's f1_score: 0.440024
# [475]	valid_0's f1_score: 0.440374
# [476]	valid_0's f1_score: 0.440363
# [477]	valid_0's f1_score: 0.440518
# [478]	valid_0's f1_score: 0.44043
# [479]	valid_0's f1_score: 0.440386
# [480]	valid_0's f1_score: 0.440461
# [481]	valid_0's f1_score: 0.440318
# [482]	valid_0's f1_score: 0.440552
# [483]	valid_0's f1_score: 0.440629
# [484]	valid_0's f1_score: 0.440711
# [485]	valid_0's f1_score: 0.440781
# [486]	valid_0's f1_score: 0.440937
# [487]	valid_0's f1_score: 0.441209
# [488]	valid_0's f1_score: 0.441173
# [489]	valid_0's f1_score: 0.44137
# [490]	valid_0's f1_score: 0.441291
# [491]	valid_0's f1_score: 0.441248
# [492]	valid_0's f1_score: 0.441255
# [493]	valid_0's f1_score: 0.441174
# [494]	valid_0's f1_score: 0.441083
# [495]	valid_0's f1_score: 0.441293
# [496]	valid_0's f1_score: 0.441568
# [497]	valid_0's f1_score: 0.441661
# [498]	valid_0's f1_score: 0.441812
# [499]	valid_0's f1_score: 0.441629
# [500]	valid_0's f1_score: 0.441752
# [501]	valid_0's f1_score: 0.441811
# [502]	valid_0's f1_score: 0.441577
# [503]	valid_0's f1_score: 0.441791
# [504]	valid_0's f1_score: 0.441762
# [505]	valid_0's f1_score: 0.441784
# [506]	valid_0's f1_score: 0.441568
# [507]	valid_0's f1_score: 0.44154
# [508]	valid_0's f1_score: 0.441689
# [509]	valid_0's f1_score: 0.44193
# [510]	valid_0's f1_score: 0.442047
# [511]	valid_0's f1_score: 0.441994
# [512]	valid_0's f1_score: 0.442219
# [513]	valid_0's f1_score: 0.442015
# [514]	valid_0's f1_score: 0.441862
# [515]	valid_0's f1_score: 0.442278
# [516]	valid_0's f1_score: 0.442194
# [517]	valid_0's f1_score: 0.442206
# [518]	valid_0's f1_score: 0.442177
# [519]	valid_0's f1_score: 0.442258
# [520]	valid_0's f1_score: 0.442297
# [521]	valid_0's f1_score: 0.442247
# [522]	valid_0's f1_score: 0.442105
# [523]	valid_0's f1_score: 0.442176
# [524]	valid_0's f1_score: 0.442448
# [525]	valid_0's f1_score: 0.442308
# [526]	valid_0's f1_score: 0.442144
# [527]	valid_0's f1_score: 0.441965
# [528]	valid_0's f1_score: 0.442171
# [529]	valid_0's f1_score: 0.442363
# [530]	valid_0's f1_score: 0.442621
# [531]	valid_0's f1_score: 0.44261
# [532]	valid_0's f1_score: 0.442691
# [533]	valid_0's f1_score: 0.442685
# [534]	valid_0's f1_score: 0.44271
# [535]	valid_0's f1_score: 0.442952
# [536]	valid_0's f1_score: 0.442947
# [537]	valid_0's f1_score: 0.442893
# [538]	valid_0's f1_score: 0.44299
# [539]	valid_0's f1_score: 0.443005
# [540]	valid_0's f1_score: 0.442952
# [541]	valid_0's f1_score: 0.44281
# [542]	valid_0's f1_score: 0.443185
# [543]	valid_0's f1_score: 0.443181
# [544]	valid_0's f1_score: 0.443027
# [545]	valid_0's f1_score: 0.443381
# [546]	valid_0's f1_score: 0.443429
# [547]	valid_0's f1_score: 0.443736
# [548]	valid_0's f1_score: 0.443739
# [549]	valid_0's f1_score: 0.443746
# [550]	valid_0's f1_score: 0.44373
# [551]	valid_0's f1_score: 0.443804
# [552]	valid_0's f1_score: 0.443928
# [553]	valid_0's f1_score: 0.443845
# [554]	valid_0's f1_score: 0.443895
# [555]	valid_0's f1_score: 0.443953
# [556]	valid_0's f1_score: 0.443886
# [557]	valid_0's f1_score: 0.443877
# [558]	valid_0's f1_score: 0.444113
# [559]	valid_0's f1_score: 0.444295
# [560]	valid_0's f1_score: 0.444414
# [561]	valid_0's f1_score: 0.444358
# [562]	valid_0's f1_score: 0.444297
# [563]	valid_0's f1_score: 0.444249
# [564]	valid_0's f1_score: 0.444183
# [565]	valid_0's f1_score: 0.444191
# [566]	valid_0's f1_score: 0.444338
# [567]	valid_0's f1_score: 0.444244
# [568]	valid_0's f1_score: 0.444327
# [569]	valid_0's f1_score: 0.444346
# [570]	valid_0's f1_score: 0.444373
# [571]	valid_0's f1_score: 0.444262
# [572]	valid_0's f1_score: 0.444385
# [573]	valid_0's f1_score: 0.444158
# [574]	valid_0's f1_score: 0.444225
# [575]	valid_0's f1_score: 0.444513
# [576]	valid_0's f1_score: 0.444531
# [577]	valid_0's f1_score: 0.444626
# [578]	valid_0's f1_score: 0.444535
# [579]	valid_0's f1_score: 0.444583
# [580]	valid_0's f1_score: 0.444489
# [581]	valid_0's f1_score: 0.444287
# [582]	valid_0's f1_score: 0.44425
# [583]	valid_0's f1_score: 0.444034
# [584]	valid_0's f1_score: 0.443997
# [585]	valid_0's f1_score: 0.4441
# [586]	valid_0's f1_score: 0.444281
# [587]	valid_0's f1_score: 0.443828
# [588]	valid_0's f1_score: 0.443906
# [589]	valid_0's f1_score: 0.443912
# [590]	valid_0's f1_score: 0.443909
# [591]	valid_0's f1_score: 0.443948
# [592]	valid_0's f1_score: 0.443836
# [593]	valid_0's f1_score: 0.444434
# [594]	valid_0's f1_score: 0.444366
# [595]	valid_0's f1_score: 0.444294
# [596]	valid_0's f1_score: 0.444448
# [597]	valid_0's f1_score: 0.444399
# [598]	valid_0's f1_score: 0.444343
# [599]	valid_0's f1_score: 0.444495
# [600]	valid_0's f1_score: 0.444892
# [601]	valid_0's f1_score: 0.444668
# [602]	valid_0's f1_score: 0.444594
# [603]	valid_0's f1_score: 0.444569
# [604]	valid_0's f1_score: 0.444596
# [605]	valid_0's f1_score: 0.444541
# [606]	valid_0's f1_score: 0.444367
# [607]	valid_0's f1_score: 0.444505
# [608]	valid_0's f1_score: 0.444724
# [609]	valid_0's f1_score: 0.444398
# [610]	valid_0's f1_score: 0.444783
# [611]	valid_0's f1_score: 0.444801
# [612]	valid_0's f1_score: 0.445075
# [613]	valid_0's f1_score: 0.445059
# [614]	valid_0's f1_score: 0.445331
# [615]	valid_0's f1_score: 0.445059
# [616]	valid_0's f1_score: 0.445072
# [617]	valid_0's f1_score: 0.44495
# [618]	valid_0's f1_score: 0.44492
# [619]	valid_0's f1_score: 0.444895
# [620]	valid_0's f1_score: 0.445014
# [621]	valid_0's f1_score: 0.444982
# [622]	valid_0's f1_score: 0.444897
# [623]	valid_0's f1_score: 0.445098
# [624]	valid_0's f1_score: 0.44501
# [625]	valid_0's f1_score: 0.445109
# [626]	valid_0's f1_score: 0.445229
# [627]	valid_0's f1_score: 0.445025
# [628]	valid_0's f1_score: 0.445199
# [629]	valid_0's f1_score: 0.445111
# [630]	valid_0's f1_score: 0.44512
# [631]	valid_0's f1_score: 0.445068
# [632]	valid_0's f1_score: 0.445232
# [633]	valid_0's f1_score: 0.445155
# [634]	valid_0's f1_score: 0.445241
# [635]	valid_0's f1_score: 0.44514
# [636]	valid_0's f1_score: 0.44515
# [637]	valid_0's f1_score: 0.445172
# [638]	valid_0's f1_score: 0.445227
# [639]	valid_0's f1_score: 0.445157
# [640]	valid_0's f1_score: 0.445527
# [641]	valid_0's f1_score: 0.445427
# [642]	valid_0's f1_score: 0.445618
# [643]	valid_0's f1_score: 0.445582
# [644]	valid_0's f1_score: 0.445627
# [645]	valid_0's f1_score: 0.44536
# [646]	valid_0's f1_score: 0.445533
# [647]	valid_0's f1_score: 0.445596
# [648]	valid_0's f1_score: 0.44571
# [649]	valid_0's f1_score: 0.445637
# [650]	valid_0's f1_score: 0.445558
# [651]	valid_0's f1_score: 0.445747
# [652]	valid_0's f1_score: 0.445706
# [653]	valid_0's f1_score: 0.445784
# [654]	valid_0's f1_score: 0.445685
# [655]	valid_0's f1_score: 0.445877
# [656]	valid_0's f1_score: 0.446048
# [657]	valid_0's f1_score: 0.446143
# [658]	valid_0's f1_score: 0.446284
# [659]	valid_0's f1_score: 0.446266
# [660]	valid_0's f1_score: 0.446246
# [661]	valid_0's f1_score: 0.446221
# [662]	valid_0's f1_score: 0.446302
# [663]	valid_0's f1_score: 0.446232
# [664]	valid_0's f1_score: 0.44636
# [665]	valid_0's f1_score: 0.446392
# [666]	valid_0's f1_score: 0.446392
# [667]	valid_0's f1_score: 0.446131
# [668]	valid_0's f1_score: 0.446032
# [669]	valid_0's f1_score: 0.445702
# [670]	valid_0's f1_score: 0.44601
# [671]	valid_0's f1_score: 0.44598
# [672]	valid_0's f1_score: 0.446339
# [673]	valid_0's f1_score: 0.446294
# [674]	valid_0's f1_score: 0.446334
# [675]	valid_0's f1_score: 0.446317
# [676]	valid_0's f1_score: 0.44613
# [677]	valid_0's f1_score: 0.446215
# [678]	valid_0's f1_score: 0.446235
# [679]	valid_0's f1_score: 0.446034
# [680]	valid_0's f1_score: 0.446102
# [681]	valid_0's f1_score: 0.446007
# [682]	valid_0's f1_score: 0.445983
# [683]	valid_0's f1_score: 0.446047
# [684]	valid_0's f1_score: 0.446326
# [685]	valid_0's f1_score: 0.446187
# [686]	valid_0's f1_score: 0.446528
# [687]	valid_0's f1_score: 0.446562
# [688]	valid_0's f1_score: 0.446566
# [689]	valid_0's f1_score: 0.446644
# [690]	valid_0's f1_score: 0.446863
# [691]	valid_0's f1_score: 0.446744
# [692]	valid_0's f1_score: 0.446735
# [693]	valid_0's f1_score: 0.446962
# [694]	valid_0's f1_score: 0.447342
# [695]	valid_0's f1_score: 0.447363
# [696]	valid_0's f1_score: 0.447538
# [697]	valid_0's f1_score: 0.447475
# [698]	valid_0's f1_score: 0.447605
# [699]	valid_0's f1_score: 0.447541
# [700]	valid_0's f1_score: 0.447808
# [701]	valid_0's f1_score: 0.447847
# [702]	valid_0's f1_score: 0.448053
# [703]	valid_0's f1_score: 0.448092
# [704]	valid_0's f1_score: 0.448156
# [705]	valid_0's f1_score: 0.448048
# [706]	valid_0's f1_score: 0.448113
# [707]	valid_0's f1_score: 0.447843
# [708]	valid_0's f1_score: 0.44819
# [709]	valid_0's f1_score: 0.448365
# [710]	valid_0's f1_score: 0.448253
# [711]	valid_0's f1_score: 0.448304
# [712]	valid_0's f1_score: 0.44829
# [713]	valid_0's f1_score: 0.448231
# [714]	valid_0's f1_score: 0.448539
# [715]	valid_0's f1_score: 0.448426
# [716]	valid_0's f1_score: 0.448742
# [717]	valid_0's f1_score: 0.448547
# [718]	valid_0's f1_score: 0.448473
# [719]	valid_0's f1_score: 0.448514
# [720]	valid_0's f1_score: 0.448554
# [721]	valid_0's f1_score: 0.448434
# [722]	valid_0's f1_score: 0.448467
# [723]	valid_0's f1_score: 0.448589
# [724]	valid_0's f1_score: 0.448597
# [725]	valid_0's f1_score: 0.448344
# [726]	valid_0's f1_score: 0.448751
# [727]	valid_0's f1_score: 0.448677
# [728]	valid_0's f1_score: 0.448588
# [729]	valid_0's f1_score: 0.448509
# [730]	valid_0's f1_score: 0.448512
# [731]	valid_0's f1_score: 0.448435
# [732]	valid_0's f1_score: 0.448374
# [733]	valid_0's f1_score: 0.448414
# [734]	valid_0's f1_score: 0.448532
# [735]	valid_0's f1_score: 0.448346
# [736]	valid_0's f1_score: 0.448358
# [737]	valid_0's f1_score: 0.448319
# [738]	valid_0's f1_score: 0.448523
# [739]	valid_0's f1_score: 0.448254
# [740]	valid_0's f1_score: 0.44826
# [741]	valid_0's f1_score: 0.44826
# [742]	valid_0's f1_score: 0.448301
# [743]	valid_0's f1_score: 0.448534
# [744]	valid_0's f1_score: 0.448602
# [745]	valid_0's f1_score: 0.448504
# [746]	valid_0's f1_score: 0.448392
# [747]	valid_0's f1_score: 0.448517
# [748]	valid_0's f1_score: 0.448784
# [749]	valid_0's f1_score: 0.44875
# [750]	valid_0's f1_score: 0.448813
# [751]	valid_0's f1_score: 0.448811
# [752]	valid_0's f1_score: 0.448837
# [753]	valid_0's f1_score: 0.448822
# [754]	valid_0's f1_score: 0.448787
# [755]	valid_0's f1_score: 0.448895
# [756]	valid_0's f1_score: 0.448901
# [757]	valid_0's f1_score: 0.448883
# [758]	valid_0's f1_score: 0.449009
# [759]	valid_0's f1_score: 0.449074
# [760]	valid_0's f1_score: 0.449156
# [761]	valid_0's f1_score: 0.448977
# [762]	valid_0's f1_score: 0.449229
# [763]	valid_0's f1_score: 0.449071
# [764]	valid_0's f1_score: 0.449064
# [765]	valid_0's f1_score: 0.449132
# [766]	valid_0's f1_score: 0.449409
# [767]	valid_0's f1_score: 0.449438
# [768]	valid_0's f1_score: 0.449308
# [769]	valid_0's f1_score: 0.449233
# [770]	valid_0's f1_score: 0.449134
# [771]	valid_0's f1_score: 0.449263
# [772]	valid_0's f1_score: 0.449172
# [773]	valid_0's f1_score: 0.44914
# [774]	valid_0's f1_score: 0.449148
# [775]	valid_0's f1_score: 0.449223
# [776]	valid_0's f1_score: 0.449342
# [777]	valid_0's f1_score: 0.449375
# [778]	valid_0's f1_score: 0.449127
# [779]	valid_0's f1_score: 0.44907
# [780]	valid_0's f1_score: 0.449102
# [781]	valid_0's f1_score: 0.449163
# [782]	valid_0's f1_score: 0.449165
# [783]	valid_0's f1_score: 0.449134
# [784]	valid_0's f1_score: 0.44911
# [785]	valid_0's f1_score: 0.449557
# [786]	valid_0's f1_score: 0.449461
# [787]	valid_0's f1_score: 0.449315
# [788]	valid_0's f1_score: 0.449389
# [789]	valid_0's f1_score: 0.449348
# [790]	valid_0's f1_score: 0.449353
# [791]	valid_0's f1_score: 0.449551
# [792]	valid_0's f1_score: 0.449612
# [793]	valid_0's f1_score: 0.449604
# [794]	valid_0's f1_score: 0.449648
# [795]	valid_0's f1_score: 0.449532
# [796]	valid_0's f1_score: 0.449591
# [797]	valid_0's f1_score: 0.449596
# [798]	valid_0's f1_score: 0.449692
# [799]	valid_0's f1_score: 0.449795
# [800]	valid_0's f1_score: 0.449785
# [801]	valid_0's f1_score: 0.450152
# [802]	valid_0's f1_score: 0.450167
# [803]	valid_0's f1_score: 0.450189
# [804]	valid_0's f1_score: 0.450216
# [805]	valid_0's f1_score: 0.450261
# [806]	valid_0's f1_score: 0.450245
# [807]	valid_0's f1_score: 0.450097
# [808]	valid_0's f1_score: 0.450003
# [809]	valid_0's f1_score: 0.450047
# [810]	valid_0's f1_score: 0.450148
# [811]	valid_0's f1_score: 0.449794
# [812]	valid_0's f1_score: 0.449786
# [813]	valid_0's f1_score: 0.44975
# [814]	valid_0's f1_score: 0.449846
# [815]	valid_0's f1_score: 0.449886
# [816]	valid_0's f1_score: 0.449951
# [817]	valid_0's f1_score: 0.449926
# [818]	valid_0's f1_score: 0.450012
# [819]	valid_0's f1_score: 0.450008
# [820]	valid_0's f1_score: 0.450032
# [821]	valid_0's f1_score: 0.450343
# [822]	valid_0's f1_score: 0.450473
# [823]	valid_0's f1_score: 0.450279
# [824]	valid_0's f1_score: 0.450259
# [825]	valid_0's f1_score: 0.450534
# [826]	valid_0's f1_score: 0.450523
# [827]	valid_0's f1_score: 0.450531
# [828]	valid_0's f1_score: 0.450596
# [829]	valid_0's f1_score: 0.450671
# [830]	valid_0's f1_score: 0.450835
# [831]	valid_0's f1_score: 0.450983
# [832]	valid_0's f1_score: 0.451291
# [833]	valid_0's f1_score: 0.45133
# [834]	valid_0's f1_score: 0.451358
# [835]	valid_0's f1_score: 0.451372
# [836]	valid_0's f1_score: 0.451491
# [837]	valid_0's f1_score: 0.451547
# [838]	valid_0's f1_score: 0.451533
# [839]	valid_0's f1_score: 0.451461
# [840]	valid_0's f1_score: 0.451568
# [841]	valid_0's f1_score: 0.451505
# [842]	valid_0's f1_score: 0.451845
# [843]	valid_0's f1_score: 0.451939
# [844]	valid_0's f1_score: 0.451981
# [845]	valid_0's f1_score: 0.451838
# [846]	valid_0's f1_score: 0.451808
# [847]	valid_0's f1_score: 0.452415
# [848]	valid_0's f1_score: 0.452277
# [849]	valid_0's f1_score: 0.45231
# [850]	valid_0's f1_score: 0.452358
# [851]	valid_0's f1_score: 0.452407
# [852]	valid_0's f1_score: 0.452238
# [853]	valid_0's f1_score: 0.452474
# [854]	valid_0's f1_score: 0.452414
# [855]	valid_0's f1_score: 0.452707
# [856]	valid_0's f1_score: 0.452774
# [857]	valid_0's f1_score: 0.452769
# [858]	valid_0's f1_score: 0.452784
# [859]	valid_0's f1_score: 0.45273
# [860]	valid_0's f1_score: 0.452783
# [861]	valid_0's f1_score: 0.452669
# [862]	valid_0's f1_score: 0.452522
# [863]	valid_0's f1_score: 0.45255
# [864]	valid_0's f1_score: 0.452559
# [865]	valid_0's f1_score: 0.452825
# [866]	valid_0's f1_score: 0.452893
# [867]	valid_0's f1_score: 0.453117
# [868]	valid_0's f1_score: 0.453073
# [869]	valid_0's f1_score: 0.453331
# [870]	valid_0's f1_score: 0.453381
# [871]	valid_0's f1_score: 0.453441
# [872]	valid_0's f1_score: 0.453401
# [873]	valid_0's f1_score: 0.453319
# [874]	valid_0's f1_score: 0.453147
# [875]	valid_0's f1_score: 0.453074
# [876]	valid_0's f1_score: 0.453543
# [877]	valid_0's f1_score: 0.453495
# [878]	valid_0's f1_score: 0.453514
# [879]	valid_0's f1_score: 0.453532
# [880]	valid_0's f1_score: 0.453354
# [881]	valid_0's f1_score: 0.453293
# [882]	valid_0's f1_score: 0.453745
# [883]	valid_0's f1_score: 0.453705
# [884]	valid_0's f1_score: 0.453759
# [885]	valid_0's f1_score: 0.453842
# [886]	valid_0's f1_score: 0.453618
# [887]	valid_0's f1_score: 0.453506
# [888]	valid_0's f1_score: 0.453573
# [889]	valid_0's f1_score: 0.453576
# [890]	valid_0's f1_score: 0.453692
# [891]	valid_0's f1_score: 0.453559
# [892]	valid_0's f1_score: 0.453924
# [893]	valid_0's f1_score: 0.453847
# [894]	valid_0's f1_score: 0.453749
# [895]	valid_0's f1_score: 0.453758
# [896]	valid_0's f1_score: 0.453669
# [897]	valid_0's f1_score: 0.453776
# [898]	valid_0's f1_score: 0.453765
# [899]	valid_0's f1_score: 0.453672
# [900]	valid_0's f1_score: 0.453482
# [901]	valid_0's f1_score: 0.453683
# [902]	valid_0's f1_score: 0.453659
# [903]	valid_0's f1_score: 0.454159
# [904]	valid_0's f1_score: 0.454235
# [905]	valid_0's f1_score: 0.454252
# [906]	valid_0's f1_score: 0.454258
# [907]	valid_0's f1_score: 0.453942
# [908]	valid_0's f1_score: 0.454012
# [909]	valid_0's f1_score: 0.454025
# [910]	valid_0's f1_score: 0.454022
# [911]	valid_0's f1_score: 0.454448
# [912]	valid_0's f1_score: 0.454365
# [913]	valid_0's f1_score: 0.454419
# [914]	valid_0's f1_score: 0.454621
# [915]	valid_0's f1_score: 0.454549
# [916]	valid_0's f1_score: 0.454459
# [917]	valid_0's f1_score: 0.454456
# [918]	valid_0's f1_score: 0.45444
# [919]	valid_0's f1_score: 0.454412
# [920]	valid_0's f1_score: 0.454365
# [921]	valid_0's f1_score: 0.45436
# [922]	valid_0's f1_score: 0.454382
# [923]	valid_0's f1_score: 0.454446
# [924]	valid_0's f1_score: 0.454461
# [925]	valid_0's f1_score: 0.454258
# [926]	valid_0's f1_score: 0.454315
# [927]	valid_0's f1_score: 0.454289
# [928]	valid_0's f1_score: 0.454268
# [929]	valid_0's f1_score: 0.454405
# [930]	valid_0's f1_score: 0.454502
# [931]	valid_0's f1_score: 0.454532
# [932]	valid_0's f1_score: 0.454634
# [933]	valid_0's f1_score: 0.454667
# [934]	valid_0's f1_score: 0.454602
# [935]	valid_0's f1_score: 0.45506
# [936]	valid_0's f1_score: 0.454862
# [937]	valid_0's f1_score: 0.45478
# [938]	valid_0's f1_score: 0.454998
# [939]	valid_0's f1_score: 0.455054
# [940]	valid_0's f1_score: 0.455206
# [941]	valid_0's f1_score: 0.455083
# [942]	valid_0's f1_score: 0.455492
# [943]	valid_0's f1_score: 0.455529
# [944]	valid_0's f1_score: 0.4556
# [945]	valid_0's f1_score: 0.455577
# [946]	valid_0's f1_score: 0.455507
# [947]	valid_0's f1_score: 0.45566
# [948]	valid_0's f1_score: 0.455604
# [949]	valid_0's f1_score: 0.455308
# [950]	valid_0's f1_score: 0.455443
# [951]	valid_0's f1_score: 0.455596
# [952]	valid_0's f1_score: 0.455474
# [953]	valid_0's f1_score: 0.455358
# [954]	valid_0's f1_score: 0.455438
# [955]	valid_0's f1_score: 0.455385
# [956]	valid_0's f1_score: 0.455485
# [957]	valid_0's f1_score: 0.455888
# [958]	valid_0's f1_score: 0.455848
# [959]	valid_0's f1_score: 0.45592
# [960]	valid_0's f1_score: 0.455896
# [961]	valid_0's f1_score: 0.456118
# [962]	valid_0's f1_score: 0.456258
# [963]	valid_0's f1_score: 0.456379
# [964]	valid_0's f1_score: 0.456354
# [965]	valid_0's f1_score: 0.456371
# [966]	valid_0's f1_score: 0.45636
# [967]	valid_0's f1_score: 0.45634
# [968]	valid_0's f1_score: 0.456304
# [969]	valid_0's f1_score: 0.45628
# [970]	valid_0's f1_score: 0.456669
# [971]	valid_0's f1_score: 0.456599
# [972]	valid_0's f1_score: 0.456967
# [973]	valid_0's f1_score: 0.456912
# [974]	valid_0's f1_score: 0.456941
# [975]	valid_0's f1_score: 0.456849
# [976]	valid_0's f1_score: 0.45676
# [977]	valid_0's f1_score: 0.456775
# [978]	valid_0's f1_score: 0.456639
# [979]	valid_0's f1_score: 0.456682
# [980]	valid_0's f1_score: 0.456922
# [981]	valid_0's f1_score: 0.456928
# [982]	valid_0's f1_score: 0.457111
# [983]	valid_0's f1_score: 0.456975
# [984]	valid_0's f1_score: 0.4571
# [985]	valid_0's f1_score: 0.457056
# [986]	valid_0's f1_score: 0.457016
# [987]	valid_0's f1_score: 0.457066
# [988]	valid_0's f1_score: 0.457097
# [989]	valid_0's f1_score: 0.457105
# [990]	valid_0's f1_score: 0.457176
# [991]	valid_0's f1_score: 0.457133
# [992]	valid_0's f1_score: 0.457143
# [993]	valid_0's f1_score: 0.457133
# [994]	valid_0's f1_score: 0.457137
# [995]	valid_0's f1_score: 0.456819
# [996]	valid_0's f1_score: 0.457099
# [997]	valid_0's f1_score: 0.457459
# [998]	valid_0's f1_score: 0.457409
# [999]	valid_0's f1_score: 0.457525
# [1000]	valid_0's f1_score: 0.457479

# %%
with open('lgb_model8_fold3.pkl', 'wb') as fout:
    pickle.dump(model, fout)
