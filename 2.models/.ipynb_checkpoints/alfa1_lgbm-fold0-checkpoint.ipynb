# %% [markdown]
# В качестве модели будем использовать бленд на 8-фолдах lgbm бустинга. Так как процесс обучения одной модели занимает около 12-16 часов на cpu, распараллелим фолды по разным ноутбукам

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
import math
import os
import gc
import sys
import pickle
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, plot_confusion_matrix, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, CatBoostRegressor, Pool, cv, sum_models
import lightgbm as lgb
import xgboost as xgb
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
from six.moves import xrange
from sklearn import preprocessing
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
def reduce_mem_usage(df):
    """ 
    iterate through all the columns of a dataframe and 
    modify the data type to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage of dataframe is {:.2f}' 
                     'MB').format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max <\
                  np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max <\
                   np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max <\
                   np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max <\
                   np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max <\
                   np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max <\
                   np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
    end_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage after optimization is: {:.2f}' 
                              'MB').format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) 
                                             / start_mem))
    
    return df

# %% [markdown]
# Собираем в один датасет подготовленные ранее файлы

# %%
df_train = pd.read_csv("alfa1_df_train6.csv")
df_valid = pd.read_csv("alfa1_df_valid6.csv")

# %%
df_train.fillna('nothing', inplace=True)
df_valid.fillna('nothing', inplace=True)

# %%
df_train = reduce_mem_usage(df_train)
df_valid = reduce_mem_usage(df_valid)
# Out:
# Memory usage of dataframe is 1775.78MB
# Memory usage after optimization is: 337.39MB
# Decreased by 81.0%
# Memory usage of dataframe is 49.16MB
# Memory usage after optimization is: 12.29MB
# Decreased by 75.0%

# %%
df_train_exp = pd.read_csv("alfa1_df_train10.csv")
df_valid_exp = pd.read_csv("alfa1_df_valid10.csv")

# %%
df_train_exp = reduce_mem_usage(df_train_exp)
df_valid_exp = reduce_mem_usage(df_valid_exp)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp1 = pd.read_csv("alfa1_df_train11.csv")
df_valid_exp1 = pd.read_csv("alfa1_df_valid11.csv")

# %%
df_train_exp1 = reduce_mem_usage(df_train_exp1)
df_valid_exp1 = reduce_mem_usage(df_valid_exp1)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp2 = pd.read_csv("alfa1_df_train12.csv")
df_valid_exp2 = pd.read_csv("alfa1_df_valid12.csv")

# %%
df_train_exp2 = reduce_mem_usage(df_train_exp2)
df_valid_exp2 = reduce_mem_usage(df_valid_exp2)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
aug = df_train_exp.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug1 = df_train_exp1.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug2 = df_train_exp2.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns

# %%
df_train[aug] = df_train_exp[aug]
df_valid[aug] = df_valid_exp[aug]
df_train[aug1] = df_train_exp1[aug1]
df_valid[aug1] = df_valid_exp1[aug1]
df_train[aug2] = df_train_exp2[aug2]
df_valid[aug2] = df_valid_exp2[aug2]

# %% [markdown]
# Задаем, на каких столбцах будет идти обучение

# %%
from_parq = ['application_id', 'event_type', 'event_category', 'event_name', 'device_screen_name', 'timezone', 'net_connection_type', 'net_connection_tech']

# %%
trn_input_lag_cols = []
for i in range(2, 36):
        trn_input_lag_cols.append(f'lag_{i}')

# %%
to_drop = []
to_drop.append('lag_1')
to_drop.append('client_pin')
to_drop.append('weight')
to_drop.append('class_weight')

# %%
categorical = trn_input_lag_cols + from_parq + ['most_popular']

# %% [markdown]
# Веса семплов представляют собой комбинацию весов по классам и весов по шифтам. По сути это одна из ключевых фишек, которая дала существенный буст скора в сравнении с использованием только классовых весов или только шифтовых

# %%
df_weight = pd.DataFrame()
df_weight['lag_1'] = df_train['lag_1'].unique()
df_weight['class_weight'] = compute_class_weight(classes=df_train['lag_1'].unique(), y=df_train['lag_1'], class_weight='balanced')**0.5

# %%
df_train = df_train.merge(df_weight, how='left', on='lag_1')
df_valid = df_valid.merge(df_weight, how='left', on='lag_1')

# %%
weights = np.array(df_train['weight'])**2 * np.array(df_train['class_weight'])
weights_val = np.array(df_valid['weight'])**2 * np.array(df_valid['class_weight'])

# %% [markdown]
# Используем енкодер таргетов для однозначности бленда

# %%
le1 = preprocessing.LabelEncoder()
le1.fit(df_valid['lag_1'].unique())
# Out:
# LabelEncoder()

# %%
df_train['lag_1'] = le1.transform(df_train['lag_1'])
df_valid['lag_1'] = le1.transform(df_valid['lag_1'])

# %% [markdown]
# Собираем валидационный и трейн датасеты в lgb датасеты

# %%
X, y = pd.DataFrame(pd.concat((df_valid.drop(to_drop, axis=1), df_train.drop(to_drop, axis=1))).reset_index(drop=True)), pd.concat((df_valid['lag_1'], df_train['lag_1'])).reset_index(drop=True)
weights = np.concatenate([weights_val,weights])

# %%
X['event_type'] = X['event_type'].astype('category')
X['net_connection_tech'] = X['net_connection_tech'].astype('category')

# %%
n_splits = 8
folds = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=777)

# %%
trn_idx, val_idx = list(folds.split(X, y))[0]

# %%
X, y = X.iloc[trn_idx],  y.iloc[trn_idx]
weights = weights[trn_idx, ]

# %%
lgb_train = lgb.Dataset(X, y, weight=weights)
lgb_eval = lgb.Dataset(df_valid.drop(to_drop, axis=1), df_valid['lag_1'], reference=lgb_train, weight=weights_val)

# %%
def evalerror(preds, dtrain):
    labels = dtrain.get_label()
    preds = preds.reshape(10, -1).T
    preds = preds.argmax(axis = 1)
    f_score = f1_score(labels , preds,  average = 'macro')
    return 'f1_score', f_score, True

# %% [markdown]
# Параметры подбирались интуитивно, не хватило времени и ресурсов на какой-то осмысленный их поиск

# %%
tree_params = {
    "objective" : "multiclass",
    'metric':'custom',
    "num_class" : 10,
    'learning_rate': 0.12,
    'max_depth': 5,
    'n_jobs': 5,
    "num_leaves" : 24,
    'boosting':'dart',
    "bagging_fraction" : 0.9,  # subsample
    "feature_fraction" : 0.9,  # colsample_bytree
    "bagging_freq" : 5,        # subsample_freq
    "bagging_seed" : 2020,
    'n_estimators': 1000
}

# %%
model = lgb.train(tree_params, 
                  lgb_train,
                  feval = evalerror,
                  valid_sets=[lgb_eval],
                  early_stopping_rounds=250)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's f1_score: 0.0603859
# /opt/conda/lib/python3.7/site-packages/lightgbm/callback.py:188: UserWarning: Early stopping is not available in dart mode
#   warnings.warn('Early stopping is not available in dart mode')
# [2]	valid_0's f1_score: 0.139334
# [3]	valid_0's f1_score: 0.22882
# [4]	valid_0's f1_score: 0.312245
# [5]	valid_0's f1_score: 0.357763
# [6]	valid_0's f1_score: 0.378471
# [7]	valid_0's f1_score: 0.391623
# [8]	valid_0's f1_score: 0.383418
# [9]	valid_0's f1_score: 0.394037
# [10]	valid_0's f1_score: 0.400537
# [11]	valid_0's f1_score: 0.404763
# [12]	valid_0's f1_score: 0.402921
# [13]	valid_0's f1_score: 0.405885
# [14]	valid_0's f1_score: 0.408617
# [15]	valid_0's f1_score: 0.41035
# [16]	valid_0's f1_score: 0.412226
# [17]	valid_0's f1_score: 0.412271
# [18]	valid_0's f1_score: 0.413831
# [19]	valid_0's f1_score: 0.414526
# [20]	valid_0's f1_score: 0.415288
# [21]	valid_0's f1_score: 0.414848
# [22]	valid_0's f1_score: 0.415571
# [23]	valid_0's f1_score: 0.415997
# [24]	valid_0's f1_score: 0.416569
# [25]	valid_0's f1_score: 0.417145
# [26]	valid_0's f1_score: 0.417532
# [27]	valid_0's f1_score: 0.418022
# [28]	valid_0's f1_score: 0.418347
# [29]	valid_0's f1_score: 0.418162
# [30]	valid_0's f1_score: 0.418893
# [31]	valid_0's f1_score: 0.418781
# [32]	valid_0's f1_score: 0.419495
# [33]	valid_0's f1_score: 0.419383
# [34]	valid_0's f1_score: 0.419937
# [35]	valid_0's f1_score: 0.419786
# [36]	valid_0's f1_score: 0.419636
# [37]	valid_0's f1_score: 0.420003
# [38]	valid_0's f1_score: 0.420602
# [39]	valid_0's f1_score: 0.42039
# [40]	valid_0's f1_score: 0.420952
# [41]	valid_0's f1_score: 0.4207
# [42]	valid_0's f1_score: 0.42082
# [43]	valid_0's f1_score: 0.420683
# [44]	valid_0's f1_score: 0.421376
# [45]	valid_0's f1_score: 0.421251
# [46]	valid_0's f1_score: 0.42086
# [47]	valid_0's f1_score: 0.420952
# [48]	valid_0's f1_score: 0.421115
# [49]	valid_0's f1_score: 0.421075
# [50]	valid_0's f1_score: 0.421034
# [51]	valid_0's f1_score: 0.421523
# [52]	valid_0's f1_score: 0.42113
# [53]	valid_0's f1_score: 0.421586
# [54]	valid_0's f1_score: 0.421492
# [55]	valid_0's f1_score: 0.421875
# [56]	valid_0's f1_score: 0.421965
# [57]	valid_0's f1_score: 0.422311
# [58]	valid_0's f1_score: 0.421143
# [59]	valid_0's f1_score: 0.421346
# [60]	valid_0's f1_score: 0.420986
# [61]	valid_0's f1_score: 0.420248
# [62]	valid_0's f1_score: 0.420916
# [63]	valid_0's f1_score: 0.420888
# [64]	valid_0's f1_score: 0.421926
# [65]	valid_0's f1_score: 0.421502
# [66]	valid_0's f1_score: 0.421814
# [67]	valid_0's f1_score: 0.422151
# [68]	valid_0's f1_score: 0.422411
# [69]	valid_0's f1_score: 0.422255
# [70]	valid_0's f1_score: 0.422633
# [71]	valid_0's f1_score: 0.423021
# [72]	valid_0's f1_score: 0.422871
# [73]	valid_0's f1_score: 0.422938
# [74]	valid_0's f1_score: 0.423038
# [75]	valid_0's f1_score: 0.422943
# [76]	valid_0's f1_score: 0.422953
# [77]	valid_0's f1_score: 0.423037
# [78]	valid_0's f1_score: 0.422822
# [79]	valid_0's f1_score: 0.422724
# [80]	valid_0's f1_score: 0.42299
# [81]	valid_0's f1_score: 0.423128
# [82]	valid_0's f1_score: 0.42346
# [83]	valid_0's f1_score: 0.423311
# [84]	valid_0's f1_score: 0.423136
# [85]	valid_0's f1_score: 0.423244
# [86]	valid_0's f1_score: 0.423626
# [87]	valid_0's f1_score: 0.423526
# [88]	valid_0's f1_score: 0.42372
# [89]	valid_0's f1_score: 0.42411
# [90]	valid_0's f1_score: 0.42381
# [91]	valid_0's f1_score: 0.423422
# [92]	valid_0's f1_score: 0.42341
# [93]	valid_0's f1_score: 0.423728
# [94]	valid_0's f1_score: 0.423361
# [95]	valid_0's f1_score: 0.423322
# [96]	valid_0's f1_score: 0.423304
# [97]	valid_0's f1_score: 0.423734
# [98]	valid_0's f1_score: 0.424014
# [99]	valid_0's f1_score: 0.423858
# [100]	valid_0's f1_score: 0.424334
# [101]	valid_0's f1_score: 0.423802
# [102]	valid_0's f1_score: 0.423663
# [103]	valid_0's f1_score: 0.423608
# [104]	valid_0's f1_score: 0.424455
# [105]	valid_0's f1_score: 0.423912
# [106]	valid_0's f1_score: 0.424041
# [107]	valid_0's f1_score: 0.424348
# [108]	valid_0's f1_score: 0.424519
# [109]	valid_0's f1_score: 0.424109
# [110]	valid_0's f1_score: 0.424481
# [111]	valid_0's f1_score: 0.424118
# [112]	valid_0's f1_score: 0.424249
# [113]	valid_0's f1_score: 0.424241
# [114]	valid_0's f1_score: 0.424452
# [115]	valid_0's f1_score: 0.424689
# [116]	valid_0's f1_score: 0.424572
# [117]	valid_0's f1_score: 0.424965
# [118]	valid_0's f1_score: 0.42491
# [119]	valid_0's f1_score: 0.425002
# [120]	valid_0's f1_score: 0.425093
# [121]	valid_0's f1_score: 0.42533
# [122]	valid_0's f1_score: 0.425534
# [123]	valid_0's f1_score: 0.425514
# [124]	valid_0's f1_score: 0.425354
# [125]	valid_0's f1_score: 0.425825
# [126]	valid_0's f1_score: 0.42572
# [127]	valid_0's f1_score: 0.425767
# [128]	valid_0's f1_score: 0.425728
# [129]	valid_0's f1_score: 0.425306
# [130]	valid_0's f1_score: 0.425691
# [131]	valid_0's f1_score: 0.425722
# [132]	valid_0's f1_score: 0.425724
# [133]	valid_0's f1_score: 0.426022
# [134]	valid_0's f1_score: 0.425723
# [135]	valid_0's f1_score: 0.425837
# [136]	valid_0's f1_score: 0.42534
# [137]	valid_0's f1_score: 0.42546
# [138]	valid_0's f1_score: 0.425635
# [139]	valid_0's f1_score: 0.425643
# [140]	valid_0's f1_score: 0.425605
# [141]	valid_0's f1_score: 0.42559
# [142]	valid_0's f1_score: 0.425797
# [143]	valid_0's f1_score: 0.426129
# [144]	valid_0's f1_score: 0.42605
# [145]	valid_0's f1_score: 0.42628
# [146]	valid_0's f1_score: 0.426251
# [147]	valid_0's f1_score: 0.426223
# [148]	valid_0's f1_score: 0.426554
# [149]	valid_0's f1_score: 0.426378
# [150]	valid_0's f1_score: 0.426584
# [151]	valid_0's f1_score: 0.426238
# [152]	valid_0's f1_score: 0.425937
# [153]	valid_0's f1_score: 0.425777
# [154]	valid_0's f1_score: 0.42569
# [155]	valid_0's f1_score: 0.426
# [156]	valid_0's f1_score: 0.425843
# [157]	valid_0's f1_score: 0.42597
# [158]	valid_0's f1_score: 0.425887
# [159]	valid_0's f1_score: 0.425937
# [160]	valid_0's f1_score: 0.425975
# [161]	valid_0's f1_score: 0.425986
# [162]	valid_0's f1_score: 0.425794
# [163]	valid_0's f1_score: 0.425502
# [164]	valid_0's f1_score: 0.425702
# [165]	valid_0's f1_score: 0.425658
# [166]	valid_0's f1_score: 0.425642
# [167]	valid_0's f1_score: 0.425997
# [168]	valid_0's f1_score: 0.426062
# [169]	valid_0's f1_score: 0.426595
# [170]	valid_0's f1_score: 0.426081
# [171]	valid_0's f1_score: 0.426191
# [172]	valid_0's f1_score: 0.425908
# [173]	valid_0's f1_score: 0.426314
# [174]	valid_0's f1_score: 0.426493
# [175]	valid_0's f1_score: 0.426735
# [176]	valid_0's f1_score: 0.426738
# [177]	valid_0's f1_score: 0.426789
# [178]	valid_0's f1_score: 0.426548
# [179]	valid_0's f1_score: 0.426885
# [180]	valid_0's f1_score: 0.426825
# [181]	valid_0's f1_score: 0.426746
# [182]	valid_0's f1_score: 0.427333
# [183]	valid_0's f1_score: 0.427721
# [184]	valid_0's f1_score: 0.428002
# [185]	valid_0's f1_score: 0.427706
# [186]	valid_0's f1_score: 0.427864
# [187]	valid_0's f1_score: 0.428094
# [188]	valid_0's f1_score: 0.428132
# [189]	valid_0's f1_score: 0.428169
# [190]	valid_0's f1_score: 0.427992
# [191]	valid_0's f1_score: 0.428191
# [192]	valid_0's f1_score: 0.428331
# [193]	valid_0's f1_score: 0.428468
# [194]	valid_0's f1_score: 0.428301
# [195]	valid_0's f1_score: 0.428348
# [196]	valid_0's f1_score: 0.428605
# [197]	valid_0's f1_score: 0.428432
# [198]	valid_0's f1_score: 0.428504
# [199]	valid_0's f1_score: 0.428733
# [200]	valid_0's f1_score: 0.42876
# [201]	valid_0's f1_score: 0.428644
# [202]	valid_0's f1_score: 0.428708
# [203]	valid_0's f1_score: 0.428337
# [204]	valid_0's f1_score: 0.42823
# [205]	valid_0's f1_score: 0.42801
# [206]	valid_0's f1_score: 0.428141
# [207]	valid_0's f1_score: 0.428108
# [208]	valid_0's f1_score: 0.428212
# [209]	valid_0's f1_score: 0.428184
# [210]	valid_0's f1_score: 0.428199
# [211]	valid_0's f1_score: 0.428087
# [212]	valid_0's f1_score: 0.428265
# [213]	valid_0's f1_score: 0.428375
# [214]	valid_0's f1_score: 0.428667
# [215]	valid_0's f1_score: 0.42913
# [216]	valid_0's f1_score: 0.429068
# [217]	valid_0's f1_score: 0.429234
# [218]	valid_0's f1_score: 0.428985
# [219]	valid_0's f1_score: 0.428831
# [220]	valid_0's f1_score: 0.429103
# [221]	valid_0's f1_score: 0.429122
# [222]	valid_0's f1_score: 0.429081
# [223]	valid_0's f1_score: 0.429515
# [224]	valid_0's f1_score: 0.429432
# [225]	valid_0's f1_score: 0.429361
# [226]	valid_0's f1_score: 0.429543
# [227]	valid_0's f1_score: 0.42953
# [228]	valid_0's f1_score: 0.429616
# [229]	valid_0's f1_score: 0.429613
# [230]	valid_0's f1_score: 0.42975
# [231]	valid_0's f1_score: 0.429742
# [232]	valid_0's f1_score: 0.430307
# [233]	valid_0's f1_score: 0.430176
# [234]	valid_0's f1_score: 0.430024
# [235]	valid_0's f1_score: 0.429935
# [236]	valid_0's f1_score: 0.429902
# [237]	valid_0's f1_score: 0.430212
# [238]	valid_0's f1_score: 0.430177
# [239]	valid_0's f1_score: 0.430486
# [240]	valid_0's f1_score: 0.430657
# [241]	valid_0's f1_score: 0.430706
# [242]	valid_0's f1_score: 0.430648
# [243]	valid_0's f1_score: 0.43065
# [244]	valid_0's f1_score: 0.430538
# [245]	valid_0's f1_score: 0.430252
# [246]	valid_0's f1_score: 0.429732
# [247]	valid_0's f1_score: 0.43003
# [248]	valid_0's f1_score: 0.430071
# [249]	valid_0's f1_score: 0.43006
# [250]	valid_0's f1_score: 0.429939
# [251]	valid_0's f1_score: 0.430016
# [252]	valid_0's f1_score: 0.430104
# [253]	valid_0's f1_score: 0.430288
# [254]	valid_0's f1_score: 0.430434
# [255]	valid_0's f1_score: 0.430719
# [256]	valid_0's f1_score: 0.430699
# [257]	valid_0's f1_score: 0.430804
# [258]	valid_0's f1_score: 0.430973
# [259]	valid_0's f1_score: 0.430882
# [260]	valid_0's f1_score: 0.430895
# [261]	valid_0's f1_score: 0.431006
# [262]	valid_0's f1_score: 0.431046
# [263]	valid_0's f1_score: 0.431326
# [264]	valid_0's f1_score: 0.431225
# [265]	valid_0's f1_score: 0.431576
# [266]	valid_0's f1_score: 0.431617
# [267]	valid_0's f1_score: 0.431651
# [268]	valid_0's f1_score: 0.431656
# [269]	valid_0's f1_score: 0.43172
# [270]	valid_0's f1_score: 0.431907
# [271]	valid_0's f1_score: 0.431944
# [272]	valid_0's f1_score: 0.431977
# [273]	valid_0's f1_score: 0.431813
# [274]	valid_0's f1_score: 0.431857
# [275]	valid_0's f1_score: 0.431948
# [276]	valid_0's f1_score: 0.43181
# [277]	valid_0's f1_score: 0.431444
# [278]	valid_0's f1_score: 0.43137
# [279]	valid_0's f1_score: 0.431907
# [280]	valid_0's f1_score: 0.432006
# [281]	valid_0's f1_score: 0.431728
# [282]	valid_0's f1_score: 0.43184
# [283]	valid_0's f1_score: 0.431865
# [284]	valid_0's f1_score: 0.432074
# [285]	valid_0's f1_score: 0.432152
# [286]	valid_0's f1_score: 0.432171
# [287]	valid_0's f1_score: 0.432585
# [288]	valid_0's f1_score: 0.432613
# [289]	valid_0's f1_score: 0.432827
# [290]	valid_0's f1_score: 0.432957
# [291]	valid_0's f1_score: 0.433079
# [292]	valid_0's f1_score: 0.432982
# [293]	valid_0's f1_score: 0.43291
# [294]	valid_0's f1_score: 0.433335
# [295]	valid_0's f1_score: 0.433305
# [296]	valid_0's f1_score: 0.43328
# [297]	valid_0's f1_score: 0.433437
# [298]	valid_0's f1_score: 0.433547
# [299]	valid_0's f1_score: 0.433469
# [300]	valid_0's f1_score: 0.433448
# [301]	valid_0's f1_score: 0.43345
# [302]	valid_0's f1_score: 0.4332
# [303]	valid_0's f1_score: 0.433207
# [304]	valid_0's f1_score: 0.433259
# [305]	valid_0's f1_score: 0.433144
# [306]	valid_0's f1_score: 0.432977
# [307]	valid_0's f1_score: 0.433024
# [308]	valid_0's f1_score: 0.433315
# [309]	valid_0's f1_score: 0.433379
# [310]	valid_0's f1_score: 0.433468
# [311]	valid_0's f1_score: 0.43334
# [312]	valid_0's f1_score: 0.433589
# [313]	valid_0's f1_score: 0.433881
# [314]	valid_0's f1_score: 0.433709
# [315]	valid_0's f1_score: 0.433679
# [316]	valid_0's f1_score: 0.433409
# [317]	valid_0's f1_score: 0.433381
# [318]	valid_0's f1_score: 0.433455
# [319]	valid_0's f1_score: 0.433482
# [320]	valid_0's f1_score: 0.433642
# [321]	valid_0's f1_score: 0.433582
# [322]	valid_0's f1_score: 0.433674
# [323]	valid_0's f1_score: 0.433704
# [324]	valid_0's f1_score: 0.43362
# [325]	valid_0's f1_score: 0.433998
# [326]	valid_0's f1_score: 0.434038
# [327]	valid_0's f1_score: 0.434064
# [328]	valid_0's f1_score: 0.434175
# [329]	valid_0's f1_score: 0.434028
# [330]	valid_0's f1_score: 0.433744
# [331]	valid_0's f1_score: 0.433884
# [332]	valid_0's f1_score: 0.433703
# [333]	valid_0's f1_score: 0.433687
# [334]	valid_0's f1_score: 0.433718
# [335]	valid_0's f1_score: 0.433746
# [336]	valid_0's f1_score: 0.433741
# [337]	valid_0's f1_score: 0.433925
# [338]	valid_0's f1_score: 0.434005
# [339]	valid_0's f1_score: 0.433823
# [340]	valid_0's f1_score: 0.433619
# [341]	valid_0's f1_score: 0.433811
# [342]	valid_0's f1_score: 0.433529
# [343]	valid_0's f1_score: 0.433685
# [344]	valid_0's f1_score: 0.433571
# [345]	valid_0's f1_score: 0.434062
# [346]	valid_0's f1_score: 0.433642
# [347]	valid_0's f1_score: 0.433557
# [348]	valid_0's f1_score: 0.433814
# [349]	valid_0's f1_score: 0.433787
# [350]	valid_0's f1_score: 0.433939
# [351]	valid_0's f1_score: 0.433795
# [352]	valid_0's f1_score: 0.433973
# [353]	valid_0's f1_score: 0.434529
# [354]	valid_0's f1_score: 0.434501
# [355]	valid_0's f1_score: 0.434333
# [356]	valid_0's f1_score: 0.434495
# [357]	valid_0's f1_score: 0.434476
# [358]	valid_0's f1_score: 0.434685
# [359]	valid_0's f1_score: 0.43448
# [360]	valid_0's f1_score: 0.434608
# [361]	valid_0's f1_score: 0.434784
# [362]	valid_0's f1_score: 0.435147
# [363]	valid_0's f1_score: 0.435277
# [364]	valid_0's f1_score: 0.435118
# [365]	valid_0's f1_score: 0.435291
# [366]	valid_0's f1_score: 0.435169
# [367]	valid_0's f1_score: 0.435227
# [368]	valid_0's f1_score: 0.435182
# [369]	valid_0's f1_score: 0.43512
# [370]	valid_0's f1_score: 0.435257
# [371]	valid_0's f1_score: 0.435162
# [372]	valid_0's f1_score: 0.43501
# [373]	valid_0's f1_score: 0.434927
# [374]	valid_0's f1_score: 0.434917
# [375]	valid_0's f1_score: 0.435085
# [376]	valid_0's f1_score: 0.43502
# [377]	valid_0's f1_score: 0.435483
# [378]	valid_0's f1_score: 0.435292
# [379]	valid_0's f1_score: 0.434996
# [380]	valid_0's f1_score: 0.43532
# [381]	valid_0's f1_score: 0.435237
# [382]	valid_0's f1_score: 0.435152
# [383]	valid_0's f1_score: 0.435533
# [384]	valid_0's f1_score: 0.435385
# [385]	valid_0's f1_score: 0.435384
# [386]	valid_0's f1_score: 0.435238
# [387]	valid_0's f1_score: 0.435387
# [388]	valid_0's f1_score: 0.435694
# [389]	valid_0's f1_score: 0.435664
# [390]	valid_0's f1_score: 0.43579
# [391]	valid_0's f1_score: 0.435783
# [392]	valid_0's f1_score: 0.435862
# [393]	valid_0's f1_score: 0.436065
# [394]	valid_0's f1_score: 0.436151
# [395]	valid_0's f1_score: 0.436181
# [396]	valid_0's f1_score: 0.436069
# [397]	valid_0's f1_score: 0.436332
# [398]	valid_0's f1_score: 0.436388
# [399]	valid_0's f1_score: 0.436226
# [400]	valid_0's f1_score: 0.436591
# [401]	valid_0's f1_score: 0.436532
# [402]	valid_0's f1_score: 0.436704
# [403]	valid_0's f1_score: 0.436589
# [404]	valid_0's f1_score: 0.436698
# [405]	valid_0's f1_score: 0.436754
# [406]	valid_0's f1_score: 0.436491
# [407]	valid_0's f1_score: 0.436751
# [408]	valid_0's f1_score: 0.436792
# [409]	valid_0's f1_score: 0.4369
# [410]	valid_0's f1_score: 0.437069
# [411]	valid_0's f1_score: 0.437391
# [412]	valid_0's f1_score: 0.437432
# [413]	valid_0's f1_score: 0.437484
# [414]	valid_0's f1_score: 0.437562
# [415]	valid_0's f1_score: 0.437453
# [416]	valid_0's f1_score: 0.437392
# [417]	valid_0's f1_score: 0.437377
# [418]	valid_0's f1_score: 0.437152
# [419]	valid_0's f1_score: 0.43743
# [420]	valid_0's f1_score: 0.437506
# [421]	valid_0's f1_score: 0.437885
# [422]	valid_0's f1_score: 0.43768
# [423]	valid_0's f1_score: 0.438069
# [424]	valid_0's f1_score: 0.438068
# [425]	valid_0's f1_score: 0.438095
# [426]	valid_0's f1_score: 0.43821
# [427]	valid_0's f1_score: 0.438302
# [428]	valid_0's f1_score: 0.43829
# [429]	valid_0's f1_score: 0.438183
# [430]	valid_0's f1_score: 0.438073
# [431]	valid_0's f1_score: 0.438363
# [432]	valid_0's f1_score: 0.438335
# [433]	valid_0's f1_score: 0.438506
# [434]	valid_0's f1_score: 0.438521
# [435]	valid_0's f1_score: 0.438495
# [436]	valid_0's f1_score: 0.438846
# [437]	valid_0's f1_score: 0.439109
# [438]	valid_0's f1_score: 0.439103
# [439]	valid_0's f1_score: 0.438906
# [440]	valid_0's f1_score: 0.43872
# [441]	valid_0's f1_score: 0.438677
# [442]	valid_0's f1_score: 0.4388
# [443]	valid_0's f1_score: 0.438807
# [444]	valid_0's f1_score: 0.438802
# [445]	valid_0's f1_score: 0.438815
# [446]	valid_0's f1_score: 0.438739
# [447]	valid_0's f1_score: 0.439023
# [448]	valid_0's f1_score: 0.439187
# [449]	valid_0's f1_score: 0.439374
# [450]	valid_0's f1_score: 0.439343
# [451]	valid_0's f1_score: 0.439227
# [452]	valid_0's f1_score: 0.439078
# [453]	valid_0's f1_score: 0.438856
# [454]	valid_0's f1_score: 0.438859
# [455]	valid_0's f1_score: 0.438979
# [456]	valid_0's f1_score: 0.439147
# [457]	valid_0's f1_score: 0.439034
# [458]	valid_0's f1_score: 0.439023
# [459]	valid_0's f1_score: 0.438955
# [460]	valid_0's f1_score: 0.439101
# [461]	valid_0's f1_score: 0.439114
# [462]	valid_0's f1_score: 0.439175
# [463]	valid_0's f1_score: 0.439244
# [464]	valid_0's f1_score: 0.439447
# [465]	valid_0's f1_score: 0.439424
# [466]	valid_0's f1_score: 0.439491
# [467]	valid_0's f1_score: 0.439327
# [468]	valid_0's f1_score: 0.439302
# [469]	valid_0's f1_score: 0.439667
# [470]	valid_0's f1_score: 0.439528
# [471]	valid_0's f1_score: 0.439686
# [472]	valid_0's f1_score: 0.439757
# [473]	valid_0's f1_score: 0.439593
# [474]	valid_0's f1_score: 0.439913
# [475]	valid_0's f1_score: 0.439857
# [476]	valid_0's f1_score: 0.43993
# [477]	valid_0's f1_score: 0.440292
# [478]	valid_0's f1_score: 0.440287
# [479]	valid_0's f1_score: 0.440139
# [480]	valid_0's f1_score: 0.440228
# [481]	valid_0's f1_score: 0.440506
# [482]	valid_0's f1_score: 0.440788
# [483]	valid_0's f1_score: 0.440605
# [484]	valid_0's f1_score: 0.440686
# [485]	valid_0's f1_score: 0.44083
# [486]	valid_0's f1_score: 0.440886
# [487]	valid_0's f1_score: 0.440394
# [488]	valid_0's f1_score: 0.440374
# [489]	valid_0's f1_score: 0.440583
# [490]	valid_0's f1_score: 0.440486
# [491]	valid_0's f1_score: 0.440495
# [492]	valid_0's f1_score: 0.440458
# [493]	valid_0's f1_score: 0.440381
# [494]	valid_0's f1_score: 0.440447
# [495]	valid_0's f1_score: 0.440957
# [496]	valid_0's f1_score: 0.440965
# [497]	valid_0's f1_score: 0.440834
# [498]	valid_0's f1_score: 0.441181
# [499]	valid_0's f1_score: 0.44116
# [500]	valid_0's f1_score: 0.441393
# [501]	valid_0's f1_score: 0.441416
# [502]	valid_0's f1_score: 0.44146
# [503]	valid_0's f1_score: 0.441424
# [504]	valid_0's f1_score: 0.441214
# [505]	valid_0's f1_score: 0.441261
# [506]	valid_0's f1_score: 0.44144
# [507]	valid_0's f1_score: 0.441442
# [508]	valid_0's f1_score: 0.441546
# [509]	valid_0's f1_score: 0.442028
# [510]	valid_0's f1_score: 0.441905
# [511]	valid_0's f1_score: 0.441877
# [512]	valid_0's f1_score: 0.441911
# [513]	valid_0's f1_score: 0.442043
# [514]	valid_0's f1_score: 0.442187
# [515]	valid_0's f1_score: 0.442589
# [516]	valid_0's f1_score: 0.442492
# [517]	valid_0's f1_score: 0.442607
# [518]	valid_0's f1_score: 0.442487
# [519]	valid_0's f1_score: 0.442492
# [520]	valid_0's f1_score: 0.442532
# [521]	valid_0's f1_score: 0.442465
# [522]	valid_0's f1_score: 0.442518
# [523]	valid_0's f1_score: 0.442423
# [524]	valid_0's f1_score: 0.442357
# [525]	valid_0's f1_score: 0.442272
# [526]	valid_0's f1_score: 0.442322
# [527]	valid_0's f1_score: 0.4423
# [528]	valid_0's f1_score: 0.442156
# [529]	valid_0's f1_score: 0.44222
# [530]	valid_0's f1_score: 0.442456
# [531]	valid_0's f1_score: 0.442511
# [532]	valid_0's f1_score: 0.442437
# [533]	valid_0's f1_score: 0.442389
# [534]	valid_0's f1_score: 0.44215
# [535]	valid_0's f1_score: 0.441919
# [536]	valid_0's f1_score: 0.441982
# [537]	valid_0's f1_score: 0.441795
# [538]	valid_0's f1_score: 0.442017
# [539]	valid_0's f1_score: 0.442054
# [540]	valid_0's f1_score: 0.44208
# [541]	valid_0's f1_score: 0.441988
# [542]	valid_0's f1_score: 0.44215
# [543]	valid_0's f1_score: 0.4422
# [544]	valid_0's f1_score: 0.442121
# [545]	valid_0's f1_score: 0.442275
# [546]	valid_0's f1_score: 0.442412
# [547]	valid_0's f1_score: 0.442721
# [548]	valid_0's f1_score: 0.442698
# [549]	valid_0's f1_score: 0.442752
# [550]	valid_0's f1_score: 0.442861
# [551]	valid_0's f1_score: 0.442953
# [552]	valid_0's f1_score: 0.442687
# [553]	valid_0's f1_score: 0.442708
# [554]	valid_0's f1_score: 0.442699
# [555]	valid_0's f1_score: 0.442782
# [556]	valid_0's f1_score: 0.442754
# [557]	valid_0's f1_score: 0.442684
# [558]	valid_0's f1_score: 0.442762
# [559]	valid_0's f1_score: 0.442868
# [560]	valid_0's f1_score: 0.443104
# [561]	valid_0's f1_score: 0.443186
# [562]	valid_0's f1_score: 0.443189
# [563]	valid_0's f1_score: 0.443151
# [564]	valid_0's f1_score: 0.44309
# [565]	valid_0's f1_score: 0.442985
# [566]	valid_0's f1_score: 0.442941
# [567]	valid_0's f1_score: 0.443348
# [568]	valid_0's f1_score: 0.443367
# [569]	valid_0's f1_score: 0.443331
# [570]	valid_0's f1_score: 0.443278
# [571]	valid_0's f1_score: 0.443343
# [572]	valid_0's f1_score: 0.443422
# [573]	valid_0's f1_score: 0.44347
# [574]	valid_0's f1_score: 0.44341
# [575]	valid_0's f1_score: 0.443496
# [576]	valid_0's f1_score: 0.443407
# [577]	valid_0's f1_score: 0.443368
# [578]	valid_0's f1_score: 0.443295
# [579]	valid_0's f1_score: 0.443277
# [580]	valid_0's f1_score: 0.443414
# [581]	valid_0's f1_score: 0.443995
# [582]	valid_0's f1_score: 0.444
# [583]	valid_0's f1_score: 0.444128
# [584]	valid_0's f1_score: 0.444083
# [585]	valid_0's f1_score: 0.44384
# [586]	valid_0's f1_score: 0.443857
# [587]	valid_0's f1_score: 0.443958
# [588]	valid_0's f1_score: 0.443945
# [589]	valid_0's f1_score: 0.443803
# [590]	valid_0's f1_score: 0.443826
# [591]	valid_0's f1_score: 0.44379
# [592]	valid_0's f1_score: 0.443818
# [593]	valid_0's f1_score: 0.444001
# [594]	valid_0's f1_score: 0.444072
# [595]	valid_0's f1_score: 0.444107
# [596]	valid_0's f1_score: 0.444247
# [597]	valid_0's f1_score: 0.444179
# [598]	valid_0's f1_score: 0.444188
# [599]	valid_0's f1_score: 0.444241
# [600]	valid_0's f1_score: 0.444296
# [601]	valid_0's f1_score: 0.444118
# [602]	valid_0's f1_score: 0.444137
# [603]	valid_0's f1_score: 0.444012
# [604]	valid_0's f1_score: 0.443862
# [605]	valid_0's f1_score: 0.443837
# [606]	valid_0's f1_score: 0.443823
# [607]	valid_0's f1_score: 0.443866
# [608]	valid_0's f1_score: 0.443962
# [609]	valid_0's f1_score: 0.444074
# [610]	valid_0's f1_score: 0.444173
# [611]	valid_0's f1_score: 0.444345
# [612]	valid_0's f1_score: 0.44434
# [613]	valid_0's f1_score: 0.444215
# [614]	valid_0's f1_score: 0.444405
# [615]	valid_0's f1_score: 0.444135
# [616]	valid_0's f1_score: 0.444037
# [617]	valid_0's f1_score: 0.444077
# [618]	valid_0's f1_score: 0.444763
# [619]	valid_0's f1_score: 0.444592
# [620]	valid_0's f1_score: 0.44477
# [621]	valid_0's f1_score: 0.444669
# [622]	valid_0's f1_score: 0.444585
# [623]	valid_0's f1_score: 0.444931
# [624]	valid_0's f1_score: 0.444938
# [625]	valid_0's f1_score: 0.44502
# [626]	valid_0's f1_score: 0.445085
# [627]	valid_0's f1_score: 0.445208
# [628]	valid_0's f1_score: 0.445525
# [629]	valid_0's f1_score: 0.445462
# [630]	valid_0's f1_score: 0.445426
# [631]	valid_0's f1_score: 0.445341
# [632]	valid_0's f1_score: 0.445545
# [633]	valid_0's f1_score: 0.445521
# [634]	valid_0's f1_score: 0.445474
# [635]	valid_0's f1_score: 0.445423
# [636]	valid_0's f1_score: 0.445514
# [637]	valid_0's f1_score: 0.445699
# [638]	valid_0's f1_score: 0.445693
# [639]	valid_0's f1_score: 0.445614
# [640]	valid_0's f1_score: 0.445586
# [641]	valid_0's f1_score: 0.445575
# [642]	valid_0's f1_score: 0.445678
# [643]	valid_0's f1_score: 0.445912
# [644]	valid_0's f1_score: 0.445723
# [645]	valid_0's f1_score: 0.445727
# [646]	valid_0's f1_score: 0.445792
# [647]	valid_0's f1_score: 0.445709
# [648]	valid_0's f1_score: 0.445952
# [649]	valid_0's f1_score: 0.445892
# [650]	valid_0's f1_score: 0.44575
# [651]	valid_0's f1_score: 0.445769
# [652]	valid_0's f1_score: 0.445812
# [653]	valid_0's f1_score: 0.445792
# [654]	valid_0's f1_score: 0.445652
# [655]	valid_0's f1_score: 0.445961
# [656]	valid_0's f1_score: 0.446019
# [657]	valid_0's f1_score: 0.445938
# [658]	valid_0's f1_score: 0.446153
# [659]	valid_0's f1_score: 0.446146
# [660]	valid_0's f1_score: 0.44613
# [661]	valid_0's f1_score: 0.446098
# [662]	valid_0's f1_score: 0.445988
# [663]	valid_0's f1_score: 0.446029
# [664]	valid_0's f1_score: 0.446029
# [665]	valid_0's f1_score: 0.446014
# [666]	valid_0's f1_score: 0.446006
# [667]	valid_0's f1_score: 0.445986
# [668]	valid_0's f1_score: 0.446015
# [669]	valid_0's f1_score: 0.446024
# [670]	valid_0's f1_score: 0.446336
# [671]	valid_0's f1_score: 0.446379
# [672]	valid_0's f1_score: 0.446435
# [673]	valid_0's f1_score: 0.446347
# [674]	valid_0's f1_score: 0.446312
# [675]	valid_0's f1_score: 0.44652
# [676]	valid_0's f1_score: 0.446538
# [677]	valid_0's f1_score: 0.446664
# [678]	valid_0's f1_score: 0.446786
# [679]	valid_0's f1_score: 0.446696
# [680]	valid_0's f1_score: 0.446749
# [681]	valid_0's f1_score: 0.446724
# [682]	valid_0's f1_score: 0.446443
# [683]	valid_0's f1_score: 0.446516
# [684]	valid_0's f1_score: 0.446761
# [685]	valid_0's f1_score: 0.446814
# [686]	valid_0's f1_score: 0.446771
# [687]	valid_0's f1_score: 0.44685
# [688]	valid_0's f1_score: 0.446758
# [689]	valid_0's f1_score: 0.446999
# [690]	valid_0's f1_score: 0.446974
# [691]	valid_0's f1_score: 0.447027
# [692]	valid_0's f1_score: 0.447012
# [693]	valid_0's f1_score: 0.447111
# [694]	valid_0's f1_score: 0.447132
# [695]	valid_0's f1_score: 0.447097
# [696]	valid_0's f1_score: 0.447085
# [697]	valid_0's f1_score: 0.446986
# [698]	valid_0's f1_score: 0.447093
# [699]	valid_0's f1_score: 0.447078
# [700]	valid_0's f1_score: 0.447181
# [701]	valid_0's f1_score: 0.447264
# [702]	valid_0's f1_score: 0.447385
# [703]	valid_0's f1_score: 0.447331
# [704]	valid_0's f1_score: 0.447419
# [705]	valid_0's f1_score: 0.447413
# [706]	valid_0's f1_score: 0.447434
# [707]	valid_0's f1_score: 0.447327
# [708]	valid_0's f1_score: 0.447457
# [709]	valid_0's f1_score: 0.447313
# [710]	valid_0's f1_score: 0.447458
# [711]	valid_0's f1_score: 0.447418
# [712]	valid_0's f1_score: 0.447395
# [713]	valid_0's f1_score: 0.447567
# [714]	valid_0's f1_score: 0.447903
# [715]	valid_0's f1_score: 0.447775
# [716]	valid_0's f1_score: 0.447781
# [717]	valid_0's f1_score: 0.447658
# [718]	valid_0's f1_score: 0.447626
# [719]	valid_0's f1_score: 0.447634
# [720]	valid_0's f1_score: 0.447683
# [721]	valid_0's f1_score: 0.447419
# [722]	valid_0's f1_score: 0.447443
# [723]	valid_0's f1_score: 0.447477
# [724]	valid_0's f1_score: 0.447471
# [725]	valid_0's f1_score: 0.447528
# [726]	valid_0's f1_score: 0.447542
# [727]	valid_0's f1_score: 0.447305
# [728]	valid_0's f1_score: 0.44721
# [729]	valid_0's f1_score: 0.44713
# [730]	valid_0's f1_score: 0.447458
# [731]	valid_0's f1_score: 0.44745
# [732]	valid_0's f1_score: 0.447361
# [733]	valid_0's f1_score: 0.447298
# [734]	valid_0's f1_score: 0.447233
# [735]	valid_0's f1_score: 0.447304
# [736]	valid_0's f1_score: 0.447389
# [737]	valid_0's f1_score: 0.447334
# [738]	valid_0's f1_score: 0.447476
# [739]	valid_0's f1_score: 0.447775
# [740]	valid_0's f1_score: 0.448269
# [741]	valid_0's f1_score: 0.448125
# [742]	valid_0's f1_score: 0.448156
# [743]	valid_0's f1_score: 0.448061
# [744]	valid_0's f1_score: 0.448209
# [745]	valid_0's f1_score: 0.448084
# [746]	valid_0's f1_score: 0.448043
# [747]	valid_0's f1_score: 0.447955
# [748]	valid_0's f1_score: 0.448061
# [749]	valid_0's f1_score: 0.44801
# [750]	valid_0's f1_score: 0.448331
# [751]	valid_0's f1_score: 0.448707
# [752]	valid_0's f1_score: 0.448746
# [753]	valid_0's f1_score: 0.448512
# [754]	valid_0's f1_score: 0.448485
# [755]	valid_0's f1_score: 0.448826
# [756]	valid_0's f1_score: 0.448726
# [757]	valid_0's f1_score: 0.448698
# [758]	valid_0's f1_score: 0.448755
# [759]	valid_0's f1_score: 0.448761
# [760]	valid_0's f1_score: 0.448653
# [761]	valid_0's f1_score: 0.448942
# [762]	valid_0's f1_score: 0.449131
# [763]	valid_0's f1_score: 0.44892
# [764]	valid_0's f1_score: 0.44906
# [765]	valid_0's f1_score: 0.44903
# [766]	valid_0's f1_score: 0.449135
# [767]	valid_0's f1_score: 0.449019
# [768]	valid_0's f1_score: 0.44898
# [769]	valid_0's f1_score: 0.448965
# [770]	valid_0's f1_score: 0.449013
# [771]	valid_0's f1_score: 0.44885
# [772]	valid_0's f1_score: 0.449032
# [773]	valid_0's f1_score: 0.448965
# [774]	valid_0's f1_score: 0.448952
# [775]	valid_0's f1_score: 0.449022
# [776]	valid_0's f1_score: 0.449117
# [777]	valid_0's f1_score: 0.448923
# [778]	valid_0's f1_score: 0.448996
# [779]	valid_0's f1_score: 0.44903
# [780]	valid_0's f1_score: 0.449087
# [781]	valid_0's f1_score: 0.44938
# [782]	valid_0's f1_score: 0.449399
# [783]	valid_0's f1_score: 0.449288
# [784]	valid_0's f1_score: 0.449291
# [785]	valid_0's f1_score: 0.449441
# [786]	valid_0's f1_score: 0.449415
# [787]	valid_0's f1_score: 0.449275
# [788]	valid_0's f1_score: 0.449344
# [789]	valid_0's f1_score: 0.449243
# [790]	valid_0's f1_score: 0.449478
# [791]	valid_0's f1_score: 0.449271
# [792]	valid_0's f1_score: 0.449209
# [793]	valid_0's f1_score: 0.449271
# [794]	valid_0's f1_score: 0.449205
# [795]	valid_0's f1_score: 0.449242
# [796]	valid_0's f1_score: 0.449257
# [797]	valid_0's f1_score: 0.449288
# [798]	valid_0's f1_score: 0.449367
# [799]	valid_0's f1_score: 0.449484
# [800]	valid_0's f1_score: 0.449428
# [801]	valid_0's f1_score: 0.44968
# [802]	valid_0's f1_score: 0.449463
# [803]	valid_0's f1_score: 0.449582
# [804]	valid_0's f1_score: 0.449589
# [805]	valid_0's f1_score: 0.449524
# [806]	valid_0's f1_score: 0.449578
# [807]	valid_0's f1_score: 0.449926
# [808]	valid_0's f1_score: 0.449733
# [809]	valid_0's f1_score: 0.449816
# [810]	valid_0's f1_score: 0.449494
# [811]	valid_0's f1_score: 0.449413
# [812]	valid_0's f1_score: 0.449426
# [813]	valid_0's f1_score: 0.449473
# [814]	valid_0's f1_score: 0.449492
# [815]	valid_0's f1_score: 0.449676
# [816]	valid_0's f1_score: 0.449934
# [817]	valid_0's f1_score: 0.449953
# [818]	valid_0's f1_score: 0.449863
# [819]	valid_0's f1_score: 0.449917
# [820]	valid_0's f1_score: 0.450061
# [821]	valid_0's f1_score: 0.45005
# [822]	valid_0's f1_score: 0.450017
# [823]	valid_0's f1_score: 0.449887
# [824]	valid_0's f1_score: 0.449993
# [825]	valid_0's f1_score: 0.450181
# [826]	valid_0's f1_score: 0.450181
# [827]	valid_0's f1_score: 0.450263
# [828]	valid_0's f1_score: 0.450274
# [829]	valid_0's f1_score: 0.450512
# [830]	valid_0's f1_score: 0.45058
# [831]	valid_0's f1_score: 0.450511
# [832]	valid_0's f1_score: 0.450777
# [833]	valid_0's f1_score: 0.450729
# [834]	valid_0's f1_score: 0.450661
# [835]	valid_0's f1_score: 0.450714
# [836]	valid_0's f1_score: 0.450923
# [837]	valid_0's f1_score: 0.450664
# [838]	valid_0's f1_score: 0.450763
# [839]	valid_0's f1_score: 0.450839
# [840]	valid_0's f1_score: 0.451223
# [841]	valid_0's f1_score: 0.451207
# [842]	valid_0's f1_score: 0.451298
# [843]	valid_0's f1_score: 0.451635
# [844]	valid_0's f1_score: 0.451627
# [845]	valid_0's f1_score: 0.45165
# [846]	valid_0's f1_score: 0.451687
# [847]	valid_0's f1_score: 0.45162
# [848]	valid_0's f1_score: 0.451565
# [849]	valid_0's f1_score: 0.451571
# [850]	valid_0's f1_score: 0.451741
# [851]	valid_0's f1_score: 0.451667
# [852]	valid_0's f1_score: 0.451695
# [853]	valid_0's f1_score: 0.451651
# [854]	valid_0's f1_score: 0.451539
# [855]	valid_0's f1_score: 0.451461
# [856]	valid_0's f1_score: 0.451728
# [857]	valid_0's f1_score: 0.451758
# [858]	valid_0's f1_score: 0.451951
# [859]	valid_0's f1_score: 0.451941
# [860]	valid_0's f1_score: 0.452001
# [861]	valid_0's f1_score: 0.452001
# [862]	valid_0's f1_score: 0.452135
# [863]	valid_0's f1_score: 0.452121
# [864]	valid_0's f1_score: 0.45213
# [865]	valid_0's f1_score: 0.452189
# [866]	valid_0's f1_score: 0.452293
# [867]	valid_0's f1_score: 0.452254
# [868]	valid_0's f1_score: 0.452259
# [869]	valid_0's f1_score: 0.452431
# [870]	valid_0's f1_score: 0.452444
# [871]	valid_0's f1_score: 0.452399
# [872]	valid_0's f1_score: 0.452757
# [873]	valid_0's f1_score: 0.452755
# [874]	valid_0's f1_score: 0.452638
# [875]	valid_0's f1_score: 0.45277
# [876]	valid_0's f1_score: 0.452622
# [877]	valid_0's f1_score: 0.452732
# [878]	valid_0's f1_score: 0.45274
# [879]	valid_0's f1_score: 0.452799
# [880]	valid_0's f1_score: 0.452732
# [881]	valid_0's f1_score: 0.452778
# [882]	valid_0's f1_score: 0.452735
# [883]	valid_0's f1_score: 0.452738
# [884]	valid_0's f1_score: 0.452522
# [885]	valid_0's f1_score: 0.452607
# [886]	valid_0's f1_score: 0.45286
# [887]	valid_0's f1_score: 0.452944
# [888]	valid_0's f1_score: 0.452865
# [889]	valid_0's f1_score: 0.452828
# [890]	valid_0's f1_score: 0.4529
# [891]	valid_0's f1_score: 0.45286
# [892]	valid_0's f1_score: 0.452998
# [893]	valid_0's f1_score: 0.45292
# [894]	valid_0's f1_score: 0.452958
# [895]	valid_0's f1_score: 0.452909
# [896]	valid_0's f1_score: 0.452928
# [897]	valid_0's f1_score: 0.452857
# [898]	valid_0's f1_score: 0.452862
# [899]	valid_0's f1_score: 0.452914
# [900]	valid_0's f1_score: 0.453065
# [901]	valid_0's f1_score: 0.453198
# [902]	valid_0's f1_score: 0.453231
# [903]	valid_0's f1_score: 0.453269
# [904]	valid_0's f1_score: 0.453397
# [905]	valid_0's f1_score: 0.453228
# [906]	valid_0's f1_score: 0.453298
# [907]	valid_0's f1_score: 0.453288
# [908]	valid_0's f1_score: 0.453296
# [909]	valid_0's f1_score: 0.453287
# [910]	valid_0's f1_score: 0.453256
# [911]	valid_0's f1_score: 0.453275
# [912]	valid_0's f1_score: 0.453306
# [913]	valid_0's f1_score: 0.453373
# [914]	valid_0's f1_score: 0.453494
# [915]	valid_0's f1_score: 0.453495
# [916]	valid_0's f1_score: 0.453519
# [917]	valid_0's f1_score: 0.453437
# [918]	valid_0's f1_score: 0.453424
# [919]	valid_0's f1_score: 0.453424
# [920]	valid_0's f1_score: 0.453451
# [921]	valid_0's f1_score: 0.453528
# [922]	valid_0's f1_score: 0.453513
# [923]	valid_0's f1_score: 0.45359
# [924]	valid_0's f1_score: 0.45331
# [925]	valid_0's f1_score: 0.453209
# [926]	valid_0's f1_score: 0.453419
# [927]	valid_0's f1_score: 0.453284
# [928]	valid_0's f1_score: 0.453351
# [929]	valid_0's f1_score: 0.453267
# [930]	valid_0's f1_score: 0.453214
# [931]	valid_0's f1_score: 0.45325
# [932]	valid_0's f1_score: 0.45328
# [933]	valid_0's f1_score: 0.453615
# [934]	valid_0's f1_score: 0.453543
# [935]	valid_0's f1_score: 0.453446
# [936]	valid_0's f1_score: 0.453474
# [937]	valid_0's f1_score: 0.453554
# [938]	valid_0's f1_score: 0.453792
# [939]	valid_0's f1_score: 0.453822
# [940]	valid_0's f1_score: 0.45355
# [941]	valid_0's f1_score: 0.453565
# [942]	valid_0's f1_score: 0.453682
# [943]	valid_0's f1_score: 0.453686
# [944]	valid_0's f1_score: 0.453867
# [945]	valid_0's f1_score: 0.453861
# [946]	valid_0's f1_score: 0.453848
# [947]	valid_0's f1_score: 0.454118
# [948]	valid_0's f1_score: 0.45418
# [949]	valid_0's f1_score: 0.454246
# [950]	valid_0's f1_score: 0.454538
# [951]	valid_0's f1_score: 0.45427
# [952]	valid_0's f1_score: 0.454248
# [953]	valid_0's f1_score: 0.454383
# [954]	valid_0's f1_score: 0.454434
# [955]	valid_0's f1_score: 0.454518
# [956]	valid_0's f1_score: 0.454573
# [957]	valid_0's f1_score: 0.454553
# [958]	valid_0's f1_score: 0.454582
# [959]	valid_0's f1_score: 0.454602
# [960]	valid_0's f1_score: 0.454834
# [961]	valid_0's f1_score: 0.454858
# [962]	valid_0's f1_score: 0.455031
# [963]	valid_0's f1_score: 0.45474
# [964]	valid_0's f1_score: 0.454698
# [965]	valid_0's f1_score: 0.454964
# [966]	valid_0's f1_score: 0.454861
# [967]	valid_0's f1_score: 0.454755
# [968]	valid_0's f1_score: 0.454727
# [969]	valid_0's f1_score: 0.454716
# [970]	valid_0's f1_score: 0.454968
# [971]	valid_0's f1_score: 0.454979
# [972]	valid_0's f1_score: 0.455038
# [973]	valid_0's f1_score: 0.455089
# [974]	valid_0's f1_score: 0.455007
# [975]	valid_0's f1_score: 0.455229
# [976]	valid_0's f1_score: 0.454941
# [977]	valid_0's f1_score: 0.454942
# [978]	valid_0's f1_score: 0.455031
# [979]	valid_0's f1_score: 0.455034
# [980]	valid_0's f1_score: 0.455051
# [981]	valid_0's f1_score: 0.455078
# [982]	valid_0's f1_score: 0.455141
# [983]	valid_0's f1_score: 0.455172
# [984]	valid_0's f1_score: 0.455326
# [985]	valid_0's f1_score: 0.4554
# [986]	valid_0's f1_score: 0.455415
# [987]	valid_0's f1_score: 0.45539
# [988]	valid_0's f1_score: 0.455394
# [989]	valid_0's f1_score: 0.455439
# [990]	valid_0's f1_score: 0.455457
# [991]	valid_0's f1_score: 0.455328
# [992]	valid_0's f1_score: 0.455314
# [993]	valid_0's f1_score: 0.455249
# [994]	valid_0's f1_score: 0.455433
# [995]	valid_0's f1_score: 0.455509
# [996]	valid_0's f1_score: 0.455405
# [997]	valid_0's f1_score: 0.455506
# [998]	valid_0's f1_score: 0.455508
# [999]	valid_0's f1_score: 0.455504
# [1000]	valid_0's f1_score: 0.455506

# %%
with open('lgb_model8_fold0.pkl', 'wb') as fout:
    pickle.dump(model, fout)
