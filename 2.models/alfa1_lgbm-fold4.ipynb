# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
import math
import os
import gc
import sys
import pickle
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, plot_confusion_matrix, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, CatBoostRegressor, Pool, cv, sum_models
import lightgbm as lgb
import xgboost as xgb
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
from six.moves import xrange
from sklearn import preprocessing
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
def reduce_mem_usage(df):
    """ 
    iterate through all the columns of a dataframe and 
    modify the data type to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage of dataframe is {:.2f}' 
                     'MB').format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max <\
                  np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max <\
                   np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max <\
                   np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max <\
                   np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max <\
                   np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max <\
                   np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
    end_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage after optimization is: {:.2f}' 
                              'MB').format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) 
                                             / start_mem))
    
    return df

# %%
df_train = pd.read_csv("alfa1_df_train6.csv")
df_valid = pd.read_csv("alfa1_df_valid6.csv")

# %%
df_train.fillna('nothing', inplace=True)
df_valid.fillna('nothing', inplace=True)

# %%
df_train = reduce_mem_usage(df_train)
df_valid = reduce_mem_usage(df_valid)
# Out:
# Memory usage of dataframe is 1775.78MB
# Memory usage after optimization is: 337.39MB
# Decreased by 81.0%
# Memory usage of dataframe is 49.16MB
# Memory usage after optimization is: 12.29MB
# Decreased by 75.0%

# %%
df_train_exp = pd.read_csv("alfa1_df_train10.csv")
df_valid_exp = pd.read_csv("alfa1_df_valid10.csv")

# %%
df_train_exp = reduce_mem_usage(df_train_exp)
df_valid_exp = reduce_mem_usage(df_valid_exp)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp1 = pd.read_csv("alfa1_df_train11.csv")
df_valid_exp1 = pd.read_csv("alfa1_df_valid11.csv")

# %%
df_train_exp1 = reduce_mem_usage(df_train_exp1)
df_valid_exp1 = reduce_mem_usage(df_valid_exp1)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp2 = pd.read_csv("alfa1_df_train12.csv")
df_valid_exp2 = pd.read_csv("alfa1_df_valid12.csv")

# %%
df_train_exp2 = reduce_mem_usage(df_train_exp2)
df_valid_exp2 = reduce_mem_usage(df_valid_exp2)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
aug = df_train_exp.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug1 = df_train_exp1.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug2 = df_train_exp2.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns

# %%
df_train[aug] = df_train_exp[aug]
df_valid[aug] = df_valid_exp[aug]
df_train[aug1] = df_train_exp1[aug1]
df_valid[aug1] = df_valid_exp1[aug1]
df_train[aug2] = df_train_exp2[aug2]
df_valid[aug2] = df_valid_exp2[aug2]

# %%
from_parq = ['application_id', 'event_type', 'event_category', 'event_name', 'device_screen_name', 'timezone', 'net_connection_type', 'net_connection_tech']

# %%
trn_input_lag_cols = []
for i in range(2, 36):
        trn_input_lag_cols.append(f'lag_{i}')

# %%
to_drop = []
to_drop.append('lag_1')
to_drop.append('client_pin')
to_drop.append('weight')
to_drop.append('class_weight')

# %%
categorical = trn_input_lag_cols + from_parq + ['most_popular']

# %%
df_weight = pd.DataFrame()
df_weight['lag_1'] = df_train['lag_1'].unique()
df_weight['class_weight'] = compute_class_weight(classes=df_train['lag_1'].unique(), y=df_train['lag_1'], class_weight='balanced')**0.5

# %%
df_train = df_train.merge(df_weight, how='left', on='lag_1')
df_valid = df_valid.merge(df_weight, how='left', on='lag_1')

# %%
weights = np.array(df_train['weight'])**2 * np.array(df_train['class_weight'])
weights_val = np.array(df_valid['weight'])**2 * np.array(df_valid['class_weight'])

# %%
le1 = preprocessing.LabelEncoder()
le1.fit(df_valid['lag_1'].unique())
# Out:
# LabelEncoder()

# %%
df_train['lag_1'] = le1.transform(df_train['lag_1'])
df_valid['lag_1'] = le1.transform(df_valid['lag_1'])

# %%
X, y = pd.DataFrame(pd.concat((df_valid.drop(to_drop, axis=1), df_train.drop(to_drop, axis=1))).reset_index(drop=True)), pd.concat((df_valid['lag_1'], df_train['lag_1'])).reset_index(drop=True)
weights = np.concatenate([weights_val,weights])

# %%
X['event_type'] = X['event_type'].astype('category')
X['net_connection_tech'] = X['net_connection_tech'].astype('category')

# %%
n_splits = 8
folds = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=777)

# %%
trn_idx, val_idx = list(folds.split(X, y))[4]

# %%
X, y = X.iloc[trn_idx],  y.iloc[trn_idx]
weights = weights[trn_idx, ]

# %%
lgb_train = lgb.Dataset(X, y, weight=weights)
lgb_eval = lgb.Dataset(df_valid.drop(to_drop, axis=1), df_valid['lag_1'], reference=lgb_train, weight=weights_val)

# %%
def evalerror(preds, dtrain):
    labels = dtrain.get_label()
    preds = preds.reshape(10, -1).T
    preds = preds.argmax(axis = 1)
    f_score = f1_score(labels , preds,  average = 'macro')
    return 'f1_score', f_score, True

# %%
tree_params = {
    "objective" : "multiclass",
    'metric':'custom',
    "num_class" : 10,
    'learning_rate': 0.12,
    'max_depth': 5,
    'n_jobs': 5,
    "num_leaves" : 24,
    'boosting':'dart',
    "bagging_fraction" : 0.9,  # subsample
    "feature_fraction" : 0.9,  # colsample_bytree
    "bagging_freq" : 5,        # subsample_freq
    "bagging_seed" : 2020,
    'n_estimators': 1000
}

# %%
model = lgb.train(tree_params, 
                  lgb_train,
                  feval = evalerror,
                  valid_sets=[lgb_eval],
                  early_stopping_rounds=250)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's f1_score: 0.0603859
# /opt/conda/lib/python3.7/site-packages/lightgbm/callback.py:188: UserWarning: Early stopping is not available in dart mode
#   warnings.warn('Early stopping is not available in dart mode')
# [2]	valid_0's f1_score: 0.141788
# [3]	valid_0's f1_score: 0.231218
# [4]	valid_0's f1_score: 0.314371
# [5]	valid_0's f1_score: 0.356011
# [6]	valid_0's f1_score: 0.377813
# [7]	valid_0's f1_score: 0.389891
# [8]	valid_0's f1_score: 0.382431
# [9]	valid_0's f1_score: 0.392238
# [10]	valid_0's f1_score: 0.399581
# [11]	valid_0's f1_score: 0.403931
# [12]	valid_0's f1_score: 0.402339
# [13]	valid_0's f1_score: 0.405022
# [14]	valid_0's f1_score: 0.408343
# [15]	valid_0's f1_score: 0.409585
# [16]	valid_0's f1_score: 0.411803
# [17]	valid_0's f1_score: 0.413133
# [18]	valid_0's f1_score: 0.413625
# [19]	valid_0's f1_score: 0.414423
# [20]	valid_0's f1_score: 0.415091
# [21]	valid_0's f1_score: 0.414603
# [22]	valid_0's f1_score: 0.415106
# [23]	valid_0's f1_score: 0.415549
# [24]	valid_0's f1_score: 0.417054
# [25]	valid_0's f1_score: 0.417103
# [26]	valid_0's f1_score: 0.417574
# [27]	valid_0's f1_score: 0.418042
# [28]	valid_0's f1_score: 0.418066
# [29]	valid_0's f1_score: 0.418049
# [30]	valid_0's f1_score: 0.418399
# [31]	valid_0's f1_score: 0.418271
# [32]	valid_0's f1_score: 0.418968
# [33]	valid_0's f1_score: 0.418815
# [34]	valid_0's f1_score: 0.419198
# [35]	valid_0's f1_score: 0.419247
# [36]	valid_0's f1_score: 0.419148
# [37]	valid_0's f1_score: 0.41938
# [38]	valid_0's f1_score: 0.419525
# [39]	valid_0's f1_score: 0.420063
# [40]	valid_0's f1_score: 0.420374
# [41]	valid_0's f1_score: 0.420187
# [42]	valid_0's f1_score: 0.42059
# [43]	valid_0's f1_score: 0.420537
# [44]	valid_0's f1_score: 0.420788
# [45]	valid_0's f1_score: 0.420587
# [46]	valid_0's f1_score: 0.41991
# [47]	valid_0's f1_score: 0.419572
# [48]	valid_0's f1_score: 0.419471
# [49]	valid_0's f1_score: 0.419872
# [50]	valid_0's f1_score: 0.420428
# [51]	valid_0's f1_score: 0.420711
# [52]	valid_0's f1_score: 0.420287
# [53]	valid_0's f1_score: 0.420724
# [54]	valid_0's f1_score: 0.420656
# [55]	valid_0's f1_score: 0.420834
# [56]	valid_0's f1_score: 0.421247
# [57]	valid_0's f1_score: 0.420861
# [58]	valid_0's f1_score: 0.420406
# [59]	valid_0's f1_score: 0.42088
# [60]	valid_0's f1_score: 0.420966
# [61]	valid_0's f1_score: 0.420252
# [62]	valid_0's f1_score: 0.420803
# [63]	valid_0's f1_score: 0.420821
# [64]	valid_0's f1_score: 0.421205
# [65]	valid_0's f1_score: 0.421366
# [66]	valid_0's f1_score: 0.421533
# [67]	valid_0's f1_score: 0.421654
# [68]	valid_0's f1_score: 0.422002
# [69]	valid_0's f1_score: 0.422135
# [70]	valid_0's f1_score: 0.422092
# [71]	valid_0's f1_score: 0.422221
# [72]	valid_0's f1_score: 0.422164
# [73]	valid_0's f1_score: 0.422339
# [74]	valid_0's f1_score: 0.422464
# [75]	valid_0's f1_score: 0.421959
# [76]	valid_0's f1_score: 0.422053
# [77]	valid_0's f1_score: 0.42219
# [78]	valid_0's f1_score: 0.422142
# [79]	valid_0's f1_score: 0.422729
# [80]	valid_0's f1_score: 0.422592
# [81]	valid_0's f1_score: 0.422515
# [82]	valid_0's f1_score: 0.422551
# [83]	valid_0's f1_score: 0.422577
# [84]	valid_0's f1_score: 0.423008
# [85]	valid_0's f1_score: 0.423187
# [86]	valid_0's f1_score: 0.423012
# [87]	valid_0's f1_score: 0.423228
# [88]	valid_0's f1_score: 0.423198
# [89]	valid_0's f1_score: 0.423318
# [90]	valid_0's f1_score: 0.42342
# [91]	valid_0's f1_score: 0.422794
# [92]	valid_0's f1_score: 0.422955
# [93]	valid_0's f1_score: 0.422998
# [94]	valid_0's f1_score: 0.422977
# [95]	valid_0's f1_score: 0.422926
# [96]	valid_0's f1_score: 0.423075
# [97]	valid_0's f1_score: 0.423583
# [98]	valid_0's f1_score: 0.42384
# [99]	valid_0's f1_score: 0.423836
# [100]	valid_0's f1_score: 0.424001
# [101]	valid_0's f1_score: 0.424444
# [102]	valid_0's f1_score: 0.42447
# [103]	valid_0's f1_score: 0.424161
# [104]	valid_0's f1_score: 0.424117
# [105]	valid_0's f1_score: 0.424206
# [106]	valid_0's f1_score: 0.424305
# [107]	valid_0's f1_score: 0.424069
# [108]	valid_0's f1_score: 0.424073
# [109]	valid_0's f1_score: 0.424048
# [110]	valid_0's f1_score: 0.424012
# [111]	valid_0's f1_score: 0.424275
# [112]	valid_0's f1_score: 0.424082
# [113]	valid_0's f1_score: 0.423793
# [114]	valid_0's f1_score: 0.424004
# [115]	valid_0's f1_score: 0.423985
# [116]	valid_0's f1_score: 0.424292
# [117]	valid_0's f1_score: 0.42443
# [118]	valid_0's f1_score: 0.424552
# [119]	valid_0's f1_score: 0.424545
# [120]	valid_0's f1_score: 0.424605
# [121]	valid_0's f1_score: 0.424522
# [122]	valid_0's f1_score: 0.424588
# [123]	valid_0's f1_score: 0.424563
# [124]	valid_0's f1_score: 0.424686
# [125]	valid_0's f1_score: 0.424896
# [126]	valid_0's f1_score: 0.424876
# [127]	valid_0's f1_score: 0.425093
# [128]	valid_0's f1_score: 0.425146
# [129]	valid_0's f1_score: 0.425002
# [130]	valid_0's f1_score: 0.425376
# [131]	valid_0's f1_score: 0.425343
# [132]	valid_0's f1_score: 0.425484
# [133]	valid_0's f1_score: 0.425328
# [134]	valid_0's f1_score: 0.424814
# [135]	valid_0's f1_score: 0.425327
# [136]	valid_0's f1_score: 0.42525
# [137]	valid_0's f1_score: 0.425182
# [138]	valid_0's f1_score: 0.425528
# [139]	valid_0's f1_score: 0.425866
# [140]	valid_0's f1_score: 0.426076
# [141]	valid_0's f1_score: 0.425787
# [142]	valid_0's f1_score: 0.425761
# [143]	valid_0's f1_score: 0.425774
# [144]	valid_0's f1_score: 0.42566
# [145]	valid_0's f1_score: 0.42573
# [146]	valid_0's f1_score: 0.425575
# [147]	valid_0's f1_score: 0.42558
# [148]	valid_0's f1_score: 0.425636
# [149]	valid_0's f1_score: 0.426016
# [150]	valid_0's f1_score: 0.426169
# [151]	valid_0's f1_score: 0.42617
# [152]	valid_0's f1_score: 0.425869
# [153]	valid_0's f1_score: 0.425826
# [154]	valid_0's f1_score: 0.425949
# [155]	valid_0's f1_score: 0.42622
# [156]	valid_0's f1_score: 0.426132
# [157]	valid_0's f1_score: 0.426284
# [158]	valid_0's f1_score: 0.42613
# [159]	valid_0's f1_score: 0.426221
# [160]	valid_0's f1_score: 0.42621
# [161]	valid_0's f1_score: 0.426318
# [162]	valid_0's f1_score: 0.426053
# [163]	valid_0's f1_score: 0.426805
# [164]	valid_0's f1_score: 0.426614
# [165]	valid_0's f1_score: 0.426504
# [166]	valid_0's f1_score: 0.426624
# [167]	valid_0's f1_score: 0.426496
# [168]	valid_0's f1_score: 0.426417
# [169]	valid_0's f1_score: 0.425993
# [170]	valid_0's f1_score: 0.425826
# [171]	valid_0's f1_score: 0.426405
# [172]	valid_0's f1_score: 0.426462
# [173]	valid_0's f1_score: 0.426674
# [174]	valid_0's f1_score: 0.426771
# [175]	valid_0's f1_score: 0.427076
# [176]	valid_0's f1_score: 0.427187
# [177]	valid_0's f1_score: 0.426929
# [178]	valid_0's f1_score: 0.426948
# [179]	valid_0's f1_score: 0.426771
# [180]	valid_0's f1_score: 0.426741
# [181]	valid_0's f1_score: 0.4269
# [182]	valid_0's f1_score: 0.426898
# [183]	valid_0's f1_score: 0.427418
# [184]	valid_0's f1_score: 0.427641
# [185]	valid_0's f1_score: 0.427625
# [186]	valid_0's f1_score: 0.427624
# [187]	valid_0's f1_score: 0.427415
# [188]	valid_0's f1_score: 0.427722
# [189]	valid_0's f1_score: 0.427816
# [190]	valid_0's f1_score: 0.427758
# [191]	valid_0's f1_score: 0.427603
# [192]	valid_0's f1_score: 0.427956
# [193]	valid_0's f1_score: 0.428075
# [194]	valid_0's f1_score: 0.427878
# [195]	valid_0's f1_score: 0.427875
# [196]	valid_0's f1_score: 0.428201
# [197]	valid_0's f1_score: 0.428248
# [198]	valid_0's f1_score: 0.428208
# [199]	valid_0's f1_score: 0.428645
# [200]	valid_0's f1_score: 0.428528
# [201]	valid_0's f1_score: 0.428548
# [202]	valid_0's f1_score: 0.428382
# [203]	valid_0's f1_score: 0.428183
# [204]	valid_0's f1_score: 0.428263
# [205]	valid_0's f1_score: 0.427932
# [206]	valid_0's f1_score: 0.4281
# [207]	valid_0's f1_score: 0.428193
# [208]	valid_0's f1_score: 0.428368
# [209]	valid_0's f1_score: 0.428288
# [210]	valid_0's f1_score: 0.428394
# [211]	valid_0's f1_score: 0.428325
# [212]	valid_0's f1_score: 0.428415
# [213]	valid_0's f1_score: 0.428685
# [214]	valid_0's f1_score: 0.428839
# [215]	valid_0's f1_score: 0.428783
# [216]	valid_0's f1_score: 0.428834
# [217]	valid_0's f1_score: 0.429062
# [218]	valid_0's f1_score: 0.429371
# [219]	valid_0's f1_score: 0.429276
# [220]	valid_0's f1_score: 0.429326
# [221]	valid_0's f1_score: 0.429219
# [222]	valid_0's f1_score: 0.429487
# [223]	valid_0's f1_score: 0.429441
# [224]	valid_0's f1_score: 0.429346
# [225]	valid_0's f1_score: 0.429334
# [226]	valid_0's f1_score: 0.429258
# [227]	valid_0's f1_score: 0.42927
# [228]	valid_0's f1_score: 0.429279
# [229]	valid_0's f1_score: 0.4293
# [230]	valid_0's f1_score: 0.429467
# [231]	valid_0's f1_score: 0.429441
# [232]	valid_0's f1_score: 0.429784
# [233]	valid_0's f1_score: 0.429735
# [234]	valid_0's f1_score: 0.429812
# [235]	valid_0's f1_score: 0.42986
# [236]	valid_0's f1_score: 0.429791
# [237]	valid_0's f1_score: 0.429713
# [238]	valid_0's f1_score: 0.430173
# [239]	valid_0's f1_score: 0.430316
# [240]	valid_0's f1_score: 0.43018
# [241]	valid_0's f1_score: 0.430074
# [242]	valid_0's f1_score: 0.43032
# [243]	valid_0's f1_score: 0.430404
# [244]	valid_0's f1_score: 0.430256
# [245]	valid_0's f1_score: 0.430386
# [246]	valid_0's f1_score: 0.4304
# [247]	valid_0's f1_score: 0.430502
# [248]	valid_0's f1_score: 0.430511
# [249]	valid_0's f1_score: 0.430523
# [250]	valid_0's f1_score: 0.430457
# [251]	valid_0's f1_score: 0.430448
# [252]	valid_0's f1_score: 0.430326
# [253]	valid_0's f1_score: 0.430559
# [254]	valid_0's f1_score: 0.430812
# [255]	valid_0's f1_score: 0.430664
# [256]	valid_0's f1_score: 0.430758
# [257]	valid_0's f1_score: 0.430784
# [258]	valid_0's f1_score: 0.430869
# [259]	valid_0's f1_score: 0.430942
# [260]	valid_0's f1_score: 0.430982
# [261]	valid_0's f1_score: 0.430744
# [262]	valid_0's f1_score: 0.430696
# [263]	valid_0's f1_score: 0.430834
# [264]	valid_0's f1_score: 0.43105
# [265]	valid_0's f1_score: 0.431188
# [266]	valid_0's f1_score: 0.43124
# [267]	valid_0's f1_score: 0.431161
# [268]	valid_0's f1_score: 0.431582
# [269]	valid_0's f1_score: 0.431409
# [270]	valid_0's f1_score: 0.431784
# [271]	valid_0's f1_score: 0.431888
# [272]	valid_0's f1_score: 0.432024
# [273]	valid_0's f1_score: 0.431859
# [274]	valid_0's f1_score: 0.431867
# [275]	valid_0's f1_score: 0.431907
# [276]	valid_0's f1_score: 0.431797
# [277]	valid_0's f1_score: 0.431838
# [278]	valid_0's f1_score: 0.431893
# [279]	valid_0's f1_score: 0.432154
# [280]	valid_0's f1_score: 0.432197
# [281]	valid_0's f1_score: 0.43195
# [282]	valid_0's f1_score: 0.432161
# [283]	valid_0's f1_score: 0.432204
# [284]	valid_0's f1_score: 0.432174
# [285]	valid_0's f1_score: 0.432412
# [286]	valid_0's f1_score: 0.432434
# [287]	valid_0's f1_score: 0.432348
# [288]	valid_0's f1_score: 0.432177
# [289]	valid_0's f1_score: 0.432421
# [290]	valid_0's f1_score: 0.4321
# [291]	valid_0's f1_score: 0.432535
# [292]	valid_0's f1_score: 0.432451
# [293]	valid_0's f1_score: 0.432551
# [294]	valid_0's f1_score: 0.432252
# [295]	valid_0's f1_score: 0.432315
# [296]	valid_0's f1_score: 0.432378
# [297]	valid_0's f1_score: 0.43243
# [298]	valid_0's f1_score: 0.432379
# [299]	valid_0's f1_score: 0.432427
# [300]	valid_0's f1_score: 0.43246
# [301]	valid_0's f1_score: 0.432152
# [302]	valid_0's f1_score: 0.432756
# [303]	valid_0's f1_score: 0.432652
# [304]	valid_0's f1_score: 0.432592
# [305]	valid_0's f1_score: 0.432582
# [306]	valid_0's f1_score: 0.432531
# [307]	valid_0's f1_score: 0.432502
# [308]	valid_0's f1_score: 0.432835
# [309]	valid_0's f1_score: 0.432992
# [310]	valid_0's f1_score: 0.432847
# [311]	valid_0's f1_score: 0.432953
# [312]	valid_0's f1_score: 0.432921
# [313]	valid_0's f1_score: 0.433204
# [314]	valid_0's f1_score: 0.433046
# [315]	valid_0's f1_score: 0.432887
# [316]	valid_0's f1_score: 0.432869
# [317]	valid_0's f1_score: 0.433076
# [318]	valid_0's f1_score: 0.433127
# [319]	valid_0's f1_score: 0.433031
# [320]	valid_0's f1_score: 0.433008
# [321]	valid_0's f1_score: 0.432973
# [322]	valid_0's f1_score: 0.433053
# [323]	valid_0's f1_score: 0.433126
# [324]	valid_0's f1_score: 0.433247
# [325]	valid_0's f1_score: 0.433
# [326]	valid_0's f1_score: 0.432966
# [327]	valid_0's f1_score: 0.433542
# [328]	valid_0's f1_score: 0.433445
# [329]	valid_0's f1_score: 0.433576
# [330]	valid_0's f1_score: 0.433462
# [331]	valid_0's f1_score: 0.433361
# [332]	valid_0's f1_score: 0.433292
# [333]	valid_0's f1_score: 0.433216
# [334]	valid_0's f1_score: 0.433312
# [335]	valid_0's f1_score: 0.433289
# [336]	valid_0's f1_score: 0.433108
# [337]	valid_0's f1_score: 0.433622
# [338]	valid_0's f1_score: 0.433721
# [339]	valid_0's f1_score: 0.433661
# [340]	valid_0's f1_score: 0.433674
# [341]	valid_0's f1_score: 0.433685
# [342]	valid_0's f1_score: 0.433697
# [343]	valid_0's f1_score: 0.434063
# [344]	valid_0's f1_score: 0.434212
# [345]	valid_0's f1_score: 0.434035
# [346]	valid_0's f1_score: 0.434173
# [347]	valid_0's f1_score: 0.434182
# [348]	valid_0's f1_score: 0.434444
# [349]	valid_0's f1_score: 0.434672
# [350]	valid_0's f1_score: 0.434775
# [351]	valid_0's f1_score: 0.434681
# [352]	valid_0's f1_score: 0.43482
# [353]	valid_0's f1_score: 0.434794
# [354]	valid_0's f1_score: 0.434823
# [355]	valid_0's f1_score: 0.434656
# [356]	valid_0's f1_score: 0.434915
# [357]	valid_0's f1_score: 0.43488
# [358]	valid_0's f1_score: 0.435166
# [359]	valid_0's f1_score: 0.434968
# [360]	valid_0's f1_score: 0.435215
# [361]	valid_0's f1_score: 0.435162
# [362]	valid_0's f1_score: 0.435079
# [363]	valid_0's f1_score: 0.435198
# [364]	valid_0's f1_score: 0.43533
# [365]	valid_0's f1_score: 0.435587
# [366]	valid_0's f1_score: 0.435439
# [367]	valid_0's f1_score: 0.43551
# [368]	valid_0's f1_score: 0.435527
# [369]	valid_0's f1_score: 0.435599
# [370]	valid_0's f1_score: 0.435777
# [371]	valid_0's f1_score: 0.435735
# [372]	valid_0's f1_score: 0.435661
# [373]	valid_0's f1_score: 0.435393
# [374]	valid_0's f1_score: 0.435414
# [375]	valid_0's f1_score: 0.435239
# [376]	valid_0's f1_score: 0.435349
# [377]	valid_0's f1_score: 0.435654
# [378]	valid_0's f1_score: 0.43561
# [379]	valid_0's f1_score: 0.4355
# [380]	valid_0's f1_score: 0.435936
# [381]	valid_0's f1_score: 0.43597
# [382]	valid_0's f1_score: 0.435907
# [383]	valid_0's f1_score: 0.43611
# [384]	valid_0's f1_score: 0.436137
# [385]	valid_0's f1_score: 0.43595
# [386]	valid_0's f1_score: 0.436262
# [387]	valid_0's f1_score: 0.436097
# [388]	valid_0's f1_score: 0.436282
# [389]	valid_0's f1_score: 0.436145
# [390]	valid_0's f1_score: 0.436398
# [391]	valid_0's f1_score: 0.436359
# [392]	valid_0's f1_score: 0.436545
# [393]	valid_0's f1_score: 0.436639
# [394]	valid_0's f1_score: 0.436485
# [395]	valid_0's f1_score: 0.436535
# [396]	valid_0's f1_score: 0.436582
# [397]	valid_0's f1_score: 0.436527
# [398]	valid_0's f1_score: 0.436734
# [399]	valid_0's f1_score: 0.436756
# [400]	valid_0's f1_score: 0.437116
# [401]	valid_0's f1_score: 0.437183
# [402]	valid_0's f1_score: 0.437092
# [403]	valid_0's f1_score: 0.437141
# [404]	valid_0's f1_score: 0.437266
# [405]	valid_0's f1_score: 0.437551
# [406]	valid_0's f1_score: 0.437299
# [407]	valid_0's f1_score: 0.437031
# [408]	valid_0's f1_score: 0.437099
# [409]	valid_0's f1_score: 0.437383
# [410]	valid_0's f1_score: 0.43758
# [411]	valid_0's f1_score: 0.43767
# [412]	valid_0's f1_score: 0.437559
# [413]	valid_0's f1_score: 0.43757
# [414]	valid_0's f1_score: 0.437578
# [415]	valid_0's f1_score: 0.437802
# [416]	valid_0's f1_score: 0.438123
# [417]	valid_0's f1_score: 0.438032
# [418]	valid_0's f1_score: 0.437901
# [419]	valid_0's f1_score: 0.437945
# [420]	valid_0's f1_score: 0.437967
# [421]	valid_0's f1_score: 0.438053
# [422]	valid_0's f1_score: 0.437993
# [423]	valid_0's f1_score: 0.438075
# [424]	valid_0's f1_score: 0.437959
# [425]	valid_0's f1_score: 0.437874
# [426]	valid_0's f1_score: 0.438239
# [427]	valid_0's f1_score: 0.438112
# [428]	valid_0's f1_score: 0.43819
# [429]	valid_0's f1_score: 0.438272
# [430]	valid_0's f1_score: 0.438071
# [431]	valid_0's f1_score: 0.438148
# [432]	valid_0's f1_score: 0.438316
# [433]	valid_0's f1_score: 0.43851
# [434]	valid_0's f1_score: 0.438559
# [435]	valid_0's f1_score: 0.438418
# [436]	valid_0's f1_score: 0.438518
# [437]	valid_0's f1_score: 0.438555
# [438]	valid_0's f1_score: 0.438559
# [439]	valid_0's f1_score: 0.438213
# [440]	valid_0's f1_score: 0.438361
# [441]	valid_0's f1_score: 0.438347
# [442]	valid_0's f1_score: 0.438561
# [443]	valid_0's f1_score: 0.438385
# [444]	valid_0's f1_score: 0.43845
# [445]	valid_0's f1_score: 0.438514
# [446]	valid_0's f1_score: 0.43857
# [447]	valid_0's f1_score: 0.438759
# [448]	valid_0's f1_score: 0.438707
# [449]	valid_0's f1_score: 0.439228
# [450]	valid_0's f1_score: 0.439151
# [451]	valid_0's f1_score: 0.439306
# [452]	valid_0's f1_score: 0.439328
# [453]	valid_0's f1_score: 0.439367
# [454]	valid_0's f1_score: 0.439401
# [455]	valid_0's f1_score: 0.43934
# [456]	valid_0's f1_score: 0.439325
# [457]	valid_0's f1_score: 0.439182
# [458]	valid_0's f1_score: 0.439547
# [459]	valid_0's f1_score: 0.439638
# [460]	valid_0's f1_score: 0.439681
# [461]	valid_0's f1_score: 0.439829
# [462]	valid_0's f1_score: 0.43976
# [463]	valid_0's f1_score: 0.439681
# [464]	valid_0's f1_score: 0.440146
# [465]	valid_0's f1_score: 0.439883
# [466]	valid_0's f1_score: 0.439767
# [467]	valid_0's f1_score: 0.440142
# [468]	valid_0's f1_score: 0.439952
# [469]	valid_0's f1_score: 0.439817
# [470]	valid_0's f1_score: 0.439672
# [471]	valid_0's f1_score: 0.439667
# [472]	valid_0's f1_score: 0.439617
# [473]	valid_0's f1_score: 0.439861
# [474]	valid_0's f1_score: 0.439778
# [475]	valid_0's f1_score: 0.439929
# [476]	valid_0's f1_score: 0.439775
# [477]	valid_0's f1_score: 0.439981
# [478]	valid_0's f1_score: 0.439967
# [479]	valid_0's f1_score: 0.439863
# [480]	valid_0's f1_score: 0.439833
# [481]	valid_0's f1_score: 0.44002
# [482]	valid_0's f1_score: 0.440199
# [483]	valid_0's f1_score: 0.440342
# [484]	valid_0's f1_score: 0.44041
# [485]	valid_0's f1_score: 0.440371
# [486]	valid_0's f1_score: 0.440392
# [487]	valid_0's f1_score: 0.44057
# [488]	valid_0's f1_score: 0.440538
# [489]	valid_0's f1_score: 0.440966
# [490]	valid_0's f1_score: 0.441147
# [491]	valid_0's f1_score: 0.441159
# [492]	valid_0's f1_score: 0.440953
# [493]	valid_0's f1_score: 0.440886
# [494]	valid_0's f1_score: 0.440552
# [495]	valid_0's f1_score: 0.441188
# [496]	valid_0's f1_score: 0.441039
# [497]	valid_0's f1_score: 0.441088
# [498]	valid_0's f1_score: 0.441292
# [499]	valid_0's f1_score: 0.441324
# [500]	valid_0's f1_score: 0.441341
# [501]	valid_0's f1_score: 0.44134
# [502]	valid_0's f1_score: 0.441551
# [503]	valid_0's f1_score: 0.441748
# [504]	valid_0's f1_score: 0.441784
# [505]	valid_0's f1_score: 0.441774
# [506]	valid_0's f1_score: 0.441855
# [507]	valid_0's f1_score: 0.44225
# [508]	valid_0's f1_score: 0.442194
# [509]	valid_0's f1_score: 0.442164
# [510]	valid_0's f1_score: 0.442209
# [511]	valid_0's f1_score: 0.442173
# [512]	valid_0's f1_score: 0.442269
# [513]	valid_0's f1_score: 0.442391
# [514]	valid_0's f1_score: 0.442318
# [515]	valid_0's f1_score: 0.442393
# [516]	valid_0's f1_score: 0.442489
# [517]	valid_0's f1_score: 0.442437
# [518]	valid_0's f1_score: 0.442306
# [519]	valid_0's f1_score: 0.442287
# [520]	valid_0's f1_score: 0.442611
# [521]	valid_0's f1_score: 0.442685
# [522]	valid_0's f1_score: 0.442713
# [523]	valid_0's f1_score: 0.442724
# [524]	valid_0's f1_score: 0.442761
# [525]	valid_0's f1_score: 0.442676
# [526]	valid_0's f1_score: 0.442691
# [527]	valid_0's f1_score: 0.442623
# [528]	valid_0's f1_score: 0.442516
# [529]	valid_0's f1_score: 0.442344
# [530]	valid_0's f1_score: 0.442446
# [531]	valid_0's f1_score: 0.442434
# [532]	valid_0's f1_score: 0.442713
# [533]	valid_0's f1_score: 0.442441
# [534]	valid_0's f1_score: 0.442654
# [535]	valid_0's f1_score: 0.442735
# [536]	valid_0's f1_score: 0.442739
# [537]	valid_0's f1_score: 0.442702
# [538]	valid_0's f1_score: 0.442976
# [539]	valid_0's f1_score: 0.442968
# [540]	valid_0's f1_score: 0.442856
# [541]	valid_0's f1_score: 0.442806
# [542]	valid_0's f1_score: 0.443049
# [543]	valid_0's f1_score: 0.443014
# [544]	valid_0's f1_score: 0.442857
# [545]	valid_0's f1_score: 0.442679
# [546]	valid_0's f1_score: 0.442944
# [547]	valid_0's f1_score: 0.443083
# [548]	valid_0's f1_score: 0.442786
# [549]	valid_0's f1_score: 0.442841
# [550]	valid_0's f1_score: 0.442869
# [551]	valid_0's f1_score: 0.442979
# [552]	valid_0's f1_score: 0.44307
# [553]	valid_0's f1_score: 0.443076
# [554]	valid_0's f1_score: 0.443045
# [555]	valid_0's f1_score: 0.443148
# [556]	valid_0's f1_score: 0.443136
# [557]	valid_0's f1_score: 0.443073
# [558]	valid_0's f1_score: 0.443044
# [559]	valid_0's f1_score: 0.443089
# [560]	valid_0's f1_score: 0.44341
# [561]	valid_0's f1_score: 0.443316
# [562]	valid_0's f1_score: 0.443223
# [563]	valid_0's f1_score: 0.443384
# [564]	valid_0's f1_score: 0.443307
# [565]	valid_0's f1_score: 0.4431
# [566]	valid_0's f1_score: 0.443087
# [567]	valid_0's f1_score: 0.443339
# [568]	valid_0's f1_score: 0.443198
# [569]	valid_0's f1_score: 0.443247
# [570]	valid_0's f1_score: 0.44323
# [571]	valid_0's f1_score: 0.443321
# [572]	valid_0's f1_score: 0.443603
# [573]	valid_0's f1_score: 0.443508
# [574]	valid_0's f1_score: 0.44351
# [575]	valid_0's f1_score: 0.443662
# [576]	valid_0's f1_score: 0.44363
# [577]	valid_0's f1_score: 0.443568
# [578]	valid_0's f1_score: 0.443513
# [579]	valid_0's f1_score: 0.443431
# [580]	valid_0's f1_score: 0.44336
# [581]	valid_0's f1_score: 0.443396
# [582]	valid_0's f1_score: 0.44326
# [583]	valid_0's f1_score: 0.443074
# [584]	valid_0's f1_score: 0.442917
# [585]	valid_0's f1_score: 0.442984
# [586]	valid_0's f1_score: 0.44304
# [587]	valid_0's f1_score: 0.443154
# [588]	valid_0's f1_score: 0.442963
# [589]	valid_0's f1_score: 0.442953
# [590]	valid_0's f1_score: 0.44293
# [591]	valid_0's f1_score: 0.44297
# [592]	valid_0's f1_score: 0.442897
# [593]	valid_0's f1_score: 0.443341
# [594]	valid_0's f1_score: 0.443396
# [595]	valid_0's f1_score: 0.443377
# [596]	valid_0's f1_score: 0.443265
# [597]	valid_0's f1_score: 0.443285
# [598]	valid_0's f1_score: 0.443252
# [599]	valid_0's f1_score: 0.443004
# [600]	valid_0's f1_score: 0.44329
# [601]	valid_0's f1_score: 0.443315
# [602]	valid_0's f1_score: 0.443326
# [603]	valid_0's f1_score: 0.443454
# [604]	valid_0's f1_score: 0.443433
# [605]	valid_0's f1_score: 0.443439
# [606]	valid_0's f1_score: 0.443545
# [607]	valid_0's f1_score: 0.443619
# [608]	valid_0's f1_score: 0.44363
# [609]	valid_0's f1_score: 0.443789
# [610]	valid_0's f1_score: 0.443517
# [611]	valid_0's f1_score: 0.443494
# [612]	valid_0's f1_score: 0.443659
# [613]	valid_0's f1_score: 0.443655
# [614]	valid_0's f1_score: 0.4436
# [615]	valid_0's f1_score: 0.443809
# [616]	valid_0's f1_score: 0.443638
# [617]	valid_0's f1_score: 0.443619
# [618]	valid_0's f1_score: 0.443578
# [619]	valid_0's f1_score: 0.443342
# [620]	valid_0's f1_score: 0.443324
# [621]	valid_0's f1_score: 0.443379
# [622]	valid_0's f1_score: 0.443168
# [623]	valid_0's f1_score: 0.443395
# [624]	valid_0's f1_score: 0.443414
# [625]	valid_0's f1_score: 0.443764
# [626]	valid_0's f1_score: 0.444064
# [627]	valid_0's f1_score: 0.444111
# [628]	valid_0's f1_score: 0.44414
# [629]	valid_0's f1_score: 0.444026
# [630]	valid_0's f1_score: 0.444029
# [631]	valid_0's f1_score: 0.444418
# [632]	valid_0's f1_score: 0.444713
# [633]	valid_0's f1_score: 0.444615
# [634]	valid_0's f1_score: 0.444554
# [635]	valid_0's f1_score: 0.444845
# [636]	valid_0's f1_score: 0.444881
# [637]	valid_0's f1_score: 0.444955
# [638]	valid_0's f1_score: 0.444949
# [639]	valid_0's f1_score: 0.444911
# [640]	valid_0's f1_score: 0.444724
# [641]	valid_0's f1_score: 0.444789
# [642]	valid_0's f1_score: 0.444798
# [643]	valid_0's f1_score: 0.444848
# [644]	valid_0's f1_score: 0.444835
# [645]	valid_0's f1_score: 0.44481
# [646]	valid_0's f1_score: 0.445046
# [647]	valid_0's f1_score: 0.445356
# [648]	valid_0's f1_score: 0.445428
# [649]	valid_0's f1_score: 0.445222
# [650]	valid_0's f1_score: 0.44523
# [651]	valid_0's f1_score: 0.445262
# [652]	valid_0's f1_score: 0.445157
# [653]	valid_0's f1_score: 0.445183
# [654]	valid_0's f1_score: 0.445222
# [655]	valid_0's f1_score: 0.445128
# [656]	valid_0's f1_score: 0.445429
# [657]	valid_0's f1_score: 0.445224
# [658]	valid_0's f1_score: 0.445105
# [659]	valid_0's f1_score: 0.445031
# [660]	valid_0's f1_score: 0.445261
# [661]	valid_0's f1_score: 0.445302
# [662]	valid_0's f1_score: 0.445072
# [663]	valid_0's f1_score: 0.445045
# [664]	valid_0's f1_score: 0.444966
# [665]	valid_0's f1_score: 0.444932
# [666]	valid_0's f1_score: 0.444846
# [667]	valid_0's f1_score: 0.444901
# [668]	valid_0's f1_score: 0.444855
# [669]	valid_0's f1_score: 0.444935
# [670]	valid_0's f1_score: 0.445013
# [671]	valid_0's f1_score: 0.445085
# [672]	valid_0's f1_score: 0.445104
# [673]	valid_0's f1_score: 0.444968
# [674]	valid_0's f1_score: 0.444994
# [675]	valid_0's f1_score: 0.445034
# [676]	valid_0's f1_score: 0.445074
# [677]	valid_0's f1_score: 0.445481
# [678]	valid_0's f1_score: 0.445526
# [679]	valid_0's f1_score: 0.445685
# [680]	valid_0's f1_score: 0.445704
# [681]	valid_0's f1_score: 0.445593
# [682]	valid_0's f1_score: 0.445527
# [683]	valid_0's f1_score: 0.445545
# [684]	valid_0's f1_score: 0.445584
# [685]	valid_0's f1_score: 0.445526
# [686]	valid_0's f1_score: 0.445786
# [687]	valid_0's f1_score: 0.445721
# [688]	valid_0's f1_score: 0.445621
# [689]	valid_0's f1_score: 0.44592
# [690]	valid_0's f1_score: 0.445713
# [691]	valid_0's f1_score: 0.445734
# [692]	valid_0's f1_score: 0.445703
# [693]	valid_0's f1_score: 0.446087
# [694]	valid_0's f1_score: 0.446065
# [695]	valid_0's f1_score: 0.44599
# [696]	valid_0's f1_score: 0.446036
# [697]	valid_0's f1_score: 0.445806
# [698]	valid_0's f1_score: 0.445997
# [699]	valid_0's f1_score: 0.446119
# [700]	valid_0's f1_score: 0.445792
# [701]	valid_0's f1_score: 0.445876
# [702]	valid_0's f1_score: 0.44597
# [703]	valid_0's f1_score: 0.445997
# [704]	valid_0's f1_score: 0.445927
# [705]	valid_0's f1_score: 0.445995
# [706]	valid_0's f1_score: 0.446043
# [707]	valid_0's f1_score: 0.446033
# [708]	valid_0's f1_score: 0.446112
# [709]	valid_0's f1_score: 0.446505
# [710]	valid_0's f1_score: 0.446375
# [711]	valid_0's f1_score: 0.446312
# [712]	valid_0's f1_score: 0.446423
# [713]	valid_0's f1_score: 0.446418
# [714]	valid_0's f1_score: 0.446545
# [715]	valid_0's f1_score: 0.446578
# [716]	valid_0's f1_score: 0.446908
# [717]	valid_0's f1_score: 0.44685
# [718]	valid_0's f1_score: 0.446791
# [719]	valid_0's f1_score: 0.446749
# [720]	valid_0's f1_score: 0.446793
# [721]	valid_0's f1_score: 0.446889
# [722]	valid_0's f1_score: 0.446937
# [723]	valid_0's f1_score: 0.44717
# [724]	valid_0's f1_score: 0.447272
# [725]	valid_0's f1_score: 0.447297
# [726]	valid_0's f1_score: 0.447424
# [727]	valid_0's f1_score: 0.447585
# [728]	valid_0's f1_score: 0.447692
# [729]	valid_0's f1_score: 0.447696
# [730]	valid_0's f1_score: 0.447422
# [731]	valid_0's f1_score: 0.447424
# [732]	valid_0's f1_score: 0.447434
# [733]	valid_0's f1_score: 0.447707
# [734]	valid_0's f1_score: 0.447594
# [735]	valid_0's f1_score: 0.447415
# [736]	valid_0's f1_score: 0.447395
# [737]	valid_0's f1_score: 0.447529
# [738]	valid_0's f1_score: 0.447524
# [739]	valid_0's f1_score: 0.447747
# [740]	valid_0's f1_score: 0.447723
# [741]	valid_0's f1_score: 0.447731
# [742]	valid_0's f1_score: 0.447901
# [743]	valid_0's f1_score: 0.447941
# [744]	valid_0's f1_score: 0.448038
# [745]	valid_0's f1_score: 0.448154
# [746]	valid_0's f1_score: 0.447954
# [747]	valid_0's f1_score: 0.447961
# [748]	valid_0's f1_score: 0.447937
# [749]	valid_0's f1_score: 0.447952
# [750]	valid_0's f1_score: 0.448117
# [751]	valid_0's f1_score: 0.448229
# [752]	valid_0's f1_score: 0.448195
# [753]	valid_0's f1_score: 0.447977
# [754]	valid_0's f1_score: 0.44809
# [755]	valid_0's f1_score: 0.447925
# [756]	valid_0's f1_score: 0.447859
# [757]	valid_0's f1_score: 0.447856
# [758]	valid_0's f1_score: 0.448076
# [759]	valid_0's f1_score: 0.447964
# [760]	valid_0's f1_score: 0.447921
# [761]	valid_0's f1_score: 0.448164
# [762]	valid_0's f1_score: 0.448344
# [763]	valid_0's f1_score: 0.448232
# [764]	valid_0's f1_score: 0.448295
# [765]	valid_0's f1_score: 0.448261
# [766]	valid_0's f1_score: 0.448644
# [767]	valid_0's f1_score: 0.448663
# [768]	valid_0's f1_score: 0.448646
# [769]	valid_0's f1_score: 0.448472
# [770]	valid_0's f1_score: 0.448458
# [771]	valid_0's f1_score: 0.448433
# [772]	valid_0's f1_score: 0.448423
# [773]	valid_0's f1_score: 0.448389
# [774]	valid_0's f1_score: 0.448435
# [775]	valid_0's f1_score: 0.448348
# [776]	valid_0's f1_score: 0.448335
# [777]	valid_0's f1_score: 0.44832
# [778]	valid_0's f1_score: 0.448536
# [779]	valid_0's f1_score: 0.448507
# [780]	valid_0's f1_score: 0.448508
# [781]	valid_0's f1_score: 0.448298
# [782]	valid_0's f1_score: 0.448469
# [783]	valid_0's f1_score: 0.448382
# [784]	valid_0's f1_score: 0.448508
# [785]	valid_0's f1_score: 0.448408
# [786]	valid_0's f1_score: 0.44838
# [787]	valid_0's f1_score: 0.448325
# [788]	valid_0's f1_score: 0.448351
# [789]	valid_0's f1_score: 0.44851
# [790]	valid_0's f1_score: 0.448592
# [791]	valid_0's f1_score: 0.448889
# [792]	valid_0's f1_score: 0.448893
# [793]	valid_0's f1_score: 0.448727
# [794]	valid_0's f1_score: 0.448636
# [795]	valid_0's f1_score: 0.449018
# [796]	valid_0's f1_score: 0.449034
# [797]	valid_0's f1_score: 0.449022
# [798]	valid_0's f1_score: 0.44906
# [799]	valid_0's f1_score: 0.448843
# [800]	valid_0's f1_score: 0.44884
# [801]	valid_0's f1_score: 0.449119
# [802]	valid_0's f1_score: 0.449131
# [803]	valid_0's f1_score: 0.449178
# [804]	valid_0's f1_score: 0.449172
# [805]	valid_0's f1_score: 0.449124
# [806]	valid_0's f1_score: 0.44909
# [807]	valid_0's f1_score: 0.44925
# [808]	valid_0's f1_score: 0.449618
# [809]	valid_0's f1_score: 0.449607
# [810]	valid_0's f1_score: 0.449451
# [811]	valid_0's f1_score: 0.449326
# [812]	valid_0's f1_score: 0.449342
# [813]	valid_0's f1_score: 0.449401
# [814]	valid_0's f1_score: 0.449461
# [815]	valid_0's f1_score: 0.449404
# [816]	valid_0's f1_score: 0.44946
# [817]	valid_0's f1_score: 0.449516
# [818]	valid_0's f1_score: 0.449523
# [819]	valid_0's f1_score: 0.449334
# [820]	valid_0's f1_score: 0.449381
# [821]	valid_0's f1_score: 0.449517
# [822]	valid_0's f1_score: 0.449458
# [823]	valid_0's f1_score: 0.449825
# [824]	valid_0's f1_score: 0.44991
# [825]	valid_0's f1_score: 0.449573
# [826]	valid_0's f1_score: 0.449621
# [827]	valid_0's f1_score: 0.44965
# [828]	valid_0's f1_score: 0.449894
# [829]	valid_0's f1_score: 0.450158
# [830]	valid_0's f1_score: 0.450112
# [831]	valid_0's f1_score: 0.450091
# [832]	valid_0's f1_score: 0.450245
# [833]	valid_0's f1_score: 0.450241
# [834]	valid_0's f1_score: 0.450248
# [835]	valid_0's f1_score: 0.450259
# [836]	valid_0's f1_score: 0.45025
# [837]	valid_0's f1_score: 0.450439
# [838]	valid_0's f1_score: 0.450472
# [839]	valid_0's f1_score: 0.450323
# [840]	valid_0's f1_score: 0.45047
# [841]	valid_0's f1_score: 0.450643
# [842]	valid_0's f1_score: 0.450592
# [843]	valid_0's f1_score: 0.450688
# [844]	valid_0's f1_score: 0.450667
# [845]	valid_0's f1_score: 0.450656
# [846]	valid_0's f1_score: 0.450667
# [847]	valid_0's f1_score: 0.450771
# [848]	valid_0's f1_score: 0.450832
# [849]	valid_0's f1_score: 0.450808
# [850]	valid_0's f1_score: 0.451144
# [851]	valid_0's f1_score: 0.451077
# [852]	valid_0's f1_score: 0.45103
# [853]	valid_0's f1_score: 0.451067
# [854]	valid_0's f1_score: 0.45112
# [855]	valid_0's f1_score: 0.451127
# [856]	valid_0's f1_score: 0.451123
# [857]	valid_0's f1_score: 0.451128
# [858]	valid_0's f1_score: 0.451198
# [859]	valid_0's f1_score: 0.451328
# [860]	valid_0's f1_score: 0.451239
# [861]	valid_0's f1_score: 0.451345
# [862]	valid_0's f1_score: 0.451314
# [863]	valid_0's f1_score: 0.451323
# [864]	valid_0's f1_score: 0.451261
# [865]	valid_0's f1_score: 0.451542
# [866]	valid_0's f1_score: 0.45148
# [867]	valid_0's f1_score: 0.451831
# [868]	valid_0's f1_score: 0.451892
# [869]	valid_0's f1_score: 0.452023
# [870]	valid_0's f1_score: 0.45216
# [871]	valid_0's f1_score: 0.452048
# [872]	valid_0's f1_score: 0.451888
# [873]	valid_0's f1_score: 0.451872
# [874]	valid_0's f1_score: 0.451691
# [875]	valid_0's f1_score: 0.45176
# [876]	valid_0's f1_score: 0.451769
# [877]	valid_0's f1_score: 0.451767
# [878]	valid_0's f1_score: 0.452174
# [879]	valid_0's f1_score: 0.452091
# [880]	valid_0's f1_score: 0.452061
# [881]	valid_0's f1_score: 0.452089
# [882]	valid_0's f1_score: 0.451815
# [883]	valid_0's f1_score: 0.451869
# [884]	valid_0's f1_score: 0.451622
# [885]	valid_0's f1_score: 0.451893
# [886]	valid_0's f1_score: 0.451757
# [887]	valid_0's f1_score: 0.451801
# [888]	valid_0's f1_score: 0.451875
# [889]	valid_0's f1_score: 0.451777
# [890]	valid_0's f1_score: 0.4518
# [891]	valid_0's f1_score: 0.452056
# [892]	valid_0's f1_score: 0.451953
# [893]	valid_0's f1_score: 0.451907
# [894]	valid_0's f1_score: 0.452043
# [895]	valid_0's f1_score: 0.451993
# [896]	valid_0's f1_score: 0.451961
# [897]	valid_0's f1_score: 0.451918
# [898]	valid_0's f1_score: 0.45194
# [899]	valid_0's f1_score: 0.451675
# [900]	valid_0's f1_score: 0.452017
# [901]	valid_0's f1_score: 0.452468
# [902]	valid_0's f1_score: 0.452351
# [903]	valid_0's f1_score: 0.452596
# [904]	valid_0's f1_score: 0.452987
# [905]	valid_0's f1_score: 0.452949
# [906]	valid_0's f1_score: 0.452905
# [907]	valid_0's f1_score: 0.452871
# [908]	valid_0's f1_score: 0.452844
# [909]	valid_0's f1_score: 0.45288
# [910]	valid_0's f1_score: 0.452924
# [911]	valid_0's f1_score: 0.453293
# [912]	valid_0's f1_score: 0.453336
# [913]	valid_0's f1_score: 0.453369
# [914]	valid_0's f1_score: 0.453582
# [915]	valid_0's f1_score: 0.45349
# [916]	valid_0's f1_score: 0.453472
# [917]	valid_0's f1_score: 0.453441
# [918]	valid_0's f1_score: 0.45344
# [919]	valid_0's f1_score: 0.453357
# [920]	valid_0's f1_score: 0.453342
# [921]	valid_0's f1_score: 0.453283
# [922]	valid_0's f1_score: 0.453322
# [923]	valid_0's f1_score: 0.453298
# [924]	valid_0's f1_score: 0.453532
# [925]	valid_0's f1_score: 0.453739
# [926]	valid_0's f1_score: 0.453756
# [927]	valid_0's f1_score: 0.453734
# [928]	valid_0's f1_score: 0.453746
# [929]	valid_0's f1_score: 0.453844
# [930]	valid_0's f1_score: 0.453969
# [931]	valid_0's f1_score: 0.45396
# [932]	valid_0's f1_score: 0.453996
# [933]	valid_0's f1_score: 0.453986
# [934]	valid_0's f1_score: 0.453969
# [935]	valid_0's f1_score: 0.454016
# [936]	valid_0's f1_score: 0.453812
# [937]	valid_0's f1_score: 0.453716
# [938]	valid_0's f1_score: 0.453935
# [939]	valid_0's f1_score: 0.453933
# [940]	valid_0's f1_score: 0.454135
# [941]	valid_0's f1_score: 0.45413
# [942]	valid_0's f1_score: 0.454149
# [943]	valid_0's f1_score: 0.454109
# [944]	valid_0's f1_score: 0.454127
# [945]	valid_0's f1_score: 0.454108
# [946]	valid_0's f1_score: 0.453975
# [947]	valid_0's f1_score: 0.454339
# [948]	valid_0's f1_score: 0.454451
# [949]	valid_0's f1_score: 0.454307
# [950]	valid_0's f1_score: 0.454465
# [951]	valid_0's f1_score: 0.454593
# [952]	valid_0's f1_score: 0.454562
# [953]	valid_0's f1_score: 0.454688
# [954]	valid_0's f1_score: 0.454682
# [955]	valid_0's f1_score: 0.454716
# [956]	valid_0's f1_score: 0.454828
# [957]	valid_0's f1_score: 0.454628
# [958]	valid_0's f1_score: 0.454599
# [959]	valid_0's f1_score: 0.454765
# [960]	valid_0's f1_score: 0.454659
# [961]	valid_0's f1_score: 0.454731
# [962]	valid_0's f1_score: 0.455033
# [963]	valid_0's f1_score: 0.45541
# [964]	valid_0's f1_score: 0.455427
# [965]	valid_0's f1_score: 0.455315
# [966]	valid_0's f1_score: 0.455375
# [967]	valid_0's f1_score: 0.455286
# [968]	valid_0's f1_score: 0.455265
# [969]	valid_0's f1_score: 0.455187
# [970]	valid_0's f1_score: 0.455232
# [971]	valid_0's f1_score: 0.455431
# [972]	valid_0's f1_score: 0.455606
# [973]	valid_0's f1_score: 0.455636
# [974]	valid_0's f1_score: 0.455595
# [975]	valid_0's f1_score: 0.455593
# [976]	valid_0's f1_score: 0.455417
# [977]	valid_0's f1_score: 0.455254
# [978]	valid_0's f1_score: 0.455391
# [979]	valid_0's f1_score: 0.455442
# [980]	valid_0's f1_score: 0.455575
# [981]	valid_0's f1_score: 0.455565
# [982]	valid_0's f1_score: 0.455557
# [983]	valid_0's f1_score: 0.455743
# [984]	valid_0's f1_score: 0.455602
# [985]	valid_0's f1_score: 0.455689
# [986]	valid_0's f1_score: 0.455897
# [987]	valid_0's f1_score: 0.455801
# [988]	valid_0's f1_score: 0.455832
# [989]	valid_0's f1_score: 0.455862
# [990]	valid_0's f1_score: 0.455884
# [991]	valid_0's f1_score: 0.456441
# [992]	valid_0's f1_score: 0.456459
# [993]	valid_0's f1_score: 0.456381
# [994]	valid_0's f1_score: 0.456213
# [995]	valid_0's f1_score: 0.456224
# [996]	valid_0's f1_score: 0.456116
# [997]	valid_0's f1_score: 0.456502
# [998]	valid_0's f1_score: 0.456473
# [999]	valid_0's f1_score: 0.456605
# [1000]	valid_0's f1_score: 0.456581

# %%
with open('lgb_model8_fold4.pkl', 'wb') as fout:
    pickle.dump(model, fout)
