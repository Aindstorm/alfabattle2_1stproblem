# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
import math
import os
import gc
import sys
import pickle
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, plot_confusion_matrix, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, CatBoostRegressor, Pool, cv, sum_models
import lightgbm as lgb
import xgboost as xgb
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight
from six.moves import xrange
from sklearn import preprocessing
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
def reduce_mem_usage(df):
    """ 
    iterate through all the columns of a dataframe and 
    modify the data type to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage of dataframe is {:.2f}' 
                     'MB').format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max <\
                  np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max <\
                   np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max <\
                   np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max <\
                   np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max <\
                   np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max <\
                   np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
    end_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage after optimization is: {:.2f}' 
                              'MB').format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) 
                                             / start_mem))
    
    return df

# %%
df_train = pd.read_csv("alfa1_df_train6.csv")
df_valid = pd.read_csv("alfa1_df_valid6.csv")

# %%
df_train.fillna('nothing', inplace=True)
df_valid.fillna('nothing', inplace=True)

# %%
df_train = reduce_mem_usage(df_train)
df_valid = reduce_mem_usage(df_valid)
# Out:
# Memory usage of dataframe is 1775.78MB
# Memory usage after optimization is: 337.39MB
# Decreased by 81.0%
# Memory usage of dataframe is 49.16MB
# Memory usage after optimization is: 12.29MB
# Decreased by 75.0%

# %%
df_train_exp = pd.read_csv("alfa1_df_train10.csv")
df_valid_exp = pd.read_csv("alfa1_df_valid10.csv")

# %%
df_train_exp = reduce_mem_usage(df_train_exp)
df_valid_exp = reduce_mem_usage(df_valid_exp)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp1 = pd.read_csv("alfa1_df_train11.csv")
df_valid_exp1 = pd.read_csv("alfa1_df_valid11.csv")

# %%
df_train_exp1 = reduce_mem_usage(df_train_exp1)
df_valid_exp1 = reduce_mem_usage(df_valid_exp1)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
df_train_exp2 = pd.read_csv("alfa1_df_train12.csv")
df_valid_exp2 = pd.read_csv("alfa1_df_valid12.csv")

# %%
df_train_exp2 = reduce_mem_usage(df_train_exp2)
df_valid_exp2 = reduce_mem_usage(df_valid_exp2)
# Out:
# Memory usage of dataframe is 1369.27MB
# Memory usage after optimization is: 345.40MB
# Decreased by 74.8%
# Memory usage of dataframe is 37.91MB
# Memory usage after optimization is: 12.50MB
# Decreased by 67.0%

# %%
aug = df_train_exp.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug1 = df_train_exp1.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns
aug2 = df_train_exp2.drop(['client_pin', 'lag_1', 'lag_2', 'weight'], axis=1).columns

# %%
df_train[aug] = df_train_exp[aug]
df_valid[aug] = df_valid_exp[aug]
df_train[aug1] = df_train_exp1[aug1]
df_valid[aug1] = df_valid_exp1[aug1]
df_train[aug2] = df_train_exp2[aug2]
df_valid[aug2] = df_valid_exp2[aug2]

# %%
from_parq = ['application_id', 'event_type', 'event_category', 'event_name', 'device_screen_name', 'timezone', 'net_connection_type', 'net_connection_tech']

# %%
trn_input_lag_cols = []
for i in range(2, 36):
        trn_input_lag_cols.append(f'lag_{i}')

# %%
to_drop = []
to_drop.append('lag_1')
to_drop.append('client_pin')
to_drop.append('weight')
to_drop.append('class_weight')

# %%
categorical = trn_input_lag_cols + from_parq + ['most_popular']

# %%
df_weight = pd.DataFrame()
df_weight['lag_1'] = df_train['lag_1'].unique()
df_weight['class_weight'] = compute_class_weight(classes=df_train['lag_1'].unique(), y=df_train['lag_1'], class_weight='balanced')**0.5

# %%
df_train = df_train.merge(df_weight, how='left', on='lag_1')
df_valid = df_valid.merge(df_weight, how='left', on='lag_1')

# %%
weights = np.array(df_train['weight'])**2 * np.array(df_train['class_weight'])
weights_val = np.array(df_valid['weight'])**2 * np.array(df_valid['class_weight'])

# %%
le1 = preprocessing.LabelEncoder()
le1.fit(df_valid['lag_1'].unique())
# Out:
# LabelEncoder()

# %%
df_train['lag_1'] = le1.transform(df_train['lag_1'])
df_valid['lag_1'] = le1.transform(df_valid['lag_1'])

# %%
X, y = pd.DataFrame(pd.concat((df_valid.drop(to_drop, axis=1), df_train.drop(to_drop, axis=1))).reset_index(drop=True)), pd.concat((df_valid['lag_1'], df_train['lag_1'])).reset_index(drop=True)
weights = np.concatenate([weights_val,weights])

# %%
X['event_type'] = X['event_type'].astype('category')
X['net_connection_tech'] = X['net_connection_tech'].astype('category')

# %%
n_splits = 8
folds = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=777)

# %%
trn_idx, val_idx = list(folds.split(X, y))[6]

# %%
X, y = X.iloc[trn_idx],  y.iloc[trn_idx]
weights = weights[trn_idx, ]

# %%
lgb_train = lgb.Dataset(X, y, weight=weights)
lgb_eval = lgb.Dataset(df_valid.drop(to_drop, axis=1), df_valid['lag_1'], reference=lgb_train, weight=weights_val)

# %%
def evalerror(preds, dtrain):
    labels = dtrain.get_label()
    preds = preds.reshape(10, -1).T
    preds = preds.argmax(axis = 1)
    f_score = f1_score(labels , preds,  average = 'macro')
    return 'f1_score', f_score, True

# %%
tree_params = {
    "objective" : "multiclass",
    'metric':'custom',
    "num_class" : 10,
    'learning_rate': 0.12,
    'max_depth': 5,
    'n_jobs': 5,
    "num_leaves" : 24,
    'boosting':'dart',
    "bagging_fraction" : 0.9,  # subsample
    "feature_fraction" : 0.9,  # colsample_bytree
    "bagging_freq" : 5,        # subsample_freq
    "bagging_seed" : 2020,
    'n_estimators': 1000
}

# %%
model = lgb.train(tree_params, 
                  lgb_train,
                  feval = evalerror,
                  valid_sets=[lgb_eval],
                  early_stopping_rounds=250)
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's f1_score: 0.0603859
# /opt/conda/lib/python3.7/site-packages/lightgbm/callback.py:188: UserWarning: Early stopping is not available in dart mode
#   warnings.warn('Early stopping is not available in dart mode')
# [2]	valid_0's f1_score: 0.141858
# [3]	valid_0's f1_score: 0.22864
# [4]	valid_0's f1_score: 0.313181
# [5]	valid_0's f1_score: 0.356835
# [6]	valid_0's f1_score: 0.379498
# [7]	valid_0's f1_score: 0.391929
# [8]	valid_0's f1_score: 0.382797
# [9]	valid_0's f1_score: 0.395373
# [10]	valid_0's f1_score: 0.401253
# [11]	valid_0's f1_score: 0.404843
# [12]	valid_0's f1_score: 0.40323
# [13]	valid_0's f1_score: 0.406315
# [14]	valid_0's f1_score: 0.408438
# [15]	valid_0's f1_score: 0.409548
# [16]	valid_0's f1_score: 0.411538
# [17]	valid_0's f1_score: 0.41223
# [18]	valid_0's f1_score: 0.412927
# [19]	valid_0's f1_score: 0.41386
# [20]	valid_0's f1_score: 0.414282
# [21]	valid_0's f1_score: 0.41429
# [22]	valid_0's f1_score: 0.414651
# [23]	valid_0's f1_score: 0.415589
# [24]	valid_0's f1_score: 0.416699
# [25]	valid_0's f1_score: 0.417044
# [26]	valid_0's f1_score: 0.417425
# [27]	valid_0's f1_score: 0.417709
# [28]	valid_0's f1_score: 0.418015
# [29]	valid_0's f1_score: 0.418317
# [30]	valid_0's f1_score: 0.418843
# [31]	valid_0's f1_score: 0.418773
# [32]	valid_0's f1_score: 0.419237
# [33]	valid_0's f1_score: 0.419803
# [34]	valid_0's f1_score: 0.420153
# [35]	valid_0's f1_score: 0.420134
# [36]	valid_0's f1_score: 0.419728
# [37]	valid_0's f1_score: 0.420248
# [38]	valid_0's f1_score: 0.419883
# [39]	valid_0's f1_score: 0.420324
# [40]	valid_0's f1_score: 0.420655
# [41]	valid_0's f1_score: 0.420588
# [42]	valid_0's f1_score: 0.42109
# [43]	valid_0's f1_score: 0.421276
# [44]	valid_0's f1_score: 0.421818
# [45]	valid_0's f1_score: 0.421749
# [46]	valid_0's f1_score: 0.420917
# [47]	valid_0's f1_score: 0.420973
# [48]	valid_0's f1_score: 0.421189
# [49]	valid_0's f1_score: 0.421321
# [50]	valid_0's f1_score: 0.421884
# [51]	valid_0's f1_score: 0.421627
# [52]	valid_0's f1_score: 0.421767
# [53]	valid_0's f1_score: 0.422061
# [54]	valid_0's f1_score: 0.422221
# [55]	valid_0's f1_score: 0.422346
# [56]	valid_0's f1_score: 0.422405
# [57]	valid_0's f1_score: 0.42221
# [58]	valid_0's f1_score: 0.421086
# [59]	valid_0's f1_score: 0.421262
# [60]	valid_0's f1_score: 0.421628
# [61]	valid_0's f1_score: 0.420175
# [62]	valid_0's f1_score: 0.420715
# [63]	valid_0's f1_score: 0.421233
# [64]	valid_0's f1_score: 0.42149
# [65]	valid_0's f1_score: 0.421626
# [66]	valid_0's f1_score: 0.422096
# [67]	valid_0's f1_score: 0.421875
# [68]	valid_0's f1_score: 0.422711
# [69]	valid_0's f1_score: 0.422952
# [70]	valid_0's f1_score: 0.422596
# [71]	valid_0's f1_score: 0.422941
# [72]	valid_0's f1_score: 0.422889
# [73]	valid_0's f1_score: 0.422954
# [74]	valid_0's f1_score: 0.422955
# [75]	valid_0's f1_score: 0.42275
# [76]	valid_0's f1_score: 0.422918
# [77]	valid_0's f1_score: 0.422817
# [78]	valid_0's f1_score: 0.42269
# [79]	valid_0's f1_score: 0.423187
# [80]	valid_0's f1_score: 0.42273
# [81]	valid_0's f1_score: 0.422756
# [82]	valid_0's f1_score: 0.423086
# [83]	valid_0's f1_score: 0.423157
# [84]	valid_0's f1_score: 0.423146
# [85]	valid_0's f1_score: 0.423227
# [86]	valid_0's f1_score: 0.423167
# [87]	valid_0's f1_score: 0.423566
# [88]	valid_0's f1_score: 0.423639
# [89]	valid_0's f1_score: 0.423738
# [90]	valid_0's f1_score: 0.423787
# [91]	valid_0's f1_score: 0.423681
# [92]	valid_0's f1_score: 0.423379
# [93]	valid_0's f1_score: 0.423532
# [94]	valid_0's f1_score: 0.423683
# [95]	valid_0's f1_score: 0.423588
# [96]	valid_0's f1_score: 0.423446
# [97]	valid_0's f1_score: 0.423552
# [98]	valid_0's f1_score: 0.423461
# [99]	valid_0's f1_score: 0.423584
# [100]	valid_0's f1_score: 0.423943
# [101]	valid_0's f1_score: 0.423826
# [102]	valid_0's f1_score: 0.423739
# [103]	valid_0's f1_score: 0.423726
# [104]	valid_0's f1_score: 0.424247
# [105]	valid_0's f1_score: 0.423896
# [106]	valid_0's f1_score: 0.423951
# [107]	valid_0's f1_score: 0.424178
# [108]	valid_0's f1_score: 0.424075
# [109]	valid_0's f1_score: 0.42424
# [110]	valid_0's f1_score: 0.424272
# [111]	valid_0's f1_score: 0.424169
# [112]	valid_0's f1_score: 0.424301
# [113]	valid_0's f1_score: 0.423917
# [114]	valid_0's f1_score: 0.424355
# [115]	valid_0's f1_score: 0.424614
# [116]	valid_0's f1_score: 0.424614
# [117]	valid_0's f1_score: 0.424737
# [118]	valid_0's f1_score: 0.42488
# [119]	valid_0's f1_score: 0.424902
# [120]	valid_0's f1_score: 0.424739
# [121]	valid_0's f1_score: 0.424867
# [122]	valid_0's f1_score: 0.424946
# [123]	valid_0's f1_score: 0.424814
# [124]	valid_0's f1_score: 0.424986
# [125]	valid_0's f1_score: 0.425143
# [126]	valid_0's f1_score: 0.425039
# [127]	valid_0's f1_score: 0.425535
# [128]	valid_0's f1_score: 0.425485
# [129]	valid_0's f1_score: 0.425596
# [130]	valid_0's f1_score: 0.425881
# [131]	valid_0's f1_score: 0.425666
# [132]	valid_0's f1_score: 0.42611
# [133]	valid_0's f1_score: 0.426061
# [134]	valid_0's f1_score: 0.426008
# [135]	valid_0's f1_score: 0.425826
# [136]	valid_0's f1_score: 0.425409
# [137]	valid_0's f1_score: 0.425469
# [138]	valid_0's f1_score: 0.425688
# [139]	valid_0's f1_score: 0.42584
# [140]	valid_0's f1_score: 0.426095
# [141]	valid_0's f1_score: 0.425788
# [142]	valid_0's f1_score: 0.425687
# [143]	valid_0's f1_score: 0.426009
# [144]	valid_0's f1_score: 0.425889
# [145]	valid_0's f1_score: 0.425692
# [146]	valid_0's f1_score: 0.425811
# [147]	valid_0's f1_score: 0.425718
# [148]	valid_0's f1_score: 0.42575
# [149]	valid_0's f1_score: 0.425923
# [150]	valid_0's f1_score: 0.42613
# [151]	valid_0's f1_score: 0.425967
# [152]	valid_0's f1_score: 0.425817
# [153]	valid_0's f1_score: 0.425483
# [154]	valid_0's f1_score: 0.42566
# [155]	valid_0's f1_score: 0.425902
# [156]	valid_0's f1_score: 0.425875
# [157]	valid_0's f1_score: 0.425849
# [158]	valid_0's f1_score: 0.425847
# [159]	valid_0's f1_score: 0.42592
# [160]	valid_0's f1_score: 0.425889
# [161]	valid_0's f1_score: 0.425893
# [162]	valid_0's f1_score: 0.426125
# [163]	valid_0's f1_score: 0.426147
# [164]	valid_0's f1_score: 0.42639
# [165]	valid_0's f1_score: 0.426581
# [166]	valid_0's f1_score: 0.426541
# [167]	valid_0's f1_score: 0.426683
# [168]	valid_0's f1_score: 0.426935
# [169]	valid_0's f1_score: 0.427052
# [170]	valid_0's f1_score: 0.426782
# [171]	valid_0's f1_score: 0.427007
# [172]	valid_0's f1_score: 0.426862
# [173]	valid_0's f1_score: 0.426697
# [174]	valid_0's f1_score: 0.42722
# [175]	valid_0's f1_score: 0.427175
# [176]	valid_0's f1_score: 0.427087
# [177]	valid_0's f1_score: 0.427097
# [178]	valid_0's f1_score: 0.427203
# [179]	valid_0's f1_score: 0.427352
# [180]	valid_0's f1_score: 0.42735
# [181]	valid_0's f1_score: 0.427575
# [182]	valid_0's f1_score: 0.427879
# [183]	valid_0's f1_score: 0.427538
# [184]	valid_0's f1_score: 0.427894
# [185]	valid_0's f1_score: 0.428026
# [186]	valid_0's f1_score: 0.427577
# [187]	valid_0's f1_score: 0.427822
# [188]	valid_0's f1_score: 0.428105
# [189]	valid_0's f1_score: 0.428016
# [190]	valid_0's f1_score: 0.428075
# [191]	valid_0's f1_score: 0.428013
# [192]	valid_0's f1_score: 0.428152
# [193]	valid_0's f1_score: 0.428247
# [194]	valid_0's f1_score: 0.428246
# [195]	valid_0's f1_score: 0.428216
# [196]	valid_0's f1_score: 0.428361
# [197]	valid_0's f1_score: 0.428412
# [198]	valid_0's f1_score: 0.428326
# [199]	valid_0's f1_score: 0.428483
# [200]	valid_0's f1_score: 0.428494
# [201]	valid_0's f1_score: 0.428464
# [202]	valid_0's f1_score: 0.428549
# [203]	valid_0's f1_score: 0.4286
# [204]	valid_0's f1_score: 0.428607
# [205]	valid_0's f1_score: 0.42837
# [206]	valid_0's f1_score: 0.428279
# [207]	valid_0's f1_score: 0.428445
# [208]	valid_0's f1_score: 0.428402
# [209]	valid_0's f1_score: 0.42838
# [210]	valid_0's f1_score: 0.428498
# [211]	valid_0's f1_score: 0.428364
# [212]	valid_0's f1_score: 0.42845
# [213]	valid_0's f1_score: 0.428371
# [214]	valid_0's f1_score: 0.428668
# [215]	valid_0's f1_score: 0.428654
# [216]	valid_0's f1_score: 0.428605
# [217]	valid_0's f1_score: 0.428601
# [218]	valid_0's f1_score: 0.428693
# [219]	valid_0's f1_score: 0.428709
# [220]	valid_0's f1_score: 0.428774
# [221]	valid_0's f1_score: 0.428565
# [222]	valid_0's f1_score: 0.428792
# [223]	valid_0's f1_score: 0.429232
# [224]	valid_0's f1_score: 0.429144
# [225]	valid_0's f1_score: 0.429085
# [226]	valid_0's f1_score: 0.429168
# [227]	valid_0's f1_score: 0.42916
# [228]	valid_0's f1_score: 0.428945
# [229]	valid_0's f1_score: 0.428983
# [230]	valid_0's f1_score: 0.429233
# [231]	valid_0's f1_score: 0.429698
# [232]	valid_0's f1_score: 0.429986
# [233]	valid_0's f1_score: 0.429957
# [234]	valid_0's f1_score: 0.429601
# [235]	valid_0's f1_score: 0.429579
# [236]	valid_0's f1_score: 0.429782
# [237]	valid_0's f1_score: 0.429731
# [238]	valid_0's f1_score: 0.42999
# [239]	valid_0's f1_score: 0.430171
# [240]	valid_0's f1_score: 0.430203
# [241]	valid_0's f1_score: 0.430086
# [242]	valid_0's f1_score: 0.430149
# [243]	valid_0's f1_score: 0.430237
# [244]	valid_0's f1_score: 0.429976
# [245]	valid_0's f1_score: 0.429965
# [246]	valid_0's f1_score: 0.430132
# [247]	valid_0's f1_score: 0.429982
# [248]	valid_0's f1_score: 0.430058
# [249]	valid_0's f1_score: 0.429962
# [250]	valid_0's f1_score: 0.430096
# [251]	valid_0's f1_score: 0.430083
# [252]	valid_0's f1_score: 0.429841
# [253]	valid_0's f1_score: 0.430182
# [254]	valid_0's f1_score: 0.43024
# [255]	valid_0's f1_score: 0.430532
# [256]	valid_0's f1_score: 0.430768
# [257]	valid_0's f1_score: 0.43103
# [258]	valid_0's f1_score: 0.430877
# [259]	valid_0's f1_score: 0.430914
# [260]	valid_0's f1_score: 0.430812
# [261]	valid_0's f1_score: 0.431059
# [262]	valid_0's f1_score: 0.431229
# [263]	valid_0's f1_score: 0.431465
# [264]	valid_0's f1_score: 0.431353
# [265]	valid_0's f1_score: 0.431529
# [266]	valid_0's f1_score: 0.43161
# [267]	valid_0's f1_score: 0.431645
# [268]	valid_0's f1_score: 0.43152
# [269]	valid_0's f1_score: 0.431574
# [270]	valid_0's f1_score: 0.432058
# [271]	valid_0's f1_score: 0.431987
# [272]	valid_0's f1_score: 0.432185
# [273]	valid_0's f1_score: 0.432022
# [274]	valid_0's f1_score: 0.432027
# [275]	valid_0's f1_score: 0.432114
# [276]	valid_0's f1_score: 0.432101
# [277]	valid_0's f1_score: 0.432345
# [278]	valid_0's f1_score: 0.432482
# [279]	valid_0's f1_score: 0.432338
# [280]	valid_0's f1_score: 0.432582
# [281]	valid_0's f1_score: 0.43214
# [282]	valid_0's f1_score: 0.432161
# [283]	valid_0's f1_score: 0.432214
# [284]	valid_0's f1_score: 0.432125
# [285]	valid_0's f1_score: 0.431855
# [286]	valid_0's f1_score: 0.432166
# [287]	valid_0's f1_score: 0.432378
# [288]	valid_0's f1_score: 0.432376
# [289]	valid_0's f1_score: 0.432593
# [290]	valid_0's f1_score: 0.432678
# [291]	valid_0's f1_score: 0.43269
# [292]	valid_0's f1_score: 0.432856
# [293]	valid_0's f1_score: 0.432832
# [294]	valid_0's f1_score: 0.432846
# [295]	valid_0's f1_score: 0.432918
# [296]	valid_0's f1_score: 0.432723
# [297]	valid_0's f1_score: 0.432586
# [298]	valid_0's f1_score: 0.432663
# [299]	valid_0's f1_score: 0.432841
# [300]	valid_0's f1_score: 0.432903
# [301]	valid_0's f1_score: 0.432724
# [302]	valid_0's f1_score: 0.432871
# [303]	valid_0's f1_score: 0.432788
# [304]	valid_0's f1_score: 0.432848
# [305]	valid_0's f1_score: 0.432873
# [306]	valid_0's f1_score: 0.432871
# [307]	valid_0's f1_score: 0.432894
# [308]	valid_0's f1_score: 0.432698
# [309]	valid_0's f1_score: 0.432822
# [310]	valid_0's f1_score: 0.433033
# [311]	valid_0's f1_score: 0.43318
# [312]	valid_0's f1_score: 0.433179
# [313]	valid_0's f1_score: 0.433182
# [314]	valid_0's f1_score: 0.433149
# [315]	valid_0's f1_score: 0.433135
# [316]	valid_0's f1_score: 0.4333
# [317]	valid_0's f1_score: 0.433182
# [318]	valid_0's f1_score: 0.43304
# [319]	valid_0's f1_score: 0.433047
# [320]	valid_0's f1_score: 0.433158
# [321]	valid_0's f1_score: 0.433152
# [322]	valid_0's f1_score: 0.432914
# [323]	valid_0's f1_score: 0.433288
# [324]	valid_0's f1_score: 0.433101
# [325]	valid_0's f1_score: 0.433129
# [326]	valid_0's f1_score: 0.433005
# [327]	valid_0's f1_score: 0.433157
# [328]	valid_0's f1_score: 0.43314
# [329]	valid_0's f1_score: 0.433492
# [330]	valid_0's f1_score: 0.433402
# [331]	valid_0's f1_score: 0.433348
# [332]	valid_0's f1_score: 0.433179
# [333]	valid_0's f1_score: 0.433222
# [334]	valid_0's f1_score: 0.433131
# [335]	valid_0's f1_score: 0.433664
# [336]	valid_0's f1_score: 0.433464
# [337]	valid_0's f1_score: 0.433601
# [338]	valid_0's f1_score: 0.433974
# [339]	valid_0's f1_score: 0.433822
# [340]	valid_0's f1_score: 0.433843
# [341]	valid_0's f1_score: 0.433944
# [342]	valid_0's f1_score: 0.433999
# [343]	valid_0's f1_score: 0.43436
# [344]	valid_0's f1_score: 0.434278
# [345]	valid_0's f1_score: 0.434359
# [346]	valid_0's f1_score: 0.434342
# [347]	valid_0's f1_score: 0.434157
# [348]	valid_0's f1_score: 0.434257
# [349]	valid_0's f1_score: 0.43423
# [350]	valid_0's f1_score: 0.434201
# [351]	valid_0's f1_score: 0.434475
# [352]	valid_0's f1_score: 0.4345
# [353]	valid_0's f1_score: 0.434469
# [354]	valid_0's f1_score: 0.434556
# [355]	valid_0's f1_score: 0.434478
# [356]	valid_0's f1_score: 0.434707
# [357]	valid_0's f1_score: 0.434667
# [358]	valid_0's f1_score: 0.434695
# [359]	valid_0's f1_score: 0.434585
# [360]	valid_0's f1_score: 0.434629
# [361]	valid_0's f1_score: 0.434933
# [362]	valid_0's f1_score: 0.435474
# [363]	valid_0's f1_score: 0.435496
# [364]	valid_0's f1_score: 0.435481
# [365]	valid_0's f1_score: 0.435377
# [366]	valid_0's f1_score: 0.435225
# [367]	valid_0's f1_score: 0.435213
# [368]	valid_0's f1_score: 0.435454
# [369]	valid_0's f1_score: 0.435457
# [370]	valid_0's f1_score: 0.435488
# [371]	valid_0's f1_score: 0.435524
# [372]	valid_0's f1_score: 0.435399
# [373]	valid_0's f1_score: 0.435547
# [374]	valid_0's f1_score: 0.435716
# [375]	valid_0's f1_score: 0.435926
# [376]	valid_0's f1_score: 0.435937
# [377]	valid_0's f1_score: 0.43541
# [378]	valid_0's f1_score: 0.435433
# [379]	valid_0's f1_score: 0.435452
# [380]	valid_0's f1_score: 0.435444
# [381]	valid_0's f1_score: 0.435427
# [382]	valid_0's f1_score: 0.435402
# [383]	valid_0's f1_score: 0.435597
# [384]	valid_0's f1_score: 0.435929
# [385]	valid_0's f1_score: 0.435911
# [386]	valid_0's f1_score: 0.436094
# [387]	valid_0's f1_score: 0.436091
# [388]	valid_0's f1_score: 0.436231
# [389]	valid_0's f1_score: 0.436443
# [390]	valid_0's f1_score: 0.436359
# [391]	valid_0's f1_score: 0.43628
# [392]	valid_0's f1_score: 0.436315
# [393]	valid_0's f1_score: 0.436534
# [394]	valid_0's f1_score: 0.436505
# [395]	valid_0's f1_score: 0.436615
# [396]	valid_0's f1_score: 0.436566
# [397]	valid_0's f1_score: 0.436559
# [398]	valid_0's f1_score: 0.436829
# [399]	valid_0's f1_score: 0.436984
# [400]	valid_0's f1_score: 0.437184
# [401]	valid_0's f1_score: 0.43703
# [402]	valid_0's f1_score: 0.436965
# [403]	valid_0's f1_score: 0.4371
# [404]	valid_0's f1_score: 0.436889
# [405]	valid_0's f1_score: 0.437187
# [406]	valid_0's f1_score: 0.437236
# [407]	valid_0's f1_score: 0.437098
# [408]	valid_0's f1_score: 0.437161
# [409]	valid_0's f1_score: 0.437226
# [410]	valid_0's f1_score: 0.437454
# [411]	valid_0's f1_score: 0.437641
# [412]	valid_0's f1_score: 0.437544
# [413]	valid_0's f1_score: 0.437496
# [414]	valid_0's f1_score: 0.437831
# [415]	valid_0's f1_score: 0.437679
# [416]	valid_0's f1_score: 0.437855
# [417]	valid_0's f1_score: 0.43788
# [418]	valid_0's f1_score: 0.437652
# [419]	valid_0's f1_score: 0.437854
# [420]	valid_0's f1_score: 0.437739
# [421]	valid_0's f1_score: 0.437911
# [422]	valid_0's f1_score: 0.438261
# [423]	valid_0's f1_score: 0.438296
# [424]	valid_0's f1_score: 0.438469
# [425]	valid_0's f1_score: 0.438456
# [426]	valid_0's f1_score: 0.438626
# [427]	valid_0's f1_score: 0.438495
# [428]	valid_0's f1_score: 0.438468
# [429]	valid_0's f1_score: 0.438516
# [430]	valid_0's f1_score: 0.438208
# [431]	valid_0's f1_score: 0.438419
# [432]	valid_0's f1_score: 0.438545
# [433]	valid_0's f1_score: 0.438574
# [434]	valid_0's f1_score: 0.438582
# [435]	valid_0's f1_score: 0.438555
# [436]	valid_0's f1_score: 0.438613
# [437]	valid_0's f1_score: 0.438733
# [438]	valid_0's f1_score: 0.438723
# [439]	valid_0's f1_score: 0.438672
# [440]	valid_0's f1_score: 0.438888
# [441]	valid_0's f1_score: 0.438764
# [442]	valid_0's f1_score: 0.43897
# [443]	valid_0's f1_score: 0.438881
# [444]	valid_0's f1_score: 0.439155
# [445]	valid_0's f1_score: 0.439293
# [446]	valid_0's f1_score: 0.439287
# [447]	valid_0's f1_score: 0.439632
# [448]	valid_0's f1_score: 0.439335
# [449]	valid_0's f1_score: 0.439762
# [450]	valid_0's f1_score: 0.439499
# [451]	valid_0's f1_score: 0.439312
# [452]	valid_0's f1_score: 0.439307
# [453]	valid_0's f1_score: 0.439185
# [454]	valid_0's f1_score: 0.439019
# [455]	valid_0's f1_score: 0.438959
# [456]	valid_0's f1_score: 0.438964
# [457]	valid_0's f1_score: 0.438931
# [458]	valid_0's f1_score: 0.439154
# [459]	valid_0's f1_score: 0.439377
# [460]	valid_0's f1_score: 0.43939
# [461]	valid_0's f1_score: 0.439754
# [462]	valid_0's f1_score: 0.439722
# [463]	valid_0's f1_score: 0.439732
# [464]	valid_0's f1_score: 0.439768
# [465]	valid_0's f1_score: 0.439739
# [466]	valid_0's f1_score: 0.439671
# [467]	valid_0's f1_score: 0.439746
# [468]	valid_0's f1_score: 0.439665
# [469]	valid_0's f1_score: 0.439934
# [470]	valid_0's f1_score: 0.439728
# [471]	valid_0's f1_score: 0.43964
# [472]	valid_0's f1_score: 0.439577
# [473]	valid_0's f1_score: 0.439624
# [474]	valid_0's f1_score: 0.439799
# [475]	valid_0's f1_score: 0.440304
# [476]	valid_0's f1_score: 0.440199
# [477]	valid_0's f1_score: 0.440241
# [478]	valid_0's f1_score: 0.440097
# [479]	valid_0's f1_score: 0.440109
# [480]	valid_0's f1_score: 0.440548
# [481]	valid_0's f1_score: 0.440457
# [482]	valid_0's f1_score: 0.440422
# [483]	valid_0's f1_score: 0.440381
# [484]	valid_0's f1_score: 0.440365
# [485]	valid_0's f1_score: 0.440307
# [486]	valid_0's f1_score: 0.440494
# [487]	valid_0's f1_score: 0.440585
# [488]	valid_0's f1_score: 0.440676
# [489]	valid_0's f1_score: 0.440595
# [490]	valid_0's f1_score: 0.440531
# [491]	valid_0's f1_score: 0.440533
# [492]	valid_0's f1_score: 0.440588
# [493]	valid_0's f1_score: 0.440579
# [494]	valid_0's f1_score: 0.440495
# [495]	valid_0's f1_score: 0.440875
# [496]	valid_0's f1_score: 0.441026
# [497]	valid_0's f1_score: 0.441526
# [498]	valid_0's f1_score: 0.441666
# [499]	valid_0's f1_score: 0.441562
# [500]	valid_0's f1_score: 0.441714
# [501]	valid_0's f1_score: 0.441646
# [502]	valid_0's f1_score: 0.441868
# [503]	valid_0's f1_score: 0.441882
# [504]	valid_0's f1_score: 0.441792
# [505]	valid_0's f1_score: 0.441695
# [506]	valid_0's f1_score: 0.441886
# [507]	valid_0's f1_score: 0.442188
# [508]	valid_0's f1_score: 0.442119
# [509]	valid_0's f1_score: 0.442143
# [510]	valid_0's f1_score: 0.44258
# [511]	valid_0's f1_score: 0.442485
# [512]	valid_0's f1_score: 0.442379
# [513]	valid_0's f1_score: 0.442526
# [514]	valid_0's f1_score: 0.442688
# [515]	valid_0's f1_score: 0.443023
# [516]	valid_0's f1_score: 0.443026
# [517]	valid_0's f1_score: 0.44301
# [518]	valid_0's f1_score: 0.442943
# [519]	valid_0's f1_score: 0.442973
# [520]	valid_0's f1_score: 0.442912
# [521]	valid_0's f1_score: 0.442817
# [522]	valid_0's f1_score: 0.442758
# [523]	valid_0's f1_score: 0.442693
# [524]	valid_0's f1_score: 0.442469
# [525]	valid_0's f1_score: 0.442461
# [526]	valid_0's f1_score: 0.442471
# [527]	valid_0's f1_score: 0.442383
# [528]	valid_0's f1_score: 0.442594
# [529]	valid_0's f1_score: 0.442755
# [530]	valid_0's f1_score: 0.442842
# [531]	valid_0's f1_score: 0.442775
# [532]	valid_0's f1_score: 0.442959
# [533]	valid_0's f1_score: 0.442937
# [534]	valid_0's f1_score: 0.44309
# [535]	valid_0's f1_score: 0.443211
# [536]	valid_0's f1_score: 0.443076
# [537]	valid_0's f1_score: 0.442908
# [538]	valid_0's f1_score: 0.442799
# [539]	valid_0's f1_score: 0.442799
# [540]	valid_0's f1_score: 0.442745
# [541]	valid_0's f1_score: 0.442764
# [542]	valid_0's f1_score: 0.442893
# [543]	valid_0's f1_score: 0.442806
# [544]	valid_0's f1_score: 0.44272
# [545]	valid_0's f1_score: 0.442856
# [546]	valid_0's f1_score: 0.442794
# [547]	valid_0's f1_score: 0.443044
# [548]	valid_0's f1_score: 0.443043
# [549]	valid_0's f1_score: 0.442959
# [550]	valid_0's f1_score: 0.443297
# [551]	valid_0's f1_score: 0.443266
# [552]	valid_0's f1_score: 0.443401
# [553]	valid_0's f1_score: 0.443574
# [554]	valid_0's f1_score: 0.443449
# [555]	valid_0's f1_score: 0.443796
# [556]	valid_0's f1_score: 0.443599
# [557]	valid_0's f1_score: 0.443555
# [558]	valid_0's f1_score: 0.443957
# [559]	valid_0's f1_score: 0.44413
# [560]	valid_0's f1_score: 0.444062
# [561]	valid_0's f1_score: 0.444057
# [562]	valid_0's f1_score: 0.444169
# [563]	valid_0's f1_score: 0.444111
# [564]	valid_0's f1_score: 0.444132
# [565]	valid_0's f1_score: 0.444349
# [566]	valid_0's f1_score: 0.444191
# [567]	valid_0's f1_score: 0.444606
# [568]	valid_0's f1_score: 0.444526
# [569]	valid_0's f1_score: 0.444591
# [570]	valid_0's f1_score: 0.444565
# [571]	valid_0's f1_score: 0.444757
# [572]	valid_0's f1_score: 0.444911
# [573]	valid_0's f1_score: 0.444925
# [574]	valid_0's f1_score: 0.444885
# [575]	valid_0's f1_score: 0.444931
# [576]	valid_0's f1_score: 0.444786
# [577]	valid_0's f1_score: 0.444716
# [578]	valid_0's f1_score: 0.444654
# [579]	valid_0's f1_score: 0.444724
# [580]	valid_0's f1_score: 0.444615
# [581]	valid_0's f1_score: 0.444692
# [582]	valid_0's f1_score: 0.444707
# [583]	valid_0's f1_score: 0.444586
# [584]	valid_0's f1_score: 0.444573
# [585]	valid_0's f1_score: 0.444425
# [586]	valid_0's f1_score: 0.444408
# [587]	valid_0's f1_score: 0.444412
# [588]	valid_0's f1_score: 0.444367
# [589]	valid_0's f1_score: 0.44439
# [590]	valid_0's f1_score: 0.444402
# [591]	valid_0's f1_score: 0.444023
# [592]	valid_0's f1_score: 0.444009
# [593]	valid_0's f1_score: 0.444434
# [594]	valid_0's f1_score: 0.444372
# [595]	valid_0's f1_score: 0.444506
# [596]	valid_0's f1_score: 0.444394
# [597]	valid_0's f1_score: 0.444343
# [598]	valid_0's f1_score: 0.444244
# [599]	valid_0's f1_score: 0.444284
# [600]	valid_0's f1_score: 0.44417
# [601]	valid_0's f1_score: 0.444133
# [602]	valid_0's f1_score: 0.444151
# [603]	valid_0's f1_score: 0.444106
# [604]	valid_0's f1_score: 0.444145
# [605]	valid_0's f1_score: 0.444154
# [606]	valid_0's f1_score: 0.444296
# [607]	valid_0's f1_score: 0.444236
# [608]	valid_0's f1_score: 0.444138
# [609]	valid_0's f1_score: 0.444061
# [610]	valid_0's f1_score: 0.444379
# [611]	valid_0's f1_score: 0.444385
# [612]	valid_0's f1_score: 0.444484
# [613]	valid_0's f1_score: 0.444463
# [614]	valid_0's f1_score: 0.444779
# [615]	valid_0's f1_score: 0.444985
# [616]	valid_0's f1_score: 0.445012
# [617]	valid_0's f1_score: 0.445037
# [618]	valid_0's f1_score: 0.444831
# [619]	valid_0's f1_score: 0.445182
# [620]	valid_0's f1_score: 0.445494
# [621]	valid_0's f1_score: 0.445419
# [622]	valid_0's f1_score: 0.445427
# [623]	valid_0's f1_score: 0.445803
# [624]	valid_0's f1_score: 0.445673
# [625]	valid_0's f1_score: 0.445599
# [626]	valid_0's f1_score: 0.445616
# [627]	valid_0's f1_score: 0.4458
# [628]	valid_0's f1_score: 0.445642
# [629]	valid_0's f1_score: 0.445636
# [630]	valid_0's f1_score: 0.445568
# [631]	valid_0's f1_score: 0.445605
# [632]	valid_0's f1_score: 0.445945
# [633]	valid_0's f1_score: 0.445917
# [634]	valid_0's f1_score: 0.445945
# [635]	valid_0's f1_score: 0.445832
# [636]	valid_0's f1_score: 0.445818
# [637]	valid_0's f1_score: 0.445819
# [638]	valid_0's f1_score: 0.445594
# [639]	valid_0's f1_score: 0.445629
# [640]	valid_0's f1_score: 0.445797
# [641]	valid_0's f1_score: 0.445818
# [642]	valid_0's f1_score: 0.445925
# [643]	valid_0's f1_score: 0.445766
# [644]	valid_0's f1_score: 0.445725
# [645]	valid_0's f1_score: 0.445764
# [646]	valid_0's f1_score: 0.446125
# [647]	valid_0's f1_score: 0.446207
# [648]	valid_0's f1_score: 0.446222
# [649]	valid_0's f1_score: 0.446126
# [650]	valid_0's f1_score: 0.446213
# [651]	valid_0's f1_score: 0.446299
# [652]	valid_0's f1_score: 0.44633
# [653]	valid_0's f1_score: 0.44638
# [654]	valid_0's f1_score: 0.44633
# [655]	valid_0's f1_score: 0.446396
# [656]	valid_0's f1_score: 0.446484
# [657]	valid_0's f1_score: 0.446338
# [658]	valid_0's f1_score: 0.446322
# [659]	valid_0's f1_score: 0.446216
# [660]	valid_0's f1_score: 0.446176
# [661]	valid_0's f1_score: 0.446181
# [662]	valid_0's f1_score: 0.446257
# [663]	valid_0's f1_score: 0.446236
# [664]	valid_0's f1_score: 0.446278
# [665]	valid_0's f1_score: 0.446384
# [666]	valid_0's f1_score: 0.446208
# [667]	valid_0's f1_score: 0.446132
# [668]	valid_0's f1_score: 0.44609
# [669]	valid_0's f1_score: 0.446189
# [670]	valid_0's f1_score: 0.446307
# [671]	valid_0's f1_score: 0.446295
# [672]	valid_0's f1_score: 0.446481
# [673]	valid_0's f1_score: 0.446535
# [674]	valid_0's f1_score: 0.446497
# [675]	valid_0's f1_score: 0.446569
# [676]	valid_0's f1_score: 0.44662
# [677]	valid_0's f1_score: 0.446447
# [678]	valid_0's f1_score: 0.446472
# [679]	valid_0's f1_score: 0.446574
# [680]	valid_0's f1_score: 0.446311
# [681]	valid_0's f1_score: 0.446315
# [682]	valid_0's f1_score: 0.446289
# [683]	valid_0's f1_score: 0.446348
# [684]	valid_0's f1_score: 0.446491
# [685]	valid_0's f1_score: 0.446433
# [686]	valid_0's f1_score: 0.44666
# [687]	valid_0's f1_score: 0.446582
# [688]	valid_0's f1_score: 0.446586
# [689]	valid_0's f1_score: 0.446694
# [690]	valid_0's f1_score: 0.446976
# [691]	valid_0's f1_score: 0.447
# [692]	valid_0's f1_score: 0.446922
# [693]	valid_0's f1_score: 0.44709
# [694]	valid_0's f1_score: 0.446874
# [695]	valid_0's f1_score: 0.44699
# [696]	valid_0's f1_score: 0.446919
# [697]	valid_0's f1_score: 0.446736
# [698]	valid_0's f1_score: 0.446743
# [699]	valid_0's f1_score: 0.446672
# [700]	valid_0's f1_score: 0.446657
# [701]	valid_0's f1_score: 0.446812
# [702]	valid_0's f1_score: 0.446937
# [703]	valid_0's f1_score: 0.446835
# [704]	valid_0's f1_score: 0.446833
# [705]	valid_0's f1_score: 0.446824
# [706]	valid_0's f1_score: 0.44677
# [707]	valid_0's f1_score: 0.446745
# [708]	valid_0's f1_score: 0.446874
# [709]	valid_0's f1_score: 0.446991
# [710]	valid_0's f1_score: 0.446988
# [711]	valid_0's f1_score: 0.44698
# [712]	valid_0's f1_score: 0.447045
# [713]	valid_0's f1_score: 0.447127
# [714]	valid_0's f1_score: 0.447009
# [715]	valid_0's f1_score: 0.44695
# [716]	valid_0's f1_score: 0.447254
# [717]	valid_0's f1_score: 0.447141
# [718]	valid_0's f1_score: 0.446989
# [719]	valid_0's f1_score: 0.446972
# [720]	valid_0's f1_score: 0.446918
# [721]	valid_0's f1_score: 0.447119
# [722]	valid_0's f1_score: 0.447039
# [723]	valid_0's f1_score: 0.44735
# [724]	valid_0's f1_score: 0.447166
# [725]	valid_0's f1_score: 0.447232
# [726]	valid_0's f1_score: 0.447139
# [727]	valid_0's f1_score: 0.447323
# [728]	valid_0's f1_score: 0.447732
# [729]	valid_0's f1_score: 0.447666
# [730]	valid_0's f1_score: 0.447851
# [731]	valid_0's f1_score: 0.447759
# [732]	valid_0's f1_score: 0.44782
# [733]	valid_0's f1_score: 0.447616
# [734]	valid_0's f1_score: 0.447515
# [735]	valid_0's f1_score: 0.447462
# [736]	valid_0's f1_score: 0.44744
# [737]	valid_0's f1_score: 0.447532
# [738]	valid_0's f1_score: 0.447478
# [739]	valid_0's f1_score: 0.447409
# [740]	valid_0's f1_score: 0.447697
# [741]	valid_0's f1_score: 0.44768
# [742]	valid_0's f1_score: 0.447737
# [743]	valid_0's f1_score: 0.447962
# [744]	valid_0's f1_score: 0.448081
# [745]	valid_0's f1_score: 0.44813
# [746]	valid_0's f1_score: 0.447952
# [747]	valid_0's f1_score: 0.448164
# [748]	valid_0's f1_score: 0.448314
# [749]	valid_0's f1_score: 0.448306
# [750]	valid_0's f1_score: 0.448473
# [751]	valid_0's f1_score: 0.448546
# [752]	valid_0's f1_score: 0.448574
# [753]	valid_0's f1_score: 0.448706
# [754]	valid_0's f1_score: 0.448726
# [755]	valid_0's f1_score: 0.448801
# [756]	valid_0's f1_score: 0.448682
# [757]	valid_0's f1_score: 0.448729
# [758]	valid_0's f1_score: 0.448727
# [759]	valid_0's f1_score: 0.448856
# [760]	valid_0's f1_score: 0.448741
# [761]	valid_0's f1_score: 0.448829
# [762]	valid_0's f1_score: 0.449132
# [763]	valid_0's f1_score: 0.44914
# [764]	valid_0's f1_score: 0.449257
# [765]	valid_0's f1_score: 0.449289
# [766]	valid_0's f1_score: 0.449648
# [767]	valid_0's f1_score: 0.449713
# [768]	valid_0's f1_score: 0.449683
# [769]	valid_0's f1_score: 0.449518
# [770]	valid_0's f1_score: 0.449458
# [771]	valid_0's f1_score: 0.449433
# [772]	valid_0's f1_score: 0.449439
# [773]	valid_0's f1_score: 0.44938
# [774]	valid_0's f1_score: 0.449371
# [775]	valid_0's f1_score: 0.449559
# [776]	valid_0's f1_score: 0.450121
# [777]	valid_0's f1_score: 0.450029
# [778]	valid_0's f1_score: 0.44976
# [779]	valid_0's f1_score: 0.44983
# [780]	valid_0's f1_score: 0.449851
# [781]	valid_0's f1_score: 0.450095
# [782]	valid_0's f1_score: 0.45016
# [783]	valid_0's f1_score: 0.450097
# [784]	valid_0's f1_score: 0.449991
# [785]	valid_0's f1_score: 0.44999
# [786]	valid_0's f1_score: 0.449935
# [787]	valid_0's f1_score: 0.449847
# [788]	valid_0's f1_score: 0.449915
# [789]	valid_0's f1_score: 0.449864
# [790]	valid_0's f1_score: 0.449878
# [791]	valid_0's f1_score: 0.450026
# [792]	valid_0's f1_score: 0.449991
# [793]	valid_0's f1_score: 0.450141
# [794]	valid_0's f1_score: 0.450069
# [795]	valid_0's f1_score: 0.450395
# [796]	valid_0's f1_score: 0.450412
# [797]	valid_0's f1_score: 0.450427
# [798]	valid_0's f1_score: 0.450442
# [799]	valid_0's f1_score: 0.450382
# [800]	valid_0's f1_score: 0.450261
# [801]	valid_0's f1_score: 0.450198
# [802]	valid_0's f1_score: 0.450256
# [803]	valid_0's f1_score: 0.450241
# [804]	valid_0's f1_score: 0.45031
# [805]	valid_0's f1_score: 0.450257
# [806]	valid_0's f1_score: 0.450307
# [807]	valid_0's f1_score: 0.450311
# [808]	valid_0's f1_score: 0.450267
# [809]	valid_0's f1_score: 0.450258
# [810]	valid_0's f1_score: 0.450178
# [811]	valid_0's f1_score: 0.450243
# [812]	valid_0's f1_score: 0.450313
# [813]	valid_0's f1_score: 0.450492
# [814]	valid_0's f1_score: 0.450536
# [815]	valid_0's f1_score: 0.45047
# [816]	valid_0's f1_score: 0.450651
# [817]	valid_0's f1_score: 0.450566
# [818]	valid_0's f1_score: 0.450668
# [819]	valid_0's f1_score: 0.450696
# [820]	valid_0's f1_score: 0.450644
# [821]	valid_0's f1_score: 0.450611
# [822]	valid_0's f1_score: 0.450623
# [823]	valid_0's f1_score: 0.45076
# [824]	valid_0's f1_score: 0.450838
# [825]	valid_0's f1_score: 0.450859
# [826]	valid_0's f1_score: 0.45078
# [827]	valid_0's f1_score: 0.450786
# [828]	valid_0's f1_score: 0.450808
# [829]	valid_0's f1_score: 0.450976
# [830]	valid_0's f1_score: 0.45111
# [831]	valid_0's f1_score: 0.451303
# [832]	valid_0's f1_score: 0.451383
# [833]	valid_0's f1_score: 0.451206
# [834]	valid_0's f1_score: 0.451176
# [835]	valid_0's f1_score: 0.451124
# [836]	valid_0's f1_score: 0.451007
# [837]	valid_0's f1_score: 0.451193
# [838]	valid_0's f1_score: 0.451063
# [840]	valid_0's f1_score: 0.451269
# [841]	valid_0's f1_score: 0.451447
# [842]	valid_0's f1_score: 0.451484
# [843]	valid_0's f1_score: 0.451832
# [844]	valid_0's f1_score: 0.451806
# [845]	valid_0's f1_score: 0.451976
# [846]	valid_0's f1_score: 0.451944
# [847]	valid_0's f1_score: 0.451864
# [848]	valid_0's f1_score: 0.451807
# [849]	valid_0's f1_score: 0.451954
# [850]	valid_0's f1_score: 0.451996
# [851]	valid_0's f1_score: 0.452022
# [852]	valid_0's f1_score: 0.452076
# [853]	valid_0's f1_score: 0.452025
# [854]	valid_0's f1_score: 0.451877
# [855]	valid_0's f1_score: 0.451983
# [856]	valid_0's f1_score: 0.452197
# [857]	valid_0's f1_score: 0.452153
# [858]	valid_0's f1_score: 0.452145
# [859]	valid_0's f1_score: 0.452071
# [860]	valid_0's f1_score: 0.452039
# [861]	valid_0's f1_score: 0.452339
# [862]	valid_0's f1_score: 0.452078
# [863]	valid_0's f1_score: 0.452041
# [864]	valid_0's f1_score: 0.452057
# [865]	valid_0's f1_score: 0.452268
# [866]	valid_0's f1_score: 0.452276
# [867]	valid_0's f1_score: 0.452048
# [868]	valid_0's f1_score: 0.452042
# [869]	valid_0's f1_score: 0.452417
# [870]	valid_0's f1_score: 0.452406
# [871]	valid_0's f1_score: 0.452349
# [872]	valid_0's f1_score: 0.45229
# [873]	valid_0's f1_score: 0.452275
# [874]	valid_0's f1_score: 0.452011
# [875]	valid_0's f1_score: 0.451976
# [876]	valid_0's f1_score: 0.452076
# [877]	valid_0's f1_score: 0.452083
# [878]	valid_0's f1_score: 0.452172
# [879]	valid_0's f1_score: 0.452156
# [880]	valid_0's f1_score: 0.452107
# [881]	valid_0's f1_score: 0.452108
# [882]	valid_0's f1_score: 0.452451
# [883]	valid_0's f1_score: 0.452444
# [884]	valid_0's f1_score: 0.45251
# [885]	valid_0's f1_score: 0.452725
# [886]	valid_0's f1_score: 0.452626
# [887]	valid_0's f1_score: 0.452569
# [888]	valid_0's f1_score: 0.452794
# [889]	valid_0's f1_score: 0.452821
# [890]	valid_0's f1_score: 0.452898
# [891]	valid_0's f1_score: 0.453046
# [892]	valid_0's f1_score: 0.452975
# [893]	valid_0's f1_score: 0.452881
# [894]	valid_0's f1_score: 0.452849
# [895]	valid_0's f1_score: 0.45281
# [896]	valid_0's f1_score: 0.452779
# [897]	valid_0's f1_score: 0.452762
# [898]	valid_0's f1_score: 0.45284
# [899]	valid_0's f1_score: 0.453058
# [900]	valid_0's f1_score: 0.453072
# [901]	valid_0's f1_score: 0.453164
# [902]	valid_0's f1_score: 0.453151
# [903]	valid_0's f1_score: 0.453265
# [904]	valid_0's f1_score: 0.453428
# [905]	valid_0's f1_score: 0.453419
# [906]	valid_0's f1_score: 0.453324
# [907]	valid_0's f1_score: 0.453434
# [908]	valid_0's f1_score: 0.453431
# [909]	valid_0's f1_score: 0.453441
# [910]	valid_0's f1_score: 0.453372
# [911]	valid_0's f1_score: 0.453566
# [912]	valid_0's f1_score: 0.453556
# [913]	valid_0's f1_score: 0.453525
# [914]	valid_0's f1_score: 0.453832
# [915]	valid_0's f1_score: 0.454002
# [916]	valid_0's f1_score: 0.454017
# [917]	valid_0's f1_score: 0.454019
# [918]	valid_0's f1_score: 0.454062
# [919]	valid_0's f1_score: 0.453913
# [920]	valid_0's f1_score: 0.453881
# [921]	valid_0's f1_score: 0.453819
# [922]	valid_0's f1_score: 0.453843
# [923]	valid_0's f1_score: 0.453768
# [924]	valid_0's f1_score: 0.453843
# [925]	valid_0's f1_score: 0.453691
# [926]	valid_0's f1_score: 0.453385
# [927]	valid_0's f1_score: 0.453333
# [928]	valid_0's f1_score: 0.453318
# [929]	valid_0's f1_score: 0.453404
# [930]	valid_0's f1_score: 0.453698
# [931]	valid_0's f1_score: 0.453675
# [932]	valid_0's f1_score: 0.453725
# [933]	valid_0's f1_score: 0.453695
# [934]	valid_0's f1_score: 0.453526
# [935]	valid_0's f1_score: 0.453453
# [936]	valid_0's f1_score: 0.453478
# [937]	valid_0's f1_score: 0.453474
# [938]	valid_0's f1_score: 0.45345
# [939]	valid_0's f1_score: 0.453493
# [940]	valid_0's f1_score: 0.453588
# [941]	valid_0's f1_score: 0.453502
# [942]	valid_0's f1_score: 0.453721
# [943]	valid_0's f1_score: 0.453791
# [944]	valid_0's f1_score: 0.454147
# [945]	valid_0's f1_score: 0.454039
# [946]	valid_0's f1_score: 0.454028
# [947]	valid_0's f1_score: 0.454111
# [948]	valid_0's f1_score: 0.454361
# [949]	valid_0's f1_score: 0.454456
# [950]	valid_0's f1_score: 0.454335
# [951]	valid_0's f1_score: 0.454471
# [952]	valid_0's f1_score: 0.454478
# [953]	valid_0's f1_score: 0.454182
# [954]	valid_0's f1_score: 0.454231
# [955]	valid_0's f1_score: 0.454048
# [956]	valid_0's f1_score: 0.454596
# [957]	valid_0's f1_score: 0.45446
# [958]	valid_0's f1_score: 0.454568
# [959]	valid_0's f1_score: 0.454615
# [960]	valid_0's f1_score: 0.454953
# [961]	valid_0's f1_score: 0.455119
# [962]	valid_0's f1_score: 0.454979
# [963]	valid_0's f1_score: 0.454979
# [964]	valid_0's f1_score: 0.455
# [965]	valid_0's f1_score: 0.454932
# [966]	valid_0's f1_score: 0.455098
# [967]	valid_0's f1_score: 0.455095
# [968]	valid_0's f1_score: 0.455071
# [969]	valid_0's f1_score: 0.455075
# [970]	valid_0's f1_score: 0.455146
# [971]	valid_0's f1_score: 0.454856
# [972]	valid_0's f1_score: 0.455146
# [973]	valid_0's f1_score: 0.455088
# [974]	valid_0's f1_score: 0.455002
# [975]	valid_0's f1_score: 0.455054
# [976]	valid_0's f1_score: 0.454763
# [977]	valid_0's f1_score: 0.45487
# [978]	valid_0's f1_score: 0.454938
# [979]	valid_0's f1_score: 0.455078
# [980]	valid_0's f1_score: 0.455034
# [981]	valid_0's f1_score: 0.455083
# [982]	valid_0's f1_score: 0.455093
# [983]	valid_0's f1_score: 0.455233
# [984]	valid_0's f1_score: 0.455215
# [985]	valid_0's f1_score: 0.45525
# [986]	valid_0's f1_score: 0.455215
# [987]	valid_0's f1_score: 0.455143
# [988]	valid_0's f1_score: 0.455483
# [989]	valid_0's f1_score: 0.455398
# [990]	valid_0's f1_score: 0.45539
# [991]	valid_0's f1_score: 0.455637
# [992]	valid_0's f1_score: 0.455883
# [993]	valid_0's f1_score: 0.455952
# [994]	valid_0's f1_score: 0.456206
# [995]	valid_0's f1_score: 0.456142
# [996]	valid_0's f1_score: 0.456032
# [997]	valid_0's f1_score: 0.455956
# [998]	valid_0's f1_score: 0.456024
# [999]	valid_0's f1_score: 0.455872
# [1000]	valid_0's f1_score: 0.455891

# %%
with open('lgb_model8_fold6.pkl', 'wb') as fout:
    pickle.dump(model, fout)
